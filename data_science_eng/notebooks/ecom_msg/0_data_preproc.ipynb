# %% [markdown]
# # Files & imports

# %%
from pandas import read_csv, DataFrame
import pandas as pd

# %%
## https://www.kaggle.com/datasets/mkechinov/direct-messaging/data #

filename_first_purchase = "dataset/client_first_purchase_date.csv"
filename_campaigns = "dataset/campaigns.csv"

filename_msg = "dataset/messages-demo.csv"
file_tag = "ecom_msg"

data_first_purchase = pd.read_csv(filename_first_purchase)
data_campaigns = pd.read_csv(filename_campaigns)
data_msg = pd.read_csv(filename_msg)

data_first_purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1854736 entries, 0 to 1854735
# Data columns (total 2 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   client_id            int64
#  1   first_purchase_date  object
# dtypes: int64(1), object(1)
# memory usage: 28.3+ MB

# %% [markdown]
# # Load File

# %% [markdown]
# ### >> method 1.1 - random sample on the merge [used]

# %%
import pandas as pd

# Sample each dataset
#data_first_purchase_sampled = sample_data(data_first_purchase, test_data=test)  # Replace test_data=False as needed
#data_campaigns_sampled = sample_data(data_campaigns, test_data=test)
#data_msg_sampled = sample_data(data_msg, test_data=test)

test = False 

def sample_per_day(group, fraction=0.1):
    return group.sample(frac=fraction)

if test==True: 

    sample = 0.01

    #data_first_purchase['first_purchase_date'] = pd.to_datetime(data_first_purchase['first_purchase_date']) 
    # Apply the sampling to each group (grouped by event_date) 1%
    #data_first_purchase = data_first_purchase.groupby('first_purchase_date').apply(lambda x: sample_per_day(x, sample)).reset_index(drop=True)

    #data_campaigns['started_at'] = pd.to_datetime(data_campaigns['started_at']) 
    # Apply the sampling to each group (grouped by event_date) 1%
    #data_campaigns = data_campaigns.groupby('started_at').apply(lambda x: sample_per_day(x, sample)).reset_index(drop=True)

    data_msg['sent_at'] = pd.to_datetime(data_msg['sent_at']) 
    # Apply the sampling to each group (grouped by event_date) 1%
    data_msg = data_msg.groupby('sent_at').apply(lambda x: sample_per_day(x, sample)).reset_index(drop=True) 
   

else: 
    sample = 0.15

    #data_first_purchase['first_purchase_date'] = pd.to_datetime(data_first_purchase['first_purchase_date']) 
    # Apply the sampling to each group (grouped by event_date) 10%
    #data_first_purchase = data_first_purchase.groupby('first_purchase_date').apply(lambda x: sample_per_day(x, sample)).reset_index(drop=True)
    
    #data_campaigns['started_at'] = pd.to_datetime(data_campaigns['started_at']) 
    # Apply the sampling to each group (grouped by event_date) 1%
    #data_campaigns = data_campaigns.groupby('started_at').apply(lambda x: sample_per_day(x, sample)).reset_index(drop=True)

    data_msg['sent_at'] = pd.to_datetime(data_msg['sent_at']) 
    # Apply the sampling to each group (grouped by event_date) 1%
    data_msg = data_msg.groupby('sent_at').apply(lambda x: sample_per_day(x, sample)).reset_index(drop=True) 

# Display some rows from the final dataset
data_first_purchase.info()
data_campaigns.info()
data_msg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1854736 entries, 0 to 1854735
# Data columns (total 2 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   client_id            int64
#  1   first_purchase_date  object
# dtypes: int64(1), object(1)
# memory usage: 28.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1907 entries, 0 to 1906
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            1907 non-null   int64
#  1   campaign_type                 1907 non-null   object
#  2   channel                       1907 non-null   object
#  3   topic                         1877 non-null   object
#  4   started_at                    1824 non-null   object
#  5   finished_at                   1808 non-null   object
#  6   total_count                   1824 non-null   float64
#  7   ab_test                       12 non-null     object
#  8   warmup_mode                   1830 non-null   object
#  9   hour_limit                    31 non-null     float64
#  10  subject_length                1880 non-null   float64
#  11  subject_with_personalization  1880 non-null   object
#  12  subject_with_deadline         1880 non-null   object
#  13  subject_with_emoji            1880 non-null   object
#  14  subject_with_bonuses          1880 non-null   object
#  15  subject_with_discount         1880 non-null   object
#  16  subject_with_saleout          1880 non-null   object
#  17  is_test                       27 non-null     object
#  18  position                      24 non-null     float64
# dtypes: float64(4), int64(1), object(14)
# memory usage: 283.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1351205 entries, 0 to 1351204
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   id                     1351205 non-null  int64
#  1   message_id             1351205 non-null  object
#  2   campaign_id            1351205 non-null  int64
#  3   message_type           1351205 non-null  object
#  4   client_id              1351205 non-null  int64
#  5   channel                1351205 non-null  object
#  6   category               0 non-null        float64
#  7   platform               97107 non-null    object
#  8   email_provider         716945 non-null   object
#  9   stream                 1351205 non-null  object
#  10  date                   1351205 non-null  object
#  11  sent_at                1351205 non-null  datetime64[ns]
#  12  is_opened              1351205 non-null  object
#  13  opened_first_time_at   203450 non-null   object
#  14  opened_last_time_at    203450 non-null   object
#  15  is_clicked             1351205 non-null  object
#  16  clicked_first_time_at  26775 non-null    object
#  17  clicked_last_time_at   26775 non-null    object
#  18  is_unsubscribed        1351205 non-null  object
#  19  unsubscribed_at        45269 non-null    object
#  20  is_hard_bounced        1351205 non-null  object
#  21  hard_bounced_at        4222 non-null     object
#  22  is_soft_bounced        1351205 non-null  object
#  23  soft_bounced_at        610 non-null      object
#  24  is_complained          1351205 non-null  object
#  25  complained_at          589 non-null      object
#  26  is_blocked             1351205 non-null  object
#  27  blocked_at             25 non-null       object
#  28  is_purchased           1351205 non-null  object
#  29  purchased_at           1115 non-null     object
#  30  created_at             1351205 non-null  object
#  31  updated_at             1351205 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(27)
# memory usage: 329.9+ MB

# %%
# Filter the relevant columns
first_purchase_filtered = data_first_purchase[['client_id', 'first_purchase_date']]
campaign_filtered = data_campaigns[['id', 'campaign_type', 'channel', 'topic', 'started_at',
                                            'finished_at', 'total_count', 'subject_length',
                                            'subject_with_personalization', 'subject_with_deadline',
                                            'subject_with_emoji', 'subject_with_bonuses',
                                            'subject_with_discount', 'subject_with_saleout']]

# Merge datasets using left join (or inner join if desired)
data_1 = pd.merge(data_msg, first_purchase_filtered, on='client_id', how='left')

# Create composite keys
data_1['composite_key'] = data_1['campaign_id'].astype(str) + '_' + data_1['message_type'].astype(str)
campaign_filtered['composite_key'] = campaign_filtered['id'].astype(str) + '_' + campaign_filtered['campaign_type'].astype(str)

# Perform the left join using the composite key
data_final = pd.merge(data_1, campaign_filtered, on='composite_key', how='left', suffixes=('_msg', '_cmp'))


# Ensure the columns have the same data type
#data_1['campaign_id'] = data_1['campaign_id'].astype(str)
#data_1['message_type'] = data_1['message_type'].astype(str)
#
#campaign_filtered['id'] = campaign_filtered['id'].astype(str)
#campaign_filtered['campaign_type'] = campaign_filtered['campaign_type'].astype(str)

#data_final = pd.merge(data_1, campaign_filtered, left_on=['campaign_id', "message_type"], right_on=['id', "campaign_type"], how='left', suffixes=('_msg', '_cmp'))

data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1351205 entries, 0 to 1351204
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   id_msg                        1351205 non-null  int64
#  1   message_id                    1351205 non-null  object
#  2   campaign_id                   1351205 non-null  int64
#  3   message_type                  1351205 non-null  object
#  4   client_id                     1351205 non-null  int64
#  5   channel_msg                   1351205 non-null  object
#  6   category                      0 non-null        float64
#  7   platform                      97107 non-null    object
#  8   email_provider                716945 non-null   object
#  9   stream                        1351205 non-null  object
#  10  date                          1351205 non-null  object
#  11  sent_at                       1351205 non-null  datetime64[ns]
#  12  is_opened                     1351205 non-null  object
#  13  opened_first_time_at          203450 non-null   object
#  14  opened_last_time_at           203450 non-null   object
#  15  is_clicked                    1351205 non-null  object
#  16  clicked_first_time_at         26775 non-null    object
#  17  clicked_last_time_at          26775 non-null    object
#  18  is_unsubscribed               1351205 non-null  object
#  19  unsubscribed_at               45269 non-null    object
#  20  is_hard_bounced               1351205 non-null  object
#  21  hard_bounced_at               4222 non-null     object
#  22  is_soft_bounced               1351205 non-null  object
#  23  soft_bounced_at               610 non-null      object
#  24  is_complained                 1351205 non-null  object
#  25  complained_at                 589 non-null      object
#  26  is_blocked                    1351205 non-null  object
#  27  blocked_at                    25 non-null       object
#  28  is_purchased                  1351205 non-null  object
#  29  purchased_at                  1115 non-null     object
#  30  created_at                    1351205 non-null  object
#  31  updated_at                    1351205 non-null  object
#  32  first_purchase_date           301957 non-null   object
#  33  composite_key                 1351205 non-null  object
#  34  id_cmp                        1351205 non-null  int64
#  35  campaign_type                 1351205 non-null  object
#  36  channel_cmp                   1351205 non-null  object
#  37  topic                         1340411 non-null  object
#  38  started_at                    1059195 non-null  object
#  39  finished_at                   1059195 non-null  object
#  40  total_count                   1059195 non-null  float64
#  41  subject_length                1120270 non-null  float64
#  42  subject_with_personalization  1120270 non-null  object
#  43  subject_with_deadline         1120270 non-null  object
#  44  subject_with_emoji            1120270 non-null  object
#  45  subject_with_bonuses          1120270 non-null  object
#  46  subject_with_discount         1120270 non-null  object
#  47  subject_with_saleout          1120270 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(40)
# memory usage: 494.8+ MB

# %%
# %run "scripts/dslabs_functions.py"

# %% [markdown]
# # Transformations

# %% [markdown]
# ## Remove columns

# %% [markdown]
# ### Remove IDs

# %%
#drop id columns - are not relevant for the prediction of the class

data_final = data_final.drop(columns=['message_id', 'id_msg', "id_cmp", 'campaign_id','client_id'])

# Drop the composite key if it's no longer needed
data_final.drop(columns=['composite_key'], inplace=True)

# %% [markdown]
# ### Irrelevant for business

# %%
#drop unnecessary values to the business/problem:

data_final = data_final.drop(columns=["created_at", "updated_at", "date", "opened_last_time_at", "clicked_last_time_at",
                               "hard_bounced_at", "soft_bounced_at", "created_at", "updated_at", "finished_at", "channel_msg"
                          ])

#created_at and updated_at, not necessary

# %% [markdown]
# ### High MV (80%+)

# %%
#drop MV columns - where MV values are around 90% or above. 

data_final = data_final.drop(columns=["category", "stream", "blocked_at", "is_blocked", "message_type"
                          ])

#stream tem apenas 1 valor e nao ajuda com nada ao modelo
#category, blocked_at tem 100% MV
#is_blocked: 1 distinct values
#message_type dropped, same as campaign_type

# %% [markdown]
# # Split 'date' column

# %%
import pandas as pd

# Split the 'date'' column to have more information and detail on the:
# - day_of_month
# - day_ok_week 
# - is_weekend
# - moment_of_day
# - hour
# - min
#As the dataset only has data from sepecific month of 2021, we don't need to get the year, quarter.

# Convert the 'date' column to datetime
data_final['sent_at'] = pd.to_datetime(data_final['sent_at'], utc=True)

# Create new columns based on the date column 'event_time'
data_final['day_of_year'] = data_final['sent_at'].dt.dayofyear  # Day of the year
data_final['week_of_month'] = data_final['sent_at'].apply(lambda x: (x.day - 1) // 7 + 1)
data_final['is_weekend'] = data_final['sent_at'].dt.weekday.apply(lambda x: True if x >= 5 else False)
data_final['day_of_week_nr'] = data_final['sent_at'].dt.weekday  # Monday=0, Sunday=6
data_final['day_of_month'] = data_final['sent_at'].dt.day
data_final['month'] = data_final['sent_at'].dt.month_name()
data_final['hour'] = data_final['sent_at'].dt.hour
data_final['min'] = data_final['sent_at'].dt.minute

# Create function to get time of the day
def categorize_time_of_day(hour):
    if 5 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    elif 17 <= hour < 21:
        return 'Evening'
    else:
        return 'Night'

data_final['time_of_day'] = data_final['hour'].apply(categorize_time_of_day)

# Display the updated DataFrame
data_final.head()
# Out:
#   platform email_provider                   sent_at is_opened  \
# 0      NaN        mail.ru 2021-04-30 05:00:07+00:00         f
# 1      NaN        mail.ru 2021-04-30 05:00:08+00:00         f
# 2      NaN      yandex.ru 2021-04-30 05:00:12+00:00         f
# 3      NaN        mail.ru 2021-04-30 05:00:16+00:00         f
# 4      NaN          bk.ru 2021-04-30 05:00:19+00:00         f
#
#   opened_first_time_at is_clicked clicked_first_time_at is_unsubscribed  \
# 0                  NaN          f                   NaN               f
# 1                  NaN          f                   NaN               f
# 2                  NaN          f                   NaN               f
# 3                  NaN          f                   NaN               f
# 4                  NaN          f                   NaN               f
#
#   unsubscribed_at is_hard_bounced  ... subject_with_saleout day_of_year  \
# 0             NaN               f  ...                  NaN         120
# 1             NaN               f  ...                  NaN         120
# 2             NaN               f  ...                  NaN         120
# 3             NaN               f  ...                  NaN         120
# 4             NaN               f  ...                  NaN         120
#
#   week_of_month is_weekend day_of_week_nr day_of_month  month hour min  \
# 0             5      False              4           30  April    5   0
# 1             5      False              4           30  April    5   0
# 2             5      False              4           30  April    5   0
# 3             5      False              4           30  April    5   0
# 4             5      False              4           30  April    5   0
#
#   time_of_day
# 0     Morning
# 1     Morning
# 2     Morning
# 3     Morning
# 4     Morning
#
# [5 rows x 37 columns]

# %% [markdown]
# # Can "is_clicked" happen at the same time as other events?
# ['is_opened', 'is_unsubscribed', 'is_complained', 'is_purchased']
# - Yes it can, however, whenever those variables are T, my target will always be T.
#     - This means i have to remove them from the dataset.
#
# (opened_first_time_at, clicked_first_time_at, unsubscribed_at, complained_at, purchased_at, first_purchase_date, started_at)
# - same thing as above
#     - This means i have to remove them from the dataset.

# %%
import pandas as pd

# Assuming your DataFrame is named 'data_final'
# Create a dictionary to store the counts of simultaneous occurrences
results = {}

# List of binary variables to compare with 'is_clicked'
variables_to_compare = ['is_opened', 'is_unsubscribed', 'is_complained', 'is_purchased', "is_clicked"]

# Loop through each variable and compare with 'is_clicked'
for variable in variables_to_compare:
    count_simultaneous = len(data_final[(data_final['is_clicked'] == "t") & (data_final[variable] == "t")])
    results[variable] = count_simultaneous

# Display the results
print(results)
# Out:
# {'is_opened': 26775, 'is_unsubscribed': 155, 'is_complained': 21, 'is_purchased': 1115, 'is_clicked': 26775}

# %%
import pandas as pd

# Assuming your DataFrame is named 'data_final'
# Create a dictionary to store the counts of simultaneous occurrences where date fields are not null
results = {}

# List of date variables to check against 'is_clicked'
date_variables = ['opened_first_time_at', 'clicked_first_time_at', 'unsubscribed_at', 
                  'complained_at', 'purchased_at', 'first_purchase_date', 'started_at']

# Loop through each date variable and check if 'is_clicked' is True and the date variable is not null
for date_var in date_variables:
    count_simultaneous = len(data_final[(data_final['is_clicked'] == "t") & (data_final[date_var].notna())])
    results[date_var] = count_simultaneous

# Display the results
print(results)
# Out:
# {'opened_first_time_at': 26775, 'clicked_first_time_at': 26775, 'unsubscribed_at': 155, 'complained_at': 21, 'purchased_at': 1115, 'first_purchase_date': 9433, 'started_at': 13032}

# %% [markdown]
# how many "t" values exist in each of the binary variables, separate the counts for the total number of "t" values in each variable and simultaneous "t" values with is_clicked

# %%
import pandas as pd

# Assuming your DataFrame is named 'data_final'
# Create a dictionary to store the counts of simultaneous occurrences and individual counts of "t"
simultaneous_results = {}
individual_results = {}

# List of binary variables to compare with 'is_clicked'
variables_to_compare = ['is_opened', 'is_unsubscribed', 'is_complained', 'is_purchased', "is_clicked"]

# Loop through each variable and compare with 'is_clicked'
for variable in variables_to_compare:
    # Count simultaneous occurrences where both 'is_clicked' and the variable are "t"
    count_simultaneous = len(data_final[(data_final['is_clicked'] == "t") & (data_final[variable] == "t")])
    simultaneous_results[variable] = count_simultaneous
    
    # Count total occurrences of "t" in each variable
    count_individual = len(data_final[data_final[variable] == "t"])
    individual_results[variable] = count_individual

# Display the results
print("Simultaneous 't' with 'is_clicked':", simultaneous_results)
print("Total 't' count for each variable:", individual_results)
# Out:
# Simultaneous 't' with 'is_clicked': {'is_opened': 26775, 'is_unsubscribed': 155, 'is_complained': 21, 'is_purchased': 1115, 'is_clicked': 26775}
# Total 't' count for each variable: {'is_opened': 203450, 'is_unsubscribed': 45269, 'is_complained': 589, 'is_purchased': 1115, 'is_clicked': 26775}

# %%
# Filter the dataset to only include rows where 'is_opened' is "t"
data_final = data_final[data_final['is_opened'] == "t"]

# Drop the specified columns, including 'is_opened'
data_final = data_final.drop(columns=['is_opened', 'is_unsubscribed', 'is_complained', 'is_purchased',
                                      'opened_first_time_at', 'clicked_first_time_at', 'unsubscribed_at', 
                                      'complained_at', 'purchased_at', 'first_purchase_date', 'started_at',
                                      'is_hard_bounced', 'is_soft_bounced'])

# Display the updated dataset (optional)
data_final.head()
# Out:
#    platform email_provider                   sent_at is_clicked  \
# 9   desktop      gmail.com 2021-04-30 05:00:37+00:00          t
# 10  desktop      yandex.ru 2021-04-30 05:00:41+00:00          t
# 11      NaN      yandex.ru 2021-04-30 05:00:42+00:00          f
# 13      NaN        mail.ru 2021-04-30 05:00:47+00:00          f
# 16  desktop        mail.ru 2021-04-30 05:00:55+00:00          f
#
#     campaign_type   channel_cmp                   topic  total_count  \
# 9         trigger  multichannel          abandoned cart          NaN
# 10        trigger  multichannel          abandoned view          NaN
# 11        trigger  multichannel          abandoned view          NaN
# 13  transactional         email  order ready for pickup          NaN
# 16        trigger  multichannel          abandoned cart          NaN
#
#     subject_length subject_with_personalization  ... subject_with_saleout  \
# 9              NaN                          NaN  ...                  NaN
# 10             NaN                          NaN  ...                  NaN
# 11             NaN                          NaN  ...                  NaN
# 13            88.0                        False  ...                False
# 16             NaN                          NaN  ...                  NaN
#
#    day_of_year week_of_month is_weekend day_of_week_nr  day_of_month  month  \
# 9          120             5      False              4            30  April
# 10         120             5      False              4            30  April
# 11         120             5      False              4            30  April
# 13         120             5      False              4            30  April
# 16         120             5      False              4            30  April
#
#     hour  min  time_of_day
# 9      5    0      Morning
# 10     5    0      Morning
# 11     5    0      Morning
# 13     5    0      Morning
# 16     5    0      Morning
#
# [5 rows x 24 columns]

# %%
data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 203450 entries, 9 to 1351197
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   platform                      97107 non-null   object
#  1   email_provider                128165 non-null  object
#  2   sent_at                       203450 non-null  datetime64[ns, UTC]
#  3   is_clicked                    203450 non-null  object
#  4   campaign_type                 203450 non-null  object
#  5   channel_cmp                   203450 non-null  object
#  6   topic                         201800 non-null  object
#  7   total_count                   148530 non-null  float64
#  8   subject_length                163867 non-null  float64
#  9   subject_with_personalization  163867 non-null  object
#  10  subject_with_deadline         163867 non-null  object
#  11  subject_with_emoji            163867 non-null  object
#  12  subject_with_bonuses          163867 non-null  object
#  13  subject_with_discount         163867 non-null  object
#  14  subject_with_saleout          163867 non-null  object
#  15  day_of_year                   203450 non-null  int32
#  16  week_of_month                 203450 non-null  int64
#  17  is_weekend                    203450 non-null  bool
#  18  day_of_week_nr                203450 non-null  int32
#  19  day_of_month                  203450 non-null  int32
#  20  month                         203450 non-null  object
#  21  hour                          203450 non-null  int32
#  22  min                           203450 non-null  int32
#  23  time_of_day                   203450 non-null  object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(2), int32(5), int64(1), object(14)
# memory usage: 33.6+ MB

# %% [markdown]
# ## Remove date columns
# Date Variables:
# -  🚫date: 20 distinct values
# -  ✅sent_at: 35261 distinct values
# -  ✅opened_first_time_at: 8720 distinct values
# -  🚫opened_last_time_at: 8737 distinct values
# -  ✅clicked_first_time_at: 892 distinct values
# -  🚫clicked_last_time_at: 893 distinct values
# -  ✅unsubscribed_at: 1923 distinct values
# -  🚫hard_bounced_at: 4 distinct values
# -  🚫soft_bounced_at: 12 distinct values
# -  ✅complained_at: 19 distinct values
# -  ✅purchased_at: 21 distinct values
# -  🚫created_at: 71568 distinct values
# -  🚫updated_at: 71568 distinct values
# -  ✅first_purchase_date: 730 distinct values
# -  ✅started_at: 35 distinct values - Bulk campaign start datetime
# -  🚫finished_at: 35 distinct values - Bulk campaign finish datetime

# %% [markdown]
# Creating more variables considering "sent_at"

# %%
## Convert all date columns to datetime format
#date_columns = ['opened_first_time_at', 'clicked_first_time_at', 'unsubscribed_at', 
#                'complained_at', 'purchased_at', 'first_purchase_date', 'started_at']
#
#data_final[['sent_at'] + date_columns] = data_final[['sent_at'] + date_columns].apply(pd.to_datetime)
#
## Remove timezone information if any column has it, making all columns tz-naive
#for col in ['sent_at'] + date_columns:
#    data_final[col] = data_final[col].dt.tz_localize(None)
#
## Calculate the difference in days between 'sent_at' and each of the specified date columns
#for col in date_columns:
#    data_final[f'days_diff_{col}_sent_at'] = (data_final[col] - data_final['sent_at']).dt.days
#
## Display the updated DataFrame
#data_final.head()

# %%
#remove other date columns:

#data_final = data_final.drop(columns=['opened_first_time_at', 'clicked_first_time_at', 'unsubscribed_at', 
#                'complained_at', 'purchased_at', 'first_purchase_date', 'started_at'])

# %% [markdown]
# # Save df from preprocessing into a csv file

# %%
# Definir o caminho para salvar o arquivo CSV
filepath = r'dataset/df_msg_pre_proc.csv'

# Salvar o DataFrame em CSV
data_final.to_csv(filepath, index=False)

data_final.head()
# Out:
#    platform email_provider                   sent_at is_clicked  \
# 9   desktop      gmail.com 2021-04-30 05:00:37+00:00          t
# 10  desktop      yandex.ru 2021-04-30 05:00:41+00:00          t
# 11      NaN      yandex.ru 2021-04-30 05:00:42+00:00          f
# 13      NaN        mail.ru 2021-04-30 05:00:47+00:00          f
# 16  desktop        mail.ru 2021-04-30 05:00:55+00:00          f
#
#     campaign_type   channel_cmp                   topic  total_count  \
# 9         trigger  multichannel          abandoned cart          NaN
# 10        trigger  multichannel          abandoned view          NaN
# 11        trigger  multichannel          abandoned view          NaN
# 13  transactional         email  order ready for pickup          NaN
# 16        trigger  multichannel          abandoned cart          NaN
#
#     subject_length subject_with_personalization  ... subject_with_saleout  \
# 9              NaN                          NaN  ...                  NaN
# 10             NaN                          NaN  ...                  NaN
# 11             NaN                          NaN  ...                  NaN
# 13            88.0                        False  ...                False
# 16             NaN                          NaN  ...                  NaN
#
#    day_of_year week_of_month is_weekend day_of_week_nr  day_of_month  month  \
# 9          120             5      False              4            30  April
# 10         120             5      False              4            30  April
# 11         120             5      False              4            30  April
# 13         120             5      False              4            30  April
# 16         120             5      False              4            30  April
#
#     hour  min  time_of_day
# 9      5    0      Morning
# 10     5    0      Morning
# 11     5    0      Morning
# 13     5    0      Morning
# 16     5    0      Morning
#
# [5 rows x 24 columns]

# %%
data_final.shape[0]
# Out:
# 203450

# %%
from pandas import read_csv, DataFrame
import pandas as pd
#get file from data pre processing notebook. This file has all the column we need to start the data profiling phase
filepath = r'dataset/df_msg_pre_proc.csv'

file_tag = 'df_msg_data_prof'

data = pd.read_csv(filepath)

# %%
# Filter for rows where 'is_clicked' is "t"
data_filtered = data[data['is_clicked'] == "t"]

# Group by 'channel_cmp' and count the occurrences
channel_cmp_counts = data_filtered.groupby('channel_cmp').size().reset_index(name='count')

# Group by 'day_of_month_cos' and count the occurrences
day_of_month_cos_counts = data_filtered.groupby('day_of_month').size().reset_index(name='count')

# Display results
print("Counts for 'channel_cmp':")
print(channel_cmp_counts)

print("\nCounts for 'day_of_month_cos':")
print(day_of_month_cos_counts)
# Out:
# Counts for 'channel_cmp':
#     channel_cmp  count
# 0         email  14808
# 1   mobile_push    844
# 2  multichannel  11123
#
# Counts for 'day_of_month_cos':
#     day_of_month  count
# 0              1    506
# 1              2    840
# 2              3    940
# 3              4    976
# 4              5    457
# 5              6    630
# 6              7   1121
# 7              8    435
# 8              9    438
# 9             10    736
# 10            11   1317
# 11            12    771
# 12            13    653
# 13            14    289
# 14            15    293
# 15            16    348
# 16            17    296
# 17            18    275
# 18            19    649
# 19            20    656
# 20            21   8318
# 21            22    530
# 22            23    547
# 23            24   1074
# 24            25    244
# 25            26    470
# 26            27   1115
# 27            28    471
# 28            29    273
# 29            30    666
# 30            31    441

# %%
# Filter for rows where 'is_clicked' is "t"
# Group by 'channel_cmp' and count the occurrences
channel_cmp_counts = data.groupby('channel_cmp').size().reset_index(name='count')

# Group by 'day_of_month_cos' and count the occurrences
day_of_month_cos_counts = data.groupby('day_of_month').size().reset_index(name='count')

# Display results
print("Counts for 'channel_cmp':")
print(channel_cmp_counts)

print("\nCounts for 'day_of_month_cos':")
print(day_of_month_cos_counts)
# Out:
# Counts for 'channel_cmp':
#     channel_cmp  count
# 0         email  88582
# 1   mobile_push  75285
# 2  multichannel  39583
#
# Counts for 'day_of_month_cos':
#     day_of_month  count
# 0              1   1992
# 1              2   3194
# 2              3   7413
# 3              4   3290
# 4              5   1752
# 5              6  32964
# 6              7   8346
# 7              8   1521
# 8              9   1920
# 9             10   6411
# 10            11   5903
# 11            12  13901
# 12            13   2253
# 13            14   1202
# 14            15   1145
# 15            16   1315
# 16            17   1117
# 17            18   1123
# 18            19  10422
# 19            20   8368
# 20            21  35357
# 21            22   2663
# 22            23   1441
# 23            24   7295
# 24            25    918
# 25            26   2764
# 26            27   9526
# 27            28   1788
# 28            29   1090
# 29            30  23510
# 30            31   1546

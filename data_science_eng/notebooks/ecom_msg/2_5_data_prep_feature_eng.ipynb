# %% [markdown]
# # File and libraries

# %%
import pandas as pd
import numpy as np

filepath=r'dataset/df_msg_scaler_input'

file_tag = "df_msg_feat_eng_input"

# %% [markdown]
# # DSLabs functions

# %%
# %run "scripts/dslabs_functions.py"

# %% [markdown]
# # Data functions

# %%
# %run "scripts/data_functions.py"
# Out:
# data_functions lodaded

# %% [markdown]
# The F2 score is a variation of the F-score that places more emphasis on recall compared to precision. While the commonly used F1 score gives equal importance to both precision and recall, the F2 score weighs recall more heavily, meaning it prioritizes minimizing false negatives.

# %% [markdown]
# # Load

# %%
#test_data=True
test_data=False

# use to evaluate strategies. otherwise False to just transform data 
evaluate=True
# evaluate=False

def sample_per_day(group, fraction=0.1):
    return group.sample(frac=fraction)


if test_data==True:

    data=pd.read_csv(f"{filepath}.csv")
    
    test= pd.read_csv(f"{filepath}_test.csv")
    train= pd.read_csv(f"{filepath}_train.csv")

    sample=0.01
    data = data.groupby('day_of_year').apply(lambda x: sample_per_day(x, sample)).reset_index(drop=True)
    test = test.groupby('day_of_year').apply(lambda x: sample_per_day(x, sample)).reset_index(drop=True)
    train = train.groupby('day_of_year').apply(lambda x: sample_per_day(x, sample)).reset_index(drop=True)
    
    # create sample df version of test/train for variance studies
    test_sample= test
    train_sample= train
    
else:
    data=pd.read_csv(f"{filepath}.csv")

    
    test= pd.read_csv(f"{filepath}_test.csv")
    train= pd.read_csv(f"{filepath}_train.csv")

    # create sample for variance studies
    sample=0.1
    test_sample = test.groupby('day_of_year').apply(lambda x: sample_per_day(x, sample)).reset_index(drop=True)
    train_sample = train.groupby('day_of_year').apply(lambda x: sample_per_day(x, sample)).reset_index(drop=True)


 
target='is_clicked'
target_metric='f2'
vars: list[str] = data.columns.to_list()


# ensure sorting by day_of_year for correct splitting 
# "When in the presence of temporal data, data partition shall use older data to train and newer to test, in order to not use future data to classify past data. In any other case, partition shall be random."
data.sort_values(by='day_of_year', inplace=True)
test.sort_values(by='day_of_year', inplace=True)
train.sort_values(by='day_of_year', inplace=True)



data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195562 entries, 0 to 195561
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   platform                      195562 non-null  float64
#  1   email_provider                195562 non-null  float64
#  2   campaign_type                 195562 non-null  float64
#  3   channel_cmp                   195562 non-null  float64
#  4   topic                         195562 non-null  float64
#  5   total_count                   195562 non-null  float64
#  6   subject_length                195562 non-null  float64
#  7   day_of_year                   195562 non-null  float64
#  8   month                         195562 non-null  float64
#  9   hour_sin                      195562 non-null  float64
#  10  hour_cos                      195562 non-null  float64
#  11  min_sin                       195562 non-null  float64
#  12  min_cos                       195562 non-null  float64
#  13  day_of_month_sin              195562 non-null  float64
#  14  day_of_month_cos              195562 non-null  float64
#  15  day_of_week_nr_sin            195562 non-null  float64
#  16  day_of_week_nr_cos            195562 non-null  float64
#  17  week_of_month_sin             195562 non-null  float64
#  18  week_of_month_cos             195562 non-null  float64
#  19  is_clicked                    195562 non-null  float64
#  20  subject_with_personalization  195562 non-null  float64
#  21  subject_with_deadline         195562 non-null  float64
#  22  subject_with_emoji            195562 non-null  float64
#  23  subject_with_bonuses          195562 non-null  float64
#  24  subject_with_discount         195562 non-null  float64
#  25  subject_with_saleout          195562 non-null  float64
#  26  is_weekend                    195562 non-null  float64
#  27  time_of_day                   195562 non-null  float64
# dtypes: float64(28)
# memory usage: 43.3 MB

# %%
print(f"Train shape: {train.shape}")
print(f"Test shape: {test.shape}")
# Out:
# Train shape: (136893, 28)
# Test shape: (58669, 28)

# %% [markdown]
# # Feat 1 - Dropping irrelevant (Low Variance) Variables

# %% [markdown]
# ## Feat 1 - Study Low Variance Variables and Threshold
#
# using sampled dataframe due to heavy processing

# %% [markdown]
# ### Selected variables from DT

# %%
max_thresh=0.8
lag_variance=0.02
mandatory_cols=['channel_cmp', 'total_count','topic', 'subject_length', 
                'email_provider', "platform", "subject_with_emoji"]

# %% [markdown]
# ### precision

# %%
# modified study_variance_for_feature_selection() in dslabs functions to keep minimum variables and print metrics (due to error)
if evaluate==True:

    eval_metric = "precision"
    figure(figsize=(2 * HEIGHT, HEIGHT))
    study_variance_for_feature_selection(
        train_sample,
        test_sample,
        target=target,
        max_threshold=max_thresh,
        lag=lag_variance,
        metric=eval_metric,
        file_tag=file_tag,
        min_features_to_keep = 3,  # Minimum features safeguard
        exclude=mandatory_cols


    )
    show()
# Out:
# Testing threshold: 0.02
# Dropping variables: ['subject_with_bonuses', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout']
# Remaining features after drop: 24
# Evaluation results at threshold 0.02: {'accuracy': [0.7619696711535184, 0.7802010563980235], 'recall': [0.34611602753195675, 0.09341199606686332], 'precision': [0.3247232472324723, 0.20518358531317496], 'auc': [0.597625202554107, 0.5087834918504144], 'f1': [0.33507853403141363, 0.12837837837837837], 'f2': [0.3416149068322981, 0.10483337011697197]}
# Evaluation for precision: [0.3247232472324723, 0.20518358531317496]
# Testing threshold: 0.04
# Dropping variables: ['subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout']
# Remaining features after drop: 23
# Evaluation results at threshold 0.04: {'accuracy': [0.7619696711535184, 0.7802010563980235], 'recall': [0.34611602753195675, 0.09341199606686332], 'precision': [0.3247232472324723, 0.20518358531317496], 'auc': [0.597625202554107, 0.5087834918504144], 'f1': [0.33507853403141363, 0.12837837837837837], 'f2': [0.3416149068322981, 0.10483337011697197]}
# Evaluation for precision: [0.3247232472324723, 0.20518358531317496]
# Testing threshold: 0.06
# Dropping variables: ['is_weekend', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout']
# Remaining features after drop: 22
# Evaluation results at threshold 0.06: {'accuracy': [0.7631623785994207, 0.7788379621741353], 'recall': [0.2969518190757129, 0.09341199606686332], 'precision': [0.3091095189355169, 0.20169851380042464], 'auc': [0.5789169647728112, 0.5079590895420879], 'f1': [0.3029087261785356, 0.12768817204301075], 'f2': [0.2993062438057483, 0.10464860101343908]}
# Evaluation for precision: [0.3091095189355169, 0.20169851380042464]
# Testing threshold: 0.08
# Dropping variables: ['hour_cos', 'is_weekend', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day']
# Remaining features after drop: 20
# Evaluation results at threshold 0.08: {'accuracy': [0.777134094394275, 0.7762821605043448], 'recall': [0.29891838741396265, 0.11209439528023599], 'precision': [0.3381535038932147, 0.21755725190839695], 'auc': [0.5881442720252007, 0.5137965793383867], 'f1': [0.3173277661795407, 0.14795587280986372], 'f2': [0.30601973021944834, 0.12412891986062717]}
# Evaluation for precision: [0.3381535038932147, 0.21755725190839695]
# Testing threshold: 0.1
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day']
# Remaining features after drop: 19
# Evaluation results at threshold 0.1: {'accuracy': [0.7827568580678139, 0.8267166467882092], 'recall': [0.29400196656833827, 0.0009832841691248771], 'precision': [0.3492990654205608, 0.5], 'auc': [0.589601972566939, 0.5003885917960216], 'f1': [0.3192738921516284, 0.001962708537782139], 'f2': [0.3036149471974005, 0.0012285012285012285]}
# Evaluation for precision: [0.3492990654205608, 0.5]
# Testing threshold: 0.12
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day']
# Remaining features after drop: 19
# Evaluation results at threshold 0.12: {'accuracy': [0.7827568580678139, 0.8267166467882092], 'recall': [0.29400196656833827, 0.0009832841691248771], 'precision': [0.3492990654205608, 0.5], 'auc': [0.589601972566939, 0.5003885917960216], 'f1': [0.3192738921516284, 0.001962708537782139], 'f2': [0.3036149471974005, 0.0012285012285012285]}
# Evaluation for precision: [0.3492990654205608, 0.5]
# Testing threshold: 0.14
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 17
# Evaluation results at threshold 0.14: {'accuracy': [0.7924689044130175, 0.8267166467882092], 'recall': [0.20943952802359883, 0.0009832841691248771], 'precision': [0.3397129186602871, 0.5], 'auc': [0.5620569445559049, 0.5003885917960216], 'f1': [0.2591240875912409, 0.001962708537782139], 'f2': [0.2268370607028754, 0.0012285012285012285]}
# Evaluation for precision: [0.3397129186602871, 0.5]
# Testing threshold: 0.16
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 17
# Evaluation results at threshold 0.16: {'accuracy': [0.7924689044130175, 0.8267166467882092], 'recall': [0.20943952802359883, 0.0009832841691248771], 'precision': [0.3397129186602871, 0.5], 'auc': [0.5620569445559049, 0.5003885917960216], 'f1': [0.2591240875912409, 0.001962708537782139], 'f2': [0.2268370607028754, 0.0012285012285012285]}
# Evaluation for precision: [0.3397129186602871, 0.5]
# Testing threshold: 0.18
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 17
# Evaluation results at threshold 0.18: {'accuracy': [0.7924689044130175, 0.8267166467882092], 'recall': [0.20943952802359883, 0.0009832841691248771], 'precision': [0.3397129186602871, 0.5], 'auc': [0.5620569445559049, 0.5003885917960216], 'f1': [0.2591240875912409, 0.001962708537782139], 'f2': [0.2268370607028754, 0.0012285012285012285]}
# Evaluation for precision: [0.3397129186602871, 0.5]
# Testing threshold: 0.2
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 17
# Evaluation results at threshold 0.2: {'accuracy': [0.7924689044130175, 0.8267166467882092], 'recall': [0.20943952802359883, 0.0009832841691248771], 'precision': [0.3397129186602871, 0.5], 'auc': [0.5620569445559049, 0.5003885917960216], 'f1': [0.2591240875912409, 0.001962708537782139], 'f2': [0.2268370607028754, 0.0012285012285012285]}
# Evaluation for precision: [0.3397129186602871, 0.5]
# Testing threshold: 0.22
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.22: {'accuracy': [0.8060998466518998, 0.8268870335661953], 'recall': [0.19960668633235004, 0.0009832841691248771], 'precision': [0.38519924098671726, 1.0], 'auc': [0.5664150496789532, 0.5004916420845624], 'f1': [0.26295336787564766, 0.0019646365422396855], 'f2': [0.22089227421109903, 0.001228803145736053]}
# Evaluation for precision: [0.38519924098671726, 1.0]
# Testing threshold: 0.24
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.24: {'accuracy': [0.8060998466518998, 0.8268870335661953], 'recall': [0.19960668633235004, 0.0009832841691248771], 'precision': [0.38519924098671726, 1.0], 'auc': [0.5664150496789532, 0.5004916420845624], 'f1': [0.26295336787564766, 0.0019646365422396855], 'f2': [0.22089227421109903, 0.001228803145736053]}
# Evaluation for precision: [0.38519924098671726, 1.0]
# Testing threshold: 0.26
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.26: {'accuracy': [0.8060998466518998, 0.8268870335661953], 'recall': [0.19960668633235004, 0.0009832841691248771], 'precision': [0.38519924098671726, 1.0], 'auc': [0.5664150496789532, 0.5004916420845624], 'f1': [0.26295336787564766, 0.0019646365422396855], 'f2': [0.22089227421109903, 0.001228803145736053]}
# Evaluation for precision: [0.38519924098671726, 1.0]
# Testing threshold: 0.28
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.28: {'accuracy': [0.8060998466518998, 0.8268870335661953], 'recall': [0.19960668633235004, 0.0009832841691248771], 'precision': [0.38519924098671726, 1.0], 'auc': [0.5664150496789532, 0.5004916420845624], 'f1': [0.26295336787564766, 0.0019646365422396855], 'f2': [0.22089227421109903, 0.001228803145736053]}
# Evaluation for precision: [0.38519924098671726, 1.0]
# Testing threshold: 0.3
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.3: {'accuracy': [0.8060998466518998, 0.8268870335661953], 'recall': [0.19960668633235004, 0.0009832841691248771], 'precision': [0.38519924098671726, 1.0], 'auc': [0.5664150496789532, 0.5004916420845624], 'f1': [0.26295336787564766, 0.0019646365422396855], 'f2': [0.22089227421109903, 0.001228803145736053]}
# Evaluation for precision: [0.38519924098671726, 1.0]
# Testing threshold: 0.32
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.32: {'accuracy': [0.8060998466518998, 0.8268870335661953], 'recall': [0.19960668633235004, 0.0009832841691248771], 'precision': [0.38519924098671726, 1.0], 'auc': [0.5664150496789532, 0.5004916420845624], 'f1': [0.26295336787564766, 0.0019646365422396855], 'f2': [0.22089227421109903, 0.001228803145736053]}
# Evaluation for precision: [0.38519924098671726, 1.0]
# Testing threshold: 0.34
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.34: {'accuracy': [0.8060998466518998, 0.8268870335661953], 'recall': [0.19960668633235004, 0.0009832841691248771], 'precision': [0.38519924098671726, 1.0], 'auc': [0.5664150496789532, 0.5004916420845624], 'f1': [0.26295336787564766, 0.0019646365422396855], 'f2': [0.22089227421109903, 0.001228803145736053]}
# Evaluation for precision: [0.38519924098671726, 1.0]
# Testing threshold: 0.36
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.36: {'accuracy': [0.8060998466518998, 0.8268870335661953], 'recall': [0.19960668633235004, 0.0009832841691248771], 'precision': [0.38519924098671726, 1.0], 'auc': [0.5664150496789532, 0.5004916420845624], 'f1': [0.26295336787564766, 0.0019646365422396855], 'f2': [0.22089227421109903, 0.001228803145736053]}
# Evaluation for precision: [0.38519924098671726, 1.0]
# Testing threshold: 0.38
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.38: {'accuracy': [0.8060998466518998, 0.8268870335661953], 'recall': [0.19960668633235004, 0.0009832841691248771], 'precision': [0.38519924098671726, 1.0], 'auc': [0.5664150496789532, 0.5004916420845624], 'f1': [0.26295336787564766, 0.0019646365422396855], 'f2': [0.22089227421109903, 0.001228803145736053]}
# Evaluation for precision: [0.38519924098671726, 1.0]
# Testing threshold: 0.4
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.4: {'accuracy': [0.8060998466518998, 0.8268870335661953], 'recall': [0.19960668633235004, 0.0009832841691248771], 'precision': [0.38519924098671726, 1.0], 'auc': [0.5664150496789532, 0.5004916420845624], 'f1': [0.26295336787564766, 0.0019646365422396855], 'f2': [0.22089227421109903, 0.001228803145736053]}
# Evaluation for precision: [0.38519924098671726, 1.0]
# Testing threshold: 0.42
# Dropping variables: ['day_of_month_cos', 'day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 15
# Evaluation results at threshold 0.42: {'accuracy': [0.7911058101891293, 0.8268870335661953], 'recall': [0.22025565388397247, 0.0009832841691248771], 'precision': [0.3409436834094368, 1.0], 'auc': [0.5655070520038163, 0.5004916420845624], 'f1': [0.26762246117084826, 0.0019646365422396855], 'f2': [0.23703703703703705, 0.001228803145736053]}
# Evaluation for precision: [0.3409436834094368, 1.0]
# Testing threshold: 0.44
# Dropping variables: ['day_of_month_cos', 'day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 15
# Evaluation results at threshold 0.44: {'accuracy': [0.7911058101891293, 0.8268870335661953], 'recall': [0.22025565388397247, 0.0009832841691248771], 'precision': [0.3409436834094368, 1.0], 'auc': [0.5655070520038163, 0.5004916420845624], 'f1': [0.26762246117084826, 0.0019646365422396855], 'f2': [0.23703703703703705, 0.001228803145736053]}
# Evaluation for precision: [0.3409436834094368, 1.0]
# Testing threshold: 0.46
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 13
# Evaluation results at threshold 0.46: {'accuracy': [0.8210938831146704, 0.8270574203441813], 'recall': [0.08947885939036382, 0.0019665683382497543], 'precision': [0.4232558139534884, 1.0], 'auc': [0.5319611939161217, 0.5009832841691249], 'f1': [0.14772727272727273, 0.003925417075564278], 'f2': [0.10623394816717255, 0.002457002457002457]}
# Evaluation for precision: [0.4232558139534884, 1.0]
# Testing threshold: 0.48
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 13
# Evaluation results at threshold 0.48: {'accuracy': [0.8210938831146704, 0.8270574203441813], 'recall': [0.08947885939036382, 0.0019665683382497543], 'precision': [0.4232558139534884, 1.0], 'auc': [0.5319611939161217, 0.5009832841691249], 'f1': [0.14772727272727273, 0.003925417075564278], 'f2': [0.10623394816717255, 0.002457002457002457]}
# Evaluation for precision: [0.4232558139534884, 1.0]
# Testing threshold: 0.5
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.5: {'accuracy': [0.8212642698926563, 0.8270574203441813], 'recall': [0.08259587020648967, 0.0019665683382497543], 'precision': [0.42, 1.0], 'auc': [0.5293441016325112, 0.5009832841691249], 'f1': [0.13804437140509448, 0.003925417075564278], 'f2': [0.09840674789128398, 0.002457002457002457]}
# Evaluation for precision: [0.42, 1.0]
# Testing threshold: 0.52
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.52: {'accuracy': [0.8212642698926563, 0.8270574203441813], 'recall': [0.08259587020648967, 0.0019665683382497543], 'precision': [0.42, 1.0], 'auc': [0.5293441016325112, 0.5009832841691249], 'f1': [0.13804437140509448, 0.003925417075564278], 'f2': [0.09840674789128398, 0.002457002457002457]}
# Evaluation for precision: [0.42, 1.0]
# Testing threshold: 0.54
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.54: {'accuracy': [0.8212642698926563, 0.8270574203441813], 'recall': [0.08259587020648967, 0.0019665683382497543], 'precision': [0.42, 1.0], 'auc': [0.5293441016325112, 0.5009832841691249], 'f1': [0.13804437140509448, 0.003925417075564278], 'f2': [0.09840674789128398, 0.002457002457002457]}
# Evaluation for precision: [0.42, 1.0]
# Testing threshold: 0.56
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.56: {'accuracy': [0.8212642698926563, 0.8270574203441813], 'recall': [0.08259587020648967, 0.0019665683382497543], 'precision': [0.42, 1.0], 'auc': [0.5293441016325112, 0.5009832841691249], 'f1': [0.13804437140509448, 0.003925417075564278], 'f2': [0.09840674789128398, 0.002457002457002457]}
# Evaluation for precision: [0.42, 1.0]
# Testing threshold: 0.58
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.58: {'accuracy': [0.8212642698926563, 0.8270574203441813], 'recall': [0.08259587020648967, 0.0019665683382497543], 'precision': [0.42, 1.0], 'auc': [0.5293441016325112, 0.5009832841691249], 'f1': [0.13804437140509448, 0.003925417075564278], 'f2': [0.09840674789128398, 0.002457002457002457]}
# Evaluation for precision: [0.42, 1.0]
# Testing threshold: 0.6
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.6: {'accuracy': [0.8199011756687681, 0.8270574203441813], 'recall': [0.16125860373647985, 0.0019665683382497543], 'precision': [0.44565217391304346, 1.0], 'auc': [0.559607043005915, 0.5009832841691249], 'f1': [0.2368231046931408, 0.003925417075564278], 'f2': [0.1848512173128945, 0.002457002457002457]}
# Evaluation for precision: [0.44565217391304346, 1.0]
# Testing threshold: 0.62
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.62: {'accuracy': [0.8199011756687681, 0.8270574203441813], 'recall': [0.16125860373647985, 0.0019665683382497543], 'precision': [0.44565217391304346, 1.0], 'auc': [0.559607043005915, 0.5009832841691249], 'f1': [0.2368231046931408, 0.003925417075564278], 'f2': [0.1848512173128945, 0.002457002457002457]}
# Evaluation for precision: [0.44565217391304346, 1.0]
# Testing threshold: 0.64
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.64: {'accuracy': [0.8199011756687681, 0.8270574203441813], 'recall': [0.16125860373647985, 0.0019665683382497543], 'precision': [0.44565217391304346, 1.0], 'auc': [0.559607043005915, 0.5009832841691249], 'f1': [0.2368231046931408, 0.003925417075564278], 'f2': [0.1848512173128945, 0.002457002457002457]}
# Evaluation for precision: [0.44565217391304346, 1.0]
# Testing threshold: 0.66
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.66: {'accuracy': [0.8199011756687681, 0.8270574203441813], 'recall': [0.16125860373647985, 0.0019665683382497543], 'precision': [0.44565217391304346, 1.0], 'auc': [0.559607043005915, 0.5009832841691249], 'f1': [0.2368231046931408, 0.003925417075564278], 'f2': [0.1848512173128945, 0.002457002457002457]}
# Evaluation for precision: [0.44565217391304346, 1.0]
# Testing threshold: 0.68
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.68: {'accuracy': [0.8199011756687681, 0.8270574203441813], 'recall': [0.16125860373647985, 0.0019665683382497543], 'precision': [0.44565217391304346, 1.0], 'auc': [0.559607043005915, 0.5009832841691249], 'f1': [0.2368231046931408, 0.003925417075564278], 'f2': [0.1848512173128945, 0.002457002457002457]}
# Evaluation for precision: [0.44565217391304346, 1.0]
# Testing threshold: 0.7
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.7: {'accuracy': [0.8199011756687681, 0.8270574203441813], 'recall': [0.16125860373647985, 0.0019665683382497543], 'precision': [0.44565217391304346, 1.0], 'auc': [0.559607043005915, 0.5009832841691249], 'f1': [0.2368231046931408, 0.003925417075564278], 'f2': [0.1848512173128945, 0.002457002457002457]}
# Evaluation for precision: [0.44565217391304346, 1.0]
# Testing threshold: 0.72
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.72: {'accuracy': [0.8199011756687681, 0.8270574203441813], 'recall': [0.16125860373647985, 0.0019665683382497543], 'precision': [0.44565217391304346, 1.0], 'auc': [0.559607043005915, 0.5009832841691249], 'f1': [0.2368231046931408, 0.003925417075564278], 'f2': [0.1848512173128945, 0.002457002457002457]}
# Evaluation for precision: [0.44565217391304346, 1.0]
# Testing threshold: 0.74
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.74: {'accuracy': [0.8199011756687681, 0.8270574203441813], 'recall': [0.16125860373647985, 0.0019665683382497543], 'precision': [0.44565217391304346, 1.0], 'auc': [0.559607043005915, 0.5009832841691249], 'f1': [0.2368231046931408, 0.003925417075564278], 'f2': [0.1848512173128945, 0.002457002457002457]}
# Evaluation for precision: [0.44565217391304346, 1.0]
# Testing threshold: 0.76
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.76: {'accuracy': [0.8199011756687681, 0.8270574203441813], 'recall': [0.16125860373647985, 0.0019665683382497543], 'precision': [0.44565217391304346, 1.0], 'auc': [0.559607043005915, 0.5009832841691249], 'f1': [0.2368231046931408, 0.003925417075564278], 'f2': [0.1848512173128945, 0.002457002457002457]}
# Evaluation for precision: [0.44565217391304346, 1.0]
# Testing threshold: 0.78
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.78: {'accuracy': [0.8199011756687681, 0.8270574203441813], 'recall': [0.16125860373647985, 0.0019665683382497543], 'precision': [0.44565217391304346, 1.0], 'auc': [0.559607043005915, 0.5009832841691249], 'f1': [0.2368231046931408, 0.003925417075564278], 'f2': [0.1848512173128945, 0.002457002457002457]}
# Evaluation for precision: [0.44565217391304346, 1.0]
# Testing threshold: 0.8
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.8: {'accuracy': [0.8199011756687681, 0.8270574203441813], 'recall': [0.16125860373647985, 0.0019665683382497543], 'precision': [0.44565217391304346, 1.0], 'auc': [0.559607043005915, 0.5009832841691249], 'f1': [0.2368231046931408, 0.003925417075564278], 'f2': [0.1848512173128945, 0.002457002457002457]}
# Evaluation for precision: [0.44565217391304346, 1.0]

# %% [markdown]
# ### recall

# %%
# modified study_variance_for_feature_selection() in dslabs functions to keep minimum variables and print metrics (due to error)
if evaluate==True:

    eval_metric = "recall"
    figure(figsize=(2 * HEIGHT, HEIGHT))
    study_variance_for_feature_selection(
        train_sample,
        test_sample,
        target=target,
        max_threshold=max_thresh,
        lag=lag_variance,
        metric=eval_metric,
        file_tag=file_tag,
        min_features_to_keep = 3,  # Minimum features safeguard
        exclude=mandatory_cols

    )
    show()
# Out:
# Testing threshold: 0.02
# Dropping variables: ['subject_with_bonuses', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout']
# Remaining features after drop: 24
# Evaluation results at threshold 0.02: {'accuracy': [0.7619696711535184, 0.7802010563980235], 'recall': [0.34611602753195675, 0.09341199606686332], 'precision': [0.3247232472324723, 0.20518358531317496], 'auc': [0.597625202554107, 0.5087834918504144], 'f1': [0.33507853403141363, 0.12837837837837837], 'f2': [0.3416149068322981, 0.10483337011697197]}
# Evaluation for recall: [0.34611602753195675, 0.09341199606686332]
# Testing threshold: 0.04
# Dropping variables: ['subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout']
# Remaining features after drop: 23
# Evaluation results at threshold 0.04: {'accuracy': [0.7619696711535184, 0.7802010563980235], 'recall': [0.34611602753195675, 0.09341199606686332], 'precision': [0.3247232472324723, 0.20518358531317496], 'auc': [0.597625202554107, 0.5087834918504144], 'f1': [0.33507853403141363, 0.12837837837837837], 'f2': [0.3416149068322981, 0.10483337011697197]}
# Evaluation for recall: [0.34611602753195675, 0.09341199606686332]
# Testing threshold: 0.06
# Dropping variables: ['is_weekend', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout']
# Remaining features after drop: 22
# Evaluation results at threshold 0.06: {'accuracy': [0.7631623785994207, 0.7788379621741353], 'recall': [0.2969518190757129, 0.09341199606686332], 'precision': [0.3091095189355169, 0.20169851380042464], 'auc': [0.5789169647728112, 0.5079590895420879], 'f1': [0.3029087261785356, 0.12768817204301075], 'f2': [0.2993062438057483, 0.10464860101343908]}
# Evaluation for recall: [0.2969518190757129, 0.09341199606686332]
# Testing threshold: 0.08
# Dropping variables: ['hour_cos', 'is_weekend', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day']
# Remaining features after drop: 20
# Evaluation results at threshold 0.08: {'accuracy': [0.777134094394275, 0.7762821605043448], 'recall': [0.29891838741396265, 0.11209439528023599], 'precision': [0.3381535038932147, 0.21755725190839695], 'auc': [0.5881442720252007, 0.5137965793383867], 'f1': [0.3173277661795407, 0.14795587280986372], 'f2': [0.30601973021944834, 0.12412891986062717]}
# Evaluation for recall: [0.29891838741396265, 0.11209439528023599]
# Testing threshold: 0.1
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day']
# Remaining features after drop: 19
# Evaluation results at threshold 0.1: {'accuracy': [0.7827568580678139, 0.7766229340603169], 'recall': [0.29400196656833827, 0.11897738446411013], 'precision': [0.3492990654205608, 0.22574626865671643], 'auc': [0.589601972566939, 0.5167228224876198], 'f1': [0.3192738921516284, 0.15582743077913716], 'f2': [0.3036149471974005, 0.13140747176368375]}
# Evaluation for recall: [0.29400196656833827, 0.11897738446411013]
# Testing threshold: 0.12
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day']
# Remaining features after drop: 19
# Evaluation results at threshold 0.12: {'accuracy': [0.7827568580678139, 0.7766229340603169], 'recall': [0.29400196656833827, 0.11897738446411013], 'precision': [0.3492990654205608, 0.22574626865671643], 'auc': [0.589601972566939, 0.5167228224876198], 'f1': [0.3192738921516284, 0.15582743077913716], 'f2': [0.3036149471974005, 0.13140747176368375]}
# Evaluation for recall: [0.29400196656833827, 0.11897738446411013]
# Testing threshold: 0.14
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 17
# Evaluation results at threshold 0.14: {'accuracy': [0.7924689044130175, 0.7766229340603169], 'recall': [0.20943952802359883, 0.11897738446411013], 'precision': [0.3397129186602871, 0.22574626865671643], 'auc': [0.5620569445559049, 0.5167228224876198], 'f1': [0.2591240875912409, 0.15582743077913716], 'f2': [0.2268370607028754, 0.13140747176368375]}
# Evaluation for recall: [0.20943952802359883, 0.11897738446411013]
# Testing threshold: 0.16
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 17
# Evaluation results at threshold 0.16: {'accuracy': [0.7924689044130175, 0.7766229340603169], 'recall': [0.20943952802359883, 0.11897738446411013], 'precision': [0.3397129186602871, 0.22574626865671643], 'auc': [0.5620569445559049, 0.5167228224876198], 'f1': [0.2591240875912409, 0.15582743077913716], 'f2': [0.2268370607028754, 0.13140747176368375]}
# Evaluation for recall: [0.20943952802359883, 0.11897738446411013]
# Testing threshold: 0.18
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 17
# Evaluation results at threshold 0.18: {'accuracy': [0.7924689044130175, 0.7766229340603169], 'recall': [0.20943952802359883, 0.11897738446411013], 'precision': [0.3397129186602871, 0.22574626865671643], 'auc': [0.5620569445559049, 0.5167228224876198], 'f1': [0.2591240875912409, 0.15582743077913716], 'f2': [0.2268370607028754, 0.13140747176368375]}
# Evaluation for recall: [0.20943952802359883, 0.11897738446411013]
# Testing threshold: 0.2
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 17
# Evaluation results at threshold 0.2: {'accuracy': [0.7924689044130175, 0.7766229340603169], 'recall': [0.20943952802359883, 0.11897738446411013], 'precision': [0.3397129186602871, 0.22574626865671643], 'auc': [0.5620569445559049, 0.5167228224876198], 'f1': [0.2591240875912409, 0.15582743077913716], 'f2': [0.2268370607028754, 0.13140747176368375]}
# Evaluation for recall: [0.20943952802359883, 0.11897738446411013]
# Testing threshold: 0.22
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.22: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for recall: [0.19960668633235004, 0.10914454277286136]
# Testing threshold: 0.24
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.24: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for recall: [0.19960668633235004, 0.10914454277286136]
# Testing threshold: 0.26
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.26: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for recall: [0.19960668633235004, 0.10914454277286136]
# Testing threshold: 0.28
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.28: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for recall: [0.19960668633235004, 0.10914454277286136]
# Testing threshold: 0.3
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.3: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for recall: [0.19960668633235004, 0.10914454277286136]
# Testing threshold: 0.32
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.32: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for recall: [0.19960668633235004, 0.10914454277286136]
# Testing threshold: 0.34
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.34: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for recall: [0.19960668633235004, 0.10914454277286136]
# Testing threshold: 0.36
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.36: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for recall: [0.19960668633235004, 0.10914454277286136]
# Testing threshold: 0.38
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.38: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for recall: [0.19960668633235004, 0.10914454277286136]
# Testing threshold: 0.4
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.4: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for recall: [0.19960668633235004, 0.10914454277286136]
# Testing threshold: 0.42
# Dropping variables: ['day_of_month_cos', 'day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 15
# Evaluation results at threshold 0.42: {'accuracy': [0.7911058101891293, 0.7749190662804566], 'recall': [0.22025565388397247, 0.1111111111111111], 'precision': [0.3409436834094368, 0.21320754716981133], 'auc': [0.5655070520038163, 0.5125835852340387], 'f1': [0.26762246117084826, 0.14608920491273433], 'f2': [0.23703703703703705, 0.12287951283166594]}
# Evaluation for recall: [0.22025565388397247, 0.1111111111111111]
# Testing threshold: 0.44
# Dropping variables: ['day_of_month_cos', 'day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 15
# Evaluation results at threshold 0.44: {'accuracy': [0.7911058101891293, 0.7749190662804566], 'recall': [0.22025565388397247, 0.1111111111111111], 'precision': [0.3409436834094368, 0.21320754716981133], 'auc': [0.5655070520038163, 0.5125835852340387], 'f1': [0.26762246117084826, 0.14608920491273433], 'f2': [0.23703703703703705, 0.12287951283166594]}
# Evaluation for recall: [0.22025565388397247, 0.1111111111111111]
# Testing threshold: 0.46
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 13
# Evaluation results at threshold 0.46: {'accuracy': [0.8210938831146704, 0.7764525472823309], 'recall': [0.08947885939036382, 0.12389380530973451], 'precision': [0.4232558139534884, 0.2303473491773309], 'auc': [0.5319611939161217, 0.518562731179187], 'f1': [0.14772727272727273, 0.16112531969309463], 'f2': [0.10623394816717255, 0.13651137594799567]}
# Evaluation for recall: [0.08947885939036382, 0.12389380530973451]
# Testing threshold: 0.48
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 13
# Evaluation results at threshold 0.48: {'accuracy': [0.8210938831146704, 0.7764525472823309], 'recall': [0.08947885939036382, 0.12389380530973451], 'precision': [0.4232558139534884, 0.2303473491773309], 'auc': [0.5319611939161217, 0.518562731179187], 'f1': [0.14772727272727273, 0.16112531969309463], 'f2': [0.10623394816717255, 0.13651137594799567]}
# Evaluation for recall: [0.08947885939036382, 0.12389380530973451]
# Testing threshold: 0.5
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.5: {'accuracy': [0.8212642698926563, 0.7866757539614926], 'recall': [0.08259587020648967, 0.10619469026548672], 'precision': [0.42, 0.2394678492239468], 'auc': [0.5293441016325112, 0.5177510961632462], 'f1': [0.13804437140509448, 0.14713896457765668], 'f2': [0.09840674789128398, 0.11949546359814119]}
# Evaluation for recall: [0.08259587020648967, 0.10619469026548672]
# Testing threshold: 0.52
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.52: {'accuracy': [0.8212642698926563, 0.7866757539614926], 'recall': [0.08259587020648967, 0.10619469026548672], 'precision': [0.42, 0.2394678492239468], 'auc': [0.5293441016325112, 0.5177510961632462], 'f1': [0.13804437140509448, 0.14713896457765668], 'f2': [0.09840674789128398, 0.11949546359814119]}
# Evaluation for recall: [0.08259587020648967, 0.10619469026548672]
# Testing threshold: 0.54
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.54: {'accuracy': [0.8212642698926563, 0.7866757539614926], 'recall': [0.08259587020648967, 0.10619469026548672], 'precision': [0.42, 0.2394678492239468], 'auc': [0.5293441016325112, 0.5177510961632462], 'f1': [0.13804437140509448, 0.14713896457765668], 'f2': [0.09840674789128398, 0.11949546359814119]}
# Evaluation for recall: [0.08259587020648967, 0.10619469026548672]
# Testing threshold: 0.56
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.56: {'accuracy': [0.8212642698926563, 0.7866757539614926], 'recall': [0.08259587020648967, 0.10619469026548672], 'precision': [0.42, 0.2394678492239468], 'auc': [0.5293441016325112, 0.5177510961632462], 'f1': [0.13804437140509448, 0.14713896457765668], 'f2': [0.09840674789128398, 0.11949546359814119]}
# Evaluation for recall: [0.08259587020648967, 0.10619469026548672]
# Testing threshold: 0.58
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.58: {'accuracy': [0.8212642698926563, 0.7866757539614926], 'recall': [0.08259587020648967, 0.10619469026548672], 'precision': [0.42, 0.2394678492239468], 'auc': [0.5293441016325112, 0.5177510961632462], 'f1': [0.13804437140509448, 0.14713896457765668], 'f2': [0.09840674789128398, 0.11949546359814119]}
# Evaluation for recall: [0.08259587020648967, 0.10619469026548672]
# Testing threshold: 0.6
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.6: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for recall: [0.16125860373647985, 0.10816125860373647]
# Testing threshold: 0.62
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.62: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for recall: [0.16125860373647985, 0.10816125860373647]
# Testing threshold: 0.64
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.64: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for recall: [0.16125860373647985, 0.10816125860373647]
# Testing threshold: 0.66
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.66: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for recall: [0.16125860373647985, 0.10816125860373647]
# Testing threshold: 0.68
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.68: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for recall: [0.16125860373647985, 0.10816125860373647]
# Testing threshold: 0.7
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.7: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for recall: [0.16125860373647985, 0.10816125860373647]
# Testing threshold: 0.72
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.72: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for recall: [0.16125860373647985, 0.10816125860373647]
# Testing threshold: 0.74
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.74: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for recall: [0.16125860373647985, 0.10816125860373647]
# Testing threshold: 0.76
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.76: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for recall: [0.16125860373647985, 0.10816125860373647]
# Testing threshold: 0.78
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.78: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for recall: [0.16125860373647985, 0.10816125860373647]
# Testing threshold: 0.8
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.8: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for recall: [0.16125860373647985, 0.10816125860373647]

# %% [markdown]
# ### f2

# %%
if evaluate==True:

    eval_metric = "f2"
    figure(figsize=(2 * HEIGHT, HEIGHT))
    study_variance_for_feature_selection(
        train_sample,
        test_sample,
        target=target,
        max_threshold=max_thresh,
        lag=lag_variance,
        metric=eval_metric,
        file_tag=file_tag,
        min_features_to_keep = 3,  # Minimum features safeguard
        exclude=mandatory_cols
    )
    show()
# Out:
# Testing threshold: 0.02
# Dropping variables: ['subject_with_bonuses', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout']
# Remaining features after drop: 24
# Evaluation results at threshold 0.02: {'accuracy': [0.7619696711535184, 0.7802010563980235], 'recall': [0.34611602753195675, 0.09341199606686332], 'precision': [0.3247232472324723, 0.20518358531317496], 'auc': [0.597625202554107, 0.5087834918504144], 'f1': [0.33507853403141363, 0.12837837837837837], 'f2': [0.3416149068322981, 0.10483337011697197]}
# Evaluation for f2: [0.3416149068322981, 0.10483337011697197]
# Testing threshold: 0.04
# Dropping variables: ['subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout']
# Remaining features after drop: 23
# Evaluation results at threshold 0.04: {'accuracy': [0.7619696711535184, 0.7802010563980235], 'recall': [0.34611602753195675, 0.09341199606686332], 'precision': [0.3247232472324723, 0.20518358531317496], 'auc': [0.597625202554107, 0.5087834918504144], 'f1': [0.33507853403141363, 0.12837837837837837], 'f2': [0.3416149068322981, 0.10483337011697197]}
# Evaluation for f2: [0.3416149068322981, 0.10483337011697197]
# Testing threshold: 0.06
# Dropping variables: ['is_weekend', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout']
# Remaining features after drop: 22
# Evaluation results at threshold 0.06: {'accuracy': [0.7631623785994207, 0.7788379621741353], 'recall': [0.2969518190757129, 0.09341199606686332], 'precision': [0.3091095189355169, 0.20169851380042464], 'auc': [0.5789169647728112, 0.5079590895420879], 'f1': [0.3029087261785356, 0.12768817204301075], 'f2': [0.2993062438057483, 0.10464860101343908]}
# Evaluation for f2: [0.2993062438057483, 0.10464860101343908]
# Testing threshold: 0.08
# Dropping variables: ['hour_cos', 'is_weekend', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day']
# Remaining features after drop: 20
# Evaluation results at threshold 0.08: {'accuracy': [0.777134094394275, 0.7762821605043448], 'recall': [0.29891838741396265, 0.11209439528023599], 'precision': [0.3381535038932147, 0.21755725190839695], 'auc': [0.5881442720252007, 0.5137965793383867], 'f1': [0.3173277661795407, 0.14795587280986372], 'f2': [0.30601973021944834, 0.12412891986062717]}
# Evaluation for f2: [0.30601973021944834, 0.12412891986062717]
# Testing threshold: 0.1
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day']
# Remaining features after drop: 19
# Evaluation results at threshold 0.1: {'accuracy': [0.7827568580678139, 0.7766229340603169], 'recall': [0.29400196656833827, 0.11897738446411013], 'precision': [0.3492990654205608, 0.22574626865671643], 'auc': [0.589601972566939, 0.5167228224876198], 'f1': [0.3192738921516284, 0.15582743077913716], 'f2': [0.3036149471974005, 0.13140747176368375]}
# Evaluation for f2: [0.3036149471974005, 0.13140747176368375]
# Testing threshold: 0.12
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day']
# Remaining features after drop: 19
# Evaluation results at threshold 0.12: {'accuracy': [0.7827568580678139, 0.7766229340603169], 'recall': [0.29400196656833827, 0.11897738446411013], 'precision': [0.3492990654205608, 0.22574626865671643], 'auc': [0.589601972566939, 0.5167228224876198], 'f1': [0.3192738921516284, 0.15582743077913716], 'f2': [0.3036149471974005, 0.13140747176368375]}
# Evaluation for f2: [0.3036149471974005, 0.13140747176368375]
# Testing threshold: 0.14
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 17
# Evaluation results at threshold 0.14: {'accuracy': [0.7924689044130175, 0.7766229340603169], 'recall': [0.20943952802359883, 0.11897738446411013], 'precision': [0.3397129186602871, 0.22574626865671643], 'auc': [0.5620569445559049, 0.5167228224876198], 'f1': [0.2591240875912409, 0.15582743077913716], 'f2': [0.2268370607028754, 0.13140747176368375]}
# Evaluation for f2: [0.2268370607028754, 0.13140747176368375]
# Testing threshold: 0.16
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 17
# Evaluation results at threshold 0.16: {'accuracy': [0.7924689044130175, 0.7766229340603169], 'recall': [0.20943952802359883, 0.11897738446411013], 'precision': [0.3397129186602871, 0.22574626865671643], 'auc': [0.5620569445559049, 0.5167228224876198], 'f1': [0.2591240875912409, 0.15582743077913716], 'f2': [0.2268370607028754, 0.13140747176368375]}
# Evaluation for f2: [0.2268370607028754, 0.13140747176368375]
# Testing threshold: 0.18
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 17
# Evaluation results at threshold 0.18: {'accuracy': [0.7924689044130175, 0.7766229340603169], 'recall': [0.20943952802359883, 0.11897738446411013], 'precision': [0.3397129186602871, 0.22574626865671643], 'auc': [0.5620569445559049, 0.5167228224876198], 'f1': [0.2591240875912409, 0.15582743077913716], 'f2': [0.2268370607028754, 0.13140747176368375]}
# Evaluation for f2: [0.2268370607028754, 0.13140747176368375]
# Testing threshold: 0.2
# Dropping variables: ['hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 17
# Evaluation results at threshold 0.2: {'accuracy': [0.7924689044130175, 0.7766229340603169], 'recall': [0.20943952802359883, 0.11897738446411013], 'precision': [0.3397129186602871, 0.22574626865671643], 'auc': [0.5620569445559049, 0.5167228224876198], 'f1': [0.2591240875912409, 0.15582743077913716], 'f2': [0.2268370607028754, 0.13140747176368375]}
# Evaluation for f2: [0.2268370607028754, 0.13140747176368375]
# Testing threshold: 0.22
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.22: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for f2: [0.22089227421109903, 0.12088869527336092]
# Testing threshold: 0.24
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.24: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for f2: [0.22089227421109903, 0.12088869527336092]
# Testing threshold: 0.26
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.26: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for f2: [0.22089227421109903, 0.12088869527336092]
# Testing threshold: 0.28
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.28: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for f2: [0.22089227421109903, 0.12088869527336092]
# Testing threshold: 0.3
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.3: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for f2: [0.22089227421109903, 0.12088869527336092]
# Testing threshold: 0.32
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.32: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for f2: [0.22089227421109903, 0.12088869527336092]
# Testing threshold: 0.34
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.34: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for f2: [0.22089227421109903, 0.12088869527336092]
# Testing threshold: 0.36
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.36: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for f2: [0.22089227421109903, 0.12088869527336092]
# Testing threshold: 0.38
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.38: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for f2: [0.22089227421109903, 0.12088869527336092]
# Testing threshold: 0.4
# Dropping variables: ['day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 16
# Evaluation results at threshold 0.4: {'accuracy': [0.8060998466518998, 0.7754302266144147], 'recall': [0.19960668633235004, 0.10914454277286136], 'precision': [0.38519924098671726, 0.21223709369024857], 'auc': [0.5664150496789532, 0.5121155525076179], 'f1': [0.26295336787564766, 0.14415584415584415], 'f2': [0.22089227421109903, 0.12088869527336092]}
# Evaluation for f2: [0.22089227421109903, 0.12088869527336092]
# Testing threshold: 0.42
# Dropping variables: ['day_of_month_cos', 'day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 15
# Evaluation results at threshold 0.42: {'accuracy': [0.7911058101891293, 0.7749190662804566], 'recall': [0.22025565388397247, 0.1111111111111111], 'precision': [0.3409436834094368, 0.21320754716981133], 'auc': [0.5655070520038163, 0.5125835852340387], 'f1': [0.26762246117084826, 0.14608920491273433], 'f2': [0.23703703703703705, 0.12287951283166594]}
# Evaluation for f2: [0.23703703703703705, 0.12287951283166594]
# Testing threshold: 0.44
# Dropping variables: ['day_of_month_cos', 'day_of_week_nr_cos', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 15
# Evaluation results at threshold 0.44: {'accuracy': [0.7911058101891293, 0.7749190662804566], 'recall': [0.22025565388397247, 0.1111111111111111], 'precision': [0.3409436834094368, 0.21320754716981133], 'auc': [0.5655070520038163, 0.5125835852340387], 'f1': [0.26762246117084826, 0.14608920491273433], 'f2': [0.23703703703703705, 0.12287951283166594]}
# Evaluation for f2: [0.23703703703703705, 0.12287951283166594]
# Testing threshold: 0.46
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 13
# Evaluation results at threshold 0.46: {'accuracy': [0.8210938831146704, 0.7764525472823309], 'recall': [0.08947885939036382, 0.12389380530973451], 'precision': [0.4232558139534884, 0.2303473491773309], 'auc': [0.5319611939161217, 0.518562731179187], 'f1': [0.14772727272727273, 0.16112531969309463], 'f2': [0.10623394816717255, 0.13651137594799567]}
# Evaluation for f2: [0.10623394816717255, 0.13651137594799567]
# Testing threshold: 0.48
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 13
# Evaluation results at threshold 0.48: {'accuracy': [0.8210938831146704, 0.7764525472823309], 'recall': [0.08947885939036382, 0.12389380530973451], 'precision': [0.4232558139534884, 0.2303473491773309], 'auc': [0.5319611939161217, 0.518562731179187], 'f1': [0.14772727272727273, 0.16112531969309463], 'f2': [0.10623394816717255, 0.13651137594799567]}
# Evaluation for f2: [0.10623394816717255, 0.13651137594799567]
# Testing threshold: 0.5
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.5: {'accuracy': [0.8212642698926563, 0.7866757539614926], 'recall': [0.08259587020648967, 0.10619469026548672], 'precision': [0.42, 0.2394678492239468], 'auc': [0.5293441016325112, 0.5177510961632462], 'f1': [0.13804437140509448, 0.14713896457765668], 'f2': [0.09840674789128398, 0.11949546359814119]}
# Evaluation for f2: [0.09840674789128398, 0.11949546359814119]
# Testing threshold: 0.52
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.52: {'accuracy': [0.8212642698926563, 0.7866757539614926], 'recall': [0.08259587020648967, 0.10619469026548672], 'precision': [0.42, 0.2394678492239468], 'auc': [0.5293441016325112, 0.5177510961632462], 'f1': [0.13804437140509448, 0.14713896457765668], 'f2': [0.09840674789128398, 0.11949546359814119]}
# Evaluation for f2: [0.09840674789128398, 0.11949546359814119]
# Testing threshold: 0.54
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.54: {'accuracy': [0.8212642698926563, 0.7866757539614926], 'recall': [0.08259587020648967, 0.10619469026548672], 'precision': [0.42, 0.2394678492239468], 'auc': [0.5293441016325112, 0.5177510961632462], 'f1': [0.13804437140509448, 0.14713896457765668], 'f2': [0.09840674789128398, 0.11949546359814119]}
# Evaluation for f2: [0.09840674789128398, 0.11949546359814119]
# Testing threshold: 0.56
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.56: {'accuracy': [0.8212642698926563, 0.7866757539614926], 'recall': [0.08259587020648967, 0.10619469026548672], 'precision': [0.42, 0.2394678492239468], 'auc': [0.5293441016325112, 0.5177510961632462], 'f1': [0.13804437140509448, 0.14713896457765668], 'f2': [0.09840674789128398, 0.11949546359814119]}
# Evaluation for f2: [0.09840674789128398, 0.11949546359814119]
# Testing threshold: 0.58
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 11
# Evaluation results at threshold 0.58: {'accuracy': [0.8212642698926563, 0.7866757539614926], 'recall': [0.08259587020648967, 0.10619469026548672], 'precision': [0.42, 0.2394678492239468], 'auc': [0.5293441016325112, 0.5177510961632462], 'f1': [0.13804437140509448, 0.14713896457765668], 'f2': [0.09840674789128398, 0.11949546359814119]}
# Evaluation for f2: [0.09840674789128398, 0.11949546359814119]
# Testing threshold: 0.6
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.6: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for f2: [0.1848512173128945, 0.12165450121654502]
# Testing threshold: 0.62
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.62: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for f2: [0.1848512173128945, 0.12165450121654502]
# Testing threshold: 0.64
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.64: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for f2: [0.1848512173128945, 0.12165450121654502]
# Testing threshold: 0.66
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.66: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for f2: [0.1848512173128945, 0.12165450121654502]
# Testing threshold: 0.68
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.68: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for f2: [0.1848512173128945, 0.12165450121654502]
# Testing threshold: 0.7
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.7: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for f2: [0.1848512173128945, 0.12165450121654502]
# Testing threshold: 0.72
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.72: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for f2: [0.1848512173128945, 0.12165450121654502]
# Testing threshold: 0.74
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.74: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for f2: [0.1848512173128945, 0.12165450121654502]
# Testing threshold: 0.76
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.76: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for f2: [0.1848512173128945, 0.12165450121654502]
# Testing threshold: 0.78
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.78: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for f2: [0.1848512173128945, 0.12165450121654502]
# Testing threshold: 0.8
# Dropping variables: ['campaign_type', 'day_of_month_cos', 'day_of_month_sin', 'day_of_week_nr_cos', 'day_of_week_nr_sin', 'hour_cos', 'hour_sin', 'is_weekend', 'min_cos', 'min_sin', 'month', 'subject_with_bonuses', 'subject_with_deadline', 'subject_with_discount', 'subject_with_personalization', 'subject_with_saleout', 'time_of_day', 'week_of_month_cos']
# Remaining features after drop: 10
# Evaluation results at threshold 0.8: {'accuracy': [0.8199011756687681, 0.7870165275174646], 'recall': [0.16125860373647985, 0.10816125860373647], 'precision': [0.44565217391304346, 0.24282560706401765], 'auc': [0.559607043005915, 0.5187343803323711], 'f1': [0.2368231046931408, 0.14965986394557823], 'f2': [0.1848512173128945, 0.12165450121654502]}
# Evaluation for f2: [0.1848512173128945, 0.12165450121654502]

# %% [markdown]
# ### accuracy study

# %%
#f evaluate==True:
#
#   eval_metric = "accuracy"
#   figure(figsize=(2 * HEIGHT, HEIGHT))
#   study_variance_for_feature_selection(
#       train_sample,
#       test_sample,
#       target=target,
#       max_threshold=0.1,
#       lag=0.003,
#       metric=eval_metric,
#       file_tag=file_tag,
#       min_features_to_keep = 10  # Minimum features safeguard
#        exclude=mandatory_cols
#
#   )
#   show()

# %% [markdown]
# ## Feat 1 strategy Application

# %%
from pandas import DataFrame, Index

def apply_strategy_1(df: DataFrame) -> DataFrame:

    # this script is available in data_functions originally from DSLabs site in Feature Selection chapter
    # threshold drop on recall nb is around 0.4 but precision increases
    df_copy=apply_remove_low_variance_variables(df,max_threshold=0.065, target=target, min_features_to_keep=3, exclude=mandatory_cols)
    

    return df_copy


data_1=apply_strategy_1(data)

data_1.describe()
# Out:
# Variance threshold: 0.065, Remaining features: 16
# Variables to drop: ['subject_with_personalization', 'subject_with_deadline', 'subject_with_bonuses', 'subject_with_discount', 'subject_with_saleout']
# columns to drop: ['subject_with_personalization', 'subject_with_deadline', 'subject_with_bonuses', 'subject_with_discount', 'subject_with_saleout']
# Remaining columns: Index(['platform', 'email_provider', 'campaign_type', 'channel_cmp', 'topic',
#        'total_count', 'subject_length', 'day_of_year', 'month', 'hour_sin',
#        'hour_cos', 'min_sin', 'min_cos', 'day_of_month_sin',
#        'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos',
#        'week_of_month_sin', 'week_of_month_cos', 'is_clicked',
#        'subject_with_emoji', 'is_weekend', 'time_of_day'],
#       dtype='object')
#             platform  email_provider  campaign_type    channel_cmp  \
# count  195562.000000   195562.000000  195562.000000  195562.000000
# mean        2.315131        1.753028       0.408024       1.217440
# std         0.853895        3.630298       0.759341       0.710786
# min         0.000000        0.000000       0.000000       0.000000
# 25%         2.315131        1.000000       0.000000       1.000000
# 50%         2.315131        1.753028       0.000000       1.000000
# 75%         3.000000        1.753028       0.000000       2.000000
# max         3.000000      187.000000       2.000000       2.000000
#
#                topic   total_count  subject_length    day_of_year  \
# count  195562.000000  1.955620e+05   195562.000000  195562.000000
# mean       13.127218  6.166253e+05      111.673004     138.209366
# std         4.006549  3.231069e+05       17.627397      12.213370
# min         0.000000  4.000000e+00       74.563519     120.000000
# 25%        15.000000  2.830630e+05       97.000000     126.000000
# 50%        15.000000  6.166253e+05      111.685307     140.000000
# 75%        15.000000  9.218380e+05      133.000000     146.000000
# max        17.000000  1.045217e+06      148.807096     165.000000
#
#                month       hour_sin  ...  day_of_month_sin  day_of_month_cos  \
# count  195562.000000  195562.000000  ...     195562.000000     195562.000000
# mean        1.054898       0.668494  ...         -0.007863          0.044449
# std         0.524333       0.353231  ...          0.772670          0.633278
# min         0.000000      -0.243735  ...         -0.999000         -0.995000
# 25%         1.000000       0.631000  ...         -0.849000         -0.440000
# 50%         1.000000       0.817000  ...         -0.201000          0.151000
# 75%         1.000000       0.942000  ...          0.898000          0.689000
# max         2.000000       0.998000  ...          0.999000          1.000000
#
#        day_of_week_nr_sin  day_of_week_nr_cos  week_of_month_sin  \
# count       195562.000000       195562.000000      195562.000000
# mean            -0.163571           -0.407341           0.125377
# std              0.626387            0.626129           0.835143
# min             -0.866000           -1.000000          -1.000000
# 25%             -0.866000           -1.000000          -1.000000
# 50%             -0.000000           -0.500000           0.000000
# 75%              0.000000           -0.500000           1.000000
# max              0.866000            0.907847           1.000000
#
#        week_of_month_cos     is_clicked  subject_with_emoji     is_weekend  \
# count      195562.000000  195562.000000        195562.00000  195562.000000
# mean           -0.031494       0.126650             0.94412       0.072734
# std             0.534630       0.332582             0.22969       0.259700
# min            -1.000000       0.000000             0.00000       0.000000
# 25%             0.000000       0.000000             1.00000       0.000000
# 50%             0.000000       0.000000             1.00000       0.000000
# 75%             0.000000       0.000000             1.00000       0.000000
# max             1.000000       1.000000             1.00000       1.000000
#
#         time_of_day
# count  195562.00000
# mean        0.10232
# std         0.30307
# min         0.00000
# 25%         0.00000
# 50%         0.00000
# 75%         0.00000
# max         1.00000
#
# [8 rows x 23 columns]

# %% [markdown]
# From DT algorithm relevante columns (precision):
# 1. channel_cmp (0.7548027155610093)
# 2. platform (0.0606325816842923)
# 3. campaign_type (0.042999446407918834)
# 4. topic (0.028237188880846933)
# 5. email_provider (0.02466188779051527)
# 6. min_cos (0.020560309249891363)
# 7. min_sin (0.018395078964791662)
# 8. day_of_month_cos (0.01681484946535776)
# 9. subject_length (0.006513235080127591)

# %% [markdown]
# ## Feat 1 train/test split

# %%
if evaluate==True:

    from pandas import concat
    from matplotlib.pyplot import figure, show
    from sklearn.model_selection import train_test_split
    from dslabs_functions import plot_multibar_chart

    # Call the function to split the data
    from numpy import array, ndarray

    y_1, X_1, labels, values = define_target_and_prepare_data(data_1, target)

    train_1, test_1 = split_data_save_csv(pd.DataFrame(X_1, columns=data_1.columns), y_1, data_columns=data_1.columns, target_column=target)

    # Distribution check
    values["Train"] = [
        len(train_1[train_1[target] == 0]),
        len(train_1[train_1[target] == 1]),
    ]
    values["Test"] = [
        len(test_1[test_1[target] == 0]),
        len(test_1[test_1[target] == 1]),
    ]

    # Visualize the distribution
    figure(figsize=(6, 4))
    plot_multibar_chart(labels, values, title="Data distribution per dataset")
    show()
# Out:
# Labels=[0.0, 1.0]

# %% [markdown]
# ## Feat 1 evaluate

# %%
if evaluate==True:

    # evaluate_approach is in data_functions originally from DSLABS/ Data Prep / Methodology
    # removed Multinomial from run_NB function because dataset has negative values

    figure()
    eval_1: dict[str, list] = evaluate_approach(train_1, test_1, target='is_clicked', metric=target_metric)
    plot_multibar_chart(
        ["NB", "KNN"], eval_1, title=f"{file_tag}_1_evaluation", percentage=True
    )
    savefig(f"images/{file_tag}_1_evaluation.png")
    show()

# %% [markdown]
# # Feat 2 - Dropping Redundant Variables

# %% [markdown]
# ## Feat 2 - Study redundant variables and threshold

# %%
min_thresh=0.05
lag_redundacy=0.05
mandatory_cols=['channel_cmp', 'total_count','topic', 'subject_length', 
                'email_provider', "platform", "subject_with_emoji"]

# %% [markdown]
# ### precision

# %%
if evaluate==True:

    # modified study_variance_for_feature_selection() in dslabs functions to keep minimum variables and print metrics (due to error)


    eval_metric = "precision"
    figure(figsize=(2 * HEIGHT, HEIGHT))
    study_redundancy_for_feature_selection(
        train_sample,
        test_sample,
        target=target,
        min_threshold = min_thresh,
        lag = lag_redundacy,
        metric=eval_metric,
        file_tag=file_tag,
        exclude=mandatory_cols
    
    )
    show()
# Out:
# Columns in the train dataset: ['campaign_type', 'day_of_year', 'month', 'hour_sin', 'hour_cos', 'min_sin', 'min_cos', 'day_of_month_sin', 'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'week_of_month_sin', 'week_of_month_cos', 'subject_with_personalization', 'subject_with_deadline', 'subject_with_bonuses', 'subject_with_discount', 'subject_with_saleout', 'is_weekend', 'time_of_day']
# Variables considered for correlation: ['campaign_type', 'day_of_year', 'month', 'hour_sin', 'hour_cos', 'min_sin', 'min_cos', 'day_of_month_sin', 'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'week_of_month_sin', 'week_of_month_cos', 'subject_with_personalization', 'subject_with_deadline', 'subject_with_bonuses', 'subject_with_discount', 'subject_with_saleout', 'is_weekend', 'time_of_day']
# Variables to drop at threshold 0.05: ['month', 'hour_sin', 'hour_cos', 'day_of_month_sin', 'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'week_of_month_cos', 'subject_with_deadline', 'subject_with_bonuses', 'is_weekend', 'time_of_day', 'min_sin', 'min_cos', 'week_of_month_sin', 'campaign_type', 'day_of_year']
# Evaluation results at threshold 0.05: {'accuracy': [0.7997955358664167, 0.837110240245357], 'recall': [0.04129793510324484, 0.13274336283185842], 'precision': [0.17355371900826447, 0.645933014354067], 'auc': [0.5000389098434608, 0.5587459600639094], 'f1': [0.06671961874503574, 0.22022838499184338], 'f2': [0.048723897911832945, 0.15782090250175357]}
# Evaluation for precision: [0.17355371900826447, 0.645933014354067]
# Variables to drop at threshold 0.1: ['month', 'hour_sin', 'hour_cos', 'day_of_month_sin', 'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'week_of_month_cos', 'subject_with_bonuses', 'is_weekend', 'time_of_day', 'min_cos', 'week_of_month_sin', 'campaign_type', 'day_of_year', 'min_sin', 'subject_with_deadline']
# Evaluation results at threshold 0.1: {'accuracy': [0.7997955358664167, 0.837110240245357], 'recall': [0.04129793510324484, 0.13274336283185842], 'precision': [0.17355371900826447, 0.645933014354067], 'auc': [0.5000389098434608, 0.5587459600639094], 'f1': [0.06671961874503574, 0.22022838499184338], 'f2': [0.048723897911832945, 0.15782090250175357]}
# Evaluation for precision: [0.17355371900826447, 0.645933014354067]
# Variables to drop at threshold 0.15: ['hour_sin', 'hour_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'min_cos', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'campaign_type', 'week_of_month_cos', 'subject_with_bonuses', 'subject_with_deadline']
# Evaluation results at threshold 0.15: {'accuracy': [0.8032032714261373, 0.8328505707957062], 'recall': [0.14749262536873156, 0.13077679449360866], 'precision': [0.3424657534246575, 0.5782608695652174], 'auc': [0.5440678295846132, 0.555392519258346], 'f1': [0.20618556701030927, 0.21331194867682438], 'f2': [0.16644474034620507, 0.15472312703583063]}
# Evaluation for precision: [0.3424657534246575, 0.5782608695652174]
# Variables to drop at threshold 0.2: ['hour_sin', 'day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'min_cos', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'campaign_type', 'hour_cos', 'week_of_month_cos']
# Evaluation results at threshold 0.2: {'accuracy': [0.7997955358664167, 0.8328505707957062], 'recall': [0.04129793510324484, 0.13077679449360866], 'precision': [0.17355371900826447, 0.5782608695652174], 'auc': [0.5000389098434608, 0.555392519258346], 'f1': [0.06671961874503574, 0.21331194867682438], 'f2': [0.048723897911832945, 0.15472312703583063]}
# Evaluation for precision: [0.17355371900826447, 0.5782608695652174]
# Variables to drop at threshold 0.25: ['hour_sin', 'day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'campaign_type', 'hour_cos', 'week_of_month_cos', 'min_cos']
# Evaluation results at threshold 0.25: {'accuracy': [0.7997955358664167, 0.8328505707957062], 'recall': [0.04129793510324484, 0.13077679449360866], 'precision': [0.17355371900826447, 0.5782608695652174], 'auc': [0.5000389098434608, 0.555392519258346], 'f1': [0.06671961874503574, 0.21331194867682438], 'f2': [0.048723897911832945, 0.15472312703583063]}
# Evaluation for precision: [0.17355371900826447, 0.5782608695652174]
# Variables to drop at threshold 0.3: ['hour_sin', 'day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'campaign_type', 'hour_cos', 'week_of_month_cos']
# Evaluation results at threshold 0.3: {'accuracy': [0.7972397341966263, 0.8287612881240416], 'recall': [0.08062930186823992, 0.1376597836774828], 'precision': [0.2433234421364985, 0.5223880597014925], 'auc': [0.5140368273562139, 0.555639454905518], 'f1': [0.12112259970457903, 0.2178988326848249], 'f2': [0.09307604994324631, 0.16143911439114392]}
# Evaluation for precision: [0.2433234421364985, 0.5223880597014925]
# Variables to drop at threshold 0.35: ['day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'hour_cos', 'week_of_month_cos', 'campaign_type', 'hour_sin']
# Evaluation results at threshold 0.35: {'accuracy': [0.7972397341966263, 0.8287612881240416], 'recall': [0.08062930186823992, 0.1376597836774828], 'precision': [0.2433234421364985, 0.5223880597014925], 'auc': [0.5140368273562139, 0.555639454905518], 'f1': [0.12112259970457903, 0.2178988326848249], 'f2': [0.09307604994324631, 0.16143911439114392]}
# Evaluation for precision: [0.2433234421364985, 0.5223880597014925]
# Variables to drop at threshold 0.4: ['day_of_week_nr_cos', 'is_weekend', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'hour_cos', 'time_of_day', 'week_of_month_cos', 'campaign_type']
# Evaluation results at threshold 0.4: {'accuracy': [0.7912761969671154, 0.8297836087919578], 'recall': [0.14454277286135694, 0.127826941986234], 'precision': [0.29282868525896416, 0.5371900826446281], 'auc': [0.5356885339986917, 0.5523718386765466], 'f1': [0.1935483870967742, 0.20651310563939634], 'f2': [0.16083150984682712, 0.15081206496519722]}
# Evaluation for precision: [0.29282868525896416, 0.5371900826446281]
# Variables to drop at threshold 0.45: ['day_of_week_nr_cos', 'is_weekend', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'hour_cos', 'time_of_day', 'day_of_week_nr_sin', 'week_of_month_cos', 'campaign_type']
# Evaluation results at threshold 0.45: {'accuracy': [0.7912761969671154, 0.8297836087919578], 'recall': [0.14454277286135694, 0.127826941986234], 'precision': [0.29282868525896416, 0.5371900826446281], 'auc': [0.5356885339986917, 0.5523718386765466], 'f1': [0.1935483870967742, 0.20651310563939634], 'f2': [0.16083150984682712, 0.15081206496519722]}
# Evaluation for precision: [0.29282868525896416, 0.5371900826446281]
# Variables to drop at threshold 0.5: ['month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'hour_cos', 'time_of_day', 'campaign_type', 'is_weekend']
# Evaluation results at threshold 0.5: {'accuracy': [0.7359004941216561, 0.8241608451184188], 'recall': [0.2782694198623402, 0.10226155358898721], 'precision': [0.2575068243858053, 0.4663677130044843], 'auc': [0.5550456744818709, 0.5388677924581374], 'f1': [0.2674858223062382, 0.16774193548387098], 'f2': [0.2738532997871105, 0.12118387322302493]}
# Evaluation for precision: [0.2575068243858053, 0.4663677130044843]
# Variables to drop at threshold 0.55: ['month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'hour_cos', 'time_of_day', 'campaign_type', 'is_weekend']
# Evaluation results at threshold 0.55: {'accuracy': [0.7359004941216561, 0.8241608451184188], 'recall': [0.2782694198623402, 0.10226155358898721], 'precision': [0.2575068243858053, 0.4663677130044843], 'auc': [0.5550456744818709, 0.5388677924581374], 'f1': [0.2674858223062382, 0.16774193548387098], 'f2': [0.2738532997871105, 0.12118387322302493]}
# Evaluation for precision: [0.2575068243858053, 0.4663677130044843]
# Variables to drop at threshold 0.6: ['month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'hour_cos', 'time_of_day', 'campaign_type', 'is_weekend']
# Evaluation results at threshold 0.6: {'accuracy': [0.7359004941216561, 0.8241608451184188], 'recall': [0.2782694198623402, 0.10226155358898721], 'precision': [0.2575068243858053, 0.4663677130044843], 'auc': [0.5550456744818709, 0.5388677924581374], 'f1': [0.2674858223062382, 0.16774193548387098], 'f2': [0.2738532997871105, 0.12118387322302493]}
# Evaluation for precision: [0.2575068243858053, 0.4663677130044843]
# Variables to drop at threshold 0.65: ['day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'month']
# Evaluation results at threshold 0.65: {'accuracy': [0.6668938490373147, 0.8241608451184188], 'recall': [0.49852507374631266, 0.08161258603736479], 'precision': [0.25973360655737704, 0.4585635359116022], 'auc': [0.600354869931689, 0.5307073647416833], 'f1': [0.34152913438868304, 0.13856427378964942], 'f2': [0.4210963455149502, 0.09767004000941398]}
# Evaluation for precision: [0.25973360655737704, 0.4585635359116022]
# Variables to drop at threshold 0.7: ['day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'month', 'day_of_month_sin']
# Evaluation results at threshold 0.7: {'accuracy': [0.6668938490373147, 0.8241608451184188], 'recall': [0.49852507374631266, 0.08161258603736479], 'precision': [0.25973360655737704, 0.4585635359116022], 'auc': [0.600354869931689, 0.5307073647416833], 'f1': [0.34152913438868304, 0.13856427378964942], 'f2': [0.4210963455149502, 0.09767004000941398]}
# Evaluation for precision: [0.25973360655737704, 0.4585635359116022]
# Variables to drop at threshold 0.75: ['day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_month_sin']
# Evaluation results at threshold 0.75: {'accuracy': [0.656500255580167, 0.8265462600102232], 'recall': [0.5093411996066863, 0.10422812192723697], 'precision': [0.2545454545454545, 0.49765258215962443], 'auc': [0.5983433120869376, 0.541087680089752], 'f1': [0.3394495412844037, 0.17235772357723578], 'f2': [0.42438145174504344, 0.12380284980144826]}
# Evaluation for precision: [0.2545454545454545, 0.49765258215962443]
# Variables to drop at threshold 0.8: ['day_of_month_cos', 'week_of_month_sin', 'day_of_year']
# Evaluation results at threshold 0.8: {'accuracy': [0.6803544044982109, 0.8245016186743909], 'recall': [0.46214355948869223, 0.0943952802359882], 'precision': [0.2612562534741523, 0.4682926829268293], 'auc': [0.5941179462736124, 0.5359651586670461], 'f1': [0.3338068181818182, 0.15711947626841244], 'f2': [0.4005454235554798, 0.11233325532412824]}
# Evaluation for precision: [0.2612562534741523, 0.4682926829268293]
# Variables to drop at threshold 0.85: ['day_of_month_cos', 'week_of_month_sin']
# Evaluation results at threshold 0.85: {'accuracy': [0.6803544044982109, 0.7813937638439257], 'recall': [0.46214355948869223, 0.10127826941986234], 'precision': [0.2612562534741523, 0.21822033898305085], 'auc': [0.5941179462736124, 0.5126135782383731], 'f1': [0.3338068181818182, 0.13834788448623236], 'f2': [0.4005454235554798, 0.11343612334801761]}
# Evaluation for precision: [0.2612562534741523, 0.21822033898305085]
# Variables to drop at threshold 0.9: []
# Evaluation results at threshold 0.9: {'accuracy': [0.753279945476231, 0.7798602828420514], 'recall': [0.35889872173058013, 0.0943952802359882], 'precision': [0.3143841515934539, 0.20556745182012848], 'auc': [0.597421331186807, 0.5089659830693544], 'f1': [0.3351698806244261, 0.1293800539083558], 'f2': [0.34901510805125263, 0.10584343991179714]}
# Evaluation for precision: [0.3143841515934539, 0.20556745182012848]
# Variables to drop at threshold 0.95: []
# Evaluation results at threshold 0.95: {'accuracy': [0.753279945476231, 0.7798602828420514], 'recall': [0.35889872173058013, 0.0943952802359882], 'precision': [0.3143841515934539, 0.20556745182012848], 'auc': [0.597421331186807, 0.5089659830693544], 'f1': [0.3351698806244261, 0.1293800539083558], 'f2': [0.34901510805125263, 0.10584343991179714]}
# Evaluation for precision: [0.3143841515934539, 0.20556745182012848]
# Variables to drop at threshold 1.0: []
# Evaluation results at threshold 1.0: {'accuracy': [0.753279945476231, 0.7798602828420514], 'recall': [0.35889872173058013, 0.0943952802359882], 'precision': [0.3143841515934539, 0.20556745182012848], 'auc': [0.597421331186807, 0.5089659830693544], 'f1': [0.3351698806244261, 0.1293800539083558], 'f2': [0.34901510805125263, 0.10584343991179714]}
# Evaluation for precision: [0.3143841515934539, 0.20556745182012848]

# %% [markdown]
# ### recall

# %%
if evaluate==True:

    # modified study_variance_for_feature_selection() in dslabs functions to keep minimum variables and print metrics (due to error)


    eval_metric = "recall"
    figure(figsize=(2 * HEIGHT, HEIGHT))
    study_redundancy_for_feature_selection(
        train_sample,
        test_sample,
        target=target,
        min_threshold = min_thresh,
        lag = lag_redundacy,
        metric=eval_metric,
        file_tag=file_tag,
        exclude=mandatory_cols
    )
    show()
# Out:
# Columns in the train dataset: ['campaign_type', 'day_of_year', 'month', 'hour_sin', 'hour_cos', 'min_sin', 'min_cos', 'day_of_month_sin', 'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'week_of_month_sin', 'week_of_month_cos', 'subject_with_personalization', 'subject_with_deadline', 'subject_with_bonuses', 'subject_with_discount', 'subject_with_saleout', 'is_weekend', 'time_of_day']
# Variables considered for correlation: ['campaign_type', 'day_of_year', 'month', 'hour_sin', 'hour_cos', 'min_sin', 'min_cos', 'day_of_month_sin', 'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'week_of_month_sin', 'week_of_month_cos', 'subject_with_personalization', 'subject_with_deadline', 'subject_with_bonuses', 'subject_with_discount', 'subject_with_saleout', 'is_weekend', 'time_of_day']
# Variables to drop at threshold 0.05: ['month', 'hour_sin', 'hour_cos', 'day_of_month_sin', 'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'week_of_month_cos', 'subject_with_deadline', 'subject_with_bonuses', 'is_weekend', 'time_of_day', 'min_sin', 'min_cos', 'week_of_month_sin', 'campaign_type', 'day_of_year']
# Evaluation results at threshold 0.05: {'accuracy': [0.7997955358664167, 0.801158630090305], 'recall': [0.04129793510324484, 0.2025565388397247], 'precision': [0.17355371900826447, 0.3665480427046263], 'auc': [0.5000389098434608, 0.5645923666993348], 'f1': [0.06671961874503574, 0.2609246358454718], 'f2': [0.048723897911832945, 0.2224622030237581]}
# Evaluation for recall: [0.04129793510324484, 0.2025565388397247]
# Variables to drop at threshold 0.1: ['month', 'hour_sin', 'hour_cos', 'day_of_month_sin', 'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'week_of_month_cos', 'subject_with_bonuses', 'is_weekend', 'time_of_day', 'min_cos', 'week_of_month_sin', 'campaign_type', 'day_of_year', 'min_sin', 'subject_with_deadline']
# Evaluation results at threshold 0.1: {'accuracy': [0.7997955358664167, 0.801158630090305], 'recall': [0.04129793510324484, 0.2025565388397247], 'precision': [0.17355371900826447, 0.3665480427046263], 'auc': [0.5000389098434608, 0.5645923666993348], 'f1': [0.06671961874503574, 0.2609246358454718], 'f2': [0.048723897911832945, 0.2224622030237581]}
# Evaluation for recall: [0.04129793510324484, 0.2025565388397247]
# Variables to drop at threshold 0.15: ['hour_sin', 'hour_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'min_cos', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'campaign_type', 'week_of_month_cos', 'subject_with_bonuses', 'subject_with_deadline']
# Evaluation results at threshold 0.15: {'accuracy': [0.8032032714261373, 0.7604361901516442], 'recall': [0.14749262536873156, 0.2015732546705998], 'precision': [0.3424657534246575, 0.2565707133917397], 'auc': [0.5440678295846132, 0.53957475594206], 'f1': [0.20618556701030927, 0.22577092511013216], 'f2': [0.16644474034620507, 0.210602013560715]}
# Evaluation for recall: [0.14749262536873156, 0.2015732546705998]
# Variables to drop at threshold 0.2: ['hour_sin', 'day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'min_cos', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'campaign_type', 'hour_cos', 'week_of_month_cos']
# Evaluation results at threshold 0.2: {'accuracy': [0.7997955358664167, 0.7604361901516442], 'recall': [0.04129793510324484, 0.2015732546705998], 'precision': [0.17355371900826447, 0.2565707133917397], 'auc': [0.5000389098434608, 0.53957475594206], 'f1': [0.06671961874503574, 0.22577092511013216], 'f2': [0.048723897911832945, 0.210602013560715]}
# Evaluation for recall: [0.04129793510324484, 0.2015732546705998]
# Variables to drop at threshold 0.25: ['hour_sin', 'day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'campaign_type', 'hour_cos', 'week_of_month_cos', 'min_cos']
# Evaluation results at threshold 0.25: {'accuracy': [0.7997955358664167, 0.7604361901516442], 'recall': [0.04129793510324484, 0.2015732546705998], 'precision': [0.17355371900826447, 0.2565707133917397], 'auc': [0.5000389098434608, 0.53957475594206], 'f1': [0.06671961874503574, 0.22577092511013216], 'f2': [0.048723897911832945, 0.210602013560715]}
# Evaluation for recall: [0.04129793510324484, 0.2015732546705998]
# Variables to drop at threshold 0.3: ['hour_sin', 'day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'campaign_type', 'hour_cos', 'week_of_month_cos']
# Evaluation results at threshold 0.3: {'accuracy': [0.7972397341966263, 0.7740671323905265], 'recall': [0.08062930186823992, 0.20845624385447395], 'precision': [0.2433234421364985, 0.2892223738062756], 'auc': [0.5140368273562139, 0.550538921597476], 'f1': [0.12112259970457903, 0.2422857142857143], 'f2': [0.09307604994324631, 0.22078733597167258]}
# Evaluation for recall: [0.08062930186823992, 0.20845624385447395]
# Variables to drop at threshold 0.35: ['day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'hour_cos', 'week_of_month_cos', 'campaign_type', 'hour_sin']
# Evaluation results at threshold 0.35: {'accuracy': [0.7972397341966263, 0.7740671323905265], 'recall': [0.08062930186823992, 0.20845624385447395], 'precision': [0.2433234421364985, 0.2892223738062756], 'auc': [0.5140368273562139, 0.550538921597476], 'f1': [0.12112259970457903, 0.2422857142857143], 'f2': [0.09307604994324631, 0.22078733597167258]}
# Evaluation for recall: [0.08062930186823992, 0.20845624385447395]
# Variables to drop at threshold 0.4: ['day_of_week_nr_cos', 'is_weekend', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'hour_cos', 'time_of_day', 'week_of_month_cos', 'campaign_type']
# Evaluation results at threshold 0.4: {'accuracy': [0.7912761969671154, 0.7791787357301073], 'recall': [0.14454277286135694, 0.21238938053097345], 'precision': [0.29282868525896416, 0.3037974683544304], 'auc': [0.5356885339986917, 0.5551847974377868], 'f1': [0.1935483870967742, 0.25], 'f2': [0.16083150984682712, 0.22598870056497175]}
# Evaluation for recall: [0.14454277286135694, 0.21238938053097345]
# Variables to drop at threshold 0.45: ['day_of_week_nr_cos', 'is_weekend', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'hour_cos', 'time_of_day', 'day_of_week_nr_sin', 'week_of_month_cos', 'campaign_type']
# Evaluation results at threshold 0.45: {'accuracy': [0.7912761969671154, 0.7791787357301073], 'recall': [0.14454277286135694, 0.21238938053097345], 'precision': [0.29282868525896416, 0.3037974683544304], 'auc': [0.5356885339986917, 0.5551847974377868], 'f1': [0.1935483870967742, 0.25], 'f2': [0.16083150984682712, 0.22598870056497175]}
# Evaluation for recall: [0.14454277286135694, 0.21238938053097345]
# Variables to drop at threshold 0.5: ['month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'hour_cos', 'time_of_day', 'campaign_type', 'is_weekend']
# Evaluation results at threshold 0.5: {'accuracy': [0.7359004941216561, 0.7756006133924007], 'recall': [0.2782694198623402, 0.22418879056047197], 'precision': [0.2575068243858053, 0.30158730158730157], 'auc': [0.5550456744818709, 0.5576838429306894], 'f1': [0.2674858223062382, 0.2571912013536379], 'f2': [0.2738532997871105, 0.236318407960199]}
# Evaluation for recall: [0.2782694198623402, 0.22418879056047197]
# Variables to drop at threshold 0.55: ['month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'hour_cos', 'time_of_day', 'campaign_type', 'is_weekend']
# Evaluation results at threshold 0.55: {'accuracy': [0.7359004941216561, 0.7756006133924007], 'recall': [0.2782694198623402, 0.22418879056047197], 'precision': [0.2575068243858053, 0.30158730158730157], 'auc': [0.5550456744818709, 0.5576838429306894], 'f1': [0.2674858223062382, 0.2571912013536379], 'f2': [0.2738532997871105, 0.236318407960199]}
# Evaluation for recall: [0.2782694198623402, 0.22418879056047197]
# Variables to drop at threshold 0.6: ['month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'hour_cos', 'time_of_day', 'campaign_type', 'is_weekend']
# Evaluation results at threshold 0.6: {'accuracy': [0.7359004941216561, 0.7756006133924007], 'recall': [0.2782694198623402, 0.22418879056047197], 'precision': [0.2575068243858053, 0.30158730158730157], 'auc': [0.5550456744818709, 0.5576838429306894], 'f1': [0.2674858223062382, 0.2571912013536379], 'f2': [0.2738532997871105, 0.236318407960199]}
# Evaluation for recall: [0.2782694198623402, 0.22418879056047197]
# Variables to drop at threshold 0.65: ['day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'month']
# Evaluation results at threshold 0.65: {'accuracy': [0.6668938490373147, 0.777304481172261], 'recall': [0.49852507374631266, 0.21632251720747295], 'precision': [0.25973360655737704, 0.3013698630136986], 'auc': [0.600354869931689, 0.5556056114479245], 'f1': [0.34152913438868304, 0.25186033199771035], 'f2': [0.4210963455149502, 0.22926219258024177]}
# Evaluation for recall: [0.49852507374631266, 0.21632251720747295]
# Variables to drop at threshold 0.7: ['day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'month', 'day_of_month_sin']
# Evaluation results at threshold 0.7: {'accuracy': [0.6668938490373147, 0.777304481172261], 'recall': [0.49852507374631266, 0.21632251720747295], 'precision': [0.25973360655737704, 0.3013698630136986], 'auc': [0.600354869931689, 0.5556056114479245], 'f1': [0.34152913438868304, 0.25186033199771035], 'f2': [0.4210963455149502, 0.22926219258024177]}
# Evaluation for recall: [0.49852507374631266, 0.21632251720747295]
# Variables to drop at threshold 0.75: ['day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_month_sin']
# Evaluation results at threshold 0.75: {'accuracy': [0.656500255580167, 0.7779860282842052], 'recall': [0.5093411996066863, 0.2153392330383481], 'precision': [0.2545454545454545, 0.30248618784530384], 'auc': [0.5983433120869376, 0.555629220806066], 'f1': [0.3394495412844037, 0.25157955198161974], 'f2': [0.42438145174504344, 0.2285058430717863]}
# Evaluation for recall: [0.5093411996066863, 0.2153392330383481]
# Variables to drop at threshold 0.8: ['day_of_month_cos', 'week_of_month_sin', 'day_of_year']
# Evaluation results at threshold 0.8: {'accuracy': [0.6803544044982109, 0.7820753109558698], 'recall': [0.46214355948869223, 0.19960668633235004], 'precision': [0.2612562534741523, 0.30389221556886226], 'auc': [0.5941179462736124, 0.5518849589946992], 'f1': [0.3338068181818182, 0.24094955489614242], 'f2': [0.4005454235554798, 0.21431587837837837]}
# Evaluation for recall: [0.46214355948869223, 0.19960668633235004]
# Variables to drop at threshold 0.85: ['day_of_month_cos', 'week_of_month_sin']
# Evaluation results at threshold 0.85: {'accuracy': [0.6803544044982109, 0.7813937638439257], 'recall': [0.46214355948869223, 0.10127826941986234], 'precision': [0.2612562534741523, 0.21822033898305085], 'auc': [0.5941179462736124, 0.5126135782383731], 'f1': [0.3338068181818182, 0.13834788448623236], 'f2': [0.4005454235554798, 0.11343612334801761]}
# Evaluation for recall: [0.46214355948869223, 0.10127826941986234]
# Variables to drop at threshold 0.9: []
# Evaluation results at threshold 0.9: {'accuracy': [0.753279945476231, 0.7798602828420514], 'recall': [0.35889872173058013, 0.0943952802359882], 'precision': [0.3143841515934539, 0.20556745182012848], 'auc': [0.597421331186807, 0.5089659830693544], 'f1': [0.3351698806244261, 0.1293800539083558], 'f2': [0.34901510805125263, 0.10584343991179714]}
# Evaluation for recall: [0.35889872173058013, 0.0943952802359882]
# Variables to drop at threshold 0.95: []
# Evaluation results at threshold 0.95: {'accuracy': [0.753279945476231, 0.7798602828420514], 'recall': [0.35889872173058013, 0.0943952802359882], 'precision': [0.3143841515934539, 0.20556745182012848], 'auc': [0.597421331186807, 0.5089659830693544], 'f1': [0.3351698806244261, 0.1293800539083558], 'f2': [0.34901510805125263, 0.10584343991179714]}
# Evaluation for recall: [0.35889872173058013, 0.0943952802359882]
# Variables to drop at threshold 1.0: []
# Evaluation results at threshold 1.0: {'accuracy': [0.753279945476231, 0.7798602828420514], 'recall': [0.35889872173058013, 0.0943952802359882], 'precision': [0.3143841515934539, 0.20556745182012848], 'auc': [0.597421331186807, 0.5089659830693544], 'f1': [0.3351698806244261, 0.1293800539083558], 'f2': [0.34901510805125263, 0.10584343991179714]}
# Evaluation for recall: [0.35889872173058013, 0.0943952802359882]

# %% [markdown]
# ### f2

# %%
if evaluate==True:

    # modified study_variance_for_feature_selection() in dslabs functions to keep minimum variables and print metrics (due to error)


    eval_metric = 'f2'
    figure(figsize=(2 * HEIGHT, HEIGHT))
    study_redundancy_for_feature_selection(
        train_sample,
        test_sample,
        target=target,
        min_threshold = min_thresh,
        lag = lag_redundacy,
        metric=eval_metric,
        file_tag=file_tag,
        exclude=mandatory_cols
    )
    show()
# Out:
# Columns in the train dataset: ['campaign_type', 'day_of_year', 'month', 'hour_sin', 'hour_cos', 'min_sin', 'min_cos', 'day_of_month_sin', 'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'week_of_month_sin', 'week_of_month_cos', 'subject_with_personalization', 'subject_with_deadline', 'subject_with_bonuses', 'subject_with_discount', 'subject_with_saleout', 'is_weekend', 'time_of_day']
# Variables considered for correlation: ['campaign_type', 'day_of_year', 'month', 'hour_sin', 'hour_cos', 'min_sin', 'min_cos', 'day_of_month_sin', 'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'week_of_month_sin', 'week_of_month_cos', 'subject_with_personalization', 'subject_with_deadline', 'subject_with_bonuses', 'subject_with_discount', 'subject_with_saleout', 'is_weekend', 'time_of_day']
# Variables to drop at threshold 0.05: ['month', 'hour_sin', 'hour_cos', 'day_of_month_sin', 'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'week_of_month_cos', 'subject_with_deadline', 'subject_with_bonuses', 'is_weekend', 'time_of_day', 'min_sin', 'min_cos', 'week_of_month_sin', 'campaign_type', 'day_of_year']
# Evaluation results at threshold 0.05: {'accuracy': [0.7997955358664167, 0.801158630090305], 'recall': [0.04129793510324484, 0.2025565388397247], 'precision': [0.17355371900826447, 0.3665480427046263], 'auc': [0.5000389098434608, 0.5645923666993348], 'f1': [0.06671961874503574, 0.2609246358454718], 'f2': [0.048723897911832945, 0.2224622030237581]}
# Evaluation for f2: [0.048723897911832945, 0.2224622030237581]
# Variables to drop at threshold 0.1: ['month', 'hour_sin', 'hour_cos', 'day_of_month_sin', 'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'week_of_month_cos', 'subject_with_bonuses', 'is_weekend', 'time_of_day', 'min_cos', 'week_of_month_sin', 'campaign_type', 'day_of_year', 'min_sin', 'subject_with_deadline']
# Evaluation results at threshold 0.1: {'accuracy': [0.7997955358664167, 0.801158630090305], 'recall': [0.04129793510324484, 0.2025565388397247], 'precision': [0.17355371900826447, 0.3665480427046263], 'auc': [0.5000389098434608, 0.5645923666993348], 'f1': [0.06671961874503574, 0.2609246358454718], 'f2': [0.048723897911832945, 0.2224622030237581]}
# Evaluation for f2: [0.048723897911832945, 0.2224622030237581]
# Variables to drop at threshold 0.15: ['hour_sin', 'hour_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'min_cos', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'campaign_type', 'week_of_month_cos', 'subject_with_bonuses', 'subject_with_deadline']
# Evaluation results at threshold 0.15: {'accuracy': [0.8032032714261373, 0.7604361901516442], 'recall': [0.14749262536873156, 0.2015732546705998], 'precision': [0.3424657534246575, 0.2565707133917397], 'auc': [0.5440678295846132, 0.53957475594206], 'f1': [0.20618556701030927, 0.22577092511013216], 'f2': [0.16644474034620507, 0.210602013560715]}
# Evaluation for f2: [0.16644474034620507, 0.210602013560715]
# Variables to drop at threshold 0.2: ['hour_sin', 'day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'min_cos', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'campaign_type', 'hour_cos', 'week_of_month_cos']
# Evaluation results at threshold 0.2: {'accuracy': [0.7997955358664167, 0.7604361901516442], 'recall': [0.04129793510324484, 0.2015732546705998], 'precision': [0.17355371900826447, 0.2565707133917397], 'auc': [0.5000389098434608, 0.53957475594206], 'f1': [0.06671961874503574, 0.22577092511013216], 'f2': [0.048723897911832945, 0.210602013560715]}
# Evaluation for f2: [0.048723897911832945, 0.210602013560715]
# Variables to drop at threshold 0.25: ['hour_sin', 'day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'campaign_type', 'hour_cos', 'week_of_month_cos', 'min_cos']
# Evaluation results at threshold 0.25: {'accuracy': [0.7997955358664167, 0.7604361901516442], 'recall': [0.04129793510324484, 0.2015732546705998], 'precision': [0.17355371900826447, 0.2565707133917397], 'auc': [0.5000389098434608, 0.53957475594206], 'f1': [0.06671961874503574, 0.22577092511013216], 'f2': [0.048723897911832945, 0.210602013560715]}
# Evaluation for f2: [0.048723897911832945, 0.210602013560715]
# Variables to drop at threshold 0.3: ['hour_sin', 'day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'campaign_type', 'hour_cos', 'week_of_month_cos']
# Evaluation results at threshold 0.3: {'accuracy': [0.7972397341966263, 0.7740671323905265], 'recall': [0.08062930186823992, 0.20845624385447395], 'precision': [0.2433234421364985, 0.2892223738062756], 'auc': [0.5140368273562139, 0.550538921597476], 'f1': [0.12112259970457903, 0.2422857142857143], 'f2': [0.09307604994324631, 0.22078733597167258]}
# Evaluation for f2: [0.09307604994324631, 0.22078733597167258]
# Variables to drop at threshold 0.35: ['day_of_week_nr_cos', 'is_weekend', 'time_of_day', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'hour_cos', 'week_of_month_cos', 'campaign_type', 'hour_sin']
# Evaluation results at threshold 0.35: {'accuracy': [0.7972397341966263, 0.7740671323905265], 'recall': [0.08062930186823992, 0.20845624385447395], 'precision': [0.2433234421364985, 0.2892223738062756], 'auc': [0.5140368273562139, 0.550538921597476], 'f1': [0.12112259970457903, 0.2422857142857143], 'f2': [0.09307604994324631, 0.22078733597167258]}
# Evaluation for f2: [0.09307604994324631, 0.22078733597167258]
# Variables to drop at threshold 0.4: ['day_of_week_nr_cos', 'is_weekend', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_week_nr_sin', 'hour_cos', 'time_of_day', 'week_of_month_cos', 'campaign_type']
# Evaluation results at threshold 0.4: {'accuracy': [0.7912761969671154, 0.7791787357301073], 'recall': [0.14454277286135694, 0.21238938053097345], 'precision': [0.29282868525896416, 0.3037974683544304], 'auc': [0.5356885339986917, 0.5551847974377868], 'f1': [0.1935483870967742, 0.25], 'f2': [0.16083150984682712, 0.22598870056497175]}
# Evaluation for f2: [0.16083150984682712, 0.22598870056497175]
# Variables to drop at threshold 0.45: ['day_of_week_nr_cos', 'is_weekend', 'month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'hour_cos', 'time_of_day', 'day_of_week_nr_sin', 'week_of_month_cos', 'campaign_type']
# Evaluation results at threshold 0.45: {'accuracy': [0.7912761969671154, 0.7791787357301073], 'recall': [0.14454277286135694, 0.21238938053097345], 'precision': [0.29282868525896416, 0.3037974683544304], 'auc': [0.5356885339986917, 0.5551847974377868], 'f1': [0.1935483870967742, 0.25], 'f2': [0.16083150984682712, 0.22598870056497175]}
# Evaluation for f2: [0.16083150984682712, 0.22598870056497175]
# Variables to drop at threshold 0.5: ['month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'hour_cos', 'time_of_day', 'campaign_type', 'is_weekend']
# Evaluation results at threshold 0.5: {'accuracy': [0.7359004941216561, 0.7756006133924007], 'recall': [0.2782694198623402, 0.22418879056047197], 'precision': [0.2575068243858053, 0.30158730158730157], 'auc': [0.5550456744818709, 0.5576838429306894], 'f1': [0.2674858223062382, 0.2571912013536379], 'f2': [0.2738532997871105, 0.236318407960199]}
# Evaluation for f2: [0.2738532997871105, 0.236318407960199]
# Variables to drop at threshold 0.55: ['month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'hour_cos', 'time_of_day', 'campaign_type', 'is_weekend']
# Evaluation results at threshold 0.55: {'accuracy': [0.7359004941216561, 0.7756006133924007], 'recall': [0.2782694198623402, 0.22418879056047197], 'precision': [0.2575068243858053, 0.30158730158730157], 'auc': [0.5550456744818709, 0.5576838429306894], 'f1': [0.2674858223062382, 0.2571912013536379], 'f2': [0.2738532997871105, 0.236318407960199]}
# Evaluation for f2: [0.2738532997871105, 0.236318407960199]
# Variables to drop at threshold 0.6: ['month', 'day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'hour_cos', 'time_of_day', 'campaign_type', 'is_weekend']
# Evaluation results at threshold 0.6: {'accuracy': [0.7359004941216561, 0.7756006133924007], 'recall': [0.2782694198623402, 0.22418879056047197], 'precision': [0.2575068243858053, 0.30158730158730157], 'auc': [0.5550456744818709, 0.5576838429306894], 'f1': [0.2674858223062382, 0.2571912013536379], 'f2': [0.2738532997871105, 0.236318407960199]}
# Evaluation for f2: [0.2738532997871105, 0.236318407960199]
# Variables to drop at threshold 0.65: ['day_of_month_sin', 'day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'month']
# Evaluation results at threshold 0.65: {'accuracy': [0.6668938490373147, 0.777304481172261], 'recall': [0.49852507374631266, 0.21632251720747295], 'precision': [0.25973360655737704, 0.3013698630136986], 'auc': [0.600354869931689, 0.5556056114479245], 'f1': [0.34152913438868304, 0.25186033199771035], 'f2': [0.4210963455149502, 0.22926219258024177]}
# Evaluation for f2: [0.4210963455149502, 0.22926219258024177]
# Variables to drop at threshold 0.7: ['day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'month', 'day_of_month_sin']
# Evaluation results at threshold 0.7: {'accuracy': [0.6668938490373147, 0.777304481172261], 'recall': [0.49852507374631266, 0.21632251720747295], 'precision': [0.25973360655737704, 0.3013698630136986], 'auc': [0.600354869931689, 0.5556056114479245], 'f1': [0.34152913438868304, 0.25186033199771035], 'f2': [0.4210963455149502, 0.22926219258024177]}
# Evaluation for f2: [0.4210963455149502, 0.22926219258024177]
# Variables to drop at threshold 0.75: ['day_of_month_cos', 'week_of_month_sin', 'day_of_year', 'day_of_month_sin']
# Evaluation results at threshold 0.75: {'accuracy': [0.656500255580167, 0.7779860282842052], 'recall': [0.5093411996066863, 0.2153392330383481], 'precision': [0.2545454545454545, 0.30248618784530384], 'auc': [0.5983433120869376, 0.555629220806066], 'f1': [0.3394495412844037, 0.25157955198161974], 'f2': [0.42438145174504344, 0.2285058430717863]}
# Evaluation for f2: [0.42438145174504344, 0.2285058430717863]
# Variables to drop at threshold 0.8: ['day_of_month_cos', 'week_of_month_sin', 'day_of_year']
# Evaluation results at threshold 0.8: {'accuracy': [0.6803544044982109, 0.7820753109558698], 'recall': [0.46214355948869223, 0.19960668633235004], 'precision': [0.2612562534741523, 0.30389221556886226], 'auc': [0.5941179462736124, 0.5518849589946992], 'f1': [0.3338068181818182, 0.24094955489614242], 'f2': [0.4005454235554798, 0.21431587837837837]}
# Evaluation for f2: [0.4005454235554798, 0.21431587837837837]
# Variables to drop at threshold 0.85: ['day_of_month_cos', 'week_of_month_sin']
# Evaluation results at threshold 0.85: {'accuracy': [0.6803544044982109, 0.7813937638439257], 'recall': [0.46214355948869223, 0.10127826941986234], 'precision': [0.2612562534741523, 0.21822033898305085], 'auc': [0.5941179462736124, 0.5126135782383731], 'f1': [0.3338068181818182, 0.13834788448623236], 'f2': [0.4005454235554798, 0.11343612334801761]}
# Evaluation for f2: [0.4005454235554798, 0.11343612334801761]
# Variables to drop at threshold 0.9: []
# Evaluation results at threshold 0.9: {'accuracy': [0.753279945476231, 0.7798602828420514], 'recall': [0.35889872173058013, 0.0943952802359882], 'precision': [0.3143841515934539, 0.20556745182012848], 'auc': [0.597421331186807, 0.5089659830693544], 'f1': [0.3351698806244261, 0.1293800539083558], 'f2': [0.34901510805125263, 0.10584343991179714]}
# Evaluation for f2: [0.34901510805125263, 0.10584343991179714]
# Variables to drop at threshold 0.95: []
# Evaluation results at threshold 0.95: {'accuracy': [0.753279945476231, 0.7798602828420514], 'recall': [0.35889872173058013, 0.0943952802359882], 'precision': [0.3143841515934539, 0.20556745182012848], 'auc': [0.597421331186807, 0.5089659830693544], 'f1': [0.3351698806244261, 0.1293800539083558], 'f2': [0.34901510805125263, 0.10584343991179714]}
# Evaluation for f2: [0.34901510805125263, 0.10584343991179714]
# Variables to drop at threshold 1.0: []
# Evaluation results at threshold 1.0: {'accuracy': [0.753279945476231, 0.7798602828420514], 'recall': [0.35889872173058013, 0.0943952802359882], 'precision': [0.3143841515934539, 0.20556745182012848], 'auc': [0.597421331186807, 0.5089659830693544], 'f1': [0.3351698806244261, 0.1293800539083558], 'f2': [0.34901510805125263, 0.10584343991179714]}
# Evaluation for f2: [0.34901510805125263, 0.10584343991179714]

# %% [markdown]
# ### accruracy

# %%
#if evaluate==True:
#
#    # modified study_variance_for_feature_selection() in dslabs functions to keep minimum variables and print metrics (due to error)
#
#
#    eval_metric = "accuracy"
#    figure(figsize=(2 * HEIGHT, HEIGHT))
#    study_redundancy_for_feature_selection(
#        train_sample,
#        test_sample,
#        target=target,
#        min_threshold = 0.001,
#        lag = 0.2,
#        metric=eval_metric,
#        file_tag=file_tag,
#    )
#    show()

# %% [markdown]
# ## Feat 2 strategy aplication

# %%
def apply_strategy_2(df):


    df_copy = apply_remove_redundant_variables(df, min_threshold=0.80, exclude=mandatory_cols, target=target)


    return df_copy


data_2=data.copy()

data_2=apply_strategy_2(data_2)
# Out:
# columns to drop: []
# Remaining columns: Index(['platform', 'email_provider', 'campaign_type', 'channel_cmp', 'topic',
#        'total_count', 'subject_length', 'day_of_year', 'month', 'hour_sin',
#        'hour_cos', 'min_sin', 'min_cos', 'day_of_month_sin',
#        'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos',
#        'week_of_month_sin', 'week_of_month_cos', 'is_clicked',
#        'subject_with_personalization', 'subject_with_deadline',
#        'subject_with_emoji', 'subject_with_bonuses', 'subject_with_discount',
#        'subject_with_saleout', 'is_weekend', 'time_of_day'],
#       dtype='object')

# %% [markdown]
# ## Feat 2 train/test split

# %%
if evaluate ==True:
    from pandas import concat
    from matplotlib.pyplot import figure, show
    from sklearn.model_selection import train_test_split
    from dslabs_functions import plot_multibar_chart

    # train/test split from DSLABS Classification/Evaluation Chapter
    # created split_data_save_csv on data_functions

    # Call the function to split the data

    y_2, X_2, labels, class_counts = define_target_and_prepare_data(data_2, target=target)


    train_2, test_2 = split_data_save_csv(pd.DataFrame(X_2, columns=data_2.columns), y_2, data_columns=data_2.columns, target_column=target)


    values["Train"] = [
        len(train_2[train_2[target] == 0]),
        len(train_2[train_2[target] == 1]),
    ]
    values["Test"] = [
        len(test_2[test_2[target] == 0]),
        len(test_2[test_2[target] == 1]),
    ]

    figure(figsize=(6, 4))
    plot_multibar_chart(labels, values, title="Data distribution per dataset")
# Out:
# Labels=[0.0, 1.0]

# %% [markdown]
# ## Feat 2 evaluate

# %%
if evaluate == True:
    figure()
    eval_2: dict[str, list] = evaluate_approach(train_2, test_2, target='is_clicked', metric=target_metric)
    plot_multibar_chart(
        ["NB", "KNN"], eval_2, title=f"{file_tag}_2_evaluation", percentage=True
    )
    savefig(f"images/{file_tag}_2_evaluation.png")
    show()

# %% [markdown]
# # Approach uplift comparison

# %% [markdown]
# ## uplift df

# %%
if evaluate == True:
    
    algorithms = ['Naive Bayes', 'KNN']

    # Create DataFrames for eval_1 and eval_2
    df_eval_1 = pd.DataFrame(eval_1, index=algorithms)
    df_eval_2 = pd.DataFrame(eval_2, index=algorithms)

    # Calculate uplift
    df_uplift = df_eval_2 - df_eval_1



    # Combine everything into one DataFrame (without misalignment issues)
    comparison_df = pd.concat([df_eval_1, df_eval_2, df_uplift], axis=1)
    comparison_df.columns = pd.MultiIndex.from_product([['Approach 1', 'Approach 2', 'Uplift'], eval_1.keys()])



    # Display the DataFrame
    display(comparison_df)
# Out:
#             Approach 1                                                    \
#               accuracy    recall precision       auc        f1        f2
# Naive Bayes   0.756720  0.346427  0.320587  0.595181  0.333006  0.340931
# KNN           0.801428  0.227030  0.386910  0.575279  0.286152  0.247483
#
#             Approach 2                                                   \
#               accuracy   recall precision       auc        f1        f2
# Naive Bayes   0.745590  0.35440  0.305507  0.591572  0.328142  0.343408
# KNN           0.801428  0.22703  0.386910  0.575279  0.286152  0.247483
#
#               Uplift
#             accuracy    recall precision       auc        f1        f2
# Naive Bayes -0.01113  0.007973  -0.01508 -0.003609 -0.004864  0.002477
# KNN          0.00000  0.000000   0.00000  0.000000  0.000000  0.000000

# %% [markdown]
# # Analysis

# %% [markdown]
# # save to csv

# %%
if test_data==False:
    
    data_save=data.copy()

    data_save=apply_strategy_2(data_save)
        
    data_save.to_csv(f"dataset/df_msg_feat_eng.csv", index=False)

    print(data_save.columns)
# Out:
# columns to drop: []
# Remaining columns: Index(['platform', 'email_provider', 'campaign_type', 'channel_cmp', 'topic',
#        'total_count', 'subject_length', 'day_of_year', 'month', 'hour_sin',
#        'hour_cos', 'min_sin', 'min_cos', 'day_of_month_sin',
#        'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos',
#        'week_of_month_sin', 'week_of_month_cos', 'is_clicked',
#        'subject_with_personalization', 'subject_with_deadline',
#        'subject_with_emoji', 'subject_with_bonuses', 'subject_with_discount',
#        'subject_with_saleout', 'is_weekend', 'time_of_day'],
#       dtype='object')
# Index(['platform', 'email_provider', 'campaign_type', 'channel_cmp', 'topic',
#        'total_count', 'subject_length', 'day_of_year', 'month', 'hour_sin',
#        'hour_cos', 'min_sin', 'min_cos', 'day_of_month_sin',
#        'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos',
#        'week_of_month_sin', 'week_of_month_cos', 'is_clicked',
#        'subject_with_personalization', 'subject_with_deadline',
#        'subject_with_emoji', 'subject_with_bonuses', 'subject_with_discount',
#        'subject_with_saleout', 'is_weekend', 'time_of_day'],
#       dtype='object')

# %% [markdown]
# ## train test csv

# %%
if test_data==False:
    

    # data_save_copy=data_save.copy() 
    # y, X, labels, class_counts = define_target_and_prepare_data(data_save_copy, target=target)
    # train, test = split_data_save_csv(pd.DataFrame(X, columns=data_save_copy.columns), y, data_columns=data_save_copy.columns, target_column=target)  

    
    train,test=simple_split_df(data_save,sort_by='day_of_year')
    
    train.to_csv(f"dataset/df_msg_feat_eng_train.csv", index=False)
    print(train.columns)
    
    test.to_csv(f"dataset/df_msg_feat_eng_test.csv", index=False)
    print(test.columns)
# Out:
# Index(['platform', 'email_provider', 'campaign_type', 'channel_cmp', 'topic',
#        'total_count', 'subject_length', 'day_of_year', 'month', 'hour_sin',
#        'hour_cos', 'min_sin', 'min_cos', 'day_of_month_sin',
#        'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos',
#        'week_of_month_sin', 'week_of_month_cos', 'is_clicked',
#        'subject_with_personalization', 'subject_with_deadline',
#        'subject_with_emoji', 'subject_with_bonuses', 'subject_with_discount',
#        'subject_with_saleout', 'is_weekend', 'time_of_day'],
#       dtype='object')
# Index(['platform', 'email_provider', 'campaign_type', 'channel_cmp', 'topic',
#        'total_count', 'subject_length', 'day_of_year', 'month', 'hour_sin',
#        'hour_cos', 'min_sin', 'min_cos', 'day_of_month_sin',
#        'day_of_month_cos', 'day_of_week_nr_sin', 'day_of_week_nr_cos',
#        'week_of_month_sin', 'week_of_month_cos', 'is_clicked',
#        'subject_with_personalization', 'subject_with_deadline',
#        'subject_with_emoji', 'subject_with_bonuses', 'subject_with_discount',
#        'subject_with_saleout', 'is_weekend', 'time_of_day'],
#       dtype='object')

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Import Functions

# %%
# %run "dslabs_functions.py" #run notebook with functions made py the professor and that are going to be use in the project

# %%
#get file from data pre processing notebook. This file has all the column we need to start the data profiling phase
filepath = r'dataset/df_ecom_profiling_v2_dummyfication.csv'

excel_mapping_filepath=r'dataset/df_ecom_values_encoded_v2_dummyfication.xlsx'

file_tag = 'df_ecom_profiling'

# %% [markdown]
# # Load

# %%
test_data = False
# test_data = False

# Load the data
if test_data:
    df = pd.read_csv(filepath, na_values="")

    df: DataFrame = df.sample(frac=0.0015, replace = False)

else:
    # If not test_data, load the entire dataset
    df = pd.read_csv(filepath)


# encoded dataframe duplication
df_enc = df.copy()

df_enc.info()

df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197632 entries, 0 to 197631
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   event_type           197632 non-null  object
#  1   category_code_lvl_1  177829 non-null  object
#  2   category_code_lvl_2  177829 non-null  object
#  3   category_code_lvl_3  177829 non-null  object
#  4   brand                171183 non-null  object
#  5   price                197632 non-null  float64
#  6   conversion           197632 non-null  object
#  7   week_of_month        197632 non-null  int64
#  8   is_weekend           197632 non-null  object
#  9   day_of_week          197632 non-null  object
#  10  day                  197632 non-null  int64
#  11  hour                 197632 non-null  int64
#  12  min                  197632 non-null  int64
#  13  time_of_day          197632 non-null  object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 21.1+ MB
#   event_type category_code_lvl_1  category_code_lvl_2  \
# 0       view        construction   construction/tools
# 1       view        construction   construction/tools
# 2       view             apparel        apparel/shoes
# 3       view         electronics    electronics/audio
# 4       view               sport        sport/bicycle
# 5       view             apparel        apparel/scarf
# 6       view        construction   construction/tools
# 7       view        construction   construction/tools
# 8       view          appliances   appliances/kitchen
# 9       view          appliances  appliances/personal
#
#                 category_code_lvl_3      brand    price    conversion  \
# 0          construction/tools/light      leeco   390.22  not_purchase
# 1          construction/tools/light     huawei   263.04  not_purchase
# 2                     apparel/shoes  decathlon    19.05  not_purchase
# 3       electronics/audio/headphone       asus   514.79  not_purchase
# 4                     sport/bicycle   scarlett    17.76  not_purchase
# 5                     apparel/scarf   kingston   143.89  not_purchase
# 6          construction/tools/light       oppo   231.64  not_purchase
# 7          construction/tools/light       oppo   125.71  not_purchase
# 8  appliances/kitchen/refrigerators    samsung   519.42  not_purchase
# 9      appliances/personal/massager        NaN  1276.48  not_purchase
#
#    week_of_month is_weekend day_of_week  day  hour  min time_of_day
# 0              4    weekday      Monday   27     8    8     morning
# 1              3    weekday     Tuesday   21     8    0     morning
# 2              4    weekday      Monday   27     4   34       night
# 3              1    weekday     Tuesday    7    11   41     morning
# 4              2    weekday    Thursday    9    18   10   afternoon
# 5              4    weekend      Sunday   26    17   27   afternoon
# 6              4    weekday      Friday   24     5   14       night
# 7              4    weekday      Friday   24     7   11     morning
# 8              1    weekday     Tuesday    7     8   18     morning
# 9              3    weekday    Thursday   16     7   51     morning

# %%
# Verificar se 'event_time' está presente e é do tipo datetime
if 'event_time' in df.columns and pd.api.types.is_datetime64_any_dtype(df['event_time']):
    # Conta o número de dias únicos
    num_unique_days = df['event_time'].nunique()
    print(f"Número de dias únicos: {num_unique_days}")
else:
    print("A coluna 'event_time' não existe ou não é do tipo datetime.")

# Contar valores distintos em todas as colunas
distinct_values = df.nunique()
print("Número de valores distintos por coluna:")
print(distinct_values)
# Out:
# A coluna 'event_time' não existe ou não é do tipo datetime.
# Número de valores distintos por coluna:
# event_type                 3
# category_code_lvl_1       13
# category_code_lvl_2       62
# category_code_lvl_3      135
# brand                   2646
# price                  20762
# conversion                 2
# week_of_month              5
# is_weekend                 2
# day_of_week                7
# day                       30
# hour                      24
# min                       60
# time_of_day                3
# dtype: int64

# %%
df.shape[0]
# Out:
# 197632

# %% [markdown]
# ## Split data between train and test dataset
# - split 70/30 and use the most recent records to the test data

# %%
df_sorted = df.sort_values(by='event_time', ascending=True).reset_index(drop=True)
df_sorted.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/c4/7p0dsfgx11b12ysjrzs_hf940000gn/T/ipykernel_303/2743569059.py in ?()
# ----> 1 df_sorted = df.sort_values(by='event_time', ascending=True).reset_index(drop=True)
#       2 df_sorted.head()
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'event_time'

# %%
df.shape[0]
df_sorted.shape[0]
# Out:
# 69884

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Define the split point: calculate the index for 70% of the data
split_index = int(len(df_sorted) * 0.7)

# Create the training set with the first 70% of the data
train_df = df_sorted.iloc[:split_index]

# Create the testing set with the last 30% of the data (the most recent data)
test_df = df_sorted.iloc[split_index:]

# Check the dimensions of the training and testing sets
print(f'Train set size: {train_df.shape[0]}')
print(f'Test set size: {test_df.shape[0]}')

# Display the first 20 rows of the training and testing sets
print("Training set:")
print(train_df.head(20))

print("\nTesting set:")
print(test_df.head(20))
# Out:
# Train set size: 48918
# Test set size: 20966
# Training set:
#                   event_time event_type     brand    price  \
# 0  2020-04-01 00:01:11+00:00       view  imperial   168.55
# 1  2020-04-01 00:07:16+00:00       view       NaN   323.30
# 2  2020-04-01 00:17:36+00:00       view   karcher   241.94
# 3  2020-04-01 00:18:11+00:00       view        hp   990.76
# 4  2020-04-01 00:21:48+00:00       view     oladi    19.31
# 5  2020-04-01 00:27:05+00:00       view       NaN   766.78
# 6  2020-04-01 00:39:10+00:00       view  dauscher  1090.63
# 7  2020-04-01 00:40:01+00:00       view     vitek    30.86
# 8  2020-04-01 00:45:59+00:00       view     vitek   141.55
# 9  2020-04-01 00:48:01+00:00       view       NaN    25.61
# 10 2020-04-01 00:48:44+00:00       view    troyka    12.84
# 11 2020-04-01 00:51:15+00:00       view   samsung   393.32
# 12 2020-04-01 00:58:09+00:00       view   tp-link    76.42
# 13 2020-04-01 01:09:53+00:00       view     intel   774.08
# 14 2020-04-01 01:11:32+00:00       view   samsung  1415.45
# 15 2020-04-01 01:12:20+00:00       view       NaN    96.27
# 16 2020-04-01 01:12:33+00:00       view     giant   591.78
# 17 2020-04-01 01:16:26+00:00       view     casio   179.41
# 18 2020-04-01 01:45:59+00:00       view       NaN   164.23
# 19 2020-04-01 01:52:23+00:00       view     midea   289.33
#
#    category_code_lvl_1 category_code_lvl_2 category_code_lvl_3    conversion  \
# 0            computers         peripherals             printer  not_purchase
# 1                  NaN                 NaN                 NaN  not_purchase
# 2                sport             trainer                 NaN  not_purchase
# 3          electronics               audio           headphone  not_purchase
# 4              apparel               shoes                 NaN  not_purchase
# 5              apparel               shoes           moccasins  not_purchase
# 6           appliances             kitchen       refrigerators  not_purchase
# 7                  NaN                 NaN                 NaN  not_purchase
# 8           appliances         environment              vacuum  not_purchase
# 9            furniture           universal               light  not_purchase
# 10             apparel               shoes                 NaN  not_purchase
# 11          appliances            personal            massager  not_purchase
# 12           furniture             kitchen               table  not_purchase
# 13             apparel               shoes            step_ins  not_purchase
# 14        construction               tools               light  not_purchase
# 15           computers         peripherals             printer  not_purchase
# 16          appliances             kitchen              toster  not_purchase
# 17         electronics              clocks                 NaN  not_purchase
# 18        construction          components              faucet  not_purchase
# 19          appliances         environment     air_conditioner  not_purchase
#
#     week_of_month is_weekend day_of_week  day  hour  min time_of_day
# 0               1    weekday   Wednesday    1     0    1       night
# 1               1    weekday   Wednesday    1     0    7       night
# 2               1    weekday   Wednesday    1     0   17       night
# 3               1    weekday   Wednesday    1     0   18       night
# 4               1    weekday   Wednesday    1     0   21       night
# 5               1    weekday   Wednesday    1     0   27       night
# 6               1    weekday   Wednesday    1     0   39       night
# 7               1    weekday   Wednesday    1     0   40       night
# 8               1    weekday   Wednesday    1     0   45       night
# 9               1    weekday   Wednesday    1     0   48       night
# 10              1    weekday   Wednesday    1     0   48       night
# 11              1    weekday   Wednesday    1     0   51       night
# 12              1    weekday   Wednesday    1     0   58       night
# 13              1    weekday   Wednesday    1     1    9       night
# 14              1    weekday   Wednesday    1     1   11       night
# 15              1    weekday   Wednesday    1     1   12       night
# 16              1    weekday   Wednesday    1     1   12       night
# 17              1    weekday   Wednesday    1     1   16       night
# 18              1    weekday   Wednesday    1     1   45       night
# 19              1    weekday   Wednesday    1     1   52       night
#
# Testing set:
#                      event_time event_type             brand    price  \
# 48918 2020-04-23 13:22:48+00:00       view             erlit   357.57
# 48919 2020-04-23 13:23:27+00:00       view              axis   244.54
# 48920 2020-04-23 13:23:48+00:00       cart           philips    56.60
# 48921 2020-04-23 13:24:48+00:00       view            mattel    32.66
# 48922 2020-04-23 13:25:59+00:00       view            sencor   168.83
# 48923 2020-04-23 13:26:08+00:00       view            xiaomi   317.90
# 48924 2020-04-23 13:26:20+00:00       view  hotpoint-ariston   344.90
# 48925 2020-04-23 13:26:35+00:00       view                lg    81.83
# 48926 2020-04-23 13:27:35+00:00       view            adidas    63.30
# 48927 2020-04-23 13:29:48+00:00       view           samsung  1016.99
# 48928 2020-04-23 13:29:52+00:00       view            roland   874.93
# 48929 2020-04-23 13:30:48+00:00       view            huawei   109.89
# 48930 2020-04-23 13:30:55+00:00       view            pituso    83.66
# 48931 2020-04-23 13:31:36+00:00   purchase              aist   231.67
# 48932 2020-04-23 13:31:48+00:00       view          delonghi  1544.42
# 48933 2020-04-23 13:31:57+00:00       view           samsung   572.45
# 48934 2020-04-23 13:31:57+00:00       view          dauscher    46.31
# 48935 2020-04-23 13:32:14+00:00       view           philips   221.34
# 48936 2020-04-23 13:32:36+00:00       view               NaN   153.16
# 48937 2020-04-23 13:32:49+00:00       view             intex   386.88
#
#       category_code_lvl_1 category_code_lvl_2 category_code_lvl_3  \
# 48918                 NaN                 NaN                 NaN
# 48919          appliances             kitchen              toster
# 48920          appliances            personal         hair_cutter
# 48921          appliances             kitchen               grill
# 48922          appliances             kitchen               mixer
# 48923        construction               tools               light
# 48924          appliances             kitchen                 hob
# 48925           furniture             bedroom             blanket
# 48926             apparel               shoes                keds
# 48927        construction               tools               light
# 48928             apparel           underwear                 NaN
# 48929             apparel               shoes             slipons
# 48930                kids              skates                 NaN
# 48931          appliances             kitchen              toster
# 48932           computers          components              cooler
# 48933        construction               tools               light
# 48934             apparel               shoes                keds
# 48935          appliances            personal            massager
# 48936          appliances             kitchen       refrigerators
# 48937                 NaN                 NaN                 NaN
#
#          conversion  week_of_month is_weekend day_of_week  day  hour  min  \
# 48918  not_purchase              4    weekday    Thursday   23    13   22
# 48919  not_purchase              4    weekday    Thursday   23    13   23
# 48920  not_purchase              4    weekday    Thursday   23    13   23
# 48921  not_purchase              4    weekday    Thursday   23    13   24
# 48922  not_purchase              4    weekday    Thursday   23    13   25
# 48923  not_purchase              4    weekday    Thursday   23    13   26
# 48924  not_purchase              4    weekday    Thursday   23    13   26
# 48925  not_purchase              4    weekday    Thursday   23    13   26
# 48926  not_purchase              4    weekday    Thursday   23    13   27
# 48927  not_purchase              4    weekday    Thursday   23    13   29
# 48928  not_purchase              4    weekday    Thursday   23    13   29
# 48929  not_purchase              4    weekday    Thursday   23    13   30
# 48930  not_purchase              4    weekday    Thursday   23    13   30
# 48931      purchase              4    weekday    Thursday   23    13   31
# 48932  not_purchase              4    weekday    Thursday   23    13   31
# 48933  not_purchase              4    weekday    Thursday   23    13   31
# 48934  not_purchase              4    weekday    Thursday   23    13   31
# 48935  not_purchase              4    weekday    Thursday   23    13   32
# 48936  not_purchase              4    weekday    Thursday   23    13   32
# 48937  not_purchase              4    weekday    Thursday   23    13   32
#
#       time_of_day
# 48918   afternoon
# 48919   afternoon
# 48920   afternoon
# 48921   afternoon
# 48922   afternoon
# 48923   afternoon
# 48924   afternoon
# 48925   afternoon
# 48926   afternoon
# 48927   afternoon
# 48928   afternoon
# 48929   afternoon
# 48930   afternoon
# 48931   afternoon
# 48932   afternoon
# 48933   afternoon
# 48934   afternoon
# 48935   afternoon
# 48936   afternoon
# 48937   afternoon

# %% [markdown]
# ### Train data

# %%
train_df.head(20)
# Out:
#                   event_time event_type     brand    price  \
# 0  2020-04-01 00:01:11+00:00       view  imperial   168.55
# 1  2020-04-01 00:07:16+00:00       view       NaN   323.30
# 2  2020-04-01 00:17:36+00:00       view   karcher   241.94
# 3  2020-04-01 00:18:11+00:00       view        hp   990.76
# 4  2020-04-01 00:21:48+00:00       view     oladi    19.31
# 5  2020-04-01 00:27:05+00:00       view       NaN   766.78
# 6  2020-04-01 00:39:10+00:00       view  dauscher  1090.63
# 7  2020-04-01 00:40:01+00:00       view     vitek    30.86
# 8  2020-04-01 00:45:59+00:00       view     vitek   141.55
# 9  2020-04-01 00:48:01+00:00       view       NaN    25.61
# 10 2020-04-01 00:48:44+00:00       view    troyka    12.84
# 11 2020-04-01 00:51:15+00:00       view   samsung   393.32
# 12 2020-04-01 00:58:09+00:00       view   tp-link    76.42
# 13 2020-04-01 01:09:53+00:00       view     intel   774.08
# 14 2020-04-01 01:11:32+00:00       view   samsung  1415.45
# 15 2020-04-01 01:12:20+00:00       view       NaN    96.27
# 16 2020-04-01 01:12:33+00:00       view     giant   591.78
# 17 2020-04-01 01:16:26+00:00       view     casio   179.41
# 18 2020-04-01 01:45:59+00:00       view       NaN   164.23
# 19 2020-04-01 01:52:23+00:00       view     midea   289.33
#
#    category_code_lvl_1 category_code_lvl_2 category_code_lvl_3    conversion  \
# 0            computers         peripherals             printer  not_purchase
# 1                  NaN                 NaN                 NaN  not_purchase
# 2                sport             trainer                 NaN  not_purchase
# 3          electronics               audio           headphone  not_purchase
# 4              apparel               shoes                 NaN  not_purchase
# 5              apparel               shoes           moccasins  not_purchase
# 6           appliances             kitchen       refrigerators  not_purchase
# 7                  NaN                 NaN                 NaN  not_purchase
# 8           appliances         environment              vacuum  not_purchase
# 9            furniture           universal               light  not_purchase
# 10             apparel               shoes                 NaN  not_purchase
# 11          appliances            personal            massager  not_purchase
# 12           furniture             kitchen               table  not_purchase
# 13             apparel               shoes            step_ins  not_purchase
# 14        construction               tools               light  not_purchase
# 15           computers         peripherals             printer  not_purchase
# 16          appliances             kitchen              toster  not_purchase
# 17         electronics              clocks                 NaN  not_purchase
# 18        construction          components              faucet  not_purchase
# 19          appliances         environment     air_conditioner  not_purchase
#
#     week_of_month is_weekend day_of_week  day  hour  min time_of_day
# 0               1    weekday   Wednesday    1     0    1       night
# 1               1    weekday   Wednesday    1     0    7       night
# 2               1    weekday   Wednesday    1     0   17       night
# 3               1    weekday   Wednesday    1     0   18       night
# 4               1    weekday   Wednesday    1     0   21       night
# 5               1    weekday   Wednesday    1     0   27       night
# 6               1    weekday   Wednesday    1     0   39       night
# 7               1    weekday   Wednesday    1     0   40       night
# 8               1    weekday   Wednesday    1     0   45       night
# 9               1    weekday   Wednesday    1     0   48       night
# 10              1    weekday   Wednesday    1     0   48       night
# 11              1    weekday   Wednesday    1     0   51       night
# 12              1    weekday   Wednesday    1     0   58       night
# 13              1    weekday   Wednesday    1     1    9       night
# 14              1    weekday   Wednesday    1     1   11       night
# 15              1    weekday   Wednesday    1     1   12       night
# 16              1    weekday   Wednesday    1     1   12       night
# 17              1    weekday   Wednesday    1     1   16       night
# 18              1    weekday   Wednesday    1     1   45       night
# 19              1    weekday   Wednesday    1     1   52       night

# %% [markdown]
# ### Test data

# %%
test_df.head(20)
# Out:
#                      event_time event_type             brand    price  \
# 48918 2020-04-23 13:22:48+00:00       view             erlit   357.57
# 48919 2020-04-23 13:23:27+00:00       view              axis   244.54
# 48920 2020-04-23 13:23:48+00:00       cart           philips    56.60
# 48921 2020-04-23 13:24:48+00:00       view            mattel    32.66
# 48922 2020-04-23 13:25:59+00:00       view            sencor   168.83
# 48923 2020-04-23 13:26:08+00:00       view            xiaomi   317.90
# 48924 2020-04-23 13:26:20+00:00       view  hotpoint-ariston   344.90
# 48925 2020-04-23 13:26:35+00:00       view                lg    81.83
# 48926 2020-04-23 13:27:35+00:00       view            adidas    63.30
# 48927 2020-04-23 13:29:48+00:00       view           samsung  1016.99
# 48928 2020-04-23 13:29:52+00:00       view            roland   874.93
# 48929 2020-04-23 13:30:48+00:00       view            huawei   109.89
# 48930 2020-04-23 13:30:55+00:00       view            pituso    83.66
# 48931 2020-04-23 13:31:36+00:00   purchase              aist   231.67
# 48932 2020-04-23 13:31:48+00:00       view          delonghi  1544.42
# 48933 2020-04-23 13:31:57+00:00       view           samsung   572.45
# 48934 2020-04-23 13:31:57+00:00       view          dauscher    46.31
# 48935 2020-04-23 13:32:14+00:00       view           philips   221.34
# 48936 2020-04-23 13:32:36+00:00       view               NaN   153.16
# 48937 2020-04-23 13:32:49+00:00       view             intex   386.88
#
#       category_code_lvl_1 category_code_lvl_2 category_code_lvl_3  \
# 48918                 NaN                 NaN                 NaN
# 48919          appliances             kitchen              toster
# 48920          appliances            personal         hair_cutter
# 48921          appliances             kitchen               grill
# 48922          appliances             kitchen               mixer
# 48923        construction               tools               light
# 48924          appliances             kitchen                 hob
# 48925           furniture             bedroom             blanket
# 48926             apparel               shoes                keds
# 48927        construction               tools               light
# 48928             apparel           underwear                 NaN
# 48929             apparel               shoes             slipons
# 48930                kids              skates                 NaN
# 48931          appliances             kitchen              toster
# 48932           computers          components              cooler
# 48933        construction               tools               light
# 48934             apparel               shoes                keds
# 48935          appliances            personal            massager
# 48936          appliances             kitchen       refrigerators
# 48937                 NaN                 NaN                 NaN
#
#          conversion  week_of_month is_weekend day_of_week  day  hour  min  \
# 48918  not_purchase              4    weekday    Thursday   23    13   22
# 48919  not_purchase              4    weekday    Thursday   23    13   23
# 48920  not_purchase              4    weekday    Thursday   23    13   23
# 48921  not_purchase              4    weekday    Thursday   23    13   24
# 48922  not_purchase              4    weekday    Thursday   23    13   25
# 48923  not_purchase              4    weekday    Thursday   23    13   26
# 48924  not_purchase              4    weekday    Thursday   23    13   26
# 48925  not_purchase              4    weekday    Thursday   23    13   26
# 48926  not_purchase              4    weekday    Thursday   23    13   27
# 48927  not_purchase              4    weekday    Thursday   23    13   29
# 48928  not_purchase              4    weekday    Thursday   23    13   29
# 48929  not_purchase              4    weekday    Thursday   23    13   30
# 48930  not_purchase              4    weekday    Thursday   23    13   30
# 48931      purchase              4    weekday    Thursday   23    13   31
# 48932  not_purchase              4    weekday    Thursday   23    13   31
# 48933  not_purchase              4    weekday    Thursday   23    13   31
# 48934  not_purchase              4    weekday    Thursday   23    13   31
# 48935  not_purchase              4    weekday    Thursday   23    13   32
# 48936  not_purchase              4    weekday    Thursday   23    13   32
# 48937  not_purchase              4    weekday    Thursday   23    13   32
#
#       time_of_day
# 48918   afternoon
# 48919   afternoon
# 48920   afternoon
# 48921   afternoon
# 48922   afternoon
# 48923   afternoon
# 48924   afternoon
# 48925   afternoon
# 48926   afternoon
# 48927   afternoon
# 48928   afternoon
# 48929   afternoon
# 48930   afternoon
# 48931   afternoon
# 48932   afternoon
# 48933   afternoon
# 48934   afternoon
# 48935   afternoon
# 48936   afternoon
# 48937   afternoon

# %%
from numpy import ndarray
from pandas import DataFrame, read_csv
from matplotlib.pyplot import savefig, show, figure
from dslabs_functions import plot_multibar_chart, CLASS_EVAL_METRICS, run_NB, run_KNN


def evaluate_approach(
    train: DataFrame, test: DataFrame, target: str = "class", metric: str = "accuracy"
) -> dict[str, list]:
    trnY = train.pop(target).values
    trnX: ndarray = train.values
    tstY = test.pop(target).values
    tstX: ndarray = test.values
    eval: dict[str, list] = {}

    eval_NB: dict[str, float] = run_NB(trnX, trnY, tstX, tstY, metric=metric)
    eval_KNN: dict[str, float] = run_KNN(trnX, trnY, tstX, tstY, metric=metric)
    if eval_NB != {} and eval_KNN != {}:
        for met in CLASS_EVAL_METRICS:
            eval[met] = [eval_NB[met], eval_KNN[met]]
    return eval


target = "conversion"
file_tag = "conversion"
train: DataFrame = train_df
test: DataFrame = test_df

figure()
eval: dict[str, list] = evaluate_approach(train, test, target=target, metric="recall")
plot_multibar_chart(
    ["NB", "KNN"], eval, title=f"{file_tag} evaluation", percentage=True
)
savefig(f"images/{file_tag}_eval.png")
show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 30
#      27 test: DataFrame = test_df
#      29 figure()
# ---> 30 eval: dict[str, list] = evaluate_approach(train, test, target=target, metric="recall")
#      31 plot_multibar_chart(
#      32     ["NB", "KNN"], eval, title=f"{file_tag} evaluation", percentage=True
#      33 )
#      34 savefig(f"images/{file_tag}_eval.png")
#
# Cell In[57], line 16, in evaluate_approach(train, test, target, metric)
#      13 tstX: ndarray = test.values
#      14 eval: dict[str, list] = {}
# ---> 16 eval_NB: dict[str, float] = run_NB(trnX, trnY, tstX, tstY, metric=metric)
#      17 eval_KNN: dict[str, float] = run_KNN(trnX, trnY, tstX, tstY, metric=metric)
#      18 if eval_NB != {} and eval_KNN != {}:
#
# File ~/Documents/Mercedes-benz.io/TRAINING/post graduation course IST - Data science/projeto curso/ist_dash_2024_rec/notebooks/ecommerce_behaviour/dslabs_functions.py:628, in run_NB(trnX, trnY, tstX, tstY, metric)
#     625 eval: dict[str, float] = {}
#     627 for clf in estimators:
# --> 628     estimators[clf].fit(trnX, trnY)
#     629     prdY: ndarray = estimators[clf].predict(tstX)
#     630     performance: float = CLASS_EVAL_METRICS[metric](tstY, prdY)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/naive_bayes.py:263, in GaussianNB.fit(self, X, y, sample_weight)
#     240 """Fit Gaussian Naive Bayes according to X, y.
#     241
#     242 Parameters
#    (...)
#     260     Returns the instance itself.
#     261 """
#     262 y = self._validate_data(y=y)
# --> 263 return self._partial_fit(
#     264     X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#     265 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/naive_bayes.py:422, in GaussianNB._partial_fit(self, X, y, classes, _refit, sample_weight)
#     419 if _refit:
#     420     self.classes_ = None
# --> 422 first_call = _check_partial_fit_first_call(self, classes)
#     423 X, y = self._validate_data(X, y, reset=first_call)
#     424 if sample_weight is not None:
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/multiclass.py:429, in _check_partial_fit_first_call(clf, classes)
#     422             raise ValueError(
#     423                 "`classes=%r` is not the same as on last call "
#     424                 "to partial_fit, was: %r" % (classes, clf.classes_)
#     425             )
#     427     else:
#     428         # This is the first call to partial_fit
# --> 429         clf.classes_ = unique_labels(classes)
#     430         return True
#     432 # classes is None and clf.classes_ has already previously been set:
#     433 # nothing to do
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/multiclass.py:106, in unique_labels(*ys)
#     104 _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#     105 if not _unique_labels:
# --> 106     raise ValueError("Unknown label type: %s" % repr(ys))
#     108 if is_array_api_compliant:
#     109     # array_api does not allow for mixed dtypes
#     110     unique_ys = xp.concat([_unique_labels(y) for y in ys])
#
# ValueError: Unknown label type: (array([0.00000e+00, 4.60000e-01, 4.70000e-01, ..., 2.57399e+03,
#        2.57404e+03, 2.57407e+03]),)

# %% [markdown]
# ## Data Preparation
# - Goal is to improve the quality of the data

# %% [markdown]
# #### List of distinct values for each variable

# %%
from pandas import Series, DataFrame, to_numeric, to_datetime

def get_variable_types(df: DataFrame) -> dict[str, list]:
    variable_types: dict = {"numeric": [], "binary": [], "date": [], "symbolic": []}

    nr_values: Series = df.nunique(axis=0, dropna=True)
    
    for c in df.columns:
        if 2 == nr_values[c]:  # Colunas com exatamente 2 valores únicos
            variable_types["binary"].append(c)
        else:
            if df[c].dtype == 'datetime64[ns, UTC]':  # Verifica se a coluna já é datetime
                variable_types["date"].append(c)
            else:
                try:
                    df[c] = to_numeric(df[c], errors="raise")
                    variable_types["numeric"].append(c)
                except ValueError:
                    try:
                        df[c] = to_datetime(df[c], errors="raise")
                        variable_types["date"].append(c)
                    except ValueError:
                        variable_types["symbolic"].append(c)

    return variable_types

# Uso da função
variable_types: dict[str, list] = get_variable_types(df)
print(variable_types)
# Out:
# {'numeric': ['price', 'week_of_month', 'day', 'hour', 'min'], 'binary': ['conversion', 'is_weekend'], 'date': [], 'symbolic': ['event_type', 'category_code_lvl_1', 'category_code_lvl_2', 'category_code_lvl_3', 'brand', 'day_of_week', 'time_of_day']}

# %%
for v in variable_types["symbolic"]:
    print(v, df[v].unique())
# Out:
# event_type ['view' 'cart' 'purchase']
# category_code_lvl_1 ['construction' 'apparel' 'electronics' 'sport' 'appliances' nan
#  'furniture' 'kids' 'computers' 'accessories' 'country_yard' 'auto'
#  'medicine' 'stationery']
# category_code_lvl_2 ['construction/tools' 'apparel/shoes' 'electronics/audio' 'sport/bicycle'
#  'apparel/scarf' 'appliances/kitchen' 'appliances/personal' nan
#  'furniture/kitchen' 'appliances/environment' 'furniture/bedroom'
#  'kids/toys' 'computers/components' 'sport/trainer' 'electronics/clocks'
#  'sport/tennis' 'electronics/camera' 'kids/swing' 'electronics/video'
#  'electronics/telephone' 'apparel/costume' 'furniture/universal'
#  'construction/components' 'computers/notebook'
#  'appliances/sewing_machine' 'accessories/bag' 'apparel/jeans'
#  'country_yard/cultivator' 'apparel/trousers' 'apparel/sock'
#  'computers/desktop' 'apparel/tshirt' 'computers/ebooks'
#  'auto/accessories' 'apparel/shirt' 'country_yard/furniture' 'kids/dolls'
#  'computers/peripherals' 'furniture/bathroom' 'sport/ski'
#  'accessories/wallet' 'furniture/living_room' 'kids/skates'
#  'electronics/smartphone' 'appliances/ironing_board' 'kids/carriage'
#  'apparel/underwear' 'apparel/shorts' 'apparel/pajamas'
#  'electronics/tablet' 'accessories/umbrella' 'sport/snowboard'
#  'country_yard/lawn_mower' 'medicine/tools' 'kids/fmcg' 'apparel/glove'
#  'apparel/jacket' 'stationery/cartrige' 'sport/diving' 'apparel/jumper'
#  'apparel/skirt' 'apparel/dress' 'country_yard/watering']
# category_code_lvl_3 ['construction/tools/light' 'apparel/shoes' 'electronics/audio/headphone'
#  'sport/bicycle' 'apparel/scarf' 'appliances/kitchen/refrigerators'
#  'appliances/personal/massager' 'apparel/shoes/slipons' nan
#  'appliances/kitchen/mixer' 'furniture/kitchen/table'
#  'appliances/environment/vacuum' 'furniture/bedroom/bed'
#  'appliances/kitchen/blender' 'appliances/personal/hair_cutter'
#  'kids/toys' 'construction/tools/welding' 'appliances/kitchen/oven'
#  'furniture/bedroom/blanket' 'computers/components/power_supply'
#  'electronics/audio/acoustic' 'appliances/kitchen/toster'
#  'appliances/kitchen/washer' 'sport/trainer'
#  'appliances/kitchen/coffee_grinder' 'electronics/clocks' 'sport/tennis'
#  'appliances/kitchen/hood' 'electronics/camera/video' 'kids/swing'
#  'electronics/video/tv' 'electronics/telephone' 'electronics/camera/photo'
#  'apparel/costume' 'furniture/universal/light'
#  'construction/components/faucet' 'construction/tools/drill'
#  'apparel/shoes/moccasins' 'computers/notebook'
#  'appliances/sewing_machine' 'accessories/bag'
#  'construction/tools/generator' 'apparel/jeans' 'country_yard/cultivator'
#  'furniture/kitchen/chair' 'apparel/trousers' 'apparel/sock'
#  'apparel/shoes/sandals' 'electronics/audio/music_tools'
#  'computers/desktop' 'appliances/kitchen/hob'
#  'electronics/audio/subwoofer' 'apparel/tshirt' 'computers/ebooks'
#  'auto/accessories/compressor' 'apparel/shirt'
#  'country_yard/furniture/hammok' 'kids/dolls'
#  'computers/peripherals/printer' 'appliances/environment/air_conditioner'
#  'furniture/bathroom/bath' 'construction/tools/saw' 'sport/ski'
#  'accessories/wallet' 'furniture/living_room/chair'
#  'appliances/kitchen/kettle' 'electronics/audio/microphone'
#  'appliances/environment/air_heater' 'auto/accessories/videoregister'
#  'kids/skates' 'auto/accessories/radar' 'appliances/kitchen/dishwasher'
#  'appliances/kitchen/juicer' 'electronics/smartphone'
#  'appliances/ironing_board' 'kids/carriage'
#  'furniture/living_room/cabinet' 'furniture/living_room/sofa'
#  'appliances/kitchen/grill' 'apparel/shoes/keds'
#  'computers/components/motherboard' 'computers/components/cooler'
#  'construction/tools/painting' 'apparel/underwear' 'apparel/shorts'
#  'apparel/pajamas' 'electronics/tablet' 'auto/accessories/alarm'
#  'furniture/bedroom/pillow' 'apparel/shoes/espadrilles'
#  'construction/tools/pump' 'accessories/umbrella' 'sport/snowboard'
#  'appliances/environment/climate' 'electronics/video/projector'
#  'country_yard/lawn_mower' 'computers/peripherals/mouse'
#  'medicine/tools/tonometer' 'apparel/shoes/step_ins' 'kids/fmcg/diapers'
#  'apparel/glove' 'computers/components/videocards'
#  'furniture/bathroom/toilet' 'appliances/kitchen/meat_grinder'
#  'apparel/jacket' 'stationery/cartrige' 'auto/accessories/light'
#  'apparel/shoes/ballet_shoes' 'construction/tools/soldering'
#  'sport/diving' 'apparel/jumper' 'appliances/personal/scales'
#  'apparel/skirt' 'auto/accessories/winch' 'construction/tools/axe'
#  'appliances/kitchen/fryer' 'auto/accessories/parktronic'
#  'construction/tools/screw' 'furniture/living_room/shelving'
#  'auto/accessories/anti_freeze' 'computers/components/hdd'
#  'computers/peripherals/keyboard' 'appliances/environment/fan'
#  'computers/components/cdrw' 'computers/components/cpu'
#  'computers/peripherals/monitor' 'apparel/dress'
#  'computers/peripherals/camera' 'country_yard/furniture/bench'
#  'electronics/audio/dictaphone' 'computers/components/memory'
#  'auto/accessories/player' 'appliances/kitchen/steam_cooker'
#  'appliances/environment/water_heater' 'country_yard/watering'
#  'appliances/kitchen/microwave']
# brand ['leeco' 'huawei' 'decathlon' ... 'seed' 'marching' 'nishane']
# day_of_week ['Monday' 'Tuesday' 'Thursday' 'Sunday' 'Friday' 'Saturday' 'Wednesday']
# time_of_day ['morning' 'night' 'afternoon']

# %%
# Verificar se 'event_time' está presente e é do tipo datetime
if 'event_time' in df.columns and pd.api.types.is_datetime64_any_dtype(df['event_time']):
    # Conta o número de dias únicos
    num_unique_days = df['event_time'].nunique()
    print(f"Número de dias únicos: {num_unique_days}")
else:
    print("A coluna 'event_time' não existe ou não é do tipo datetime.")

# Contar valores distintos em todas as colunas
distinct_values = df.nunique()
print("Número de valores distintos por coluna:")
print(distinct_values)
# Out:
# A coluna 'event_time' não existe ou não é do tipo datetime.
# Número de valores distintos por coluna:
# event_type                 3
# category_code_lvl_1       13
# category_code_lvl_2       62
# category_code_lvl_3      135
# brand                   2646
# price                  20762
# conversion                 2
# week_of_month              5
# is_weekend                 2
# day_of_week                7
# day                       30
# hour                      24
# min                       60
# time_of_day                3
# dtype: int64

# %% [markdown]
# ### Encoding
# - we need to do the enconding of the symoblic and cyclical vraibles of the dataset
#     - Simbolyc
#         - event_type
#         - brand
#         - category_code_lvl_1
#         - category_code_lvl_2
#         - category_code_lvl_3
#     - Cyclical
#         - time_of_day
#         - day_of_week
#         - hour
#         - min
#
#     - Numeric
#         - week_of_month
#         - day
#
#     - Binary
#         - is_weekend
#         - conversion
#
#
# {'numeric': ['price', 'week_of_month', 'day', 'hour', 'min'], 'binary': ['conversion', 'is_weekend'], 'date': ['event_time'], 'symbolic': ['event_type', 'brand', 'category_code_lvl_1', 'category_code_lvl_2', 'category_code_lvl_3', 'day_of_week', 'time_of_day']}

# %% [markdown]
# #### Ordinal enconding
#
# For these variables, they are cyclical. However, as we only have data for 1 month in our dataset, there are some variables that will not repeat in our dataset. So for this variables will make the hierarchy according to the proximity in time of the values:
# Ex: week 1, is more close to week 2, than to week 5
# - week_of_month
# - day
#
# For event_type, we are doing the hiearchy accoring to the proximity of the events in the user journey inside the website
# ex: view, is more close to view_cart than to purchase
# - event_type
#
#
#
# For Brand for the hierarchy we will considering the proximity between the countries of each brand
# - brand
#
# For the category_code columns
# - category_code_level1
# - category_code_level2
# - category_code_level3

# %%
from pandas import Series, DataFrame, to_numeric, to_datetime

def get_variable_types(df: DataFrame) -> dict[str, list]:
    variable_types: dict = {"numeric": [], "binary": [], "date": [], "symbolic": []}

    nr_values: Series = df.nunique(axis=0, dropna=True)
    
    for c in df.columns:
        if 2 == nr_values[c]:  # Colunas com exatamente 2 valores únicos
            variable_types["binary"].append(c)
        else:
            if df[c].dtype == 'datetime64[ns, UTC]':  # Verifica se a coluna já é datetime
                variable_types["date"].append(c)
            else:
                try:
                    df[c] = to_numeric(df[c], errors="raise")
                    variable_types["numeric"].append(c)
                except ValueError:
                    try:
                        df[c] = to_datetime(df[c], errors="raise")
                        variable_types["date"].append(c)
                    except ValueError:
                        variable_types["symbolic"].append(c)

    return variable_types

# Uso da função
variable_types: dict[str, list] = get_variable_types(df)
print(variable_types)
# Out:
# {'numeric': ['price', 'week_of_month', 'day', 'hour', 'min'], 'binary': ['conversion', 'is_weekend'], 'date': [], 'symbolic': ['event_type', 'category_code_lvl_1', 'category_code_lvl_2', 'category_code_lvl_3', 'brand', 'day_of_week', 'time_of_day']}

# %% [markdown]
# #### bulk Symbolic mapping through Excel
#
#     - Simbolyc
#         - event_type
#         - brand
#         - category_code_lvl_1
#         - category_code_lvl_2
#         - category_code_lvl_3
#
#    - Numeric
#         - week_of_month
#         - day
#
#     - Binary
#         - is_weekend
#         - conversion

# %%
# Generalized function to encode any column based on a mapping dictionary
def encode_column_with_mapping(df, column, mapping_dict, default_value=np.nan):
    """
    Encode a column based on a mapping dictionary.
    
    Args:
    df (pd.DataFrame): The DataFrame containing the column to encode.
    column (str): The column name to encode.
    mapping_dict (dict): Dictionary where keys are the original values and values are the encodings.
    default_value: Value to assign if the key is not found in the mapping dict (default is NaN).
    
    Returns:
    pd.Series: Encoded column.
    """
    return df[column].map(mapping_dict).fillna(default_value)



def sheet_to_dict(excel_file, sheet_name):
    """
    Converts a sheet in an Excel file to a dictionary with the first column as the key and the second as the value.
    
    Args:
    excel_file (str): Path to the Excel file.
    sheet_name (str): Name of the sheet to convert.
    
    Returns:
    dict: A dictionary with keys from the first column and values from the second column.
    """
    # Read the sheet into a DataFrame
    df = pd.read_excel(excel_file, sheet_name=sheet_name)
    
    # Ensure that there are at least two columns
    if df.shape[1] < 2:
        raise ValueError(f"The sheet '{sheet_name}' does not have at least two columns.")
    
    # Create a dictionary from the first and second columns
    mapping_dict = dict(zip(df.iloc[:, 0], df.iloc[:, 1]))
    
    return mapping_dict

# %%
excel_file = pd.ExcelFile(excel_mapping_filepath)
sheet_names = excel_file.sheet_names  # List of all sheet names

# Iterate over each sheet and map the corresponding column
for sheet in sheet_names:
    # Assuming the sheet names match the column names in data_enc
    if sheet in df_enc.columns:
        # Load the sheet as a dictionary
        category_mapping = sheet_to_dict(excel_mapping_filepath, sheet)
        
        # Encode the corresponding column in data_enc using the mapping
        df_enc[sheet] = encode_column_with_mapping(df_enc, sheet, category_mapping)
        print(f'{sheet} column encoded')

    else:
        print(f"Warning: No matching column found in data_enc for sheet '{sheet}'")
# Out:
# category_code_lvl_1 column encoded
# category_code_lvl_2 column encoded
# category_code_lvl_3 column encoded
# brand column encoded
# conversion column encoded
# week_of_month column encoded
# day column encoded
# is_weekend column encoded

# %%
df_enc.head()
# Out:
#   event_type  category_code_lvl_1  category_code_lvl_2  category_code_lvl_3  \
# 0       view                 11.0                 57.0                125.0
# 1       view                 11.0                 57.0                125.0
# 2       view                  5.0                 38.0                 90.0
# 3       view                  0.0                  0.0                  2.0
# 4       view                  7.0                 50.0                104.0
#
#    brand   price  conversion  week_of_month  is_weekend day_of_week  day  \
# 0    NaN  390.22           0              3           0      Monday   26
# 1    NaN  263.04           0              2           0     Tuesday   20
# 2    NaN   19.05           0              3           0      Monday   26
# 3    NaN  514.79           0              0           0     Tuesday    6
# 4    NaN   17.76           0              1           0    Thursday    8
#
#    hour  min time_of_day
# 0     8    8     morning
# 1     8    0     morning
# 2     4   34       night
# 3    11   41     morning
# 4    18   10   afternoon

# %%
for v in variable_types["symbolic"]:
    print(v, df_enc[v].unique())
# Out:
# event_type ['view' 'cart' 'purchase']
# category_code_lvl_1 [11.  5.  0.  7.  2. nan  3.  6.  1. 12.  4.  8.  9. 10.]
# category_code_lvl_2 [57. 38.  0. 50. 40. 15. 16. nan 18. 17. 20. 42.  9. 48.  6. 49.  2. 45.
#   1.  5. 41. 22. 58.  8. 14. 59. 33. 24. 32. 37.  7. 26. 11. 54. 27. 25.
#  43. 10. 21. 52. 60. 19. 46.  3. 13. 44. 36. 34. 35.  4. 61. 53. 23. 55.
#  47. 39. 28. 56. 51. 29. 31. 30.]
# category_code_lvl_3 [125.  90.   2. 104.  79.  52.  55.  96.  nan  47.  68.  34.  60.  37.
#   54. 102. 131.  48.  61.  20.   0.  51.  53. 109.  38.  10. 105.  43.
#    7.  99.   9.  13.   6.  87.  69. 121. 123.  94.  23.  57. 132. 124.
#   81.  70.  67.  82.  86.  95.   4.  22.  42.   5.  75.  24. 112.  76.
#   74. 101.  28.  30.  58. 128. 106. 133.  64.  45.   3.  31. 117. 100.
#  116.  39.  44.  11.  36.  98.  63.  66.  41.  93.  19.  15. 126.  85.
#   83.  89.  12. 110.  62.  92. 127. 134. 107.  32.   8.  71.  27. 119.
#   97. 103.  80.  21.  59.  46.  78. 120. 113.  91. 130. 108.  77.  56.
#   84. 118. 122.  40. 114. 129.  65. 111.  18.  25.  33.  14.  16.  26.
#   88.  29.  73.   1.  17. 115.  49.  35.  72.  50.]
# brand [nan]
# day_of_week ['Monday' 'Tuesday' 'Thursday' 'Sunday' 'Friday' 'Saturday' 'Wednesday']
# time_of_day ['morning' 'night' 'afternoon']

# %% [markdown]
# ##### var brand

# %%
unique_brands = df['brand'].unique()
print(unique_brands)

for brand in df['brand'].unique():
    print(brand)
# Out:
# [nan]
# nan

# %%
unique_brands = df['brand'].unique().tolist()

# Exibir os primeiros 100 valores
print(unique_brands)  # Exibe os primeiros 100 valores

# Para exibir o total de valores
print(f'Total de marcas únicas: {len(unique_brands)}')
# Out:
# [nan, 'xiaomi', 'ariston', 'kawai', 'defacto', 'samsung', 'asus', 'galaxy', 'vivo', 'redmond', 'bosch', 'pride', 'hp', 'continent', 'holder', 'iqos', 'force', 'lg', 'oppo', 'stanley', 'fabretti', 'huawei', 'skad', 'philips', 'meizu', 'apple', 'pulser', 'fubag', 'beko', 'jbl', 'cortland', 'lucente', 'tp-link', 'adidas', 'pocketbook', 'harper', 'vitek', 'scarlett', 'milavitsa', 'casio', 'viatti', 'noname', 'haier', 'lenovo', 'vinzer', 'starline', 'rapoo', 'sony', 'arg', 'gorenje', 'asel', 'domyos', 'levenhuk', 'rieker', 'ubisoft', 'polaris', 'tefal', 'axis', 'domini', 'acer', 'alpine', 'kivi', 'janome', 'centek', 'artel', 'a-derma', 'ezetil', 'torrent', 'hansa', 'greyder', 'mykronoz', 'huter', 'kartal', 'midea', 'comfort', 'aimile', 'makita', 'magnetta', 'trefl', 'hyundai', 'pioneer', 'schreuder', 'amd', 'dauscher', 'koss', 'artex', 'maxwell', 'cordiant', 'crown', 'bmw', 'scorpion', 'digma', 'atlant', 'teknum', 'electrolux', 'tuffoni', 'jvc', 'canon', 'thomas', 'remington', 'indesit', 'ivt', 'pirelli', 'ecocool', 'syma', 'decathlon', 'tmnt', 'panasonic', 'netechnics', 'triangle', 'maxima', 'kolner', 'trust', 'bq', 'dell', 'emil', 'bts', 'thermomix', 'bugaboo', 'shivaki', 'braun', 'apollo', 'nike', 'aardwolf', 'klima', 'yasin', 'roxar', 'glo', 'sjcam', 'aerocool', 'aist', 'intel', 'dyson', 'dahon', 'karcher', 'alteco', 'scovo', 'saturn', 'fila', 'elenberg', 'rowenta', 'respect', 'lol', 'oasis', 'asrock', 'baden', 'disney', 'almacom', 'brother', 'canyon', 'nika', 'defender', 'syntrax', 'glasman', 'kelli', 'texet', 'irisk', 'yokohama', 'nexpero', 'ergo', 'antec', 'jade', 'jinga', 'olmio', 'bruder', 'ava', 'delonghi', 'silverlit', 'housefit', 'helpfer', 'brw', 'avalon', 'alis', 'rock', 'greenway', 'go-sport', 'giant', 'tramontina', 'stels', 'kukmara', 'escan', 'versace', 'huntkey', 'manfrotto', 'tanix', 'lider', 'prestigio', 'arnica', 'hygge', 'kitfort', 'omron', 'sapphire', 'ecotex', 'nixx', 'alphard', 'terris', 'nokia', 'kurzweil', 'favorite', 'mersco', 'continental', 'x-game', 'vega', 'puma', 'gf', 'sega', 'geitaran', 'thermex', 'lux', 'msi', 'agness', 'kingrun', 'ams', 'clatronic', 'realme', 'shua', 'max', 'phoenix', 'trek', 'columbia', 'onlitop', 'powerplant', 'cinemood', 'fly', 'berghoff', 'imperial', 'mart', 'logitech', 'travelite', 'indigo', 'granhel', 'irbis', 'carbon', 'delmax', 'goodride', 'boyscout', 'svc', 'ollin', 'hasbro', 'kicx', 'berlingerhaus', 'forclaz', 'gran-stone', 'cort', 'yamato', 'bridgestone', 'deepcool', 'delux', 'dwt', 'meade', 'forward', 'sokolov', 'sigma', 'gefest', 'cube', 'pozis', 'rivertoys', 'aimoto', 'sencor', 'lego', 'aquamarine', 'atlantic', 'bvlgari', 'vestel', 'micmax', 'hyperx', 'zanussi', 'pastel', 'insight', 'goodyear', 'midwest', 'lorelli', 'omnio', 'redbo', 'a-case', 'epson', 'ccm', 'tigar', 'moulinex', 'bioderma', 'longines', 'gembird', 'bene', 'henglei', 'whirlpool', 'thermaltake', 'michelin', 'bravat', 'aeroforce', 'stiga', 'rebus', 'beeline', 'babyliss', 'hoco', 'sv', 'yamaha', 'bauer', 'collistar', 'smart', 'skytech', 'sven', 'inkax', 'beurer', 'gigabyte', 'bfgoodrich', 'farinni', 'stagg', 'gopro', 'aoteli', 'verloni', 'kitchenaid', 'swat', 'sakura', 'kleancolor', 'mattel', 'galanz', 'laston', 'grundfos', 'weifeng', 'tunga', 'payot', 'transcend', 'halmar', 'nexen', 'calve', 'intex', 'renova', 'givenchy', 'bernina', 'sailun', 'zeta', 'aero', 'shure', 'aston', 'trussardi', 'tissot', 'riken', 'salvimar', 'geil', 'altenzo', 'junior', 'naturehike', 'destra', 'kingston', 'compliment', 'elysium', 'demix', 'vanstore', 'uplus', 'smeg', 'eco', 'amazfit', 'gigwi', 'nestogen', 'wowwee', 'pt-group', 'scott', 'machete', 'leatherman', 'biomecanics', 'nyx', 'weekend', 'autoline', 'honor', 'strobbs', 'fest', 'swatch', 'panolino', 'focusrite', 'rondell', 'restime', 'nabaiji', 'nutribullet', 'ryobi', 'cafemimi', 'creed', 'alilo', 'jaguar', 'toyota', 'dewalt', 'yato', 'microsoft', 'ritmix', 'kenwood', 'microlab', 'sensis', 'carfashion', 'roadx', 'aurora', 'kidwick', 'molly', 'chayka', 'serebroff', 'artmu ...
# Total de marcas únicas: 2045

# %%
unique_brands_df = pd.DataFrame(df['brand'].unique(), columns=['brand'])

# Exibir o DataFrame
print(unique_brands_df)

# Se quiser, você pode salvar o DataFrame em um arquivo CSV
unique_brands_df.to_csv('unique_brands.csv', index=False)
print("Valores únicos salvos em 'unique_brands.csv'")
# Out:
#          brand
# 0          NaN
# 1       xiaomi
# 2      ariston
# 3        kawai
# 4      defacto
# ...        ...
# 2040   goodram
# 2041   quantex
# 2042  lunecase
# 2043  babylock
# 2044    redblu
#
# [2045 rows x 1 columns]
# Valores únicos salvos em 'unique_brands.csv'

# %%
df_enc.head()
# Out:
#    event_type  category_code_lvl_1  category_code_lvl_2  category_code_lvl_3  \
# 0           0                  5.0                 40.0                 76.0
# 1           0                 11.0                 57.0                122.0
# 2           0                  0.0                  6.0                 10.0
# 3           0                  7.0                 50.0                101.0
# 4           0                  6.0                 46.0                 97.0
#
#    brand    price  conversion  week_of_month  is_weekend day_of_week  day  \
# 0    NaN    14.13           0              1           0    Thursday    1
# 1    NaN  1280.32           0              2           1    Saturday   17
# 2    NaN    20.59           0              1           1      Sunday   11
# 3    NaN    82.34           0              1           0   Wednesday    7
# 4    NaN   144.12           0              3           1    Saturday   24
#
#    hour  min time_of_day
# 0     7    6     morning
# 1    14   31   afternoon
# 2    10    4     morning
# 3     5   38       night
# 4    20   31       night

# %% [markdown]
# #### Dummyification enconding
# - Event type é usada para criar a coluna conversion, e por isso está diretamente ligada à coluna target, porque quanod event_type= conversion entao conversion=purchase. O que temos que fazer é em vez de temrmos so uma coluna, vamos fazer dummyification, em que vamos criar 3 colunas para event_type (is_view, is_cart, is_purchase) em que is_purchase é a nossa target
#     - event_type
#
#     - Novas colunas
#         - is_view
#         - is_cart
#         - is_purchase

# %%
import pandas as pd

# Supondo que df já contém a coluna 'event_type'
# Verifica os valores únicos em 'event_type' antes de fazer a dummyificação
print(df_enc['event_type'].unique())

# Cria as colunas dummificadas
df_enc['is_view'] = df_enc['event_type'].apply(lambda x: 1 if x == 'view' else 0)
df_enc['is_cart'] = df_enc['event_type'].apply(lambda x: 1 if x == 'cart' else 0)
df_enc['is_purchase'] = df_enc['event_type'].apply(lambda x: 1 if x == 'purchase' else 0)

# Mostra as primeiras linhas para verificar o resultado
print(df_enc[['event_type', 'is_view', 'is_cart', 'is_purchase']].head())
# Out:
# ['view' 'cart' 'purchase']
#   event_type  is_view  is_cart  is_purchase
# 0       view        1        0            0
# 1       view        1        0            0
# 2       view        1        0            0
# 3       view        1        0            0
# 4       view        1        0            0

# %%
# Contar os valores distintos em 'event_type'
event_type_counts = df_enc['event_type'].value_counts()

# Contar os valores distintos nas novas colunas
is_view_counts = df_enc['is_view'].value_counts()
is_cart_counts = df_enc['is_cart'].value_counts()
is_purchase_counts = df_enc['is_purchase'].value_counts()

# Exibir os resultados
print("Contagem de valores em 'event_type':")
print(event_type_counts)

print("\nContagem de valores em 'is_view':")
print(is_view_counts)

print("\nContagem de valores em 'is_cart':")
print(is_cart_counts)

print("\nContagem de valores em 'is_purchase':")
print(is_purchase_counts)
# Out:
# Contagem de valores em 'event_type':
# event_type
# view        180281
# cart          9508
# purchase      7843
# Name: count, dtype: int64
#
# Contagem de valores em 'is_view':
# is_view
# 1    180281
# 0     17351
# Name: count, dtype: int64
#
# Contagem de valores em 'is_cart':
# is_cart
# 0    188124
# 1      9508
# Name: count, dtype: int64
#
# Contagem de valores em 'is_purchase':
# is_purchase
# 0    189789
# 1      7843
# Name: count, dtype: int64

# %%
df_enc.head()
# Out:
#   event_type  category_code_lvl_1  category_code_lvl_2  category_code_lvl_3  \
# 0       view                 11.0                 57.0                125.0
# 1       view                 11.0                 57.0                125.0
# 2       view                  5.0                 38.0                 90.0
# 3       view                  0.0                  0.0                  2.0
# 4       view                  7.0                 50.0                104.0
#
#    brand   price  conversion  week_of_month  is_weekend day_of_week  day  \
# 0    NaN  390.22           0              3           0      Monday   26
# 1    NaN  263.04           0              2           0     Tuesday   20
# 2    NaN   19.05           0              3           0      Monday   26
# 3    NaN  514.79           0              0           0     Tuesday    6
# 4    NaN   17.76           0              1           0    Thursday    8
#
#    hour  min time_of_day  is_view  is_cart  is_purchase
# 0     8    8     morning        1        0            0
# 1     8    0     morning        1        0            0
# 2     4   34       night        1        0            0
# 3    11   41     morning        1        0            0
# 4    18   10   afternoon        1        0            0

# %%
#we will drop event_type column as it was tranfromed into numeric.
# We will also drop conversion, and assume the new is_purchase column as our new target columns
df_enc = df_enc.drop(columns=['event_type','conversion'])

df_enc.head()
# Out:
#    category_code_lvl_1  category_code_lvl_2  category_code_lvl_3  brand  \
# 0                 11.0                 57.0                125.0    NaN
# 1                 11.0                 57.0                125.0    NaN
# 2                  5.0                 38.0                 90.0    NaN
# 3                  0.0                  0.0                  2.0    NaN
# 4                  7.0                 50.0                104.0    NaN
#
#     price  week_of_month  is_weekend day_of_week  day  hour  min time_of_day  \
# 0  390.22              3           0      Monday   26     8    8     morning
# 1  263.04              2           0     Tuesday   20     8    0     morning
# 2   19.05              3           0      Monday   26     4   34       night
# 3  514.79              0           0     Tuesday    6    11   41     morning
# 4   17.76              1           0    Thursday    8    18   10   afternoon
#
#    is_view  is_cart  is_purchase
# 0        1        0            0
# 1        1        0            0
# 2        1        0            0
# 3        1        0            0
# 4        1        0            0

# %% [markdown]
# #### Cyclical enconding
# - We have variables, time variables, that are cyclical, meaning that the values of the variables can repeat over time.
#     - day_of_week
#     - time_of_day
#     - hour
#     - min
#
#
# So basicaly, if we look to time_of_day (morning, afternoon, night). Night is close to afternoon but is also at the same distant from morning, becase after night we will have the monrning

# %%
from math import pi, sin, cos

# Dicionários para as variáveis categóricas
day_of_week_val: dict[str, float] = {
    "Sunday": 0,           # Domingo
    "Monday": pi / 6,      # Segunda-feira
    "Tuesday": pi / 3,     # Terça-feira
    "Wednesday": pi / 2,   # Quarta-feira
    "Thursday": 2 * pi / 3,  # Quinta-feira
    "Friday": 5 * pi / 6,  # Sexta-feira
    "Saturday": 2 * pi     # Sábado
}

time_of_day_val: dict[str, float] = {
    "morning": 0,         # 0 radians
    "afternoon": pi / 2,  # 90 degrees (π/2)
    "night": pi           # 180 degrees (π)
}

# Dicionário de encoding apenas para as variáveis categóricas
encoding: dict[str, dict] = {
    "day_of_week": day_of_week_val,
    "time_of_day": time_of_day_val,
}

# Aplicar o encoding ao DataFrame
df_enc = df_enc.replace(encoding)

df_enc.head(10)
# Out:
#    category_code_lvl_1  category_code_lvl_2  category_code_lvl_3  brand  \
# 0                 11.0                 57.0                125.0    NaN
# 1                 11.0                 57.0                125.0    NaN
# 2                  5.0                 38.0                 90.0    NaN
# 3                  0.0                  0.0                  2.0    NaN
# 4                  7.0                 50.0                104.0    NaN
# 5                  5.0                 40.0                 79.0    NaN
# 6                 11.0                 57.0                125.0    NaN
# 7                 11.0                 57.0                125.0    NaN
# 8                  2.0                 15.0                 52.0    NaN
# 9                  2.0                 16.0                 55.0    NaN
#
#      price  week_of_month  is_weekend  day_of_week  day  hour  min  \
# 0   390.22              3           0     0.523599   26     8    8
# 1   263.04              2           0     1.047198   20     8    0
# 2    19.05              3           0     0.523599   26     4   34
# 3   514.79              0           0     1.047198    6    11   41
# 4    17.76              1           0     2.094395    8    18   10
# 5   143.89              3           1     0.000000   25    17   27
# 6   231.64              3           0     2.617994   23     5   14
# 7   125.71              3           0     2.617994   23     7   11
# 8   519.42              0           0     1.047198    6     8   18
# 9  1276.48              2           0     2.094395   15     7   51
#
#    time_of_day  is_view  is_cart  is_purchase
# 0     0.000000        1        0            0
# 1     0.000000        1        0            0
# 2     3.141593        1        0            0
# 3     0.000000        1        0            0
# 4     1.570796        1        0            0
# 5     1.570796        1        0            0
# 6     3.141593        1        0            0
# 7     0.000000        1        0            0
# 8     0.000000        1        0            0
# 9     0.000000        1        0            0

# %%
from math import sin, cos

# Função para aplicar encoding cíclico
def encode_cyclic_variables(df_enc, vars):
    for v in vars:
        x_max = max(df_enc[v])  # O valor máximo da variável cíclica
        df_enc[v + "_sin"] = df_enc[v].apply(lambda x: round(sin(2 * pi * x / x_max), 3))
        df_enc[v + "_cos"] = df_enc[v].apply(lambda x: round(cos(2 * pi * x / x_max), 3))
    return df_enc

# Variáveis cíclicas que já estão numericamente codificadas ou são numéricas
cyclical_vars = ["time_of_day", "day_of_week", "hour", "min"]

# Aplicar a codificação cíclica
df_enc = encode_cyclic_variables(df_enc, cyclical_vars)

# Verificar os resultados
df_enc.head(15)
# Out:
#     category_code_lvl_1  category_code_lvl_2  category_code_lvl_3  brand  \
# 0                  11.0                 57.0                125.0    NaN
# 1                  11.0                 57.0                125.0    NaN
# 2                   5.0                 38.0                 90.0    NaN
# 3                   0.0                  0.0                  2.0    NaN
# 4                   7.0                 50.0                104.0    NaN
# 5                   5.0                 40.0                 79.0    NaN
# 6                  11.0                 57.0                125.0    NaN
# 7                  11.0                 57.0                125.0    NaN
# 8                   2.0                 15.0                 52.0    NaN
# 9                   2.0                 16.0                 55.0    NaN
# 10                  5.0                 38.0                 96.0    NaN
# 11                  NaN                  NaN                  NaN    NaN
# 12                 11.0                 57.0                125.0    NaN
# 13                  2.0                 15.0                 47.0    NaN
# 14                 11.0                 57.0                125.0    NaN
#
#       price  week_of_month  is_weekend  day_of_week  day  hour  ...  is_cart  \
# 0    390.22              3           0     0.523599   26     8  ...        0
# 1    263.04              2           0     1.047198   20     8  ...        0
# 2     19.05              3           0     0.523599   26     4  ...        0
# 3    514.79              0           0     1.047198    6    11  ...        0
# 4     17.76              1           0     2.094395    8    18  ...        0
# 5    143.89              3           1     0.000000   25    17  ...        0
# 6    231.64              3           0     2.617994   23     5  ...        0
# 7    125.71              3           0     2.617994   23     7  ...        0
# 8    519.42              0           0     1.047198    6     8  ...        0
# 9   1276.48              2           0     2.094395   15     7  ...        0
# 10    65.89              2           0     0.523599   19     3  ...        0
# 11    22.11              3           1     6.283185   24    13  ...        0
# 12   166.77              0           0     1.570796    0    10  ...        1
# 13    33.44              2           0     1.570796   14     9  ...        0
# 14   191.23              2           1     6.283185   17     3  ...        0
#
#     is_purchase  time_of_day_sin  time_of_day_cos  day_of_week_sin  \
# 0             0              0.0              1.0            0.500
# 1             0              0.0              1.0            0.866
# 2             0             -0.0              1.0            0.500
# 3             0              0.0              1.0            0.866
# 4             0              0.0             -1.0            0.866
# 5             0              0.0             -1.0            0.000
# 6             0             -0.0              1.0            0.500
# 7             0              0.0              1.0            0.500
# 8             0              0.0              1.0            0.866
# 9             0              0.0              1.0            0.866
# 10            0             -0.0              1.0            0.500
# 11            0              0.0             -1.0           -0.000
# 12            0              0.0              1.0            1.000
# 13            0              0.0              1.0            1.000
# 14            0             -0.0              1.0           -0.000
#
#     day_of_week_cos  hour_sin  hour_cos  min_sin  min_cos
# 0             0.866     0.817    -0.577    0.753    0.659
# 1             0.500     0.817    -0.577    0.000    1.000
# 2             0.866     0.888     0.460   -0.461   -0.887
# 3             0.500     0.136    -0.991   -0.941   -0.339
# 4            -0.500    -0.979     0.203    0.875    0.485
# 5             1.000    -0.998    -0.068    0.263   -0.965
# 6            -0.866     0.979     0.203    0.997    0.080
# 7            -0.866     0.942    -0.335    0.921    0.389
# 8             0.500     0.817    -0.577    0.941   -0.339
# 9            -0.500     0.942    -0.335   -0.753    0.659
# 10            0.866     0.731     0.683   -0.787   -0.618
# 11            1.000    -0.398    -0.917    0.971   -0.237
# 12            0.000     0.398    -0.917    0.053   -0.999
# 13            0.000     0.631    -0.776   -0.997    0.080
# 14            1.000     0.731     0.683    0.263   -0.965
#
# [15 rows x 23 columns]

# %%
print(df_enc.dtypes)
# Out:
# category_code_lvl_1    float64
# category_code_lvl_2    float64
# category_code_lvl_3    float64
# brand                  float64
# price                  float64
# week_of_month            int64
# is_weekend               int64
# day_of_week            float64
# day                      int64
# hour                     int64
# min                      int64
# time_of_day            float64
# is_view                  int64
# is_cart                  int64
# is_purchase              int64
# time_of_day_sin        float64
# time_of_day_cos        float64
# day_of_week_sin        float64
# day_of_week_cos        float64
# hour_sin               float64
# hour_cos               float64
# min_sin                float64
# min_cos                float64
# dtype: object

# %%
# Remover as colunas originais
df_enc = df_enc.drop(columns=["brand","time_of_day", "day_of_week", "hour", "min"])

# Verificar os resultados
df_enc.head(15)
# Out:
#     category_code_lvl_1  category_code_lvl_2  category_code_lvl_3    price  \
# 0                  11.0                 57.0                125.0   390.22
# 1                  11.0                 57.0                125.0   263.04
# 2                   5.0                 38.0                 90.0    19.05
# 3                   0.0                  0.0                  2.0   514.79
# 4                   7.0                 50.0                104.0    17.76
# 5                   5.0                 40.0                 79.0   143.89
# 6                  11.0                 57.0                125.0   231.64
# 7                  11.0                 57.0                125.0   125.71
# 8                   2.0                 15.0                 52.0   519.42
# 9                   2.0                 16.0                 55.0  1276.48
# 10                  5.0                 38.0                 96.0    65.89
# 11                  NaN                  NaN                  NaN    22.11
# 12                 11.0                 57.0                125.0   166.77
# 13                  2.0                 15.0                 47.0    33.44
# 14                 11.0                 57.0                125.0   191.23
#
#     week_of_month  is_weekend  day  is_view  is_cart  is_purchase  \
# 0               3           0   26        1        0            0
# 1               2           0   20        1        0            0
# 2               3           0   26        1        0            0
# 3               0           0    6        1        0            0
# 4               1           0    8        1        0            0
# 5               3           1   25        1        0            0
# 6               3           0   23        1        0            0
# 7               3           0   23        1        0            0
# 8               0           0    6        1        0            0
# 9               2           0   15        1        0            0
# 10              2           0   19        1        0            0
# 11              3           1   24        1        0            0
# 12              0           0    0        0        1            0
# 13              2           0   14        1        0            0
# 14              2           1   17        1        0            0
#
#     time_of_day_sin  time_of_day_cos  day_of_week_sin  day_of_week_cos  \
# 0               0.0              1.0            0.500            0.866
# 1               0.0              1.0            0.866            0.500
# 2              -0.0              1.0            0.500            0.866
# 3               0.0              1.0            0.866            0.500
# 4               0.0             -1.0            0.866           -0.500
# 5               0.0             -1.0            0.000            1.000
# 6              -0.0              1.0            0.500           -0.866
# 7               0.0              1.0            0.500           -0.866
# 8               0.0              1.0            0.866            0.500
# 9               0.0              1.0            0.866           -0.500
# 10             -0.0              1.0            0.500            0.866
# 11              0.0             -1.0           -0.000            1.000
# 12              0.0              1.0            1.000            0.000
# 13              0.0              1.0            1.000            0.000
# 14             -0.0              1.0           -0.000            1.000
#
#     hour_sin  hour_cos  min_sin  min_cos
# 0      0.817    -0.577    0.753    0.659
# 1      0.817    -0.577    0.000    1.000
# 2      0.888     0.460   -0.461   -0.887
# 3      0.136    -0.991   -0.941   -0.339
# 4     -0.979     0.203    0.875    0.485
# 5     -0.998    -0.068    0.263   -0.965
# 6      0.979     0.203    0.997    0.080
# 7      0.942    -0.335    0.921    0.389
# 8      0.817    -0.577    0.941   -0.339
# 9      0.942    -0.335   -0.753    0.659
# 10     0.731     0.683   -0.787   -0.618
# 11    -0.398    -0.917    0.971   -0.237
# 12     0.398    -0.917    0.053   -0.999
# 13     0.631    -0.776   -0.997    0.080
# 14     0.731     0.683    0.263   -0.965

# %%
for v in vars["symbolic"]:
    print(v, df_enc[v].unique())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 for v in vars["symbolic"]:
#       2     print(v, df_enc[v].unique())
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
df_enc.columns
# Out:
# Index(['event_type', 'category_code_lvl_1', 'category_code_lvl_2',
#        'category_code_lvl_3', 'price', 'conversion', 'week_of_month',
#        'is_weekend', 'day', 'time_of_day_sin', 'time_of_day_cos',
#        'day_of_week_sin', 'day_of_week_cos', 'hour_sin', 'hour_cos', 'min_sin',
#        'min_cos'],
#       dtype='object')

# %%
df_enc.head(10)
# Out:
#    event_type  category_code_lvl_1  category_code_lvl_2  category_code_lvl_3  \
# 0           0                  5.0                 40.0                 76.0
# 1           0                 11.0                 57.0                122.0
# 2           0                  0.0                  6.0                 10.0
# 3           0                  7.0                 50.0                101.0
# 4           0                  6.0                 46.0                 97.0
# 5           0                 11.0                 57.0                121.0
# 6           0                 11.0                 57.0                122.0
# 7           0                  NaN                  NaN                  NaN
# 8           0                 11.0                 57.0                122.0
# 9           1                  2.0                 15.0                  NaN
#
#      price  conversion  week_of_month  is_weekend  day  time_of_day_sin  \
# 0    14.13           0              1           0    1              0.0
# 1  1280.32           0              2           1   17              0.0
# 2    20.59           0              1           1   11              0.0
# 3    82.34           0              1           0    7             -0.0
# 4   144.12           0              3           1   24             -0.0
# 5    58.27           0              2           0   14              0.0
# 6   123.27           0              3           1   25             -0.0
# 7   728.72           0              3           0   27             -0.0
# 8   106.04           0              4           0   29              0.0
# 9   139.98           0              1           0    2              0.0
#
#    time_of_day_cos  day_of_week_sin  day_of_week_cos  hour_sin  hour_cos  \
# 0              1.0            0.866           -0.500     0.942    -0.335
# 1             -1.0           -0.000            1.000    -0.631    -0.776
# 2              1.0            0.000            1.000     0.398    -0.917
# 3              1.0            1.000            0.000     0.979     0.203
# 4              1.0           -0.000            1.000    -0.731     0.683
# 5             -1.0            1.000            0.000    -0.817    -0.577
# 6              1.0            0.000            1.000     0.731     0.683
# 7              1.0            0.866            0.500     0.731     0.683
# 8              1.0            0.866           -0.500     0.817    -0.577
# 9             -1.0            0.500           -0.866    -0.817    -0.577
#
#    min_sin  min_cos
# 0    0.596    0.803
# 1   -0.159   -0.987
# 2    0.413    0.911
# 3   -0.787   -0.618
# 4   -0.159   -0.987
# 5   -0.461   -0.887
# 6   -0.000    1.000
# 7    0.997    0.080
# 8   -0.983    0.185
# 9   -0.787   -0.618

# %%
# Criar uma lista para armazenar os valores distintos
distinct_values = {}

# Variáveis cíclicas que você criou
cyclical_vars = ['time_of_day', 'day_of_week', 'hour', 'min']

# Loop para obter valores distintos de cada coluna sin e cos
for var in cyclical_vars:
    distinct_sin = df_enc[f'{var}_sin'].unique()
    distinct_cos = df_enc[f'{var}_cos'].unique()
    
    # Armazenar os valores distintos em um dicionário
    distinct_values[f'{var}_sin'] = distinct_sin
    distinct_values[f'{var}_cos'] = distinct_cos

# Imprimir os valores distintos
for key, values in distinct_values.items():
    print(f"Valores distintos de {key}:", values)
# Out:
# Valores distintos de time_of_day_sin: [0.]
# Valores distintos de time_of_day_cos: [ 1. -1.]
# Valores distintos de day_of_week_sin: [ 0.866 -0.     1.     0.5  ]
# Valores distintos de day_of_week_cos: [-0.5    1.     0.     0.5   -0.866  0.866]
# Valores distintos de hour_sin: [ 0.942 -0.631  0.398  0.979 -0.731 -0.817  0.731  0.817 -0.942 -0.998
#   0.136 -0.136  0.998 -0.398  0.888 -0.979 -0.52   0.    -0.888  0.631
#   0.27  -0.27   0.52 ]
# Valores distintos de hour_cos: [-0.335 -0.776 -0.917  0.203  0.683 -0.577 -0.068 -0.991  0.46   0.854
#   1.     0.963]
# Valores distintos de min_sin: [ 0.596 -0.159  0.413 -0.787 -0.461 -0.     0.997 -0.983  0.106 -0.106
#   0.971 -0.053 -0.971 -0.314 -0.678  0.941 -0.211  0.957  0.875  0.263
#   0.848 -0.848  0.899 -0.596 -0.413  0.678 -0.991  0.553  0.818  0.508
#   0.983  0.716 -0.638  0.787 -0.921 -0.364 -0.997  0.211  0.638  0.991
#  -0.899 -0.716 -0.875 -0.753  0.159  0.314 -0.818  0.053 -0.941  0.753
#  -0.553  0.921 -0.263 -0.957  1.    -0.508  0.364 -1.     0.461]
# Valores distintos de min_cos: [ 0.803 -0.987  0.911 -0.618 -0.887  1.     0.08   0.185  0.994 -0.237
#  -0.999  0.949  0.735 -0.339  0.977  0.289  0.485 -0.965 -0.53  -0.437
#  -0.133 -0.833  0.575  0.862 -0.698 -0.77   0.389 -0.931  0.659 -0.027]

# %% [markdown]
# ##### Visual representation of cyclical variables

# %%
import matplotlib.pyplot as plt

# Lista de variáveis cíclicas
cyclical_vars = ['time_of_day', 'day_of_week', 'hour', 'min']

# Criar gráficos de dispersão para cada variável cíclica com tamanho maior
plt.figure(figsize=(14, 14))  # Aumentando o tamanho da figura

for i, var in enumerate(cyclical_vars):
    # Valores de seno e cosseno para a variável atual
    x_values = df_enc[f'{var}_cos']
    y_values = df_enc[f'{var}_sin']
    
    # Criar um subplot para cada variável
    plt.subplot(len(cyclical_vars), 1, i + 1)
    plt.scatter(x_values, y_values, alpha=0.6)
    plt.axhline(0, color='gray', lw=0.5, ls='--')
    plt.axvline(0, color='gray', lw=0.5, ls='--')
    
    # Ajustar os limites dos eixos para melhor visualização
    plt.xlim(-1.1, 1.1)
    plt.ylim(-1.1, 1.1)
    
    # Adicionar título e rótulos
    plt.title(f'Projeção Bidimensional de {var.capitalize()}')
    plt.xlabel(f'{var.capitalize()} Cos')
    plt.ylabel(f'{var.capitalize()} Sin')
    
    # Mostrar a grade
    plt.grid()
    plt.gca().set_aspect('equal', adjustable='box')  # Para garantir que o gráfico é circular

plt.tight_layout()  # Ajustar o layout
plt.show()  # Mostrar todos os gráficos

# %% [markdown]
# ## Correlation between variable after enconding

# %%
from seaborn import heatmap
from matplotlib.pyplot import figure, savefig, show

variables_types: dict[str, list] = get_variable_types(df_enc)
numeric: list[str] = variables_types["numeric"]
corr_mtx: DataFrame = df_enc[numeric].corr().abs()

figure()
heatmap(
    abs(corr_mtx),
    xticklabels=numeric,
    yticklabels=numeric,
    annot=False,
    cmap="Blues",
    vmin=0,
    vmax=1,
)
#savefig(f"images/{file_tag}_correlation_analysis.png")
show()

# %%
from seaborn import heatmap
from matplotlib.pyplot import figure, savefig, show

variables_types: dict[str, list] = get_variable_types(df_enc)
numeric: list[str] = variables_types["numeric"]
corr_mtx: DataFrame = df_enc.corr().abs()

figure()
heatmap(
    abs(corr_mtx),
    xticklabels=df_enc.columns,
    yticklabels=df_enc.columns,
    annot=False,
    cmap="Blues",
    vmin=0,
    vmax=1,
)
#savefig(f"images/{file_tag}_correlation_analysis.png")
show()

# %% [markdown]
# ## Save final df from Data preparation - ENCODING into a csv file
# - We will use this dataset for the missing alues

# %%
# Definir o caminho para salvar o arquivo CSV
filepath = r'dataset/df_ecom_data_prep_encoded_v2_dummyfication.csv'

# Salvar o DataFrame em CSV
df_enc.to_csv(filepath, index=False)

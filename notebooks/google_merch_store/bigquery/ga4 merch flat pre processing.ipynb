# %% [markdown]
# # Example 1: Query a table with SQL and magic commands

# %%
# Running this code will query a table in BigQuery and download
# the results to a Pandas DataFrame named `results`.
# Learn more here: https://cloud.google.com/bigquery/docs/visualize-jupyter

# %%bigquery results --project ist-data-science
SELECT * FROM `ist-data-science.ga4_google_merch_store.flattened_raw` #this table name was set based on the table you chose to query
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
# You can view the resulting Pandas DataFrame and work with using the Pandas library.
# https://pandas.pydata.org/docs/getting_started/index.html#getting-started
results
# Out:
#          event_date  session_id       user_pseudo_id       event_name  \
# 0        2020-12-22  8295718812  71887902.6884854131        view_item
# 1        2020-12-22  7515860174  81182117.7869823509        view_item
# 2        2020-12-22  1788192033  81894085.3422774223        view_item
# 3        2020-12-22  5657894112  86022908.3549627221        view_item
# 4        2020-12-22  4580887347  88165568.4190327455        view_item
# ...             ...         ...                  ...              ...
# 7765965  2021-01-07  2556063595   6056436.0721934785        page_view
# 7765966  2021-01-07   516341687   6977726.6622989527  user_engagement
# 7765967  2021-01-07   901832470   7563617.7895603330        page_view
# 7765968  2021-01-07  2027269181   7613000.5592937160  user_engagement
# 7765969  2021-01-07  8057289089   7687394.8608023492  user_engagement
#
#           event_timestamp                                      page_location  \
# 0        1608623214574191  https://shop.googlemerchandisestore.com/Google...
# 1        1608675207045905  https://shop.googlemerchandisestore.com/Google...
# 2        1608635992913745  https://shop.googlemerchandisestore.com/Google...
# 3        1608612362941329  https://shop.googlemerchandisestore.com/Google...
# 4        1608608855939864  https://shop.googlemerchandisestore.com/store....
# ...                   ...                                                ...
# 7765965  1610022877151761  https://shop.googlemerchandisestore.com/basket...
# 7765966  1610044934375087  https://shop.googlemerchandisestore.com/Google...
# 7765967  1610020232692622  https://shop.googlemerchandisestore.com/google...
# 7765968  1610029843474335  https://shop.googlemerchandisestore.com/Google...
# 7765969  1609993464911029  https://shop.googlemerchandisestore.com/Google...
#
#                                                 page_title device_category  \
# 0        Small Goods | Lifestyle | Google Merchandise S...          mobile
# 1                  Eco-Friendly | Google Merchandise Store          mobile
# 2        Men's / Unisex | Apparel | Google Merchandise ...         desktop
# 3                           New | Google Merchandise Store          mobile
# 4                                                     Home         desktop
# ...                                                    ...             ...
# 7765965                                      Shopping Cart          mobile
# 7765966  Small Goods | Lifestyle | Google Merchandise S...          mobile
# 7765967                                   Page Unavailable          mobile
# 7765968   Drinkware | Lifestyle | Google Merchandise Store         desktop
# 7765969                      Google Men's Tech Fleece Grey         desktop
#
#         device_mobile_brand_name device_mobile_model_name  ...  \
# 0                        Samsung                  <Other>  ...
# 1                        <Other>                  <Other>  ...
# 2                         Google                   Chrome  ...
# 3                          Apple                   iPhone  ...
# 4                         Google                   Chrome  ...
# ...                          ...                      ...  ...
# 7765965                  <Other>                  <Other>  ...
# 7765966                    Apple                   iPhone  ...
# 7765967                  <Other>                  <Other>  ...
# 7765968                   Google                   Chrome  ...
# 7765969                    Apple                   Safari  ...
#
#                 item_id                           item_name item_brand  \
# 0        GGOEGABB100999          Google Cloth & Pouch Black  (not set)
# 1          GGCOGXXX1570   Google Land & Sea Women's Eco Tee  (not set)
# 2          GGOEGXXX1193     Google Campus Bike Eco Tee Navy  (not set)
# 3          GGOEGXXX1613              Super G Unisex Joggers     Google
# 4          GGOEGXXX0919  YouTube Women's Favorite Tee White  (not set)
# ...                 ...                                 ...        ...
# 7765965            None                                None       None
# 7765966            None                                None       None
# 7765967            None                                None       None
# 7765968            None                                None       None
# 7765969            None                                None       None
#
#         item_variant                 item_category price quantity  \
# 0          (not set)        Lifestyle/Small Goods/   4.0     <NA>
# 1          (not set)            Home/Eco-Friendly/  25.0     <NA>
# 2          (not set)  Home/Apparel/Men's / Unisex/  25.0     <NA>
# 3          (not set)                     Home/New/  37.0     <NA>
# 4          (not set)                    Home/Sale/  22.0     <NA>
# ...              ...                           ...   ...      ...
# 7765965         None                          None   NaN     <NA>
# 7765966         None                          None   NaN     <NA>
# 7765967         None                          None   NaN     <NA>
# 7765968         None                          None   NaN     <NA>
# 7765969         None                          None   NaN     <NA>
#
#         item_revenue item_list_index promotion_name
# 0                0.0               2      (not set)
# 1                0.0               5      (not set)
# 2                0.0              11      (not set)
# 3                0.0               1      (not set)
# 4                0.0               5      (not set)
# ...              ...             ...            ...
# 7765965          NaN            <NA>           None
# 7765966          NaN            <NA>           None
# 7765967          NaN            <NA>           None
# 7765968          NaN            <NA>           None
# 7765969          NaN            <NA>           None
#
# [7765970 rows x 48 columns]

# %% [markdown]
# # Example 2: Query a table with BigQuery DataFrames

# %%
# With BigQuery DataFrames, you can use many familiar Pandas methods, but the
# processing happens BigQuery rather than the runtime, allowing you to work with larger
# DataFrames that would otherwise not fit in the runtime memory.
# Learn more here: https://cloud.google.com/python/docs/reference/bigframes/latest

import bigframes.pandas as bf

bf.options.bigquery.location = "US" #this variable is set based on the dataset you chose to query
bf.options.bigquery.project = "ist-data-science" #this variable is set based on the dataset you chose to query

# %%
df = bf.read_gbq("ist-data-science.ga4_google_merch_store.flattened_raw") #this variable is set based on the dataset you chose to query
# Out:
# WARNING: google.colab.auth.authenticate_user() is not supported in Colab Enterprise.
# /usr/local/lib/python3.10/dist-packages/bigframes/session/_io/bigquery/read_gbq_table.py:261: DefaultIndexWarning: Table 'ist-data-science.ga4_google_merch_store.flattened_raw' is clustered and/or partitioned, but BigQuery DataFrames was not able to find a suitable index. To avoid this warning, set at least one of: `index_col` or `filters`.
#   warnings.warn(

# %%
# BigFrames can work with tables that are too large to fit in the notebook memory.
# Look at the first 20 rows.
df.head(20)
# Out:
# 14  1605571567688496  https://shop.googlemerchandisestore.com/Google...
# 15  1611363738757656           https://shop.googlemerchandisestore.com/
# 16  1612072724384624  https://shop.googlemerchandisestore.com/Google...
# 17  1610349560685869  https://shop.googlemerchandisestore.com/Google...
# 18  1606931713810963  https://shop.googlemerchandisestore.com/Google...
# 19  1607618653959208  https://shop.googlemerchandisestore.com/Google...
#
#                                            page_title device_category  \
# 0         Bags | Lifestyle | Google Merchandise Store         desktop
# 1         Womens | Apparel | Google Merchandise Store         desktop
# 2         Womens | Apparel | Google Merchandise Store         desktop
# 3   Men's / Unisex | Apparel | Google Merchandise ...         desktop
# 4   Men's / Unisex | Apparel | Google Merchandise ...         desktop
# 5                  Apparel | Google Merchandise Store          mobile
# 6                  Apparel | Google Merchandise Store         desktop
# 7                      New | Google Merchandise Store          mobile
# 8   Mugs & Tumblers | Drinkware | Google Merchandi...          mobile
# 9   Notebooks | Stationery | Google Merchandise Store         desktop
# 10  Men's T-Shirts | Apparel | Google Merchandise ...          mobile
# 11                                               Home          mobile
# 12                                          Lifestyle          mobile
# 13  Google | Shop by Brand | Google Merchandise Store          mobile
# 14       Campus Collection | Google Merchandise Store          mobile
# 15                                               Home          mobile
# 16                    Sale | Google Merchandise Store         desktop
# 17                    Google Seattle Campus Lapel Pin         desktop
# 18          Hats | Apparel | Google Merchandise Store         desktop
# 19          Hats | Apparel | Google Merchandise Store         desktop
#
#    device_mobile_brand_name device_mobile_model_name  ...         item_id  \
# 0                    Google                   Chrome  ...  GGOEGBJC122399
# 1                     Apple                   Safari  ...    GGOEGXXX1264
# 2                     Apple                   Safari  ...    GGCOGXXX1007
# 3                    Google                   Chrome  ...    GGOEAXXX1308
# 4                     Apple                   Safari  ...    GGOEGXXX1040
# 5                   Samsung                  <Other>  ...            <NA>
# 6                    Google                   Chrome  ...  GGOEGAEB105210
# 7                   Samsung                  <Other>  ...  GGCOGDHC161299
# 8                   Samsung                  <Other>  ...  GGOEGDBJ132299
# 9                    Google                   Chrome  ...  GGOEGOCR132199
# 10                    Apple                   iPhone  ...            <NA>
# 11                  Samsung                  <Other>  ...       (not set)
# 12                   Huawei                  <Other>  ...  GGOEGDHL116999
# 13                  <Other>                  <Other>  ...  GGOEGDHG162299
# 14                    Apple                   iPhone  ...            <NA>
# 15                  Samsung                  <Other>  ...            <NA>
# 16                   Google                   Chrome  ...    GGOEGXXX1181
# 17                   Google                   Chrome  ...            <NA>
# 18                   Google               ChromeBook  ...  GGOEGHPB120910
# 19                   Google                   Chrome  ...  GGOEYHPB121110
#
#                                  item_name item_brand item_variant  \
# 0             Google Campus Bike Tote Navy  (not set)    (not set)
# 1                Android Garden Tee Orange  (not set)    (not set)
# 2            #IamRemarkable Ladies T-Shirt  (not set)    (not set)
# 3       Android Iconic Crewneck Sweatshirt  (not set)    (not set)
# 4                Google Tudes Recycled Tee  (not set)    (not set)
# 5                                     <NA>       <NA>         <NA>
# 6                        Google Crew Socks  (not set)    (not set)
# 7                    Google Blue Stojo Cup  (not set)    (not set)
# 8             Stainless Bent Straw/Cleaner  (not set)    (not set)
# 9                Google ApPeel Journal Red  (not set)    (not set)
# 10                                    <NA>       <NA>         <NA>
# 11                               (not set)  (not set)    (not set)
# 12               Google Campus Bike Bottle  (not set)    (not set)
# 13  Google Land & Sea Nalgene Water Bottle  (not set)    (not set)
# 14                                    <NA>       <NA>         <NA>
# 15                                    <NA>       <NA>         <NA>
# 16              Google Women's Striped L/S  (not set)    (not set)
# 17                                    <NA>       <NA>         <NA>
# 18          Google Leather Strap Hat Black  (not set)    (not set)
# 19         YouTube Leather Strap Hat Black  (not set)    (not set)
#
#                    item_category price quantity item_revenue item_list_index  \
# 0                Lifestyle/Bags/  11.0     <NA>          0.0               6
# 1          Home/Apparel/Women's/  29.0     <NA>          0.0              11
# 2          Home/Apparel/Women's/  12.0     <NA>          0.0              12
# 3   Home/Apparel/Men's / Unisex/  55.0     <NA>          0.0               9
# 4   Home/Apparel/Men's / Unisex/  30.0     <NA>          0.0              11
# 5                           <NA>  <NA>     <NA>         <NA>            <NA>
# 6                  Home/Apparel/  16.0     <NA>          0.0               7
# 7                      Home/New/  25.0     <NA>          0.0              10
# 8               Mugs & Tumblers/   4.0     <NA>          0.0               9
# 9     Home/Stationery/Notebooks/  19.0     <NA>          0.0               7
# 10                          <NA>  <NA>     <NA>         <NA>            <NA>
# 11                     (not set)  <NA>     <NA>          0.0               1
# 12                    Lifestyle/  27.0     <NA>          0.0               8
# 13    Home/Shop by Brand/Google/  25.0     <NA>          0.0              11
# 14                          <NA>  <NA>     <NA>         <NA>            <NA>
# 15                          <NA>  <NA>     <NA>         <NA>            <NA>
# 16                    Home/Sale/  29.0     <NA>          0.0              11
# 17                          <NA>  <NA>     <NA>         <NA>            <NA>
# 18            Home/Apparel/Hats/  17.0     <NA>          0.0               2
# 19            Home/Apparel/Hats/  17.0     <NA>          0.0               4
#
#        promotion_name
# 0           (not set)
# 1           (not set)
# 2           (not set)
# 3           (not set)
# 4           (not set)
# 5                <NA>
# 6           (not set)
# 7           (not set)
# 8           (not set)
# 9           (not set)
# 10               <NA>
# 11  Reach New Heights
# 12          (not set)
# 13          (not set)
# 14               <NA>
# 15               <NA>
# 16          (not set)
# 17               <NA>
# 18          (not set)
# 19          (not set)
#
# [20 rows x 48 columns]

# %%
df.shape
# Out:
# Query job e22c8c82-ad9b-404c-afcb-10d352fa8b20 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=ist-data-science&j=bq:US:e22c8c82-ad9b-404c-afcb-10d352fa8b20&page=queryresults">Open Job</a>
# (7765970, 48)

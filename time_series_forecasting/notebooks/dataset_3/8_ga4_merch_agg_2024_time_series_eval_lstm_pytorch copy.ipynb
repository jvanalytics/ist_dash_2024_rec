# %% [markdown]
# # Install pytorch
# - https://pytorch.org/
#
# 1. Go to anaconda terminal as admin and enter
# ```bash
# conda create --name pytorch_cpu python=3.12
# ```
#
# 2. activate environment
#
# ```bash
# conda activate pytorch_cpu
# ```
#
# 3. install pytorch
# ```bash
#
# # CPU Only Windows and Linux
# conda install pytorch==2.5.0 torchvision==0.20.0 torchaudio==2.5.0 cpuonly -c pytorch
#
# # MAC OSX
# conda install pytorch==2.5.0 torchvision==0.20.0 torchaudio==2.5.0 -c pytorch
#
# ```
#
# 4. install additional packages from dslabs and data functions
# ```bash
# conda install pandas scikit-learn matplotlib statsmodels
# ```
#
# 5. if jupyter has errors run
#
# ```bash
# conda install -n pytorch_cpu ipykernel --update-deps --force-reinstall
# ```

# %% [markdown]
# # DSLabs functions

# %%
# %run "scripts/dslabs_functions.py"

# %% [markdown]
# # Data functions

# %%
# %run "scripts/data_functions.py"
# Out:
# data_functions loaded

# %% [markdown]
# # Load

# %%
import pandas as pd
import numpy as np


file_tag = "Google Merch Store 2024-2025"


# smoothed time series with split. uncomment to use
# train=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_train.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)
# test=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_test.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)


# unsmoothed time series with split to test the model. uncomment to use
test_split_threshold = 0.7
data_no_smoothing=pd.read_csv('data/df_merch_0_2024_agg_time_diff_input.csv', decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)     
train, test = series_train_test_split(data_no_smoothing, trn_pct=test_split_threshold)





target='Sessions'


test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 128 entries, 2024-10-29 to 2025-03-05
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Sessions                         128 non-null    float64
#  1   Seven-day active users           128 non-null    float64
#  2   28-day active users              128 non-null    float64
#  3   Events per session               128 non-null    float64
#  4   Add to baskets                   128 non-null    float64
#  5   Checkouts                        128 non-null    float64
#  6   E-commerce purchases             128 non-null    float64
#  7   Average purchase revenue         128 non-null    float64
#  8   Purchase revenue                 128 non-null    float64
#  9   Average session duration         128 non-null    float64
#  10  ARPU                             128 non-null    float64
#  11  ARPPU                            128 non-null    float64
#  12  Views per user                   128 non-null    float64
#  13  Total users                      128 non-null    float64
#  14  Promotion views                  128 non-null    float64
#  15  Promotion clicks                 128 non-null    float64
#  16  Sessions Mobile                  128 non-null    float64
#  17  Seven-day active users Mobile    128 non-null    float64
#  18  28-day active users Mobile       128 non-null    float64
#  19  New users Mobile                 128 non-null    float64
#  20  Scrolled users Mobile            128 non-null    float64
#  21  Engaged sessions Mobile          128 non-null    float64
#  22  Views Mobile                     128 non-null    float64
#  23  Event count Mobile               128 non-null    float64
#  24  Events per session Mobile        128 non-null    float64
#  25  Item-list view events Mobile     128 non-null    float64
#  26  Item view events Mobile          128 non-null    float64
#  27  Add to baskets Mobile            128 non-null    float64
#  28  Checkouts Mobile                 128 non-null    float64
#  29  E-commerce purchases Mobile      128 non-null    float64
#  30  Average purchase revenue Mobile  128 non-null    float64
#  31  Purchase revenue Mobile          128 non-null    float64
#  32  First time purchasers Mobile     128 non-null    float64
#  33  Average session duration Mobile  128 non-null    float64
#  34  Sessions (not set)               128 non-null    float64
#  35  Sessions affiliate               128 non-null    float64
#  36  Sessions cpc                     128 non-null    float64
#  37  Sessions cpm                     128 non-null    float64
#  38  Sessions email                   128 non-null    float64
#  39  Sessions organic                 128 non-null    float64
#  40  Sessions other                   128 non-null    float64
#  41  Sessions referral                128 non-null    float64
#  42  season                           128 non-null    float64
#  43  commercial_season                128 non-null    float64
#  44  is_weekend                       128 non-null    float64
#  45  is_holiday                       128 non-null    float64
# dtypes: float64(46)
# memory usage: 47.0 KB

# %% [markdown]
# # LSTM Pytorch Univariate

# %% [markdown]
# ## Univariate Pytorch Functions and data prep

# %%
from torch import no_grad, tensor
from torch.nn import LSTM, Linear, Module, MSELoss
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset


def prepare_dataset_for_lstm_uni(series, seq_length: int = 4):
    setX: list = []
    setY: list = []
    for i in range(len(series) - seq_length):
        past = series[i : i + seq_length]
        future = series[i + 1 : i + seq_length + 1]
        setX.append(past)
        setY.append(future)
    return tensor(setX), tensor(setY)


class DS_LSTM_Univariate(Module):
    def __init__(self, train, input_size: int = 1, hidden_size: int = 50, num_layers: int = 1, length: int = 4):
        super().__init__()
        self.lstm = LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.linear = Linear(hidden_size, 1)
        self.optimizer = Adam(self.parameters())
        self.loss_fn = MSELoss()

        trnX, trnY = prepare_dataset_for_lstm_uni(train, seq_length=length)
        self.loader = DataLoader(TensorDataset(trnX, trnY), shuffle=True, batch_size=len(train) // 10)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.linear(x)
        return x

    def fit(self):
        self.train()
        for batchX, batchY in self.loader:
            y_pred = self(batchX)
            loss = self.loss_fn(y_pred, batchY)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
        return loss

    def predict(self, X):
        with no_grad():
            y_pred = self(X)
        return y_pred[:, -1, :]

# %%
from dslabs_functions import HEIGHT, plot_multiline_chart
from copy import deepcopy

from matplotlib.pyplot import figure, savefig, subplots
from dslabs_functions import FORECAST_MEASURES, DELTA_IMPROVE, plot_multiline_chart


def lstm_study_uni(train, nr_episodes: int = 1000, sequence_size: list = [2, 4, 8], nr_hidden_units: list = [25, 50, 100], measure: str = "R2", val_split: float = 0.2):
    """
    Train, study, and validate an LSTM model using only the training dataset.

    Parameters:
    - train: Training dataset (DataFrame)
    - nr_episodes: Number of training episodes
    - sequence_size: List of sequence lengths to evaluate
    - nr_hidden_units: List of hidden unit sizes to evaluate
    - measure: Evaluation metric (e.g., "R2")
    - val_split: Fraction of the training data to use for validation (default: 20%)

    Returns:
    - best_model: The best LSTM model based on validation performance
    - best_params: Parameters of the best model
    """
    # Split the training data into training and validation subsets
    train_data, val_data = train_test_split(train, test_size=val_split, shuffle=False)

    step: int = nr_episodes // 10
    episodes = [1] + list(range(0, nr_episodes + 1, step))[1:]
    flag = measure == "R2" or measure == "MAPE"
    best_model = None
    best_params: dict = {"name": "LSTM", "metric": measure, "params": ()}
    best_performance: float = -100000

    _, axs = subplots(1, len(sequence_size), figsize=(len(sequence_size) * HEIGHT, HEIGHT))

    for i in range(len(sequence_size)):
        length = sequence_size[i]
        # Prepare datasets for LSTM
        trnX, trnY = prepare_dataset_for_lstm_uni(train_data, seq_length=length)
        valX, valY = prepare_dataset_for_lstm_uni(val_data, seq_length=length)

        values = {}
        for hidden in nr_hidden_units:
            yvalues = []
            model = DS_LSTM_Univariate(train_data, hidden_size=hidden)
            for n in range(0, nr_episodes + 1):
                model.fit()
                if n % step == 0:
                    prd_val = model.predict(valX)
                    # Evaluate on validation predictions
                    eval: float = FORECAST_MEASURES[measure](val_data[length:], prd_val)
                    print(f"seq length={length} hidden_units={hidden} nr_episodes={n}", eval)
                    if eval > best_performance and abs(eval - best_performance) > DELTA_IMPROVE:
                        best_performance: float = eval
                        best_params["params"] = (length, hidden, n)
                        best_model = deepcopy(model)
                    yvalues.append(eval)
            values[hidden] = yvalues
        plot_multiline_chart(
            episodes,
            values,
            ax=axs[i],
            title=f"LSTM seq length={length} ({measure})",
            xlabel="nr episodes",
            ylabel=measure,
            percentage=flag,
        )
    print(
        f"LSTM best results achieved with length={best_params['params'][0]} hidden_units={best_params['params'][1]} and nr_episodes={best_params['params'][2]}) ==> measure={best_performance:.2f}"
    )
    return best_model, best_params

# %% [markdown]
# ## Univariate Pytorch Study

# %%
# # Prepare the training and testing data using the time index as the feature
from numpy import arange


train_series_float = train[[target]].values.astype("float32")
test_series_float = test[[target]].values.astype("float32")


best_model, best_params = lstm_study_uni(train_series_float,
                                        #  test_series_float,
                                         nr_episodes=100,
                                         sequence_size=[5,7,14,21,28],
                                         nr_hidden_units=[5,10,15,25,50,100],
                                         measure='R2',
                                         val_split=0.2)
# Out:
# seq length=5 hidden_units=5 nr_episodes=0 -0.21194839477539062
# seq length=5 hidden_units=5 nr_episodes=10 0.04206812381744385
# seq length=5 hidden_units=5 nr_episodes=20 0.06634438037872314
# seq length=5 hidden_units=5 nr_episodes=30 0.10940426588058472
# seq length=5 hidden_units=5 nr_episodes=40 0.16312092542648315
# seq length=5 hidden_units=5 nr_episodes=50 0.20503902435302734
# seq length=5 hidden_units=5 nr_episodes=60 0.22151625156402588
# seq length=5 hidden_units=5 nr_episodes=70 0.2325800657272339
# seq length=5 hidden_units=5 nr_episodes=80 0.23762941360473633
# seq length=5 hidden_units=5 nr_episodes=90 0.24380642175674438
# seq length=5 hidden_units=5 nr_episodes=100 0.24513226747512817
# seq length=5 hidden_units=10 nr_episodes=0 -0.08982372283935547
# seq length=5 hidden_units=10 nr_episodes=10 0.05640459060668945
# seq length=5 hidden_units=10 nr_episodes=20 0.18653416633605957
# seq length=5 hidden_units=10 nr_episodes=30 0.2585868835449219
# seq length=5 hidden_units=10 nr_episodes=40 0.27759885787963867
# seq length=5 hidden_units=10 nr_episodes=50 0.27550458908081055
# seq length=5 hidden_units=10 nr_episodes=60 0.25188958644866943
# seq length=5 hidden_units=10 nr_episodes=70 0.2315889596939087
# seq length=5 hidden_units=10 nr_episodes=80 0.21158254146575928
# seq length=5 hidden_units=10 nr_episodes=90 0.1719629168510437
# seq length=5 hidden_units=10 nr_episodes=100 0.14982378482818604
# seq length=5 hidden_units=15 nr_episodes=0 -0.00484311580657959
# seq length=5 hidden_units=15 nr_episodes=10 0.14163297414779663
# seq length=5 hidden_units=15 nr_episodes=20 0.3048993945121765
# seq length=5 hidden_units=15 nr_episodes=30 0.29616546630859375
# seq length=5 hidden_units=15 nr_episodes=40 0.3011487126350403
# seq length=5 hidden_units=15 nr_episodes=50 0.2962002158164978
# seq length=5 hidden_units=15 nr_episodes=60 0.28315019607543945
# seq length=5 hidden_units=15 nr_episodes=70 0.253558874130249
# seq length=5 hidden_units=15 nr_episodes=80 0.23133164644241333
# seq length=5 hidden_units=15 nr_episodes=90 0.17942070960998535
# seq length=5 hidden_units=15 nr_episodes=100 0.1675378680229187
# seq length=5 hidden_units=25 nr_episodes=0 0.011563718318939209
# seq length=5 hidden_units=25 nr_episodes=10 0.24404776096343994
# seq length=5 hidden_units=25 nr_episodes=20 0.29435592889785767
# seq length=5 hidden_units=25 nr_episodes=30 0.28526949882507324
# seq length=5 hidden_units=25 nr_episodes=40 0.2772558927536011
# seq length=5 hidden_units=25 nr_episodes=50 0.258727490901947
# seq length=5 hidden_units=25 nr_episodes=60 0.23004812002182007
# seq length=5 hidden_units=25 nr_episodes=70 0.22304731607437134
# seq length=5 hidden_units=25 nr_episodes=80 0.19456344842910767
# seq length=5 hidden_units=25 nr_episodes=90 0.16991740465164185
# seq length=5 hidden_units=25 nr_episodes=100 0.1766182780265808
# seq length=5 hidden_units=50 nr_episodes=0 0.03041219711303711
# seq length=5 hidden_units=50 nr_episodes=10 0.3141134977340698
# seq length=5 hidden_units=50 nr_episodes=20 0.2696133255958557
# seq length=5 hidden_units=50 nr_episodes=30 0.2998684048652649
# seq length=5 hidden_units=50 nr_episodes=40 0.2884976267814636
# seq length=5 hidden_units=50 nr_episodes=50 0.25981301069259644
# seq length=5 hidden_units=50 nr_episodes=60 0.2282359004020691
# seq length=5 hidden_units=50 nr_episodes=70 0.2029232382774353
# seq length=5 hidden_units=50 nr_episodes=80 0.19857823848724365
# seq length=5 hidden_units=50 nr_episodes=90 0.22305399179458618
# seq length=5 hidden_units=50 nr_episodes=100 0.21580904722213745
# seq length=5 hidden_units=100 nr_episodes=0 0.03408235311508179
# seq length=5 hidden_units=100 nr_episodes=10 0.2613617181777954
# seq length=5 hidden_units=100 nr_episodes=20 0.2974969744682312
# seq length=5 hidden_units=100 nr_episodes=30 0.2929289937019348
# seq length=5 hidden_units=100 nr_episodes=40 0.22954899072647095
# seq length=5 hidden_units=100 nr_episodes=50 0.22237128019332886
# seq length=5 hidden_units=100 nr_episodes=60 0.25265026092529297
# seq length=5 hidden_units=100 nr_episodes=70 0.26185834407806396
# seq length=5 hidden_units=100 nr_episodes=80 0.23107409477233887
# seq length=5 hidden_units=100 nr_episodes=90 0.19604885578155518
# seq length=5 hidden_units=100 nr_episodes=100 0.16313040256500244
# seq length=7 hidden_units=5 nr_episodes=0 -0.3464447259902954
# seq length=7 hidden_units=5 nr_episodes=10 0.02185910940170288
# seq length=7 hidden_units=5 nr_episodes=20 -0.010334610939025879
# seq length=7 hidden_units=5 nr_episodes=30 0.03356689214706421
# seq length=7 hidden_units=5 nr_episodes=40 0.07299083471298218
# seq length=7 hidden_units=5 nr_episodes=50 0.13591516017913818
# seq length=7 hidden_units=5 nr_episodes=60 0.16411393880844116
# seq length=7 hidden_units=5 nr_episodes=70 0.19145643711090088
# seq length=7 hidden_units=5 nr_episodes=80 0.20547592639923096
# seq length=7 hidden_units=5 nr_episodes=90 0.20186841487884521
# seq length=7 hidden_units=5 nr_episodes=100 0.19076639413833618
# seq length=7 hidden_units=10 nr_episodes=0 -0.000914454460144043
# seq length=7 hidden_units=10 nr_episodes=10 0.032791972160339355
# seq length=7 hidden_units=10 nr_episodes=20 0.033019959926605225
# seq length=7 hidden_units=10 nr_episodes=30 0.023364245891571045
# seq length=7 hidden_units=10 nr_episodes=40 0.11533969640731812
# seq length=7 hidden_units=10 nr_episodes=50 0.155767560005188
# seq length=7 hidden_units=10 nr_episodes=60 0.1755395531654358
# seq length=7 hidden_units=10 nr_episodes=70 0.19245964288711548
# seq length=7 hidden_units=10 nr_episodes=80 0.17280733585357666
# seq length=7 hidden_units=10 nr_episodes=90 0.15808916091918945
# seq length=7 hidden_units=10 nr_episodes=100 0.135833740234375
# seq length=7 hidden_units=15 nr_episodes=0 -0.004041433334350586
# seq length=7 hidden_units=15 nr_episodes=10 0.0725785493850708
# seq length=7 hidden_units=15 nr_episodes=20 0.13058191537857056
# seq length=7 hidden_units=15 nr_episodes=30 0.18369311094284058
# seq length=7 hidden_units=15 nr_episodes=40 0.20087778568267822
# seq length=7 hidden_units=15 nr_episodes=50 0.20109343528747559
# seq length=7 hidden_units=15 nr_episodes=60 0.1880054473876953
# seq length=7 hidden_units=15 nr_episodes=70 0.16449075937271118
# seq length=7 hidden_units=15 nr_episodes=80 0.13748478889465332
# seq length=7 hidden_units=15 nr_episodes=90 0.11357063055038452
# seq length=7 hidden_units=15 nr_episodes=100 0.10840332508087158
# seq length=7 hidden_units=25 nr_episodes=0 0.007256448268890381
# seq length=7 hidden_units=25 nr_episodes=10 0.12554031610488892
# seq length=7 hidden_units=25 nr_episodes=20 0.18240052461624146
# seq length=7 hidden_units=25 nr_episodes=30 0.19606655836105347
# seq length=7 hidden_units=25 nr_episodes=40 0.1738775372505188
# seq length=7 hidden_units=25 nr_episodes=50 0.15268301963806152
# seq length=7 hidden_units=25 nr_episodes=60 0.10651248693466187
# seq length=7 hidden_units=25 nr_episodes=70 0.09368395805358887
# seq length=7 hidden_units=25 nr_episodes=80 0.04261362552642822
# seq length=7 hidden_units=25 nr_episodes=90 -0.007131814956665039
# seq length=7 hidden_units=25 nr_episodes=100 -0.048416972160339355
# seq length=7 hidden_units=50 nr_episodes=0 0.020520567893981934
# seq length=7 hidden_units=50 nr_episodes=10 0.04442316293716431
# seq length=7 hidden_units=50 nr_episodes=20 0.12686586380004883
# seq length=7 hidden_units=50 nr_episodes=30 0.18363142013549805
# seq length=7 hidden_units=50 nr_episodes=40 0.11335277557373047
# seq length=7 hidden_units=50 nr_episodes=50 0.1274200677871704
# seq length=7 hidden_units=50 nr_episodes=60 0.061147987842559814
# seq length=7 hidden_units=50 nr_episodes=70 -0.02830648422241211
# seq length=7 hidden_units=50 nr_episodes=80 -0.09834837913513184
# seq length=7 hidden_units=50 nr_episodes=90 -0.20923984050750732
# seq length=7 hidden_units=50 nr_episodes=100 -0.17488384246826172
# seq length=7 hidden_units=100 nr_episodes=0 0.013615310192108154
# seq length=7 hidden_units=100 nr_episodes=10 0.1704273819923401
# seq length=7 hidden_units=100 nr_episodes=20 0.09346961975097656
# seq length=7 hidden_units=100 nr_episodes=30 0.03880029916763306
# seq length=7 hidden_units=100 nr_episodes=40 -0.03565073013305664
# seq length=7 hidden_units=100 nr_episodes=50 -0.2385481595993042
# seq length=7 hidden_units=100 nr_episodes=60 -0.044429898262023926
# seq length=7 hidden_units=100 nr_episodes=70 -0.1742159128189087
# seq length=7 hidden_units=100 nr_episodes=80 -0.23536896705627441
# seq length=7 hidden_units=100 nr_episodes=90 -0.3356149196624756
# seq length=7 hidden_units=100 nr_episodes=100 -0.4907413721084595
# seq length=14 hidden_units=5 nr_episodes=0 -0.06505787372589111
# seq length=14 hidden_units=5 nr_episodes=10 -0.03925478458404541
# seq length=14 hidden_units=5 nr_episodes=20 -0.01682150363922119
# seq length=14 hidden_units=5 nr_episodes=30 -0.03024590015411377
# seq length=14 hidden_units=5 nr_episodes=40 -0.045903921127319336
# seq length=14 hidden_units=5 nr_episodes=50 0.06700307130813599
# seq length=14 hidden_units=5 nr_episodes=60 0.14945530891418457
# seq length=14 hidden_units=5 nr_episodes=70 0.19750607013702393
# seq length=14 hidden_units=5 nr_episodes=80 0.2111099362373352
# seq length=14 hidden_units=5 nr_episodes=90 0.20153206586837769
# seq length=14 hidden_units=5 nr_episodes=100 0.20768076181411743
# seq length=14 hidden_units=10 nr_episodes=0 -0.15368521213531494
# seq length=14 hidden_units=10 nr_episodes=10 0.012996673583984375
# seq length=14 hidden_units=10 nr_episodes=20 0.13180744647979736
# seq length=14 hidden_units=10 nr_episodes=30 0.15239757299423218
# seq length=14 hidden_units=10 nr_episodes=40 0.11666935682296753
# seq length=14 hidden_units=10 nr_episodes=50 0.1766369342803955
# seq length=14 hidden_units=10 nr_episodes=60 0.1876990795135498
# seq length=14 hidden_units=10 nr_episodes=70 0.2244936227798462
# seq length=14 hidden_units=10 nr_episodes=80 0.22253936529159546
# seq length=14 hidden_units=10 nr_episodes=90 0.18526148796081543
# seq length=14 hidden_units=10 nr_episodes=100 0.12165844440460205
# seq length=14 hidden_units=15 nr_episodes=0 -0.009895682334899902
# seq length=14 hidden_units=15 nr_episodes=10 0.031239449977874756
# seq length=14 hidden_units=15 nr_episodes=20 -0.2525811195373535
# seq length=14 hidden_units=15 nr_episodes=30 0.040729403495788574
# seq length=14 hidden_units=15 nr_episodes=40 0.17587685585021973
# seq length=14 hidden_units=15 nr_episodes=50 0.20618444681167603
# seq length=14 hidden_units=15 nr_episodes=60 0.2070174217224121
# seq length=14 hidden_units=15 nr_episodes=70 0.18978673219680786
# seq length=14 hidden_units=15 nr_episodes=80 0.17353659868240356
# seq length=14 hidden_units=15 nr_episodes=90 0.14795541763305664
# seq length=14 hidden_units=15 nr_episodes=100 0.10857033729553223
# seq length=14 hidden_units=25 nr_episodes=0 -0.08343100547790527
# seq length=14 hidden_units=25 nr_episodes=10 -0.4404311180114746
# seq length=14 hidden_units=25 nr_episodes=20 -0.1462247371673584
# seq length=14 hidden_units=25 nr_episodes=30 0.18109643459320068
# seq length=14 hidden_units=25 nr_episodes=40 0.21576178073883057
# seq length=14 hidden_units=25 nr_episodes=50 0.2095651626586914
# seq length=14 hidden_units=25 nr_episodes=60 0.1705668568611145
# seq length=14 hidden_units=25 nr_episodes=70 -0.0015376806259155273
# seq length=14 hidden_units=25 nr_episodes=80 -0.1764218807220459
# seq length=14 hidden_units=25 nr_episodes=90 -0.26025307178497314
# seq length=14 hidden_units=25 nr_episodes=100 -0.5121922492980957
# seq length=14 hidden_units=50 nr_episodes=0 0.006058871746063232
# seq length=14 hidden_units=50 nr_episodes=10 -0.24533414840698242
# seq length=14 hidden_units=50 nr_episodes=20 0.09664160013198853
# seq length=14 hidden_units=50 nr_episodes=30 0.22887003421783447
# seq length=14 hidden_units=50 nr_episodes=40 0.18398696184158325
# seq length=14 hidden_units=50 nr_episodes=50 0.03078216314315796
# seq length=14 hidden_units=50 nr_episodes=60 -0.16015100479125977
# seq length=14 hidden_units=50 nr_episodes=70 -0.24127185344696045
# seq length=14 hidden_units=50 nr_episodes=80 -0.29337239265441895
# seq length=14 hidden_units=50 nr_episodes=90 -0.833503246307373
# seq length=14 hidden_units=50 nr_episodes=100 -1.1095161437988281
# seq length=14 hidden_units=100 nr_episodes=0 0.02348107099533081
# seq length=14 hidden_units=100 nr_episodes=10 -0.33795464038848877
# seq length=14 hidden_units=100 nr_episodes=20 -0.5877475738525391
# seq length=14 hidden_units=100 nr_episodes=30 -0.74346923828125
# seq length=14 hidden_units=100 nr_episodes=40 -1.278306007385254
# seq length=14 hidden_units=100 nr_episodes=50 -0.8431473970413208
# seq length=14 hidden_units=100 nr_episodes=60 -0.4578707218170166
# seq length=14 hidden_units=100 nr_episodes=70 -3.468289852142334
# seq length=14 hidden_units=100 nr_episodes=80 -3.3237791061401367
# seq length=14 hidden_units=100 nr_episodes=90 -5.931278228759766
# seq length=14 hidden_units=100 nr_episodes=100 -3.4869565963745117
# seq length=21 hidden_units=5 nr_episodes=0 -0.024546027183532715
# seq length=21 hidden_units=5 nr_episodes=10 0.02171880006790161
# seq length=21 hidden_units=5 nr_episodes=20 0.0720682144165039
# seq length=21 hidden_units=5 nr_episodes=30 0.09929615259170532
# seq length=21 hidden_units=5 nr_episodes=40 0.12191259860992432
# seq length=21 hidden_units=5 nr_episodes=50 0.15899288654327393
# seq length=21 hidden_units=5 nr_episodes=60 0.19588619470596313
# seq length=21 hidden_units=5 nr_episodes=70 0.21857380867004395
# seq length=21 hidden_units=5 nr_episodes=80 0.2134709358215332
# seq length=21 hidden_units=5 nr_episodes=90 0.20909923315048218
# seq length=21 hidden_units=5 nr_episodes=100 0.2066361904144287
# seq length=21 hidden_units=10 nr_episodes=0 -0.04345345497131348
# seq length=21 hidden_units=10 nr_episodes=10 0.0006712675094604492
# seq length=21 hidden_units=10 nr_episodes=20 0.05945706367492676
# seq length=21 hidden_units=10 nr_episodes=30 -0.01165759563446045
# seq length=21 hidden_units=10 nr_episodes=40 -0.07217156887054443
# seq length=21 hidden_units=10 nr_episodes=50 -0.10539638996124268
# seq length=21 hidden_units=10 nr_episodes=60 -0.08234786987304688
# seq length=21 hidden_units=10 nr_episodes=70 -0.09720969200134277
# seq length=21 hidden_units=10 nr_episodes=80 -0.0869133472442627
# seq length=21 hidden_units=10 nr_episodes=90 -0.09844207763671875
# seq length=21 hidden_units=10 nr_episodes=100 -0.09693694114685059
# seq length=21 hidden_units=15 nr_episodes=0 -0.10894107818603516
# seq length=21 hidden_units=15 nr_episodes=10 0.04005587100982666
# seq length=21 hidden_units=15 nr_episodes=20 0.11375308036804199
# seq length=21 hidden_units=15 nr_episodes=30 0.07107788324356079
# seq length=21 hidden_units=15 nr_episodes=40 0.11494207382202148
# seq length=21 hidden_units=15 nr_episodes=50 0.19904470443725586
# seq length=21 hidden_units=15 nr_episodes=60 0.2147945761680603
# seq length=21 hidden_units=15 nr_episodes=70 0.18376457691192627
# seq length=21 hidden_units=15 nr_episodes=80 0.07882916927337646
# seq length=21 hidden_units=15 nr_episodes=90 -0.059033870697021484
# seq length=21 hidden_units=15 nr_episodes=100 -0.27046680450439453
# seq length=21 hidden_units=25 nr_episodes=0 0.013401329517364502
# seq length=21 hidden_units=25 nr_episodes=10 -0.8818533420562744
# seq length=21 hidden_units=25 nr_episodes=20 -0.016125798225402832
# seq length=21 hidden_units=25 nr_episodes=30 0.20927804708480835
# seq length=21 hidden_units=25 nr_episodes=40 0.17869919538497925
# seq length=21 hidden_units=25 nr_episodes=50 -0.1560434103012085
# seq length=21 hidden_units=25 nr_episodes=60 -0.19261837005615234
# seq length=21 hidden_units=25 nr_episodes=70 -0.30097270011901855
# seq length=21 hidden_units=25 nr_episodes=80 -0.49752628803253174
# seq length=21 hidden_units=25 nr_episodes=90 -0.35449230670928955
# seq length=21 hidden_units=25 nr_episodes=100 -0.4041426181793213
# seq length=21 hidden_units=50 nr_episodes=0 0.009229540824890137
# seq length=21 hidden_units=50 nr_episodes=10 -4.293111801147461
# seq length=21 hidden_units=50 nr_episodes=20 0.073497474193573
# seq length=21 hidden_units=50 nr_episodes=30 -0.56644606590271
# seq length=21 hidden_units=50 nr_episodes=40 -0.5229668617248535
# seq length=21 hidden_units=50 nr_episodes=50 -0.7109110355377197
# seq length=21 hidden_units=50 nr_episodes=60 -0.5217477083206177
# seq length=21 hidden_units=50 nr_episodes=70 -0.46447789669036865
# seq length=21 hidden_units=50 nr_episodes=80 -1.101381540298462
# seq length=21 hidden_units=50 nr_episodes=90 -1.3350610733032227
# seq length=21 hidden_units=50 nr_episodes=100 -2.139596939086914
# seq length=21 hidden_units=100 nr_episodes=0 0.021164894104003906
# seq length=21 hidden_units=100 nr_episodes=10 0.22212332487106323
# seq length=21 hidden_units=100 nr_episodes=20 -0.37181663513183594
# seq length=21 hidden_units=100 nr_episodes=30 -0.9007656574249268
# seq length=21 hidden_units=100 nr_episodes=40 -1.8275985717773438
# seq length=21 hidden_units=100 nr_episodes=50 -3.6069579124450684
# seq length=21 hidden_units=100 nr_episodes=60 -3.148789405822754
# seq length=21 hidden_units=100 nr_episodes=70 -2.6571919918060303
# seq length=21 hidden_units=100 nr_episodes=80 -3.3307604789733887
# seq length=21 hidden_units=100 nr_episodes=90 -2.646911382675171
# seq length=21 hidden_units=100 nr_episodes=100 -2.911588430404663
# seq length=28 hidden_units=5 nr_episodes=0 -0.09319782257080078
# seq length=28 hidden_units=5 nr_episodes=10 -0.004298806190490723
# seq length=28 hidden_units=5 nr_episodes=20 0.012709438800811768
# seq length=28 hidden_units=5 nr_episodes=30 0.05800741910934448
# seq length=28 hidden_units=5 nr_episodes=40 0.15711355209350586
# seq length=28 hidden_units=5 nr_episodes=50 0.1517108678817749
# seq length=28 hidden_units=5 nr_episodes=60 0.17453885078430176
# seq length=28 hidden_units=5 nr_episodes=70 0.18609219789505005
# seq length=28 hidden_units=5 nr_episodes=80 0.20734572410583496
# seq length=28 hidden_units=5 nr_episodes=90 0.18312561511993408
# seq length=28 hidden_units=5 nr_episodes=100 0.16420865058898926
# seq length=28 hidden_units=10 nr_episodes=0 -0.012700080871582031
# seq length=28 hidden_units=10 nr_episodes=10 0.045705556869506836
# seq length=28 hidden_units=10 nr_episodes=20 -0.3332139253616333
# seq length=28 hidden_units=10 nr_episodes=30 -0.7126246690750122
# seq length=28 hidden_units=10 nr_episodes=40 0.1282261610031128
# seq length=28 hidden_units=10 nr_episodes=50 0.18447554111480713
# seq length=28 hidden_units=10 nr_episodes=60 0.1838337779045105
# seq length=28 hidden_units=10 nr_episodes=70 0.14246362447738647
# seq length=28 hidden_units=10 nr_episodes=80 0.10678821802139282
# seq length=28 hidden_units=10 nr_episodes=90 0.059249281883239746
# seq length=28 hidden_units=10 nr_episodes=100 0.016005218029022217
# seq length=28 hidden_units=15 nr_episodes=0 0.03503859043121338
# seq length=28 hidden_units=15 nr_episodes=10 -0.08219718933105469
# seq length=28 hidden_units=15 nr_episodes=20 0.1844080686569214
# seq length=28 hidden_units=15 nr_episodes=30 0.11306935548782349
# seq length=28 hidden_units=15 nr_episodes=40 0.06616806983947754
# seq length=28 hidden_units=15 nr_episodes=50 0.05866658687591553
# seq length=28 hidden_units=15 nr_episodes=60 0.070281982421875
# seq length=28 hidden_units=15 nr_episodes=70 0.10778522491455078
# seq length=28 hidden_units=15 nr_episodes=80 0.06366896629333496
# seq length=28 hidden_units=15 nr_episodes=90 0.01847398281097412
# seq length=28 hidden_units=15 nr_episodes=100 -0.06563138961791992
# seq length=28 hidden_units=25 nr_episodes=0 0.005376875400543213
# seq length=28 hidden_units=25 nr_episodes=10 0.12215965986251831
# seq length=28 hidden_units=25 nr_episodes=20 0.18753093481063843
# seq length=28 hidden_units=25 nr_episodes=30 0.22450345754623413
# seq length=28 hidden_units=25 nr_episodes=40 0.12637263536453247
# seq length=28 hidden_units=25 nr_episodes=50 -0.10404884815216064
# seq length=28 hidden_units=25 nr_episodes=60 -0.14341199398040771
# seq length=28 hidden_units=25 nr_episodes=70 -0.17199110984802246
# seq length=28 hidden_units=25 nr_episodes=80 -0.11307954788208008
# seq length=28 hidden_units=25 nr_episodes=90 -0.10476446151733398
# seq length=28 hidden_units=25 nr_episodes=100 -0.25900864601135254
# seq length=28 hidden_units=50 nr_episodes=0 0.01247936487197876
# seq length=28 hidden_units=50 nr_episodes=10 -0.4799855947494507
# seq length=28 hidden_units=50 nr_episodes=20 -0.12188434600830078
# seq length=28 hidden_units=50 nr_episodes=30 -1.2230761051177979
# seq length=28 hidden_units=50 nr_episodes=40 -1.334947109222412
# seq length=28 hidden_units=50 nr_episodes=50 -0.7121797800064087
# seq length=28 hidden_units=50 nr_episodes=60 -0.7384216785430908
# seq length=28 hidden_units=50 nr_episodes=70 -1.4111840724945068
# seq length=28 hidden_units=50 nr_episodes=80 -4.2426066398620605
# seq length=28 hidden_units=50 nr_episodes=90 -2.7956621646881104
# seq length=28 hidden_units=50 nr_episodes=100 -4.074799060821533
# seq length=28 hidden_units=100 nr_episodes=0 0.01712888479232788
# seq length=28 hidden_units=100 nr_episodes=10 -0.11690998077392578
# seq length=28 hidden_units=100 nr_episodes=20 -8.303336143493652
# seq length=28 hidden_units=100 nr_episodes=30 -7.905169486999512
# seq length=28 hidden_units=100 nr_episodes=40 -4.976687908172607
# seq length=28 hidden_units=100 nr_episodes=50 -3.4421839714050293
# seq length=28 hidden_units=100 nr_episodes=60 -4.092308521270752
# seq length=28 hidden_units=100 nr_episodes=70 -10.165606498718262
# seq length=28 hidden_units=100 nr_episodes=80 -8.536096572875977
# seq length=28 hidden_units=100 nr_episodes=90 -10.058415412902832
# seq length=28 hidden_units=100 nr_episodes=100 -11.922252655029297
# LSTM best results achieved with length=5 hidden_units=50 and nr_episodes=10) ==> measure=0.31

# %% [markdown]
# ## Univariate Pytorch eval

# %%
params = best_params["params"]
best_length = params[0]


# Assuming train and test are DataFrames with a DateTime index
trn_series = train[[target]]
tst_series = test[[target]]


trnX, trnY = prepare_dataset_for_lstm_uni(trn_series.values.astype("float32"), seq_length=best_length)
tstX, tstY  = prepare_dataset_for_lstm_uni(tst_series.values.astype("float32"), seq_length=best_length)


prd_trn = best_model.predict(trnX)
prd_tst = best_model.predict(tstX)

# Plot the forecasting evaluation
plot_single_model_evaluation(trn_series[best_length:], tst_series[best_length:], prd_trn, prd_tst, title=f"{file_tag} - LSTM Univariate (length={best_length}, hidden={params[1]}, epochs={params[2]})")

# %% [markdown]
# ## Plot lstm tensorflow model univariate

# %%
from pandas import Series
pred_series = Series(prd_tst.numpy().ravel(), index=tst_series.index[best_length:])


plot_forecasting_series(
    trn_series[best_length:],
    tst_series[best_length:],
    pred_series,
    title=f"{file_tag} - LSTM Univariate Predictions (length={best_length}, hidden={params[1]}, epochs={params[2]})",
    xlabel='Date',
    ylabel=target,
)
# Out:
# <Axes: xlabel='Date', ylabel='Sessions'>

# %% [markdown]
# ## Pytorch Univariate Model and Loss

# %%
model = DS_LSTM_Univariate(train_series_float, input_size=train_series_float.shape[1], hidden_size=50, num_layers=1)
loss = model.fit()
print(loss)
# Out:
# tensor(0.9404, grad_fn=<MseLossBackward0>)

# %% [markdown]
# # LSTM Pytorch Multivariate

# %% [markdown]
# ## Pytorch Multivariate Functions

# %%
from torch import no_grad, tensor
from torch.nn import LSTM, Linear, Module, MSELoss
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

def prepare_dataset_for_lstm_multi(features, target, seq_length: int = 4):
    setX: list = []
    setY: list = []
    for i in range(len(target) - seq_length):
        past = features[i : i + seq_length]
        future = target[i + seq_length]  # Predict the next value only
        setX.append(past)
        setY.append(future)
    setX = tensor(np.array(setX, dtype=np.float32))  # Convert to torch.float32
    setY = tensor(np.array(setY, dtype=np.float32)).view(-1, 1)  # Convert to torch.float32 and reshape
    return setX, setY


class DS_LSTM_Multivariate(Module):
    def __init__(self, trainX, trainY, input_size: int, hidden_size: int = 50, num_layers: int = 1, length: int = 4):
        super().__init__()
        self.lstm = LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.linear = Linear(hidden_size, 1)
        self.optimizer = Adam(self.parameters())
        self.loss_fn = MSELoss()

        trnX, trnY = prepare_dataset_for_lstm_multi(trainX, trainY, seq_length=length)
        self.loader = DataLoader(TensorDataset(trnX, trnY), shuffle=True, batch_size=len(trainX) // 10)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.linear(x[:, -1, :])  # Use the last output of the LSTM
        return x

    def fit(self):
        self.train()
        for batchX, batchY in self.loader:
            y_pred = self(batchX)
            loss = self.loss_fn(y_pred, batchY)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
        return loss

    def predict(self, X):
        with no_grad():
            y_pred = self(X)
        return y_pred

from dslabs_functions import HEIGHT, plot_multiline_chart
from copy import deepcopy
from matplotlib.pyplot import figure, savefig, subplots
from dslabs_functions import FORECAST_MEASURES, DELTA_IMPROVE, plot_multiline_chart
from sklearn.model_selection import train_test_split

def lstm_study_multi(trainX, trainY, testX, testY, nr_episodes: int = 1000, sequence_size: list = [2, 4, 8], nr_hidden_units: list = [25, 50, 100], measure: str = "R2", val_split: float = 0.2):
    """
    Train, study, and validate a multivariate LSTM model using only the training dataset.

    Parameters:
    - trainX: Features of the training dataset
    - trainY: Target of the training dataset
    - testX: Features of the test dataset (not used during training)
    - testY: Target of the test dataset (not used during training)
    - nr_episodes: Number of training episodes
    - sequence_size: List of sequence lengths to evaluate
    - nr_hidden_units: List of hidden unit sizes to evaluate
    - measure: Evaluation metric (e.g., "R2")
    - val_split: Fraction of the training data to use for validation (default: 20%)

    Returns:
    - best_model: The best LSTM model based on validation performance
    - best_params: Parameters of the best model
    """
    # Split the training data into training and validation subsets
    trainX_split, valX_split, trainY_split, valY_split = train_test_split(trainX, trainY, test_size=val_split, shuffle=False)

    step: int = nr_episodes // 10
    episodes = [1] + list(range(0, nr_episodes + 1, step))[1:]
    flag = measure == "R2" or measure == "MAPE"
    best_model = None
    best_params: dict = {"name": "LSTM", "metric": measure, "params": ()}
    best_performance: float = -100000

    _, axs = subplots(1, len(sequence_size), figsize=(len(sequence_size) * HEIGHT, HEIGHT))

    for i in range(len(sequence_size)):
        length = sequence_size[i]
        # Prepare datasets for LSTM
        trnX, trnY = prepare_dataset_for_lstm_multi(trainX_split, trainY_split, seq_length=length)
        valX, valY = prepare_dataset_for_lstm_multi(valX_split, valY_split, seq_length=length)

        values = {}
        for hidden in nr_hidden_units:
            yvalues = []
            model = DS_LSTM_Multivariate(trainX_split, trainY_split, input_size=trainX.shape[1], hidden_size=hidden, length=length)
            for n in range(0, nr_episodes + 1):
                model.fit()
                if n % step == 0:
                    prd_val = model.predict(valX)
                    # Align lengths of valY and prd_val
                    eval: float = FORECAST_MEASURES[measure](valY[length:], prd_val[:len(valY[length:])])
                    print(f"seq length={length} hidden_units={hidden} nr_episodes={n}", eval)
                    if eval > best_performance and abs(eval - best_performance) > DELTA_IMPROVE:
                        best_performance: float = eval
                        best_params["params"] = (length, hidden, n)
                        best_model = deepcopy(model)
                    yvalues.append(eval)
            values[hidden] = yvalues
        plot_multiline_chart(
            episodes,
            values,
            ax=axs[i],
            title=f"LSTM seq length={length} ({measure})",
            xlabel="nr episodes",
            ylabel=measure,
            percentage=flag,
        )
    print(
        f"LSTM best results achieved with length={best_params['params'][0]} hidden_units={best_params['params'][1]} and nr_episodes={best_params['params'][2]}) ==> measure={best_performance:.2f}"
    )
    return best_model, best_params

# %% [markdown]
# ## Pytorch Multivariate Data Study

# %%
# smoothed time series with split. uncomment to use
# train=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_train.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)
# test=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_test.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)


# unsmoothed time series with split to test the model. uncomment to use
test_split_threshold = 0.7
data_no_smoothing=pd.read_csv('data/df_merch_0_2024_agg_time_diff_input.csv', decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)     
train, test = series_train_test_split(data_no_smoothing, trn_pct=test_split_threshold)







# Example usage
# Assuming `train` and `test` are your DataFrames and `target` is the target column name
trnY_float = train.pop(target).values.astype(np.float32)
tstY_float = test.pop(target).values.astype(np.float32)
trnX_float = train.values.astype(np.float32)
tstX_float = test.values.astype(np.float32)

# Run the study
best_model, best_params = lstm_study_multi(trnX_float,
                                            trnY_float,
                                            tstX_float,
                                            tstY_float,
                                            nr_episodes=100,
                                            sequence_size=[5,7,14,21,28],
                                            nr_hidden_units=[5,10,15,25,50,100],
                                            measure='R2',
                                            val_split=0.2)
# Out:
# seq length=5 hidden_units=5 nr_episodes=0 -0.1106171305455832
# seq length=5 hidden_units=5 nr_episodes=10 -0.13945392199485784
# seq length=5 hidden_units=5 nr_episodes=20 -0.18975778622697992
# seq length=5 hidden_units=5 nr_episodes=30 -0.2523243196447851
# seq length=5 hidden_units=5 nr_episodes=40 -0.33413870028395953
# seq length=5 hidden_units=5 nr_episodes=50 -0.44008032217053006
# seq length=5 hidden_units=5 nr_episodes=60 -0.5203204627430824
# seq length=5 hidden_units=5 nr_episodes=70 -0.6136168888787175
# seq length=5 hidden_units=5 nr_episodes=80 -0.6499575033244078
# seq length=5 hidden_units=5 nr_episodes=90 -0.7284186561917507
# seq length=5 hidden_units=5 nr_episodes=100 -0.785566802321841
# seq length=5 hidden_units=10 nr_episodes=0 -0.008549537977966315
# seq length=5 hidden_units=10 nr_episodes=10 -0.23129610990001637
# seq length=5 hidden_units=10 nr_episodes=20 -0.5512544790145422
# seq length=5 hidden_units=10 nr_episodes=30 -0.74816478382649
# seq length=5 hidden_units=10 nr_episodes=40 -0.8620749395949492
# seq length=5 hidden_units=10 nr_episodes=50 -0.9844823277379564
# seq length=5 hidden_units=10 nr_episodes=60 -1.0325941211790144
# seq length=5 hidden_units=10 nr_episodes=70 -1.1913955463969077
# seq length=5 hidden_units=10 nr_episodes=80 -1.193429676561549
# seq length=5 hidden_units=10 nr_episodes=90 -1.2426369882885413
# seq length=5 hidden_units=10 nr_episodes=100 -1.2823334549234549
# seq length=5 hidden_units=15 nr_episodes=0 -0.026585119635873955
# seq length=5 hidden_units=15 nr_episodes=10 -0.2793097076295179
# seq length=5 hidden_units=15 nr_episodes=20 -0.7505354226450232
# seq length=5 hidden_units=15 nr_episodes=30 -0.9011527806187143
# seq length=5 hidden_units=15 nr_episodes=40 -0.9860876370528928
# seq length=5 hidden_units=15 nr_episodes=50 -1.1492989398738649
# seq length=5 hidden_units=15 nr_episodes=60 -1.1827103001107022
# seq length=5 hidden_units=15 nr_episodes=70 -1.231439739706338
# seq length=5 hidden_units=15 nr_episodes=80 -1.2189486353110155
# seq length=5 hidden_units=15 nr_episodes=90 -1.2844270942782
# seq length=5 hidden_units=15 nr_episodes=100 -1.2450810236061427
# seq length=5 hidden_units=25 nr_episodes=0 -0.01909142948600029
# seq length=5 hidden_units=25 nr_episodes=10 -0.657765209416
# seq length=5 hidden_units=25 nr_episodes=20 -0.9739798365861321
# seq length=5 hidden_units=25 nr_episodes=30 -1.0147021771596934
# seq length=5 hidden_units=25 nr_episodes=40 -1.1047266659136454
# seq length=5 hidden_units=25 nr_episodes=50 -1.067631441777201
# seq length=5 hidden_units=25 nr_episodes=60 -1.1049319589989866
# seq length=5 hidden_units=25 nr_episodes=70 -1.108705981973035
# seq length=5 hidden_units=25 nr_episodes=80 -1.1397428612227323
# seq length=5 hidden_units=25 nr_episodes=90 -1.1289376372676965
# seq length=5 hidden_units=25 nr_episodes=100 -1.126484177490238
# seq length=5 hidden_units=50 nr_episodes=0 -0.02823528900000971
# seq length=5 hidden_units=50 nr_episodes=10 -0.9942094821130762
# seq length=5 hidden_units=50 nr_episodes=20 -1.12930557900666
# seq length=5 hidden_units=50 nr_episodes=30 -1.2587692539110296
# seq length=5 hidden_units=50 nr_episodes=40 -1.2425755861092096
# seq length=5 hidden_units=50 nr_episodes=50 -1.257790211252031
# seq length=5 hidden_units=50 nr_episodes=60 -1.2522970081885507
# seq length=5 hidden_units=50 nr_episodes=70 -1.298779746287773
# seq length=5 hidden_units=50 nr_episodes=80 -1.2901392573638746
# seq length=5 hidden_units=50 nr_episodes=90 -1.2883108948529256
# seq length=5 hidden_units=50 nr_episodes=100 -1.2543630654245832
# seq length=5 hidden_units=100 nr_episodes=0 -0.17937093499143253
# seq length=5 hidden_units=100 nr_episodes=10 -1.1689583972337116
# seq length=5 hidden_units=100 nr_episodes=20 -1.1133468029981293
# seq length=5 hidden_units=100 nr_episodes=30 -1.1036351341505117
# seq length=5 hidden_units=100 nr_episodes=40 -1.197456346790903
# seq length=5 hidden_units=100 nr_episodes=50 -1.2192793072335442
# seq length=5 hidden_units=100 nr_episodes=60 -1.1921801460133956
# seq length=5 hidden_units=100 nr_episodes=70 -1.2469851120369069
# seq length=5 hidden_units=100 nr_episodes=80 -1.2520992572108267
# seq length=5 hidden_units=100 nr_episodes=90 -1.2539338281151862
# seq length=5 hidden_units=100 nr_episodes=100 -1.248090686249994
# seq length=7 hidden_units=5 nr_episodes=0 0.03700833623245314
# seq length=7 hidden_units=5 nr_episodes=10 0.07448160671386161
# seq length=7 hidden_units=5 nr_episodes=20 0.09610416801485921
# seq length=7 hidden_units=5 nr_episodes=30 0.1228065405330907
# seq length=7 hidden_units=5 nr_episodes=40 0.12068883123032059
# seq length=7 hidden_units=5 nr_episodes=50 0.1468244021232814
# seq length=7 hidden_units=5 nr_episodes=60 0.16108234179922332
# seq length=7 hidden_units=5 nr_episodes=70 0.17152053802278833
# seq length=7 hidden_units=5 nr_episodes=80 0.14025989677396944
# seq length=7 hidden_units=5 nr_episodes=90 0.12718062767481286
# seq length=7 hidden_units=5 nr_episodes=100 0.08017360076947566
# seq length=7 hidden_units=10 nr_episodes=0 -0.11252927645375554
# seq length=7 hidden_units=10 nr_episodes=10 0.054991738042008076
# seq length=7 hidden_units=10 nr_episodes=20 0.050582100777490036
# seq length=7 hidden_units=10 nr_episodes=30 0.05739672291175357
# seq length=7 hidden_units=10 nr_episodes=40 0.0056363771810820085
# seq length=7 hidden_units=10 nr_episodes=50 -0.11617547937330075
# seq length=7 hidden_units=10 nr_episodes=60 -0.22237260766897826
# seq length=7 hidden_units=10 nr_episodes=70 -0.24286492251535852
# seq length=7 hidden_units=10 nr_episodes=80 -0.3133325038685424
# seq length=7 hidden_units=10 nr_episodes=90 -0.3054617809524689
# seq length=7 hidden_units=10 nr_episodes=100 -0.3134309638026489
# seq length=7 hidden_units=15 nr_episodes=0 -0.008405550440575116
# seq length=7 hidden_units=15 nr_episodes=10 0.015477617867422744
# seq length=7 hidden_units=15 nr_episodes=20 0.1109068316247025
# seq length=7 hidden_units=15 nr_episodes=30 0.08802235636784905
# seq length=7 hidden_units=15 nr_episodes=40 0.11773052475313661
# seq length=7 hidden_units=15 nr_episodes=50 0.061227593787931855
# seq length=7 hidden_units=15 nr_episodes=60 0.024103019500110734
# seq length=7 hidden_units=15 nr_episodes=70 -0.06187169944662019
# seq length=7 hidden_units=15 nr_episodes=80 -0.14234481437688973
# seq length=7 hidden_units=15 nr_episodes=90 -0.22446423980489882
# seq length=7 hidden_units=15 nr_episodes=100 -0.2843489407237605
# seq length=7 hidden_units=25 nr_episodes=0 -0.06046210568124466
# seq length=7 hidden_units=25 nr_episodes=10 0.030757378006494362
# seq length=7 hidden_units=25 nr_episodes=20 0.14685668223280823
# seq length=7 hidden_units=25 nr_episodes=30 -0.03436324650630995
# seq length=7 hidden_units=25 nr_episodes=40 -0.04669099746953265
# seq length=7 hidden_units=25 nr_episodes=50 -0.1950087580780362
# seq length=7 hidden_units=25 nr_episodes=60 -0.1522123552127883
# seq length=7 hidden_units=25 nr_episodes=70 -0.20283728777550736
# seq length=7 hidden_units=25 nr_episodes=80 -0.2832116601433674
# seq length=7 hidden_units=25 nr_episodes=90 -0.2873720117739149
# seq length=7 hidden_units=25 nr_episodes=100 -0.391808794274072
# seq length=7 hidden_units=50 nr_episodes=0 -0.020164553466165636
# seq length=7 hidden_units=50 nr_episodes=10 0.034892837963175216
# seq length=7 hidden_units=50 nr_episodes=20 -0.11463922658833647
# seq length=7 hidden_units=50 nr_episodes=30 -0.48636398361757793
# seq length=7 hidden_units=50 nr_episodes=40 -0.626287138058883
# seq length=7 hidden_units=50 nr_episodes=50 -0.614713751230427
# seq length=7 hidden_units=50 nr_episodes=60 -0.7243352284297255
# seq length=7 hidden_units=50 nr_episodes=70 -0.8071826756657414
# seq length=7 hidden_units=50 nr_episodes=80 -0.6150686370968999
# seq length=7 hidden_units=50 nr_episodes=90 -0.804038646272643
# seq length=7 hidden_units=50 nr_episodes=100 -0.8387087925950747
# seq length=7 hidden_units=100 nr_episodes=0 -0.0030941155897972195
# seq length=7 hidden_units=100 nr_episodes=10 -0.08957052967643508
# seq length=7 hidden_units=100 nr_episodes=20 -0.03674837504617634
# seq length=7 hidden_units=100 nr_episodes=30 -0.14690668427973796
# seq length=7 hidden_units=100 nr_episodes=40 -0.40085157261430426
# seq length=7 hidden_units=100 nr_episodes=50 -0.49206394653188634
# seq length=7 hidden_units=100 nr_episodes=60 -0.6514189274350504
# seq length=7 hidden_units=100 nr_episodes=70 -0.5770693224320658
# seq length=7 hidden_units=100 nr_episodes=80 -0.5417962551599413
# seq length=7 hidden_units=100 nr_episodes=90 -0.6147173839806377
# seq length=7 hidden_units=100 nr_episodes=100 -0.6814443259934511
# seq length=14 hidden_units=5 nr_episodes=0 -0.07372157335742902
# seq length=14 hidden_units=5 nr_episodes=10 -0.014262671655548731
# seq length=14 hidden_units=5 nr_episodes=20 -0.06037795118010969
# seq length=14 hidden_units=5 nr_episodes=30 -0.11396147591513994
# seq length=14 hidden_units=5 nr_episodes=40 -0.1915495309887354
# seq length=14 hidden_units=5 nr_episodes=50 -0.2729275281121597
# seq length=14 hidden_units=5 nr_episodes=60 -0.4158876397540614
# seq length=14 hidden_units=5 nr_episodes=70 -0.5532106974511442
# seq length=14 hidden_units=5 nr_episodes=80 -0.7099430840318581
# seq length=14 hidden_units=5 nr_episodes=90 -0.8826270570977459
# seq length=14 hidden_units=5 nr_episodes=100 -1.0527367972955668
# seq length=14 hidden_units=10 nr_episodes=0 -0.23528497186720565
# seq length=14 hidden_units=10 nr_episodes=10 -0.09499990207891229
# seq length=14 hidden_units=10 nr_episodes=20 -0.061131524204964593
# seq length=14 hidden_units=10 nr_episodes=30 -0.06048382436160771
# seq length=14 hidden_units=10 nr_episodes=40 -0.18056981614881162
# seq length=14 hidden_units=10 nr_episodes=50 -0.3963323701182462
# seq length=14 hidden_units=10 nr_episodes=60 -0.6267988345169613
# seq length=14 hidden_units=10 nr_episodes=70 -0.9011829900831214
# seq length=14 hidden_units=10 nr_episodes=80 -1.145198403194812
# seq length=14 hidden_units=10 nr_episodes=90 -1.3760729661315172
# seq length=14 hidden_units=10 nr_episodes=100 -1.5959625977000456
# seq length=14 hidden_units=15 nr_episodes=0 -0.01142834928340175
# seq length=14 hidden_units=15 nr_episodes=10 -0.04590246446208113
# seq length=14 hidden_units=15 nr_episodes=20 -0.13748367107202575
# seq length=14 hidden_units=15 nr_episodes=30 -0.413873979018498
# seq length=14 hidden_units=15 nr_episodes=40 -0.7166550461357124
# seq length=14 hidden_units=15 nr_episodes=50 -1.2240848549514958
# seq length=14 hidden_units=15 nr_episodes=60 -1.5744513094857981
# seq length=14 hidden_units=15 nr_episodes=70 -1.9417755052294372
# seq length=14 hidden_units=15 nr_episodes=80 -2.428189582869441
# seq length=14 hidden_units=15 nr_episodes=90 -2.6675162750568577
# seq length=14 hidden_units=15 nr_episodes=100 -2.922405632727557
# seq length=14 hidden_units=25 nr_episodes=0 -0.004751922561062827
# seq length=14 hidden_units=25 nr_episodes=10 -0.04923037715592726
# seq length=14 hidden_units=25 nr_episodes=20 -0.27114169782514264
# seq length=14 hidden_units=25 nr_episodes=30 -0.7307224310755926
# seq length=14 hidden_units=25 nr_episodes=40 -1.2178078495233624
# seq length=14 hidden_units=25 nr_episodes=50 -1.4599799458223295
# seq length=14 hidden_units=25 nr_episodes=60 -1.837484824869927
# seq length=14 hidden_units=25 nr_episodes=70 -2.2998791969259824
# seq length=14 hidden_units=25 nr_episodes=80 -2.3571973529903705
# seq length=14 hidden_units=25 nr_episodes=90 -2.5072324260614733
# seq length=14 hidden_units=25 nr_episodes=100 -2.6310439470250766
# seq length=14 hidden_units=50 nr_episodes=0 -0.003126932330747678
# seq length=14 hidden_units=50 nr_episodes=10 -0.2159280586975969
# seq length=14 hidden_units=50 nr_episodes=20 -0.6924338619107007
# seq length=14 hidden_units=50 nr_episodes=30 -1.3453160496617738
# seq length=14 hidden_units=50 nr_episodes=40 -1.8966148381596302
# seq length=14 hidden_units=50 nr_episodes=50 -1.7910968540843664
# seq length=14 hidden_units=50 nr_episodes=60 -1.9756350914939054
# seq length=14 hidden_units=50 nr_episodes=70 -2.0483729989828365
# seq length=14 hidden_units=50 nr_episodes=80 -2.1752027564921392
# seq length=14 hidden_units=50 nr_episodes=90 -2.163533316349232
# seq length=14 hidden_units=50 nr_episodes=100 -2.152585851785589
# seq length=14 hidden_units=100 nr_episodes=0 0.0021063787708104353
# seq length=14 hidden_units=100 nr_episodes=10 -0.3438924314971281
# seq length=14 hidden_units=100 nr_episodes=20 -0.6849981069675359
# seq length=14 hidden_units=100 nr_episodes=30 -0.9066180092064393
# seq length=14 hidden_units=100 nr_episodes=40 -0.9962052030132253
# seq length=14 hidden_units=100 nr_episodes=50 -0.9421088864722431
# seq length=14 hidden_units=100 nr_episodes=60 -0.93886113907931
# seq length=14 hidden_units=100 nr_episodes=70 -0.9943964813337742
# seq length=14 hidden_units=100 nr_episodes=80 -0.9643897879613297
# seq length=14 hidden_units=100 nr_episodes=90 -0.9785627988416583
# seq length=14 hidden_units=100 nr_episodes=100 -0.9987680083119239
# seq length=21 hidden_units=5 nr_episodes=0 -0.015554294665582669
# seq length=21 hidden_units=5 nr_episodes=10 -0.02436289051205409
# seq length=21 hidden_units=5 nr_episodes=20 0.017441970169147503
# seq length=21 hidden_units=5 nr_episodes=30 0.10280708496974056
# seq length=21 hidden_units=5 nr_episodes=40 0.1585536038204819
# seq length=21 hidden_units=5 nr_episodes=50 0.12519589703109013
# seq length=21 hidden_units=5 nr_episodes=60 0.029160753146085128
# seq length=21 hidden_units=5 nr_episodes=70 -0.10868000313000525
# seq length=21 hidden_units=5 nr_episodes=80 -0.2272873882431088
# seq length=21 hidden_units=5 nr_episodes=90 -0.3115639686821421
# seq length=21 hidden_units=5 nr_episodes=100 -0.41387884182952384
# seq length=21 hidden_units=10 nr_episodes=0 -0.2706775710700955
# seq length=21 hidden_units=10 nr_episodes=10 -0.10345203256198321
# seq length=21 hidden_units=10 nr_episodes=20 -0.26807276059273866
# seq length=21 hidden_units=10 nr_episodes=30 -0.4639507916854688
# seq length=21 hidden_units=10 nr_episodes=40 -0.7640987642593025
# seq length=21 hidden_units=10 nr_episodes=50 -1.0691865320182705
# seq length=21 hidden_units=10 nr_episodes=60 -1.3082596906088737
# seq length=21 hidden_units=10 nr_episodes=70 -1.488979268037875
# seq length=21 hidden_units=10 nr_episodes=80 -1.7995095441884845
# seq length=21 hidden_units=10 nr_episodes=90 -1.9779428967342767
# seq length=21 hidden_units=10 nr_episodes=100 -2.1855517723920537
# seq length=21 hidden_units=15 nr_episodes=0 -0.2080340222525694
# seq length=21 hidden_units=15 nr_episodes=10 -0.24958670471059552
# seq length=21 hidden_units=15 nr_episodes=20 -0.3923543092256587
# seq length=21 hidden_units=15 nr_episodes=30 -0.5579944400633585
# seq length=21 hidden_units=15 nr_episodes=40 -0.732601587153302
# seq length=21 hidden_units=15 nr_episodes=50 -0.8582101175415371
# seq length=21 hidden_units=15 nr_episodes=60 -0.9958554859424813
# seq length=21 hidden_units=15 nr_episodes=70 -1.1124855479233906
# seq length=21 hidden_units=15 nr_episodes=80 -1.2540632709146906
# seq length=21 hidden_units=15 nr_episodes=90 -1.445843295798798
# seq length=21 hidden_units=15 nr_episodes=100 -1.5979297687348764
# seq length=21 hidden_units=25 nr_episodes=0 -0.050133811811697626
# seq length=21 hidden_units=25 nr_episodes=10 -0.22773149594052478
# seq length=21 hidden_units=25 nr_episodes=20 -0.6026441758486984
# seq length=21 hidden_units=25 nr_episodes=30 -1.1791111011156556
# seq length=21 hidden_units=25 nr_episodes=40 -1.6038120151029833
# seq length=21 hidden_units=25 nr_episodes=50 -1.8720686652191385
# seq length=21 hidden_units=25 nr_episodes=60 -2.2649269440886575
# seq length=21 hidden_units=25 nr_episodes=70 -2.4826753769440058
# seq length=21 hidden_units=25 nr_episodes=80 -2.6745086765156545
# seq length=21 hidden_units=25 nr_episodes=90 -2.9142502759956437
# seq length=21 hidden_units=25 nr_episodes=100 -3.0040857944930375
# seq length=21 hidden_units=50 nr_episodes=0 0.06410120943395814
# seq length=21 hidden_units=50 nr_episodes=10 -0.6635027502856221
# seq length=21 hidden_units=50 nr_episodes=20 -1.376649678991296
# seq length=21 hidden_units=50 nr_episodes=30 -2.1982420559342177
# seq length=21 hidden_units=50 nr_episodes=40 -2.7394299048168516
# seq length=21 hidden_units=50 nr_episodes=50 -3.4858585358343017
# seq length=21 hidden_units=50 nr_episodes=60 -3.8420116042211054
# seq length=21 hidden_units=50 nr_episodes=70 -3.8710860574768144
# seq length=21 hidden_units=50 nr_episodes=80 -3.8423043320961696
# seq length=21 hidden_units=50 nr_episodes=90 -3.785891139941432
# seq length=21 hidden_units=50 nr_episodes=100 -3.6901982176208312
# seq length=21 hidden_units=100 nr_episodes=0 -0.009197654930124477
# seq length=21 hidden_units=100 nr_episodes=10 -0.9636195034162738
# seq length=21 hidden_units=100 nr_episodes=20 -1.4611404661180263
# seq length=21 hidden_units=100 nr_episodes=30 -1.9244832927394864
# seq length=21 hidden_units=100 nr_episodes=40 -2.078305452461285
# seq length=21 hidden_units=100 nr_episodes=50 -1.9476124308850657
# seq length=21 hidden_units=100 nr_episodes=60 -2.056281134584431
# seq length=21 hidden_units=100 nr_episodes=70 -1.925995843709897
# seq length=21 hidden_units=100 nr_episodes=80 -1.9867317909698015
# seq length=21 hidden_units=100 nr_episodes=90 -2.100141840354734
# seq length=21 hidden_units=100 nr_episodes=100 -1.9115817418381975
# seq length=28 hidden_units=5 nr_episodes=0 -0.17893681420542062
# seq length=28 hidden_units=5 nr_episodes=10 0.3486314441500732
# seq length=28 hidden_units=5 nr_episodes=20 0.44793226871942926
# seq length=28 hidden_units=5 nr_episodes=30 0.49856543228827466
# seq length=28 hidden_units=5 nr_episodes=40 0.5104934785255502
# seq length=28 hidden_units=5 nr_episodes=50 0.44792820526380184
# seq length=28 hidden_units=5 nr_episodes=60 0.2824477930763212
# seq length=28 hidden_units=5 nr_episodes=70 0.16090664254511866
# seq length=28 hidden_units=5 nr_episodes=80 0.012058841563548861
# seq length=28 hidden_units=5 nr_episodes=90 -0.12348252133017867
# seq length=28 hidden_units=5 nr_episodes=100 -0.31960847193216346
# seq length=28 hidden_units=10 nr_episodes=0 0.07676807294136834
# seq length=28 hidden_units=10 nr_episodes=10 0.3820441545042299
# seq length=28 hidden_units=10 nr_episodes=20 0.4475519582778994
# seq length=28 hidden_units=10 nr_episodes=30 0.5039115437350201
# seq length=28 hidden_units=10 nr_episodes=40 0.3011112977470277
# seq length=28 hidden_units=10 nr_episodes=50 0.1635912620606651
# seq length=28 hidden_units=10 nr_episodes=60 0.23788817863388856
# seq length=28 hidden_units=10 nr_episodes=70 0.21766902751049988
# seq length=28 hidden_units=10 nr_episodes=80 0.21996103131955225
# seq length=28 hidden_units=10 nr_episodes=90 0.3485164154279651
# seq length=28 hidden_units=10 nr_episodes=100 0.3926806085697282
# seq length=28 hidden_units=15 nr_episodes=0 -0.02601992923194807
# seq length=28 hidden_units=15 nr_episodes=10 0.4211560007009617
# seq length=28 hidden_units=15 nr_episodes=20 0.35089436257095685
# seq length=28 hidden_units=15 nr_episodes=30 0.4674478441662815
# seq length=28 hidden_units=15 nr_episodes=40 0.12386292763441664
# seq length=28 hidden_units=15 nr_episodes=50 0.049622737918450066
# seq length=28 hidden_units=15 nr_episodes=60 0.011137519853949285
# seq length=28 hidden_units=15 nr_episodes=70 -0.013548279478510894
# seq length=28 hidden_units=15 nr_episodes=80 -0.15489685409187404
# seq length=28 hidden_units=15 nr_episodes=90 -0.09172202178675115
# seq length=28 hidden_units=15 nr_episodes=100 -0.09559487287318924
# seq length=28 hidden_units=25 nr_episodes=0 -0.07517058242802399
# seq length=28 hidden_units=25 nr_episodes=10 0.4817544628486581
# seq length=28 hidden_units=25 nr_episodes=20 0.15258607675282698
# seq length=28 hidden_units=25 nr_episodes=30 -0.028708506172317128
# seq length=28 hidden_units=25 nr_episodes=40 -0.09736120873927989
# seq length=28 hidden_units=25 nr_episodes=50 -0.26504342160437555
# seq length=28 hidden_units=25 nr_episodes=60 -0.32023129639931924
# seq length=28 hidden_units=25 nr_episodes=70 -0.6188000719412896
# seq length=28 hidden_units=25 nr_episodes=80 -0.871482989154369
# seq length=28 hidden_units=25 nr_episodes=90 -1.0567740223038506
# seq length=28 hidden_units=25 nr_episodes=100 -0.9723458576417499
# seq length=28 hidden_units=50 nr_episodes=0 0.20202422195770775
# seq length=28 hidden_units=50 nr_episodes=10 0.6423624513216509
# seq length=28 hidden_units=50 nr_episodes=20 0.2973680783479441
# seq length=28 hidden_units=50 nr_episodes=30 0.16394581201999914
# seq length=28 hidden_units=50 nr_episodes=40 -0.03507629119577427
# seq length=28 hidden_units=50 nr_episodes=50 -0.36914102395438997
# seq length=28 hidden_units=50 nr_episodes=60 -0.624379811899122
# seq length=28 hidden_units=50 nr_episodes=70 -0.6287177826946435
# seq length=28 hidden_units=50 nr_episodes=80 -1.0186984117487201
# seq length=28 hidden_units=50 nr_episodes=90 -1.1516557973588206
# seq length=28 hidden_units=50 nr_episodes=100 -0.7559849532635614
# seq length=28 hidden_units=100 nr_episodes=0 0.4204158328259987
# seq length=28 hidden_units=100 nr_episodes=10 -0.25741341180647526
# seq length=28 hidden_units=100 nr_episodes=20 -0.34752973613433413
# seq length=28 hidden_units=100 nr_episodes=30 -0.26287835121078973
# seq length=28 hidden_units=100 nr_episodes=40 -0.5935525677798432
# seq length=28 hidden_units=100 nr_episodes=50 -0.6803808300912455
# seq length=28 hidden_units=100 nr_episodes=60 -0.7207393577131811
# seq length=28 hidden_units=100 nr_episodes=70 -0.6107497880648745
# seq length=28 hidden_units=100 nr_episodes=80 -0.44182522297800064
# seq length=28 hidden_units=100 nr_episodes=90 -0.3765125646849963
# seq length=28 hidden_units=100 nr_episodes=100 -0.31805989102492926
# LSTM best results achieved with length=28 hidden_units=50 and nr_episodes=10) ==> measure=0.64

# %% [markdown]
# ## Pytorch Multivariate Model Evaluation

# %%
params = best_params["params"]
best_length = params[0]


# smoothed time series with split. uncomment to use
# train=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_train.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)
# test=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_test.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)


# unsmoothed time series with split to test the model. uncomment to use
test_split_threshold = 0.7
data_no_smoothing=pd.read_csv('data/df_merch_0_2024_agg_time_diff_input.csv', decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)     
train, test = series_train_test_split(data_no_smoothing, trn_pct=test_split_threshold)



# Assuming `train` and `test` are your DataFrames and `target` is the target column name
trnY_float = train.pop(target).values.astype(np.float32)
tstY_float = test.pop(target).values.astype(np.float32)
trnX_float = train.values.astype(np.float32)
tstX_float = test.values.astype(np.float32)


trnX, trnY = prepare_dataset_for_lstm_multi(trnX_float, trnY_float, seq_length=best_length)
tstX, tstY  = prepare_dataset_for_lstm_multi(tstX_float, tstY_float, seq_length=best_length)


prd_trn = best_model.predict(trnX)
prd_tst = best_model.predict(tstX)


# Assuming train and test are DataFrames with a DateTime index
# Reconstruct the series for plotting
train[target] = trnY_float
test[target] = tstY_float
trn_series = train[[target]]
tst_series = test[[target]]


# Plot the forecasting evaluation
plot_single_model_evaluation(trn_series[best_length:], tst_series[best_length:], prd_trn, prd_tst, title=f"{file_tag} - LSTM Multivariate (length={best_length}, hidden={params[1]}, epochs={params[2]})")
savefig(f"images/{file_tag}_LSTM_multivariate_predictions.png")

# %% [markdown]
# ## Pytorch Multivariate Plots

# %%
from pandas import Series
pred_series = Series(prd_tst.numpy().ravel(), index=tst_series.index[best_length:])


plot_forecasting_series(
    trn_series[best_length:],
    tst_series[best_length:],
    pred_series,
    title=f"{file_tag} - LSTM Multivariate Predictions (length={best_length}, hidden={params[1]}, epochs={params[2]})",
    xlabel='Date',
    ylabel=target,
)
# Out:
# <Axes: xlabel='Date', ylabel='Sessions'>

# %% [markdown]
# ## Pytorch Multivariate Model and Loss

# %%
model = DS_LSTM_Multivariate(trnX_float, trnY_float, input_size=trnX_float.shape[1], hidden_size=50, num_layers=1)
loss = model.fit()
print(loss)
# Out:
# tensor(0.6422, grad_fn=<MseLossBackward0>)

# %% [markdown]
# # Install pytorch

# %% [markdown]
# - https://pytorch.org/
#
# 1. Go to anaconda terminal as admin and enter
# ```bash
# conda create --name pytorch_cpu python=3.12
# ```
#
# 2. activate environment
#
# ```bash
# conda activate pytorch_cpu
# ```
#
# 3. install pytorch
# ```bash
#
# # CPU Only Windows and Linux
# conda install pytorch==2.5.0 torchvision==0.20.0 torchaudio==2.5.0 cpuonly -c pytorch
#
# # MAC OSX
# conda install pytorch==2.5.0 torchvision==0.20.0 torchaudio==2.5.0 -c pytorch
#
# ```
#
# 4. install additional packages from dslabs and data functions
# ```bash
# conda install pandas scikit-learn matplotlib statsmodels
# ```
#
# 5. if jupyter has errors run
#
# ```bash
# conda install -n pytorch_cpu ipykernel --update-deps --force-reinstall
# ```

# %%
import torch
print(torch.__version__)
# Out:
# 2.5.0

# %% [markdown]
# # DSLabs functions

# %%
# %run "scripts/dslabs_functions.py"

# %%
import sys
sys.path.append('scripts')

from dslabs_functions import FORECAST_MEASURES, DELTA_IMPROVE, plot_multiline_chart

# %% [markdown]
# # Data functions

# %%
# %run "scripts/data_functions.py"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/Mercedes-benz.io/TRAINING/post graduation course IST - Data science/projeto curso/ist_dash_2024_rec/time_series_forecasting/notebooks/dataset_1/scripts/data_functions.py:1371
#    1367     fig.suptitle(title, fontsize=16)
#    1368     plt.show()
# -> 1371 import seaborn as sns
#    1373 def plot_cluster_boxplots(dataframe, features, cluster_labels):
#    1374     """
#    1375     Plots boxplots for the given features in the dataframe, comparing the specified cluster labels.
#    1376
#    (...)   1380     cluster_labels (list): List of cluster labels to compare.
#    1381     """
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# # Load

# %%
import pandas as pd

test_data=False
# test_data=False


file_tag = "Gira Bike"


train=pd.read_csv(f"data/df_gira_agg_2h_wtimevars_final_train.csv", decimal=".",  index_col='date', parse_dates=True,  infer_datetime_format=True)
test=pd.read_csv(f"data/df_gira_agg_2h_wtimevars_final_test.csv", decimal=".",  index_col='date', parse_dates=True,  infer_datetime_format=True)
target='target_station_load_rate'
# Se os dados já tiverem a frequência correta para cada dia (com todas as horas), 
# podemos apenas ajustar o índice para começar no horário correto.
#
#train.index = pd.date_range(start='2022-01-01 14:00', periods=len(train), freq='2H')
#test.index = pd.date_range(start='2023-02-14 16:00', periods=len(test), freq='2H')



test_split_threshold=0.9
# Prepare the training and testing data from dataframes with features and target
trnX = train.drop(columns=[target])
trnY = train[target]
tstX = test.drop(columns=[target])
tstY = test[target]

from numpy import arange

# Ensure no data leakage
assert not set(train.index).intersection(set(test.index)), "Data leakage detected: Train and test sets overlap."


train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4878 entries, 2022-01-01 14:00:00 to 2023-02-14 14:00:00
# Data columns (total 18 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   index                                                        4878 non-null   int64
#  1   temperature_2m                                               4878 non-null   float64
#  2   rain_mm                                                      4878 non-null   float64
#  3   wmo_weather_code                                             4878 non-null   float64
#  4   wind_speed_10m                                               4878 non-null   float64
#  5   is_holiday_lisbon                                            4878 non-null   float64
#  6   is_weekend                                                   4878 non-null   float64
#  7   day_of_week_sin                                              4878 non-null   float64
#  8   day_of_week_cos                                              4878 non-null   float64
#  9   time_of_day_sin                                              4878 non-null   float64
#  10  time_of_day_cos                                              4878 non-null   float64
#  11  target_station_status                                        4878 non-null   float64
#  12  target_station_load_rate                                     4878 non-null   float64
#  13  station_load_rate_ Rua do Arco Cego / Av. Magalhães Lima     4878 non-null   float64
#  14  station_load_rate_ Av. Rovisco Pais / Av. Manuel da Maia     4878 non-null   float64
#  15  station_load_rate_ Praça de Londres                          4878 non-null   float64
#  16  station_load_rate_ Av. Duque de Ávila / Jardim Arco Do Cego  4878 non-null   float64
#  17  station_load_rate_ Av. Barbosa Du Bocage / Rua Arco do Cego  4878 non-null   float64
# dtypes: float64(17), int64(1)
# memory usage: 724.1 KB

# %% [markdown]
# # LSTM Pytorch Univariate

# %% [markdown]
# ## Univariate Pytorch Functions and data prep

# %%
from torch import no_grad, tensor
from torch.nn import LSTM, Linear, Module, MSELoss
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset


def prepare_dataset_for_lstm_uni(series, seq_length: int = 4):
    setX: list = []
    setY: list = []
    for i in range(len(series) - seq_length):
        past = series[i : i + seq_length]
        future = series[i + 1 : i + seq_length + 1]
        setX.append(past)
        setY.append(future)
    return tensor(setX), tensor(setY)


class DS_LSTM_Univariate(Module):
    def __init__(self, train, input_size: int = 1, hidden_size: int = 50, num_layers: int = 1, length: int = 4):
        super().__init__()
        self.lstm = LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.linear = Linear(hidden_size, 1)
        self.optimizer = Adam(self.parameters())
        self.loss_fn = MSELoss()

        trnX, trnY = prepare_dataset_for_lstm_uni(train, seq_length=length)
        self.loader = DataLoader(TensorDataset(trnX, trnY), shuffle=True, batch_size=len(train) // 10)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.linear(x)
        return x

    def fit(self):
        self.train()
        for batchX, batchY in self.loader:
            y_pred = self(batchX)
            loss = self.loss_fn(y_pred, batchY)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
        return loss

    def predict(self, X):
        with no_grad():
            y_pred = self(X)
        return y_pred[:, -1, :]

# %%
#from dslabs_functions import HEIGHT, plot_multiline_chart
from copy import deepcopy

from matplotlib.pyplot import figure, savefig, subplots
#from dslabs_functions import FORECAST_MEASURES, DELTA_IMPROVE, plot_multiline_chart


def lstm_study_uni(train, test, nr_episodes: int = 1000, sequence_size: list =[2,4,8], nr_hidden_units: list =[25,50,100], measure: str = "R2"):
    # sequence_size = [2, 4, 8]
    # nr_hidden_units = [25, 50, 100]

    step: int = nr_episodes // 10
    episodes = [1] + list(range(0, nr_episodes + 1, step))[1:]
    flag = measure == "R2" or measure == "MAPE"
    best_model = None
    best_params: dict = {"name": "LSTM", "metric": measure, "params": ()}
    best_performance: float = -100000

    _, axs = subplots(1, len(sequence_size), figsize=(len(sequence_size) * HEIGHT, HEIGHT))

    for i in range(len(sequence_size)):
        length = sequence_size[i]
        tstX, tstY = prepare_dataset_for_lstm_uni(test, seq_length=length)

        values = {}
        for hidden in nr_hidden_units:
            yvalues = []
            model = DS_LSTM_Univariate(train, hidden_size=hidden)
            for n in range(0, nr_episodes + 1):
                model.fit()
                if n % step == 0:
                    prd_tst = model.predict(tstX)
                    eval: float = FORECAST_MEASURES[measure](test[length:], prd_tst)
                    print(f"seq length={length} hidden_units={hidden} nr_episodes={n}", eval)
                    if eval > best_performance and abs(eval - best_performance) > DELTA_IMPROVE:
                        best_performance: float = eval
                        best_params["params"] = (length, hidden, n)
                        best_model = deepcopy(model)
                    yvalues.append(eval)
            values[hidden] = yvalues
        plot_multiline_chart(
            episodes,
            values,
            ax=axs[i],
            title=f"LSTM seq length={length} ({measure})",
            xlabel="nr episodes",
            ylabel=measure,
            percentage=flag,
        )
    print(
        f"LSTM best results achieved with length={best_params["params"][0]} hidden_units={best_params["params"][1]} and nr_episodes={best_params["params"][2]}) ==> measure={best_performance:.2f}"
    )
    return best_model, best_params

# %% [markdown]
# ## Univariate Pytorch Study

# %%
# # Prepare the training and testing data using the time index as the feature
from numpy import arange


train_series_float = train[[target]].values.astype("float32")
test_series_float = test[[target]].values.astype("float32")


best_model, best_params = lstm_study_uni(train_series_float, test_series_float, nr_episodes=20,sequence_size=[1,5,7,12,18,24],nr_hidden_units=[5,15,25,50,75], measure='R2')
# Out:
# seq length=1 hidden_units=5 nr_episodes=0 -0.29408860206604004
# seq length=1 hidden_units=5 nr_episodes=2 -0.23222732543945312
# seq length=1 hidden_units=5 nr_episodes=4 -0.18008875846862793
# seq length=1 hidden_units=5 nr_episodes=6 -0.13633108139038086
# seq length=1 hidden_units=5 nr_episodes=8 -0.09909617900848389
# seq length=1 hidden_units=5 nr_episodes=10 -0.07147347927093506
# seq length=1 hidden_units=5 nr_episodes=12 -0.05146443843841553
# seq length=1 hidden_units=5 nr_episodes=14 -0.036092519760131836
# seq length=1 hidden_units=5 nr_episodes=16 -0.026712656021118164
# seq length=1 hidden_units=5 nr_episodes=18 -0.02144646644592285
# seq length=1 hidden_units=5 nr_episodes=20 -0.01880824565887451
# seq length=1 hidden_units=15 nr_episodes=0 -0.028293132781982422
# seq length=1 hidden_units=15 nr_episodes=2 -0.006553769111633301
# seq length=1 hidden_units=15 nr_episodes=4 0.0012451410293579102
# seq length=1 hidden_units=15 nr_episodes=6 0.0035207271575927734
# seq length=1 hidden_units=15 nr_episodes=8 0.002844393253326416
# seq length=1 hidden_units=15 nr_episodes=10 0.0022044777870178223
# seq length=1 hidden_units=15 nr_episodes=12 0.0030171871185302734
# seq length=1 hidden_units=15 nr_episodes=14 0.003355264663696289
# seq length=1 hidden_units=15 nr_episodes=16 0.003420114517211914
# seq length=1 hidden_units=15 nr_episodes=18 0.0006497502326965332
# seq length=1 hidden_units=15 nr_episodes=20 0.004873991012573242
# seq length=1 hidden_units=25 nr_episodes=0 -0.059460997581481934
# seq length=1 hidden_units=25 nr_episodes=2 -0.027869462966918945
# seq length=1 hidden_units=25 nr_episodes=4 -0.014663219451904297
# seq length=1 hidden_units=25 nr_episodes=6 -0.010651350021362305
# seq length=1 hidden_units=25 nr_episodes=8 -0.00914919376373291
# seq length=1 hidden_units=25 nr_episodes=10 -0.006247758865356445
# seq length=1 hidden_units=25 nr_episodes=12 -0.006102204322814941
# seq length=1 hidden_units=25 nr_episodes=14 -0.003113389015197754
# seq length=1 hidden_units=25 nr_episodes=16 0.00208890438079834
# seq length=1 hidden_units=25 nr_episodes=18 0.004136145114898682
# seq length=1 hidden_units=25 nr_episodes=20 0.0041735172271728516
# seq length=1 hidden_units=50 nr_episodes=0 -7.522106170654297e-05
# seq length=1 hidden_units=50 nr_episodes=2 0.000629425048828125
# seq length=1 hidden_units=50 nr_episodes=4 0.002756655216217041
# seq length=1 hidden_units=50 nr_episodes=6 0.0050449371337890625
# seq length=1 hidden_units=50 nr_episodes=8 0.0041672587394714355
# seq length=1 hidden_units=50 nr_episodes=10 0.003048241138458252
# seq length=1 hidden_units=50 nr_episodes=12 0.006775319576263428
# seq length=1 hidden_units=50 nr_episodes=14 0.00769650936126709
# seq length=1 hidden_units=50 nr_episodes=16 0.0074547529220581055
# seq length=1 hidden_units=50 nr_episodes=18 0.008423924446105957
# seq length=1 hidden_units=50 nr_episodes=20 0.009339392185211182
# seq length=1 hidden_units=75 nr_episodes=0 0.004269421100616455
# seq length=1 hidden_units=75 nr_episodes=2 0.0034095048904418945
# seq length=1 hidden_units=75 nr_episodes=4 0.004228055477142334
# seq length=1 hidden_units=75 nr_episodes=6 0.0031447410583496094
# seq length=1 hidden_units=75 nr_episodes=8 0.006906270980834961
# seq length=1 hidden_units=75 nr_episodes=10 0.008057355880737305
# seq length=1 hidden_units=75 nr_episodes=12 0.007186770439147949
# seq length=1 hidden_units=75 nr_episodes=14 0.0072359442710876465
# seq length=1 hidden_units=75 nr_episodes=16 0.0036652684211730957
# seq length=1 hidden_units=75 nr_episodes=18 0.0035533905029296875
# seq length=1 hidden_units=75 nr_episodes=20 0.006570398807525635
# seq length=5 hidden_units=5 nr_episodes=0 -0.15245866775512695
# seq length=5 hidden_units=5 nr_episodes=2 -0.09687435626983643
# seq length=5 hidden_units=5 nr_episodes=4 -0.05591273307800293
# seq length=5 hidden_units=5 nr_episodes=6 -0.02755594253540039
# seq length=5 hidden_units=5 nr_episodes=8 -0.011654376983642578
# seq length=5 hidden_units=5 nr_episodes=10 -0.0022552013397216797
# seq length=5 hidden_units=5 nr_episodes=12 0.0026317834854125977
# seq length=5 hidden_units=5 nr_episodes=14 0.004710793495178223
# seq length=5 hidden_units=5 nr_episodes=16 0.0097428560256958
# seq length=5 hidden_units=5 nr_episodes=18 0.017872393131256104
# seq length=5 hidden_units=5 nr_episodes=20 0.029795825481414795
# seq length=5 hidden_units=15 nr_episodes=0 0.0035709142684936523
# seq length=5 hidden_units=15 nr_episodes=2 0.001334846019744873
# seq length=5 hidden_units=15 nr_episodes=4 0.009769201278686523
# seq length=5 hidden_units=15 nr_episodes=6 0.021115124225616455
# seq length=5 hidden_units=15 nr_episodes=8 0.03300774097442627
# seq length=5 hidden_units=15 nr_episodes=10 0.0450512170791626
# seq length=5 hidden_units=15 nr_episodes=12 0.056711792945861816
# seq length=5 hidden_units=15 nr_episodes=14 0.07199150323867798
# seq length=5 hidden_units=15 nr_episodes=16 0.08876365423202515
# seq length=5 hidden_units=15 nr_episodes=18 0.1170964241027832
# seq length=5 hidden_units=15 nr_episodes=20 0.1386547088623047
# seq length=5 hidden_units=25 nr_episodes=0 -0.011528849601745605
# seq length=5 hidden_units=25 nr_episodes=2 0.011183977127075195
# seq length=5 hidden_units=25 nr_episodes=4 0.019390881061553955
# seq length=5 hidden_units=25 nr_episodes=6 0.04657280445098877
# seq length=5 hidden_units=25 nr_episodes=8 0.08478409051895142
# seq length=5 hidden_units=25 nr_episodes=10 0.13429492712020874
# seq length=5 hidden_units=25 nr_episodes=12 0.16262400150299072
# seq length=5 hidden_units=25 nr_episodes=14 0.16132938861846924
# seq length=5 hidden_units=25 nr_episodes=16 0.17717278003692627
# seq length=5 hidden_units=25 nr_episodes=18 0.18782329559326172
# seq length=5 hidden_units=25 nr_episodes=20 0.1893066167831421
# seq length=5 hidden_units=50 nr_episodes=0 0.00631636381149292
# seq length=5 hidden_units=50 nr_episodes=2 0.028955936431884766
# seq length=5 hidden_units=50 nr_episodes=4 0.06771641969680786
# seq length=5 hidden_units=50 nr_episodes=6 0.11612248420715332
# seq length=5 hidden_units=50 nr_episodes=8 0.14977729320526123
# seq length=5 hidden_units=50 nr_episodes=10 0.15589767694473267
# seq length=5 hidden_units=50 nr_episodes=12 0.13971728086471558
# seq length=5 hidden_units=50 nr_episodes=14 0.1785346269607544
# seq length=5 hidden_units=50 nr_episodes=16 0.19394415616989136
# seq length=5 hidden_units=50 nr_episodes=18 0.20319515466690063
# seq length=5 hidden_units=50 nr_episodes=20 0.23376744985580444
# seq length=5 hidden_units=75 nr_episodes=0 0.009707391262054443
# seq length=5 hidden_units=75 nr_episodes=2 0.041527748107910156
# seq length=5 hidden_units=75 nr_episodes=4 0.11192494630813599
# seq length=5 hidden_units=75 nr_episodes=6 0.1458379030227661
# seq length=5 hidden_units=75 nr_episodes=8 0.16483259201049805
# seq length=5 hidden_units=75 nr_episodes=10 0.16827696561813354
# seq length=5 hidden_units=75 nr_episodes=12 0.17905843257904053
# seq length=5 hidden_units=75 nr_episodes=14 0.18394625186920166
# seq length=5 hidden_units=75 nr_episodes=16 0.2038494348526001
# seq length=5 hidden_units=75 nr_episodes=18 0.21044021844863892
# seq length=5 hidden_units=75 nr_episodes=20 0.2185792326927185
# seq length=7 hidden_units=5 nr_episodes=0 0.013830244541168213
# seq length=7 hidden_units=5 nr_episodes=2 0.01748138666152954
# seq length=7 hidden_units=5 nr_episodes=4 0.025828003883361816
# seq length=7 hidden_units=5 nr_episodes=6 0.03512775897979736
# seq length=7 hidden_units=5 nr_episodes=8 0.047624051570892334
# seq length=7 hidden_units=5 nr_episodes=10 0.06698697805404663
# seq length=7 hidden_units=5 nr_episodes=12 0.08589643239974976
# seq length=7 hidden_units=5 nr_episodes=14 0.10265302658081055
# seq length=7 hidden_units=5 nr_episodes=16 0.12017762660980225
# seq length=7 hidden_units=5 nr_episodes=18 0.13554984331130981
# seq length=7 hidden_units=5 nr_episodes=20 0.15153586864471436
# seq length=7 hidden_units=15 nr_episodes=0 -0.04895055294036865
# seq length=7 hidden_units=15 nr_episodes=2 0.007046520709991455
# seq length=7 hidden_units=15 nr_episodes=4 -0.0059288740158081055
# seq length=7 hidden_units=15 nr_episodes=6 -0.010697484016418457
# seq length=7 hidden_units=15 nr_episodes=8 0.011771857738494873
# seq length=7 hidden_units=15 nr_episodes=10 0.02218306064605713
# seq length=7 hidden_units=15 nr_episodes=12 0.023519575595855713
# seq length=7 hidden_units=15 nr_episodes=14 0.050527334213256836
# seq length=7 hidden_units=15 nr_episodes=16 0.06214308738708496
# seq length=7 hidden_units=15 nr_episodes=18 0.0721508264541626
# seq length=7 hidden_units=15 nr_episodes=20 0.08693110942840576
# seq length=7 hidden_units=25 nr_episodes=0 0.0005448460578918457
# seq length=7 hidden_units=25 nr_episodes=2 0.008021295070648193
# seq length=7 hidden_units=25 nr_episodes=4 0.019846677780151367
# seq length=7 hidden_units=25 nr_episodes=6 0.03743875026702881
# seq length=7 hidden_units=25 nr_episodes=8 0.05660855770111084
# seq length=7 hidden_units=25 nr_episodes=10 0.0972667932510376
# seq length=7 hidden_units=25 nr_episodes=12 0.15226614475250244
# seq length=7 hidden_units=25 nr_episodes=14 0.1984848976135254
# seq length=7 hidden_units=25 nr_episodes=16 0.17965459823608398
# seq length=7 hidden_units=25 nr_episodes=18 0.1598077416419983
# seq length=7 hidden_units=25 nr_episodes=20 0.15950781106948853
# seq length=7 hidden_units=50 nr_episodes=0 0.0013788342475891113
# seq length=7 hidden_units=50 nr_episodes=2 0.023603379726409912
# seq length=7 hidden_units=50 nr_episodes=4 0.065399169921875
# seq length=7 hidden_units=50 nr_episodes=6 0.14388197660446167
# seq length=7 hidden_units=50 nr_episodes=8 0.15509569644927979
# seq length=7 hidden_units=50 nr_episodes=10 0.10683643817901611
# seq length=7 hidden_units=50 nr_episodes=12 -0.14076316356658936
# seq length=7 hidden_units=50 nr_episodes=14 -0.11835014820098877
# seq length=7 hidden_units=50 nr_episodes=16 0.017274677753448486
# seq length=7 hidden_units=50 nr_episodes=18 0.033681631088256836
# seq length=7 hidden_units=50 nr_episodes=20 0.07807564735412598
# seq length=7 hidden_units=75 nr_episodes=0 0.016760647296905518
# seq length=7 hidden_units=75 nr_episodes=2 0.07332134246826172
# seq length=7 hidden_units=75 nr_episodes=4 0.1441859006881714
# seq length=7 hidden_units=75 nr_episodes=6 0.14475220441818237
# seq length=7 hidden_units=75 nr_episodes=8 0.016778290271759033
# seq length=7 hidden_units=75 nr_episodes=10 0.060666441917419434
# seq length=7 hidden_units=75 nr_episodes=12 -0.17238080501556396
# seq length=7 hidden_units=75 nr_episodes=14 0.0851815938949585
# seq length=7 hidden_units=75 nr_episodes=16 0.003863096237182617
# seq length=7 hidden_units=75 nr_episodes=18 0.10011768341064453
# seq length=7 hidden_units=75 nr_episodes=20 0.18935996294021606
# seq length=12 hidden_units=5 nr_episodes=0 -0.09235858917236328
# seq length=12 hidden_units=5 nr_episodes=2 -0.02377796173095703
# seq length=12 hidden_units=5 nr_episodes=4 0.012779474258422852
# seq length=12 hidden_units=5 nr_episodes=6 0.016438424587249756
# seq length=12 hidden_units=5 nr_episodes=8 0.012179553508758545
# seq length=12 hidden_units=5 nr_episodes=10 0.004223227500915527
# seq length=12 hidden_units=5 nr_episodes=12 0.012574076652526855
# seq length=12 hidden_units=5 nr_episodes=14 0.023709475994110107
# seq length=12 hidden_units=5 nr_episodes=16 0.047081053256988525
# seq length=12 hidden_units=5 nr_episodes=18 0.05422830581665039
# seq length=12 hidden_units=5 nr_episodes=20 0.04769694805145264
# seq length=12 hidden_units=15 nr_episodes=0 0.004810631275177002
# seq length=12 hidden_units=15 nr_episodes=2 0.010188281536102295
# seq length=12 hidden_units=15 nr_episodes=4 0.017144203186035156
# seq length=12 hidden_units=15 nr_episodes=6 0.02837216854095459
# seq length=12 hidden_units=15 nr_episodes=8 0.0469895601272583
# seq length=12 hidden_units=15 nr_episodes=10 0.06943672895431519
# seq length=12 hidden_units=15 nr_episodes=12 0.10345697402954102
# seq length=12 hidden_units=15 nr_episodes=14 0.13181060552597046
# seq length=12 hidden_units=15 nr_episodes=16 0.05808424949645996
# seq length=12 hidden_units=15 nr_episodes=18 -0.00021958351135253906
# seq length=12 hidden_units=15 nr_episodes=20 -0.04161810874938965
# seq length=12 hidden_units=25 nr_episodes=0 0.003039538860321045
# seq length=12 hidden_units=25 nr_episodes=2 0.01689201593399048
# seq length=12 hidden_units=25 nr_episodes=4 0.041912734508514404
# seq length=12 hidden_units=25 nr_episodes=6 0.0675511360168457
# seq length=12 hidden_units=25 nr_episodes=8 0.11292821168899536
# seq length=12 hidden_units=25 nr_episodes=10 0.14297908544540405
# seq length=12 hidden_units=25 nr_episodes=12 0.206764817237854
# seq length=12 hidden_units=25 nr_episodes=14 0.13634872436523438
# seq length=12 hidden_units=25 nr_episodes=16 0.10513979196548462
# seq length=12 hidden_units=25 nr_episodes=18 0.08989650011062622
# seq length=12 hidden_units=25 nr_episodes=20 0.08324456214904785
# seq length=12 hidden_units=50 nr_episodes=0 0.011427342891693115
# seq length=12 hidden_units=50 nr_episodes=2 0.04172563552856445
# seq length=12 hidden_units=50 nr_episodes=4 0.09581071138381958
# seq length=12 hidden_units=50 nr_episodes=6 0.15296995639801025
# seq length=12 hidden_units=50 nr_episodes=8 0.1394742727279663
# seq length=12 hidden_units=50 nr_episodes=10 0.0008763670921325684
# seq length=12 hidden_units=50 nr_episodes=12 -0.023006677627563477
# seq length=12 hidden_units=50 nr_episodes=14 -0.18284547328948975
# seq length=12 hidden_units=50 nr_episodes=16 -0.04844796657562256
# seq length=12 hidden_units=50 nr_episodes=18 -0.11062932014465332
# seq length=12 hidden_units=50 nr_episodes=20 -0.3436751365661621
# seq length=12 hidden_units=75 nr_episodes=0 0.016259193420410156
# seq length=12 hidden_units=75 nr_episodes=2 0.043045639991760254
# seq length=12 hidden_units=75 nr_episodes=4 0.09996271133422852
# seq length=12 hidden_units=75 nr_episodes=6 0.18390697240829468
# seq length=12 hidden_units=75 nr_episodes=8 0.08455467224121094
# seq length=12 hidden_units=75 nr_episodes=10 0.11314982175827026
# seq length=12 hidden_units=75 nr_episodes=12 -0.11786758899688721
# seq length=12 hidden_units=75 nr_episodes=14 -0.15389800071716309
# seq length=12 hidden_units=75 nr_episodes=16 0.025769412517547607
# seq length=12 hidden_units=75 nr_episodes=18 0.07360988855361938
# seq length=12 hidden_units=75 nr_episodes=20 0.08636093139648438
# seq length=18 hidden_units=5 nr_episodes=0 -0.047950148582458496
# seq length=18 hidden_units=5 nr_episodes=2 -0.011160969734191895
# seq length=18 hidden_units=5 nr_episodes=4 0.0049169063568115234
# seq length=18 hidden_units=5 nr_episodes=6 0.0050702691078186035
# seq length=18 hidden_units=5 nr_episodes=8 0.0020629167556762695
# seq length=18 hidden_units=5 nr_episodes=10 -4.673004150390625e-05
# seq length=18 hidden_units=5 nr_episodes=12 0.005217552185058594
# seq length=18 hidden_units=5 nr_episodes=14 0.004611313343048096
# seq length=18 hidden_units=5 nr_episodes=16 0.006983697414398193
# seq length=18 hidden_units=5 nr_episodes=18 0.012702524662017822
# seq length=18 hidden_units=5 nr_episodes=20 0.0237005352973938
# seq length=18 hidden_units=15 nr_episodes=0 0.003647446632385254
# seq length=18 hidden_units=15 nr_episodes=2 0.010107994079589844
# seq length=18 hidden_units=15 nr_episodes=4 0.016706466674804688
# seq length=18 hidden_units=15 nr_episodes=6 0.030273914337158203
# seq length=18 hidden_units=15 nr_episodes=8 0.047554850578308105
# seq length=18 hidden_units=15 nr_episodes=10 0.08230626583099365
# seq length=18 hidden_units=15 nr_episodes=12 0.12229472398757935
# seq length=18 hidden_units=15 nr_episodes=14 0.16543692350387573
# seq length=18 hidden_units=15 nr_episodes=16 0.2053186297416687
# seq length=18 hidden_units=15 nr_episodes=18 0.21530681848526
# seq length=18 hidden_units=15 nr_episodes=20 0.14549267292022705
# seq length=18 hidden_units=25 nr_episodes=0 0.0035477876663208008
# seq length=18 hidden_units=25 nr_episodes=2 0.01784348487854004
# seq length=18 hidden_units=25 nr_episodes=4 0.03785747289657593
# seq length=18 hidden_units=25 nr_episodes=6 0.056986331939697266
# seq length=18 hidden_units=25 nr_episodes=8 0.09435456991195679
# seq length=18 hidden_units=25 nr_episodes=10 0.10807299613952637
# seq length=18 hidden_units=25 nr_episodes=12 0.07177793979644775
# seq length=18 hidden_units=25 nr_episodes=14 0.0407792329788208
# seq length=18 hidden_units=25 nr_episodes=16 0.006179630756378174
# seq length=18 hidden_units=25 nr_episodes=18 -0.07040047645568848
# seq length=18 hidden_units=25 nr_episodes=20 -0.573011040687561
# seq length=18 hidden_units=50 nr_episodes=0 0.005812168121337891
# seq length=18 hidden_units=50 nr_episodes=2 0.018452465534210205
# seq length=18 hidden_units=50 nr_episodes=4 0.05892390012741089
# seq length=18 hidden_units=50 nr_episodes=6 0.09223413467407227
# seq length=18 hidden_units=50 nr_episodes=8 0.11068671941757202
# seq length=18 hidden_units=50 nr_episodes=10 0.1442732810974121
# seq length=18 hidden_units=50 nr_episodes=12 0.0927971601486206
# seq length=18 hidden_units=50 nr_episodes=14 -0.2503335475921631
# seq length=18 hidden_units=50 nr_episodes=16 -0.7878659963607788
# seq length=18 hidden_units=50 nr_episodes=18 -0.34257006645202637
# seq length=18 hidden_units=50 nr_episodes=20 -0.6404449939727783
# seq length=18 hidden_units=75 nr_episodes=0 0.013741552829742432
# seq length=18 hidden_units=75 nr_episodes=2 0.03692871332168579
# seq length=18 hidden_units=75 nr_episodes=4 0.0905299186706543
# seq length=18 hidden_units=75 nr_episodes=6 0.15899723768234253
# seq length=18 hidden_units=75 nr_episodes=8 -5.4296040534973145
# seq length=18 hidden_units=75 nr_episodes=10 -0.645330548286438
# seq length=18 hidden_units=75 nr_episodes=12 -1.1436049938201904
# seq length=18 hidden_units=75 nr_episodes=14 -0.2514829635620117
# seq length=18 hidden_units=75 nr_episodes=16 0.10772395133972168
# seq length=18 hidden_units=75 nr_episodes=18 0.012300193309783936
# seq length=18 hidden_units=75 nr_episodes=20 0.11690413951873779
# seq length=24 hidden_units=5 nr_episodes=0 -0.19594943523406982
# seq length=24 hidden_units=5 nr_episodes=2 -0.11572730541229248
# seq length=24 hidden_units=5 nr_episodes=4 -0.052344441413879395
# seq length=24 hidden_units=5 nr_episodes=6 -0.014803051948547363
# seq length=24 hidden_units=5 nr_episodes=8 -0.003456592559814453
# seq length=24 hidden_units=5 nr_episodes=10 -0.01586174964904785
# seq length=24 hidden_units=5 nr_episodes=12 -0.02425527572631836
# seq length=24 hidden_units=5 nr_episodes=14 -0.0222395658493042
# seq length=24 hidden_units=5 nr_episodes=16 0.004325807094573975
# seq length=24 hidden_units=5 nr_episodes=18 0.021708548069000244
# seq length=24 hidden_units=5 nr_episodes=20 0.03848433494567871
# seq length=24 hidden_units=15 nr_episodes=0 -0.016975045204162598
# seq length=24 hidden_units=15 nr_episodes=2 0.003235340118408203
# seq length=24 hidden_units=15 nr_episodes=4 0.002152740955352783
# seq length=24 hidden_units=15 nr_episodes=6 0.003434419631958008
# seq length=24 hidden_units=15 nr_episodes=8 0.0009313225746154785
# seq length=24 hidden_units=15 nr_episodes=10 0.004594922065734863
# seq length=24 hidden_units=15 nr_episodes=12 0.011471390724182129
# seq length=24 hidden_units=15 nr_episodes=14 0.014579296112060547
# seq length=24 hidden_units=15 nr_episodes=16 0.023950815200805664
# seq length=24 hidden_units=15 nr_episodes=18 0.035386085510253906
# seq length=24 hidden_units=15 nr_episodes=20 0.04990595579147339
# seq length=24 hidden_units=25 nr_episodes=0 -0.0017015933990478516
# seq length=24 hidden_units=25 nr_episodes=2 0.007847309112548828
# seq length=24 hidden_units=25 nr_episodes=4 0.01920372247695923
# seq length=24 hidden_units=25 nr_episodes=6 0.039771080017089844
# seq length=24 hidden_units=25 nr_episodes=8 0.07855051755905151
# seq length=24 hidden_units=25 nr_episodes=10 0.13679105043411255
# seq length=24 hidden_units=25 nr_episodes=12 0.0009902715682983398
# seq length=24 hidden_units=25 nr_episodes=14 -1.974039077758789
# seq length=24 hidden_units=25 nr_episodes=16 -0.7096889019012451
# seq length=24 hidden_units=25 nr_episodes=18 -1.1676528453826904
# seq length=24 hidden_units=25 nr_episodes=20 -1.0598483085632324
# seq length=24 hidden_units=50 nr_episodes=0 0.005742847919464111
# seq length=24 hidden_units=50 nr_episodes=2 0.013594388961791992
# seq length=24 hidden_units=50 nr_episodes=4 0.04060620069503784
# seq length=24 hidden_units=50 nr_episodes=6 0.06499689817428589
# seq length=24 hidden_units=50 nr_episodes=8 0.10632675886154175
# seq length=24 hidden_units=50 nr_episodes=10 -0.013293981552124023
# seq length=24 hidden_units=50 nr_episodes=12 -2.4578802585601807
# seq length=24 hidden_units=50 nr_episodes=14 -2.7228851318359375
# seq length=24 hidden_units=50 nr_episodes=16 -2.959406852722168
# seq length=24 hidden_units=50 nr_episodes=18 -4.722508430480957
# seq length=24 hidden_units=50 nr_episodes=20 -3.8724632263183594
# seq length=24 hidden_units=75 nr_episodes=0 0.0013383030891418457
# seq length=24 hidden_units=75 nr_episodes=2 0.03580445051193237
# seq length=24 hidden_units=75 nr_episodes=4 0.08422082662582397
# seq length=24 hidden_units=75 nr_episodes=6 0.15716838836669922
# seq length=24 hidden_units=75 nr_episodes=8 -7.917716979980469
# seq length=24 hidden_units=75 nr_episodes=10 -3.330815315246582
# seq length=24 hidden_units=75 nr_episodes=12 -2.3437230587005615
# seq length=24 hidden_units=75 nr_episodes=14 -0.6613057851791382
# seq length=24 hidden_units=75 nr_episodes=16 -3.56118106842041
# seq length=24 hidden_units=75 nr_episodes=18 -3.4260826110839844
# seq length=24 hidden_units=75 nr_episodes=20 -3.332700729370117
# LSTM best results achieved with length=5 hidden_units=50 and nr_episodes=20) ==> measure=0.23

# %% [markdown]
# ## Univariate Pytorch eval

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from pandas import Series
from matplotlib import pyplot as plt

def plot_single_model_evaluation(train: Series, test: Series, prd_train: Series, prd_test: Series, title: str = ""):
    # Calculate performance metrics
    metrics = {
        "MAE": [
            mean_absolute_error(train, prd_train),
            mean_absolute_error(test, prd_test),
        ],
        "MSE": [
            mean_squared_error(train, prd_train),
            mean_squared_error(test, prd_test),
        ],
        "RMSE": [
            np.sqrt(mean_squared_error(train, prd_train)),
            np.sqrt(mean_squared_error(test, prd_test)),
        ],
        "R²": [
            r2_score(train, prd_train),
            r2_score(test, prd_test),
        ]
    }

    # Create a DataFrame from the metrics dictionary
    performance_df = pd.DataFrame(metrics, index=["Train", "Test"]).T
    
    # Create subplots
    fig, axs = plt.subplots(1, 2, figsize=(14, 6))
    fig.suptitle(title, fontsize=16)
    
    # Plot scale-dependent errors
    scale_dependent_errors = ["MAE", "MSE", "RMSE"]
    scale_dependent_data = performance_df.loc[scale_dependent_errors]
    ax = axs[0]
    ax.set_title("Scale-dependent errors")
    ax.set_xlabel("Metrics")
    ax.set_ylabel("Values")
    bar_width = 0.2  # Adjusted bar width for more spacing
    index = np.arange(len(scale_dependent_data.columns))
    for i, metric in enumerate(scale_dependent_data.index):
        bars = ax.bar(index + i * bar_width * 1.5, scale_dependent_data.loc[metric], bar_width, label=metric)
        ax.bar_label(bars, fmt='%.2f')
    ax.set_xticks(index + bar_width)
    ax.set_xticklabels(scale_dependent_data.columns)
    ax.legend()
    
    # Plot percentage errors
    percentage_errors = ["R²"]
    percentage_data = performance_df.loc[percentage_errors]
    ax = axs[1]
    ax.set_title("Percentage errors")
    ax.set_xlabel("Metrics")
    ax.set_ylabel("Values")
    bar_width = 0.35
    index = np.arange(len(percentage_data.columns))
    for i, metric in enumerate(percentage_data.index):
        bars = ax.bar(index + i * bar_width, percentage_data.loc[metric], bar_width, label=metric)
        ax.bar_label(bars, fmt='%.2f')
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(percentage_data.columns)
    ax.legend()
    
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()



def plot_performance_metrics(metrics: dict, title: str = ""):
    # Create a DataFrame from the metrics dictionary
    performance_df = pd.DataFrame(metrics)
    
    # Separate scale-dependent errors and percentage errors
    scale_dependent_errors = ["MAE", "MSE", "RMSE"]
    percentage_errors = ["R²"]
    
    # Create subplots
    fig, axs = plt.subplots(1, 2, figsize=(14, 6))
    fig.suptitle(title, fontsize=16)
    
    # Plot scale-dependent errors
    scale_dependent_data = performance_df[["Model"] + scale_dependent_errors].set_index("Model").T
    ax = axs[0]
    ax.set_title("Scale-dependent errors")
    ax.set_xlabel("Metrics")
    ax.set_ylabel("Values")
    bar_width = 0.2  # Adjusted bar width for more spacing
    index = np.arange(len(scale_dependent_data.columns))
    for i, metric in enumerate(scale_dependent_data.index):
        bars = ax.bar(index + i * bar_width * 1.5, scale_dependent_data.loc[metric], bar_width, label=metric)
        ax.bar_label(bars, fmt='%.2f')
    ax.set_xticks(index + bar_width)
    ax.set_xticklabels(scale_dependent_data.columns)
    ax.legend()
    
    # Plot percentage errors
    percentage_data = performance_df[["Model"] + percentage_errors].set_index("Model").T
    ax = axs[1]
    ax.set_title("Percentage errors")
    ax.set_xlabel("Metrics")
    ax.set_ylabel("Values")
    bar_width = 0.35
    index = np.arange(len(percentage_data.columns))
    for i, metric in enumerate(percentage_data.index):
        bars = ax.bar(index + i * bar_width, percentage_data.loc[metric], bar_width, label=metric)
        ax.bar_label(bars, fmt='%.2f')
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(percentage_data.columns)
    ax.legend()
    
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# %%
params = best_params["params"]
best_length = params[0]


# Assuming train and test are DataFrames with a DateTime index
trn_series = train[[target]]
tst_series = test[[target]]


trnX, trnY = prepare_dataset_for_lstm_uni(trn_series.values.astype("float32"), seq_length=best_length)
tstX, tstY  = prepare_dataset_for_lstm_uni(tst_series.values.astype("float32"), seq_length=best_length)


prd_trn = best_model.predict(trnX)
prd_tst = best_model.predict(tstX)

# Plot the forecasting evaluation
plot_single_model_evaluation(trn_series[best_length:], tst_series[best_length:], prd_trn, prd_tst, title=f"{file_tag} - LSTM Univariate (length={best_length}, hidden={params[1]}, epochs={params[2]})")

# %% [markdown]
# ## Plot lstm tensorflow model univariate

# %%
from pandas import Series
pred_series = Series(prd_tst.numpy().ravel(), index=tst_series.index[best_length:])


plot_forecasting_series(
    trn_series[best_length:],
    tst_series[best_length:],
    pred_series,
    title=f"{file_tag} - LSTM Univariate Predictions (length={best_length}, hidden={params[1]}, epochs={params[2]})",
    xlabel='Date',
    ylabel=target,
)
# Out:
# <Axes: xlabel='Date', ylabel='target_station_load_rate'>

# %% [markdown]
# ## Pytorch Univariate Model and Loss

# %%
model = DS_LSTM_Univariate(train_series_float, input_size=train_series_float.shape[1], hidden_size=50, num_layers=1)
loss = model.fit()
print(loss)
# Out:
# tensor(0.2835, grad_fn=<MseLossBackward0>)

# %% [markdown]
# ## Analysis - Results from Model Implementation

# %% [markdown]
# # LSTM Pytorch Multivariate

# %% [markdown]
# ## Pytorch Multivariate Functions

# %%
from torch import no_grad, tensor
from torch.nn import LSTM, Linear, Module, MSELoss
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

def prepare_dataset_for_lstm_multi(features, target, seq_length: int = 4):
    setX: list = []
    setY: list = []
    for i in range(len(target) - seq_length):
        past = features[i : i + seq_length]
        future = target[i + seq_length]  # Predict the next value only
        setX.append(past)
        setY.append(future)
    setX = tensor(np.array(setX, dtype=np.float32))  # Convert to torch.float32
    setY = tensor(np.array(setY, dtype=np.float32)).view(-1, 1)  # Convert to torch.float32 and reshape
    return setX, setY


class DS_LSTM_Multivariate(Module):
    def __init__(self, trainX, trainY, input_size: int, hidden_size: int = 50, num_layers: int = 1, length: int = 4):
        super().__init__()
        self.lstm = LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.linear = Linear(hidden_size, 1)
        self.optimizer = Adam(self.parameters())
        self.loss_fn = MSELoss()

        trnX, trnY = prepare_dataset_for_lstm_multi(trainX, trainY, seq_length=length)
        self.loader = DataLoader(TensorDataset(trnX, trnY), shuffle=True, batch_size=len(trainX) // 10)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.linear(x[:, -1, :])  # Use the last output of the LSTM
        return x

    def fit(self):
        self.train()
        for batchX, batchY in self.loader:
            y_pred = self(batchX)
            loss = self.loss_fn(y_pred, batchY)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
        return loss

    def predict(self, X):
        with no_grad():
            y_pred = self(X)
        return y_pred

from dslabs_functions import HEIGHT, plot_multiline_chart
from copy import deepcopy
from matplotlib.pyplot import figure, savefig, subplots
from dslabs_functions import FORECAST_MEASURES, DELTA_IMPROVE, plot_multiline_chart

def lstm_study_multi(trainX, trainY, testX, testY, nr_episodes: int = 1000,sequence_size: list =[2,4,8], nr_hidden_units: list =[25,50,100], measure: str = "R2"):
    # sequence_size = [2, 4, 8]
    # nr_hidden_units = [25, 50, 100]

    step: int = nr_episodes // 10
    episodes = [1] + list(range(0, nr_episodes + 1, step))[1:]
    flag = measure == "R2" or measure == "MAPE"
    best_model = None
    best_params: dict = {"name": "LSTM", "metric": measure, "params": ()}
    best_performance: float = -100000

    _, axs = subplots(1, len(sequence_size), figsize=(len(sequence_size) * HEIGHT, HEIGHT))

    for i in range(len(sequence_size)):
        length = sequence_size[i]
        tstX, tstY = prepare_dataset_for_lstm_multi(testX, testY, seq_length=length)

        values = {}
        for hidden in nr_hidden_units:
            yvalues = []
            model = DS_LSTM_Multivariate(trainX, trainY, input_size=trainX.shape[1], hidden_size=hidden, length=length)
            for n in range(0, nr_episodes + 1):
                model.fit()
                if n % step == 0:
                    prd_tst = model.predict(tstX)
                    eval: float = FORECAST_MEASURES[measure](testY[length:], prd_tst)
                    print(f"seq length={length} hidden_units={hidden} nr_episodes={n}", eval)
                    if eval > best_performance and abs(eval - best_performance) > DELTA_IMPROVE:
                        best_performance: float = eval
                        best_params["params"] = (length, hidden, n)
                        best_model = deepcopy(model)
                    yvalues.append(eval)
            values[hidden] = yvalues
        plot_multiline_chart(
            episodes,
            values,
            ax=axs[i],
            title=f"LSTM seq length={length} ({measure})",
            xlabel="nr episodes",
            ylabel=measure,
            percentage=flag,
        )
    print(
        f"LSTM best results achieved with length={best_params['params'][0]} hidden_units={best_params['params'][1]} and nr_episodes={best_params['params'][2]}) ==> measure={best_performance:.2f}"
    )
    return best_model, best_params

# %% [markdown]
# ## Pytorch Multivariate Data Study

# %%
# Example usage
# Assuming `train` and `test` are your DataFrames and `target` is the target column name
trnY_float = train.pop(target).values.astype(np.float32)
tstY_float = test.pop(target).values.astype(np.float32)
trnX_float = train.values.astype(np.float32)
tstX_float = test.values.astype(np.float32)

# Run the study
best_model, best_params = lstm_study_multi(trnX_float,
                                           trnY_float,
                                           tstX_float,
                                           tstY_float,
                                           nr_episodes=50,
                                           sequence_size=[1,3,5,7,12,14,16],
                                           nr_hidden_units=[5,15,25,50,75],
                                           measure='R2')
# Out:
# seq length=1 hidden_units=5 nr_episodes=0 -0.0003972053527832031
# seq length=1 hidden_units=5 nr_episodes=5 -0.0005700588226318359
# seq length=1 hidden_units=5 nr_episodes=10 -0.00012743473052978516
# seq length=1 hidden_units=5 nr_episodes=15 -0.0002503395080566406
# seq length=1 hidden_units=5 nr_episodes=20 -0.00014328956604003906
# seq length=1 hidden_units=5 nr_episodes=25 -0.00010180473327636719
# seq length=1 hidden_units=5 nr_episodes=30 -6.413459777832031e-05
# seq length=1 hidden_units=5 nr_episodes=35 -4.887580871582031e-06
# seq length=1 hidden_units=5 nr_episodes=40 -0.0003930330276489258
# seq length=1 hidden_units=5 nr_episodes=45 -9.5367431640625e-07
# seq length=1 hidden_units=5 nr_episodes=50 -1.4901161193847656e-05
# seq length=1 hidden_units=15 nr_episodes=0 -0.010625123977661133
# seq length=1 hidden_units=15 nr_episodes=5 -0.0004527568817138672
# seq length=1 hidden_units=15 nr_episodes=10 -2.5033950805664062e-06
# seq length=1 hidden_units=15 nr_episodes=15 -0.0001055002212524414
# seq length=1 hidden_units=15 nr_episodes=20 -1.1086463928222656e-05
# seq length=1 hidden_units=15 nr_episodes=25 -0.00044548511505126953
# seq length=1 hidden_units=15 nr_episodes=30 -0.00018846988677978516
# seq length=1 hidden_units=15 nr_episodes=35 -5.5909156799316406e-05
# seq length=1 hidden_units=15 nr_episodes=40 -1.704692840576172e-05
# seq length=1 hidden_units=15 nr_episodes=45 -0.0011265277862548828
# seq length=1 hidden_units=15 nr_episodes=50 -2.9087066650390625e-05
# seq length=1 hidden_units=25 nr_episodes=0 -0.006510615348815918
# seq length=1 hidden_units=25 nr_episodes=5 -0.0002753734588623047
# seq length=1 hidden_units=25 nr_episodes=10 -3.5762786865234375e-07
# seq length=1 hidden_units=25 nr_episodes=15 -0.0002415180206298828
# seq length=1 hidden_units=25 nr_episodes=20 -9.691715240478516e-05
# seq length=1 hidden_units=25 nr_episodes=25 -1.1920928955078125e-06
# seq length=1 hidden_units=25 nr_episodes=30 -2.682209014892578e-05
# seq length=1 hidden_units=25 nr_episodes=35 -3.5762786865234375e-07
# seq length=1 hidden_units=25 nr_episodes=40 -3.9696693420410156e-05
# seq length=1 hidden_units=25 nr_episodes=45 -0.0002262592315673828
# seq length=1 hidden_units=25 nr_episodes=50 -0.0006364583969116211
# seq length=1 hidden_units=50 nr_episodes=0 -0.008322715759277344
# seq length=1 hidden_units=50 nr_episodes=5 -3.218650817871094e-05
# seq length=1 hidden_units=50 nr_episodes=10 -0.0008072853088378906
# seq length=1 hidden_units=50 nr_episodes=15 -0.0008705854415893555
# seq length=1 hidden_units=50 nr_episodes=20 -0.0002459287643432617
# seq length=1 hidden_units=50 nr_episodes=25 -0.0006663799285888672
# seq length=1 hidden_units=50 nr_episodes=30 -3.7670135498046875e-05
# seq length=1 hidden_units=50 nr_episodes=35 -0.00012481212615966797
# seq length=1 hidden_units=50 nr_episodes=40 -4.76837158203125e-06
# seq length=1 hidden_units=50 nr_episodes=45 -0.0006282329559326172
# seq length=1 hidden_units=50 nr_episodes=50 -0.0032243728637695312
# seq length=1 hidden_units=75 nr_episodes=0 -0.039925575256347656
# seq length=1 hidden_units=75 nr_episodes=5 -0.0005140304565429688
# seq length=1 hidden_units=75 nr_episodes=10 -1.1444091796875e-05
# seq length=1 hidden_units=75 nr_episodes=15 -0.002534151077270508
# seq length=1 hidden_units=75 nr_episodes=20 -0.0002180337905883789
# seq length=1 hidden_units=75 nr_episodes=25 -3.7670135498046875e-05
# seq length=1 hidden_units=75 nr_episodes=30 -0.0009845495223999023
# seq length=1 hidden_units=75 nr_episodes=35 -5.340576171875e-05
# seq length=1 hidden_units=75 nr_episodes=40 -5.650520324707031e-05
# seq length=1 hidden_units=75 nr_episodes=45 -1.9073486328125e-05
# seq length=1 hidden_units=75 nr_episodes=50 -0.0009553432464599609
# seq length=3 hidden_units=5 nr_episodes=0 -0.1835181713104248
# seq length=3 hidden_units=5 nr_episodes=5 -0.08996546268463135
# seq length=3 hidden_units=5 nr_episodes=10 -0.0755767822265625
# seq length=3 hidden_units=5 nr_episodes=15 -0.02106332778930664
# seq length=3 hidden_units=5 nr_episodes=20 -0.0075626373291015625
# seq length=3 hidden_units=5 nr_episodes=25 -0.001073002815246582
# seq length=3 hidden_units=5 nr_episodes=30 -2.86102294921875e-06
# seq length=3 hidden_units=5 nr_episodes=35 -0.0001710653305053711
# seq length=3 hidden_units=5 nr_episodes=40 -0.0004483461380004883
# seq length=3 hidden_units=5 nr_episodes=45 -0.29998600482940674
# seq length=3 hidden_units=5 nr_episodes=50 -0.00035583972930908203
# seq length=3 hidden_units=15 nr_episodes=0 -0.0003025531768798828
# seq length=3 hidden_units=15 nr_episodes=5 -5.364418029785156e-06
# seq length=3 hidden_units=15 nr_episodes=10 -2.6226043701171875e-06
# seq length=3 hidden_units=15 nr_episodes=15 -9.369850158691406e-05
# seq length=3 hidden_units=15 nr_episodes=20 -9.715557098388672e-05
# seq length=3 hidden_units=15 nr_episodes=25 -0.0007441043853759766
# seq length=3 hidden_units=15 nr_episodes=30 -0.0006606578826904297
# seq length=3 hidden_units=15 nr_episodes=35 -0.00045883655548095703
# seq length=3 hidden_units=15 nr_episodes=40 -9.107589721679688e-05
# seq length=3 hidden_units=15 nr_episodes=45 -6.985664367675781e-05
# seq length=3 hidden_units=15 nr_episodes=50 -0.0003197193145751953
# seq length=3 hidden_units=25 nr_episodes=0 -0.0010929107666015625
# seq length=3 hidden_units=25 nr_episodes=5 -0.0003838539123535156
# seq length=3 hidden_units=25 nr_episodes=10 -0.0003579854965209961
# seq length=3 hidden_units=25 nr_episodes=15 -0.0004659891128540039
# seq length=3 hidden_units=25 nr_episodes=20 -0.0003508329391479492
# seq length=3 hidden_units=25 nr_episodes=25 -5.7697296142578125e-05
# seq length=3 hidden_units=25 nr_episodes=30 -0.0002760887145996094
# seq length=3 hidden_units=25 nr_episodes=35 -0.0007674694061279297
# seq length=3 hidden_units=25 nr_episodes=40 -8.535385131835938e-05
# seq length=3 hidden_units=25 nr_episodes=45 -0.0020133256912231445
# seq length=3 hidden_units=25 nr_episodes=50 -0.021851420402526855
# seq length=3 hidden_units=50 nr_episodes=0 -0.0003508329391479492
# seq length=3 hidden_units=50 nr_episodes=5 -8.225440979003906e-06
# seq length=3 hidden_units=50 nr_episodes=10 -7.987022399902344e-05
# seq length=3 hidden_units=50 nr_episodes=15 -0.00030744075775146484
# seq length=3 hidden_units=50 nr_episodes=20 -0.0003579854965209961
# seq length=3 hidden_units=50 nr_episodes=25 -0.0006794929504394531
# seq length=3 hidden_units=50 nr_episodes=30 -0.00010609626770019531
# seq length=3 hidden_units=50 nr_episodes=35 -0.0009405612945556641
# seq length=3 hidden_units=50 nr_episodes=40 -0.0037282705307006836
# seq length=3 hidden_units=50 nr_episodes=45 -0.0028960704803466797
# seq length=3 hidden_units=50 nr_episodes=50 -0.0006819963455200195
# seq length=3 hidden_units=75 nr_episodes=0 -0.00226438045501709
# seq length=3 hidden_units=75 nr_episodes=5 -0.0010584592819213867
# seq length=3 hidden_units=75 nr_episodes=10 -0.001734614372253418
# seq length=3 hidden_units=75 nr_episodes=15 -0.001590132713317871
# seq length=3 hidden_units=75 nr_episodes=20 -0.0006289482116699219
# seq length=3 hidden_units=75 nr_episodes=25 3.0934810638427734e-05
# seq length=3 hidden_units=75 nr_episodes=30 -0.0013954639434814453
# seq length=3 hidden_units=75 nr_episodes=35 -6.365776062011719e-05
# seq length=3 hidden_units=75 nr_episodes=40 0.0008059144020080566
# seq length=3 hidden_units=75 nr_episodes=45 0.004136860370635986
# seq length=3 hidden_units=75 nr_episodes=50 -0.0004787445068359375
# seq length=5 hidden_units=5 nr_episodes=0 -0.0007450580596923828
# seq length=5 hidden_units=5 nr_episodes=5 -0.00034677982330322266
# seq length=5 hidden_units=5 nr_episodes=10 -8.225440979003906e-06
# seq length=5 hidden_units=5 nr_episodes=15 -8.952617645263672e-05
# seq length=5 hidden_units=5 nr_episodes=20 -7.605552673339844e-05
# seq length=5 hidden_units=5 nr_episodes=25 -1.0013580322265625e-05
# seq length=5 hidden_units=5 nr_episodes=30 -0.0002751350402832031
# seq length=5 hidden_units=5 nr_episodes=35 -3.4570693969726562e-06
# seq length=5 hidden_units=5 nr_episodes=40 -1.5735626220703125e-05
# seq length=5 hidden_units=5 nr_episodes=45 -0.00010132789611816406
# seq length=5 hidden_units=5 nr_episodes=50 -5.960464477539062e-07
# seq length=5 hidden_units=15 nr_episodes=0 -0.005288600921630859
# seq length=5 hidden_units=15 nr_episodes=5 -0.00013053417205810547
# seq length=5 hidden_units=15 nr_episodes=10 -0.00018227100372314453
# seq length=5 hidden_units=15 nr_episodes=15 -0.0005295276641845703
# seq length=5 hidden_units=15 nr_episodes=20 -0.0005451440811157227
# seq length=5 hidden_units=15 nr_episodes=25 -0.000995039939880371
# seq length=5 hidden_units=15 nr_episodes=30 -0.0005172491073608398
# seq length=5 hidden_units=15 nr_episodes=35 -0.00033080577850341797
# seq length=5 hidden_units=15 nr_episodes=40 -5.519390106201172e-05
# seq length=5 hidden_units=15 nr_episodes=45 -0.03916001319885254
# seq length=5 hidden_units=15 nr_episodes=50 -0.0030885934829711914
# seq length=5 hidden_units=25 nr_episodes=0 -0.00015795230865478516
# seq length=5 hidden_units=25 nr_episodes=5 -2.1338462829589844e-05
# seq length=5 hidden_units=25 nr_episodes=10 -0.0034154653549194336
# seq length=5 hidden_units=25 nr_episodes=15 -0.004950165748596191
# seq length=5 hidden_units=25 nr_episodes=20 -0.0008155107498168945
# seq length=5 hidden_units=25 nr_episodes=25 -0.0019837617874145508
# seq length=5 hidden_units=25 nr_episodes=30 -0.011376380920410156
# seq length=5 hidden_units=25 nr_episodes=35 5.304813385009766e-06
# seq length=5 hidden_units=25 nr_episodes=40 -0.002137303352355957
# seq length=5 hidden_units=25 nr_episodes=45 -8.022785186767578e-05
# seq length=5 hidden_units=25 nr_episodes=50 -0.00020074844360351562
# seq length=5 hidden_units=50 nr_episodes=0 -0.008171677589416504
# seq length=5 hidden_units=50 nr_episodes=5 -0.005463242530822754
# seq length=5 hidden_units=50 nr_episodes=10 -0.0009604692459106445
# seq length=5 hidden_units=50 nr_episodes=15 -0.0002715587615966797
# seq length=5 hidden_units=50 nr_episodes=20 -0.00013959407806396484
# seq length=5 hidden_units=50 nr_episodes=25 -0.0008628368377685547
# seq length=5 hidden_units=50 nr_episodes=30 -0.002329587936401367
# seq length=5 hidden_units=50 nr_episodes=35 -0.0007218122482299805
# seq length=5 hidden_units=50 nr_episodes=40 -4.553794860839844e-05
# seq length=5 hidden_units=50 nr_episodes=45 -0.0024526119232177734
# seq length=5 hidden_units=50 nr_episodes=50 -0.00034165382385253906
# seq length=5 hidden_units=75 nr_episodes=0 -0.0010739564895629883
# seq length=5 hidden_units=75 nr_episodes=5 -0.0020079612731933594
# seq length=5 hidden_units=75 nr_episodes=10 -0.0030001401901245117
# seq length=5 hidden_units=75 nr_episodes=15 -0.00022482872009277344
# seq length=5 hidden_units=75 nr_episodes=20 -0.001048445701599121
# seq length=5 hidden_units=75 nr_episodes=25 -0.0019360780715942383
# seq length=5 hidden_units=75 nr_episodes=30 -0.0005803108215332031
# seq length=5 hidden_units=75 nr_episodes=35 -0.0018701553344726562
# seq length=5 hidden_units=75 nr_episodes=40 -0.0005782842636108398
# seq length=5 hidden_units=75 nr_episodes=45 -0.0014886856079101562
# seq length=5 hidden_units=75 nr_episodes=50 -8.058547973632812e-05
# seq length=7 hidden_units=5 nr_episodes=0 -0.30395209789276123
# seq length=7 hidden_units=5 nr_episodes=5 -0.18855071067810059
# seq length=7 hidden_units=5 nr_episodes=10 -0.11897385120391846
# seq length=7 hidden_units=5 nr_episodes=15 -0.0008375644683837891
# seq length=7 hidden_units=5 nr_episodes=20 -0.00016129016876220703
# seq length=7 hidden_units=5 nr_episodes=25 -0.0003609657287597656
# seq length=7 hidden_units=5 nr_episodes=30 -3.2067298889160156e-05
# seq length=7 hidden_units=5 nr_episodes=35 -0.0007561445236206055
# seq length=7 hidden_units=5 nr_episodes=40 -0.0008658170700073242
# seq length=7 hidden_units=5 nr_episodes=45 -0.001431584358215332
# seq length=7 hidden_units=5 nr_episodes=50 -4.76837158203125e-07
# seq length=7 hidden_units=15 nr_episodes=0 -0.10429084300994873
# seq length=7 hidden_units=15 nr_episodes=5 -0.0002900362014770508
# seq length=7 hidden_units=15 nr_episodes=10 -1.7404556274414062e-05
# seq length=7 hidden_units=15 nr_episodes=15 -0.0013388395309448242
# seq length=7 hidden_units=15 nr_episodes=20 -0.000102996826171875
# seq length=7 hidden_units=15 nr_episodes=25 -0.0006173849105834961
# seq length=7 hidden_units=15 nr_episodes=30 -0.003923535346984863
# seq length=7 hidden_units=15 nr_episodes=35 -0.017432332038879395
# seq length=7 hidden_units=15 nr_episodes=40 -4.935264587402344e-05
# seq length=7 hidden_units=15 nr_episodes=45 -7.212162017822266e-05
# seq length=7 hidden_units=15 nr_episodes=50 0.0028417110443115234
# seq length=7 hidden_units=25 nr_episodes=0 -0.0008404254913330078
# seq length=7 hidden_units=25 nr_episodes=5 -0.008855104446411133
# seq length=7 hidden_units=25 nr_episodes=10 -0.0002353191375732422
# seq length=7 hidden_units=25 nr_episodes=15 -1.3113021850585938e-05
# seq length=7 hidden_units=25 nr_episodes=20 0.0010334253311157227
# seq length=7 hidden_units=25 nr_episodes=25 -0.0007499456405639648
# seq length=7 hidden_units=25 nr_episodes=30 0.0008568167686462402
# seq length=7 hidden_units=25 nr_episodes=35 0.00010198354721069336
# seq length=7 hidden_units=25 nr_episodes=40 -4.9233436584472656e-05
# seq length=7 hidden_units=25 nr_episodes=45 -0.007977485656738281
# seq length=7 hidden_units=25 nr_episodes=50 -7.62939453125e-06
# seq length=7 hidden_units=50 nr_episodes=0 -0.00434267520904541
# seq length=7 hidden_units=50 nr_episodes=5 -0.0010982751846313477
# seq length=7 hidden_units=50 nr_episodes=10 -0.0012938976287841797
# seq length=7 hidden_units=50 nr_episodes=15 -0.0003991127014160156
# seq length=7 hidden_units=50 nr_episodes=20 -0.00013184547424316406
# seq length=7 hidden_units=50 nr_episodes=25 -0.0014789104461669922
# seq length=7 hidden_units=50 nr_episodes=30 -0.006150484085083008
# seq length=7 hidden_units=50 nr_episodes=35 -0.0010129213333129883
# seq length=7 hidden_units=50 nr_episodes=40 -0.008725285530090332
# seq length=7 hidden_units=50 nr_episodes=45 -0.020987391471862793
# seq length=7 hidden_units=50 nr_episodes=50 -0.0013079643249511719
# seq length=7 hidden_units=75 nr_episodes=0 -0.0024172067642211914
# seq length=7 hidden_units=75 nr_episodes=5 -0.005672454833984375
# seq length=7 hidden_units=75 nr_episodes=10 -0.0002484321594238281
# seq length=7 hidden_units=75 nr_episodes=15 -1.3113021850585938e-05
# seq length=7 hidden_units=75 nr_episodes=20 -1.1920928955078125e-07
# seq length=7 hidden_units=75 nr_episodes=25 -2.6226043701171875e-05
# seq length=7 hidden_units=75 nr_episodes=30 -0.001394033432006836
# seq length=7 hidden_units=75 nr_episodes=35 -0.05026543140411377
# seq length=7 hidden_units=75 nr_episodes=40 -0.003289341926574707
# seq length=7 hidden_units=75 nr_episodes=45 -0.0002911090850830078
# seq length=7 hidden_units=75 nr_episodes=50 -0.0009698867797851562
# seq length=12 hidden_units=5 nr_episodes=0 -0.12551355361938477
# seq length=12 hidden_units=5 nr_episodes=5 -0.05403459072113037
# seq length=12 hidden_units=5 nr_episodes=10 -0.01905500888824463
# seq length=12 hidden_units=5 nr_episodes=15 -0.005264163017272949
# seq length=12 hidden_units=5 nr_episodes=20 -0.0011790990829467773
# seq length=12 hidden_units=5 nr_episodes=25 -0.0002962350845336914
# seq length=12 hidden_units=5 nr_episodes=30 -6.413459777832031e-05
# seq length=12 hidden_units=5 nr_episodes=35 -9.894371032714844e-06
# seq length=12 hidden_units=5 nr_episodes=40 -8.344650268554688e-07
# seq length=12 hidden_units=5 nr_episodes=45 -3.814697265625e-06
# seq length=12 hidden_units=5 nr_episodes=50 -5.030632019042969e-05
# seq length=12 hidden_units=15 nr_episodes=0 -1.6689300537109375e-05
# seq length=12 hidden_units=15 nr_episodes=5 -1.9073486328125e-06
# seq length=12 hidden_units=15 nr_episodes=10 -9.5367431640625e-07
# seq length=12 hidden_units=15 nr_episodes=15 -1.7881393432617188e-06
# seq length=12 hidden_units=15 nr_episodes=20 -1.1920928955078125e-07
# seq length=12 hidden_units=15 nr_episodes=25 -9.298324584960938e-06
# seq length=12 hidden_units=15 nr_episodes=30 -2.872943878173828e-05
# seq length=12 hidden_units=15 nr_episodes=35 -0.0031745433807373047
# seq length=12 hidden_units=15 nr_episodes=40 -0.0006221532821655273
# seq length=12 hidden_units=15 nr_episodes=45 0.0013971924781799316
# seq length=12 hidden_units=15 nr_episodes=50 -0.0002307891845703125
# seq length=12 hidden_units=25 nr_episodes=0 -0.00039327144622802734
# seq length=12 hidden_units=25 nr_episodes=5 -5.125999450683594e-06
# seq length=12 hidden_units=25 nr_episodes=10 -1.5139579772949219e-05
# seq length=12 hidden_units=25 nr_episodes=15 -8.344650268554688e-07
# seq length=12 hidden_units=25 nr_episodes=20 -1.1920928955078125e-06
# seq length=12 hidden_units=25 nr_episodes=25 0.0005865097045898438
# seq length=12 hidden_units=25 nr_episodes=30 0.00045037269592285156
# seq length=12 hidden_units=25 nr_episodes=35 -8.702278137207031e-05
# seq length=12 hidden_units=25 nr_episodes=40 0.00886756181716919
# seq length=12 hidden_units=25 nr_episodes=45 -0.00010144710540771484
# seq length=12 hidden_units=25 nr_episodes=50 -6.628036499023438e-05
# seq length=12 hidden_units=50 nr_episodes=0 -0.0066263675689697266
# seq length=12 hidden_units=50 nr_episodes=5 -2.3245811462402344e-05
# seq length=12 hidden_units=50 nr_episodes=10 -7.808208465576172e-05
# seq length=12 hidden_units=50 nr_episodes=15 -4.553794860839844e-05
# seq length=12 hidden_units=50 nr_episodes=20 -0.012653112411499023
# seq length=12 hidden_units=50 nr_episodes=25 -3.826618194580078e-05
# seq length=12 hidden_units=50 nr_episodes=30 -0.00011372566223144531
# seq length=12 hidden_units=50 nr_episodes=35 -0.0003389120101928711
# seq length=12 hidden_units=50 nr_episodes=40 -0.001355290412902832
# seq length=12 hidden_units=50 nr_episodes=45 -2.3484230041503906e-05
# seq length=12 hidden_units=50 nr_episodes=50 0.007563292980194092
# seq length=12 hidden_units=75 nr_episodes=0 -0.00040221214294433594
# seq length=12 hidden_units=75 nr_episodes=5 -6.830692291259766e-05
# seq length=12 hidden_units=75 nr_episodes=10 0.0014995932579040527
# seq length=12 hidden_units=75 nr_episodes=15 -4.76837158203125e-07
# seq length=12 hidden_units=75 nr_episodes=20 -9.751319885253906e-05
# seq length=12 hidden_units=75 nr_episodes=25 -0.002421855926513672
# seq length=12 hidden_units=75 nr_episodes=30 0.002718210220336914
# seq length=12 hidden_units=75 nr_episodes=35 -2.6226043701171875e-05
# seq length=12 hidden_units=75 nr_episodes=40 -0.0100327730178833
# seq length=12 hidden_units=75 nr_episodes=45 0.0028976798057556152
# seq length=12 hidden_units=75 nr_episodes=50 0.003922462463378906
# seq length=14 hidden_units=5 nr_episodes=0 -0.004906654357910156
# seq length=14 hidden_units=5 nr_episodes=5 -0.0004906654357910156
# seq length=14 hidden_units=5 nr_episodes=10 -1.430511474609375e-06
# seq length=14 hidden_units=5 nr_episodes=15 -1.1086463928222656e-05
# seq length=14 hidden_units=5 nr_episodes=20 -3.0040740966796875e-05
# seq length=14 hidden_units=5 nr_episodes=25 -1.4781951904296875e-05
# seq length=14 hidden_units=5 nr_episodes=30 -1.2874603271484375e-05
# seq length=14 hidden_units=5 nr_episodes=35 -2.6345252990722656e-05
# seq length=14 hidden_units=5 nr_episodes=40 -2.6941299438476562e-05
# seq length=14 hidden_units=5 nr_episodes=45 -1.990795135498047e-05
# seq length=14 hidden_units=5 nr_episodes=50 -4.172325134277344e-06
# seq length=14 hidden_units=15 nr_episodes=0 -0.0005619525909423828
# seq length=14 hidden_units=15 nr_episodes=5 -2.1576881408691406e-05
# seq length=14 hidden_units=15 nr_episodes=10 -0.000874638557434082
# seq length=14 hidden_units=15 nr_episodes=15 -0.00010144710540771484
# seq length=14 hidden_units=15 nr_episodes=20 -0.0015069246292114258
# seq length=14 hidden_units=15 nr_episodes=25 -4.172325134277344e-06
# seq length=14 hidden_units=15 nr_episodes=30 0.0001672506332397461
# seq length=14 hidden_units=15 nr_episodes=35 -0.003361821174621582
# seq length=14 hidden_units=15 nr_episodes=40 -8.344650268554688e-07
# seq length=14 hidden_units=15 nr_episodes=45 -5.996227264404297e-05
# seq length=14 hidden_units=15 nr_episodes=50 -0.0003012418746948242
# seq length=14 hidden_units=25 nr_episodes=0 -0.019803166389465332
# seq length=14 hidden_units=25 nr_episodes=5 -0.0007914304733276367
# seq length=14 hidden_units=25 nr_episodes=10 -2.574920654296875e-05
# seq length=14 hidden_units=25 nr_episodes=15 0.00022876262664794922
# seq length=14 hidden_units=25 nr_episodes=20 -0.00032198429107666016
# seq length=14 hidden_units=25 nr_episodes=25 -9.5367431640625e-07
# seq length=14 hidden_units=25 nr_episodes=30 -5.5789947509765625e-05
# seq length=14 hidden_units=25 nr_episodes=35 -1.5854835510253906e-05
# seq length=14 hidden_units=25 nr_episodes=40 -1.5020370483398438e-05
# seq length=14 hidden_units=25 nr_episodes=45 -0.012148857116699219
# seq length=14 hidden_units=25 nr_episodes=50 -7.152557373046875e-06
# seq length=14 hidden_units=50 nr_episodes=0 -0.0438694953918457
# seq length=14 hidden_units=50 nr_episodes=5 -3.2186508178710938e-06
# seq length=14 hidden_units=50 nr_episodes=10 -7.474422454833984e-05
# seq length=14 hidden_units=50 nr_episodes=15 -7.557868957519531e-05
# seq length=14 hidden_units=50 nr_episodes=20 -2.7894973754882812e-05
# seq length=14 hidden_units=50 nr_episodes=25 0.0005494356155395508
# seq length=14 hidden_units=50 nr_episodes=30 -5.614757537841797e-05
# seq length=14 hidden_units=50 nr_episodes=35 -0.0005954504013061523
# seq length=14 hidden_units=50 nr_episodes=40 -0.0004601478576660156
# seq length=14 hidden_units=50 nr_episodes=45 -0.0001876354217529297
# seq length=14 hidden_units=50 nr_episodes=50 -4.4465065002441406e-05
# seq length=14 hidden_units=75 nr_episodes=0 -9.5367431640625e-07
# seq length=14 hidden_units=75 nr_episodes=5 -6.556510925292969e-06
# seq length=14 hidden_units=75 nr_episodes=10 -2.586841583251953e-05
# seq length=14 hidden_units=75 nr_episodes=15 0.004177749156951904
# seq length=14 hidden_units=75 nr_episodes=20 0.0001271367073059082
# seq length=14 hidden_units=75 nr_episodes=25 0.00010573863983154297
# seq length=14 hidden_units=75 nr_episodes=30 -0.0011082887649536133
# seq length=14 hidden_units=75 nr_episodes=35 0.0027571916580200195
# seq length=14 hidden_units=75 nr_episodes=40 -3.337860107421875e-05
# seq length=14 hidden_units=75 nr_episodes=45 -0.015751123428344727
# seq length=14 hidden_units=75 nr_episodes=50 0.0009887218475341797
# seq length=16 hidden_units=5 nr_episodes=0 -0.08726668357849121
# seq length=16 hidden_units=5 nr_episodes=5 -0.011351227760314941
# seq length=16 hidden_units=5 nr_episodes=10 -0.001059889793395996
# seq length=16 hidden_units=5 nr_episodes=15 -0.00011515617370605469
# seq length=16 hidden_units=5 nr_episodes=20 -4.649162292480469e-05
# seq length=16 hidden_units=5 nr_episodes=25 -2.3245811462402344e-05
# seq length=16 hidden_units=5 nr_episodes=30 -3.266334533691406e-05
# seq length=16 hidden_units=5 nr_episodes=35 -3.0517578125e-05
# seq length=16 hidden_units=5 nr_episodes=40 -3.159046173095703e-05
# seq length=16 hidden_units=5 nr_episodes=45 -1.4185905456542969e-05
# seq length=16 hidden_units=5 nr_episodes=50 -5.614757537841797e-05
# seq length=16 hidden_units=15 nr_episodes=0 -0.00034296512603759766
# seq length=16 hidden_units=15 nr_episodes=5 -3.719329833984375e-05
# seq length=16 hidden_units=15 nr_episodes=10 -4.363059997558594e-05
# seq length=16 hidden_units=15 nr_episodes=15 -5.257129669189453e-05
# seq length=16 hidden_units=15 nr_episodes=20 6.16908073425293e-05
# seq length=16 hidden_units=15 nr_episodes=25 -7.081031799316406e-05
# seq length=16 hidden_units=15 nr_episodes=30 -3.4928321838378906e-05
# seq length=16 hidden_units=15 nr_episodes=35 -7.319450378417969e-05
# seq length=16 hidden_units=15 nr_episodes=40 -0.00016427040100097656
# seq length=16 hidden_units=15 nr_episodes=45 -0.0007340908050537109
# seq length=16 hidden_units=15 nr_episodes=50 -0.0011069774627685547
# seq length=16 hidden_units=25 nr_episodes=0 -0.00015985965728759766
# seq length=16 hidden_units=25 nr_episodes=5 -1.0728836059570312e-05
# seq length=16 hidden_units=25 nr_episodes=10 1.1324882507324219e-06
# seq length=16 hidden_units=25 nr_episodes=15 0.00013959407806396484
# seq length=16 hidden_units=25 nr_episodes=20 5.960464477539062e-07
# seq length=16 hidden_units=25 nr_episodes=25 -3.0994415283203125e-05
# seq length=16 hidden_units=25 nr_episodes=30 -7.796287536621094e-05
# seq length=16 hidden_units=25 nr_episodes=35 -7.62939453125e-06
# seq length=16 hidden_units=25 nr_episodes=40 -1.33514404296875e-05
# seq length=16 hidden_units=25 nr_episodes=45 -8.225440979003906e-05
# seq length=16 hidden_units=25 nr_episodes=50 -0.00018107891082763672
# seq length=16 hidden_units=50 nr_episodes=0 -0.0010846853256225586
# seq length=16 hidden_units=50 nr_episodes=5 -1.5616416931152344e-05
# seq length=16 hidden_units=50 nr_episodes=10 -8.344650268554688e-07
# seq length=16 hidden_units=50 nr_episodes=15 -8.821487426757812e-06
# seq length=16 hidden_units=50 nr_episodes=20 0.0030527710914611816
# seq length=16 hidden_units=50 nr_episodes=25 0.008407056331634521
# seq length=16 hidden_units=50 nr_episodes=30 -0.0001817941665649414
# seq length=16 hidden_units=50 nr_episodes=35 -0.00016951560974121094
# seq length=16 hidden_units=50 nr_episodes=40 0.0012886524200439453
# seq length=16 hidden_units=50 nr_episodes=45 -0.0019837617874145508
# seq length=16 hidden_units=50 nr_episodes=50 0.006954014301300049
# seq length=16 hidden_units=75 nr_episodes=0 -0.0011723041534423828
# seq length=16 hidden_units=75 nr_episodes=5 0.005762159824371338
# seq length=16 hidden_units=75 nr_episodes=10 4.392862319946289e-05
# seq length=16 hidden_units=75 nr_episodes=15 -0.0002624988555908203
# seq length=16 hidden_units=75 nr_episodes=20 0.0014559030532836914
# seq length=16 hidden_units=75 nr_episodes=25 -0.0038415193557739258
# seq length=16 hidden_units=75 nr_episodes=30 0.0007483959197998047
# seq length=16 hidden_units=75 nr_episodes=35 -0.0020971298217773438
# seq length=16 hidden_units=75 nr_episodes=40 0.0008164644241333008
# seq length=16 hidden_units=75 nr_episodes=45 0.00042325258255004883
# seq length=16 hidden_units=75 nr_episodes=50 0.0007097125053405762
# LSTM best results achieved with length=12 hidden_units=25 and nr_episodes=40) ==> measure=0.01

# %% [markdown]
# ## Pytorch Multivariate Model Evaluation

# %%
params = best_params["params"]
best_length = params[0]


train=pd.read_csv(f"data/df_gira_agg_2h_wtimevars_final_train.csv", decimal=".",  index_col='date', parse_dates=True,  infer_datetime_format=True)
test=pd.read_csv(f"data/df_gira_agg_2h_wtimevars_final_test.csv", decimal=".",  index_col='date', parse_dates=True,  infer_datetime_format=True)
target='target_station_load_rate'


# Assuming `train` and `test` are your DataFrames and `target` is the target column name
trnY_float = train.pop(target).values.astype(np.float32)
tstY_float = test.pop(target).values.astype(np.float32)
trnX_float = train.values.astype(np.float32)
tstX_float = test.values.astype(np.float32)


trnX, trnY = prepare_dataset_for_lstm_multi(trnX_float, trnY_float, seq_length=best_length)
tstX, tstY  = prepare_dataset_for_lstm_multi(tstX_float, tstY_float, seq_length=best_length)


prd_trn = best_model.predict(trnX)
prd_tst = best_model.predict(tstX)


# Assuming train and test are DataFrames with a DateTime index
# Reconstruct the series for plotting
train[target] = trnY_float
test[target] = tstY_float
trn_series = train[[target]]
tst_series = test[[target]]


# Plot the forecasting evaluation
plot_single_model_evaluation(trn_series[best_length:], tst_series[best_length:], prd_trn, prd_tst, title=f"{file_tag} - LSTM Multivariate (length={best_length}, hidden={params[1]}, epochs={params[2]})")
savefig(f"images/{file_tag}_LSTM_multivariate_predictions.png")

# %% [markdown]
# ## Pytorch Multivariate Plots

# %%
from pandas import Series
pred_series = Series(prd_tst.numpy().ravel(), index=tst_series.index[best_length:])


plot_forecasting_series(
    trn_series[best_length:],
    tst_series[best_length:],
    pred_series,
    title=f"{file_tag} - LSTM Multivariate Predictions (length={best_length}, hidden={params[1]}, epochs={params[2]})",
    xlabel='Date',
    ylabel=target,
)
# Out:
# <Axes: xlabel='Date', ylabel='target_station_load_rate'>

# %% [markdown]
# ## Pytorch Multivariate Model and Loss

# %%
model = DS_LSTM_Multivariate(trnX_float, trnY_float, input_size=trnX_float.shape[1], hidden_size=50, num_layers=1)
loss = model.fit()
print(loss)
# Out:
# tensor(0.1777, grad_fn=<MseLossBackward0>)

# %% [markdown]
# ## Analysis - Results from Model Implementation

# %% [markdown]
# # Install pytorch
# - https://pytorch.org/
#
# 1. Go to anaconda terminal as admin and enter
# ```bash
# conda create --name pytorch_cpu python=3.12
# ```
#
# 2. activate environment
#
# ```bash
# conda activate pytorch_cpu
# ```
#
# 3. install pytorch
# ```bash
#
# # CPU Only Windows and Linux
# conda install pytorch==2.5.0 torchvision==0.20.0 torchaudio==2.5.0 cpuonly -c pytorch
#
# # MAC OSX
# conda install pytorch==2.5.0 torchvision==0.20.0 torchaudio==2.5.0 -c pytorch
#
# ```
#
# 4. install additional packages from dslabs and data functions
# ```bash
# conda install pandas scikit-learn matplotlib statsmodels
# ```
#
# 5. if jupyter has errors run
#
# ```bash
# conda install -n pytorch_cpu ipykernel --update-deps --force-reinstall
# ```

# %% [markdown]
# # DSLabs functions

# %%
# %run "scripts/dslabs_functions.py"

# %% [markdown]
# # Data functions

# %%
# %run "scripts/data_functions.py"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/Mercedes-benz.io/TRAINING/post graduation course IST - Data science/projeto curso/ist_dash_2024_rec/time_series_forecasting/notebooks/dataset_1/scripts/data_functions.py:1371
#    1367     fig.suptitle(title, fontsize=16)
#    1368     plt.show()
# -> 1371 import seaborn as sns
#    1373 def plot_cluster_boxplots(dataframe, features, cluster_labels):
#    1374     """
#    1375     Plots boxplots for the given features in the dataframe, comparing the specified cluster labels.
#    1376
#    (...)   1380     cluster_labels (list): List of cluster labels to compare.
#    1381     """
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import sys
sys.path.append('scripts')

from dslabs_functions import FORECAST_MEASURES, DELTA_IMPROVE, plot_multiline_chart, plot_forecasting_series

# %% [markdown]
# # Load

# %%
# Function to split the series into train and test sets
def series_train_test_split(series, trn_pct=0.90):
    train_size = int(len(series) * trn_pct)
    train, test = series[:train_size], series[train_size:]
    return train, test
from sklearn.base import RegressorMixin

# %%
import pandas as pd
import numpy as np


file_tag = "Gira bike"


# smoothed time series with split. uncomment to use
# train=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_train.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)
# test=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_test.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)


# unsmoothed time series with split to test the model. uncomment to use
test_split_threshold = 0.9
data_no_smoothing=pd.read_csv('data/df_gira_agg_2h_diff_input.csv', decimal=".",  index_col='date', parse_dates=True,  infer_datetime_format=True)     
#data_no_smoothing = data_no_smoothing.loc["2022"]
train, test = series_train_test_split(data_no_smoothing, trn_pct=test_split_threshold)

target='target_station_load_rate'


test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 542 entries, 2023-02-14 16:00:00 to 2023-03-31 22:00:00
# Data columns (total 12 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   temperature_2m                                               542 non-null    float64
#  1   rain_mm                                                      542 non-null    float64
#  2   wmo_weather_code                                             542 non-null    float64
#  3   wind_speed_10m                                               542 non-null    float64
#  4   is_holiday_lisbon                                            542 non-null    float64
#  5   target_station_status                                        542 non-null    float64
#  6   target_station_load_rate                                     542 non-null    float64
#  7   station_load_rate_ Rua do Arco Cego / Av. Magalhães Lima     542 non-null    float64
#  8   station_load_rate_ Av. Rovisco Pais / Av. Manuel da Maia     542 non-null    float64
#  9   station_load_rate_ Praça de Londres                          542 non-null    float64
#  10  station_load_rate_ Av. Duque de Ávila / Jardim Arco Do Cego  542 non-null    float64
#  11  station_load_rate_ Av. Barbosa Du Bocage / Rua Arco do Cego  542 non-null    float64
# dtypes: float64(12)
# memory usage: 55.0 KB

# %%
import pandas as pd
import numpy as np


file_tag = "Google Merch Store 2024-2025"


# smoothed time series with split. uncomment to use
# train=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_train.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)
# test=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_test.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)


# unsmoothed time series with split to test the model. uncomment to use
test_split_threshold = 0.7
data_no_smoothing=pd.read_csv('data/df_merch_0_2024_agg_time_diff_input.csv', decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)     
train, test = series_train_test_split(data_no_smoothing, trn_pct=test_split_threshold)





target='Sessions'


test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 128 entries, 2024-10-29 to 2025-03-05
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Sessions                         128 non-null    float64
#  1   Seven-day active users           128 non-null    float64
#  2   28-day active users              128 non-null    float64
#  3   Events per session               128 non-null    float64
#  4   Add to baskets                   128 non-null    float64
#  5   Checkouts                        128 non-null    float64
#  6   E-commerce purchases             128 non-null    float64
#  7   Average purchase revenue         128 non-null    float64
#  8   Purchase revenue                 128 non-null    float64
#  9   Average session duration         128 non-null    float64
#  10  ARPU                             128 non-null    float64
#  11  ARPPU                            128 non-null    float64
#  12  Views per user                   128 non-null    float64
#  13  Total users                      128 non-null    float64
#  14  Promotion views                  128 non-null    float64
#  15  Promotion clicks                 128 non-null    float64
#  16  Sessions Mobile                  128 non-null    float64
#  17  Seven-day active users Mobile    128 non-null    float64
#  18  28-day active users Mobile       128 non-null    float64
#  19  New users Mobile                 128 non-null    float64
#  20  Scrolled users Mobile            128 non-null    float64
#  21  Engaged sessions Mobile          128 non-null    float64
#  22  Views Mobile                     128 non-null    float64
#  23  Event count Mobile               128 non-null    float64
#  24  Events per session Mobile        128 non-null    float64
#  25  Item-list view events Mobile     128 non-null    float64
#  26  Item view events Mobile          128 non-null    float64
#  27  Add to baskets Mobile            128 non-null    float64
#  28  Checkouts Mobile                 128 non-null    float64
#  29  E-commerce purchases Mobile      128 non-null    float64
#  30  Average purchase revenue Mobile  128 non-null    float64
#  31  Purchase revenue Mobile          128 non-null    float64
#  32  First time purchasers Mobile     128 non-null    float64
#  33  Average session duration Mobile  128 non-null    float64
#  34  Sessions (not set)               128 non-null    float64
#  35  Sessions affiliate               128 non-null    float64
#  36  Sessions cpc                     128 non-null    float64
#  37  Sessions cpm                     128 non-null    float64
#  38  Sessions email                   128 non-null    float64
#  39  Sessions organic                 128 non-null    float64
#  40  Sessions other                   128 non-null    float64
#  41  Sessions referral                128 non-null    float64
#  42  season                           128 non-null    float64
#  43  commercial_season                128 non-null    float64
#  44  is_weekend                       128 non-null    float64
#  45  is_holiday                       128 non-null    float64
# dtypes: float64(46)
# memory usage: 47.0 KB

# %% [markdown]
# # LSTM Pytorch Univariate

# %% [markdown]
# ## Univariate Pytorch Functions and data prep

# %%
from torch import no_grad, tensor
from torch.nn import LSTM, Linear, Module, MSELoss
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset


def prepare_dataset_for_lstm_uni(series, seq_length: int = 4):
    setX: list = []
    setY: list = []
    for i in range(len(series) - seq_length):
        past = series[i : i + seq_length]
        future = series[i + 1 : i + seq_length + 1]
        setX.append(past)
        setY.append(future)
    return tensor(setX), tensor(setY)


class DS_LSTM_Univariate(Module):
    def __init__(self, train, input_size: int = 1, hidden_size: int = 50, num_layers: int = 1, length: int = 4):
        super().__init__()
        self.lstm = LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.linear = Linear(hidden_size, 1)
        self.optimizer = Adam(self.parameters())
        self.loss_fn = MSELoss()

        trnX, trnY = prepare_dataset_for_lstm_uni(train, seq_length=length)
        self.loader = DataLoader(TensorDataset(trnX, trnY), shuffle=True, batch_size=len(train) // 10)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.linear(x)
        return x

    def fit(self):
        self.train()
        for batchX, batchY in self.loader:
            y_pred = self(batchX)
            loss = self.loss_fn(y_pred, batchY)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
        return loss

    def predict(self, X):
        with no_grad():
            y_pred = self(X)
        return y_pred[:, -1, :]

# %%
from dslabs_functions import HEIGHT, plot_multiline_chart
from copy import deepcopy

from matplotlib.pyplot import figure, savefig, subplots
from dslabs_functions import FORECAST_MEASURES, DELTA_IMPROVE, plot_multiline_chart
from sklearn.model_selection import train_test_split

def lstm_study_uni(train, nr_episodes: int = 1000, sequence_size: list = [2, 4, 8], nr_hidden_units: list = [25, 50, 100], measure: str = "R2", val_split: float = 0.2):
    """
    Train, study, and validate an LSTM model using only the training dataset.

    Parameters:
    - train: Training dataset (DataFrame)
    - nr_episodes: Number of training episodes
    - sequence_size: List of sequence lengths to evaluate
    - nr_hidden_units: List of hidden unit sizes to evaluate
    - measure: Evaluation metric (e.g., "R2")
    - val_split: Fraction of the training data to use for validation (default: 20%)

    Returns:
    - best_model: The best LSTM model based on validation performance
    - best_params: Parameters of the best model
    """
    # Split the training data into training and validation subsets
    train_data, val_data = train_test_split(train, test_size=val_split, shuffle=False)

    step: int = nr_episodes // 10
    episodes = [1] + list(range(0, nr_episodes + 1, step))[1:]
    flag = measure == "R2" or measure == "MAPE"
    best_model = None
    best_params: dict = {"name": "LSTM", "metric": measure, "params": ()}
    best_performance: float = -100000

    _, axs = subplots(1, len(sequence_size), figsize=(len(sequence_size) * HEIGHT, HEIGHT))

    for i in range(len(sequence_size)):
        length = sequence_size[i]
        # Prepare datasets for LSTM
        trnX, trnY = prepare_dataset_for_lstm_uni(train_data, seq_length=length)
        valX, valY = prepare_dataset_for_lstm_uni(val_data, seq_length=length)

        values = {}
        for hidden in nr_hidden_units:
            yvalues = []
            model = DS_LSTM_Univariate(train_data, hidden_size=hidden)
            for n in range(0, nr_episodes + 1):
                model.fit()
                if n % step == 0:
                    prd_val = model.predict(valX)
                    # Evaluate on validation predictions
                    eval: float = FORECAST_MEASURES[measure](val_data[length:], prd_val)
                    print(f"seq length={length} hidden_units={hidden} nr_episodes={n}", eval)
                    if eval > best_performance and abs(eval - best_performance) > DELTA_IMPROVE:
                        best_performance: float = eval
                        best_params["params"] = (length, hidden, n)
                        best_model = deepcopy(model)
                    yvalues.append(eval)
            values[hidden] = yvalues
        plot_multiline_chart(
            episodes,
            values,
            ax=axs[i],
            title=f"LSTM seq length={length} ({measure})",
            xlabel="nr episodes",
            ylabel=measure,
            percentage=flag,
        )
    print(
        f"LSTM best results achieved with length={best_params['params'][0]} hidden_units={best_params['params'][1]} and nr_episodes={best_params['params'][2]}) ==> measure={best_performance:.2f}"
    )
    return best_model, best_params

# %% [markdown]
# ## Univariate Pytorch Study

# %%
# # Prepare the training and testing data using the time index as the feature
from numpy import arange


train_series_float = train[[target]].values.astype("float32")
test_series_float = test[[target]].values.astype("float32")


best_model, best_params = lstm_study_uni(train_series_float,
                                        #  test_series_float,
                                         nr_episodes=2000,
                                         sequence_size=[5,7,12,16],
                                         nr_hidden_units=[5,10,15,25,50,75],
                                         measure='R2',
                                         val_split=0.2)
# Out:
# seq length=5 hidden_units=5 nr_episodes=0 -0.017505407333374023
# seq length=5 hidden_units=5 nr_episodes=200 0.23691058158874512
# seq length=5 hidden_units=5 nr_episodes=400 0.25966548919677734
# seq length=5 hidden_units=5 nr_episodes=600 0.2658126950263977
# seq length=5 hidden_units=5 nr_episodes=800 0.2612875699996948
# seq length=5 hidden_units=5 nr_episodes=1000 0.2511502504348755
# seq length=5 hidden_units=5 nr_episodes=1200 0.24552732706069946
# seq length=5 hidden_units=5 nr_episodes=1400 0.24635034799575806
# seq length=5 hidden_units=5 nr_episodes=1600 0.24723201990127563
# seq length=5 hidden_units=5 nr_episodes=1800 0.24291694164276123
# seq length=5 hidden_units=5 nr_episodes=2000 0.2475299835205078
# seq length=5 hidden_units=10 nr_episodes=0 -0.008141160011291504
# seq length=5 hidden_units=10 nr_episodes=200 0.250755250453949
# seq length=5 hidden_units=10 nr_episodes=400 0.24535900354385376
# seq length=5 hidden_units=10 nr_episodes=600 0.2422318458557129
# seq length=5 hidden_units=10 nr_episodes=800 0.23633253574371338
# seq length=5 hidden_units=10 nr_episodes=1000 0.23308056592941284
# seq length=5 hidden_units=10 nr_episodes=1200 0.23005527257919312
# seq length=5 hidden_units=10 nr_episodes=1400 0.23135250806808472
# seq length=5 hidden_units=10 nr_episodes=1600 0.23378092050552368
# seq length=5 hidden_units=10 nr_episodes=1800 0.23191410303115845
# seq length=5 hidden_units=10 nr_episodes=2000 0.22557544708251953
# seq length=5 hidden_units=15 nr_episodes=0 0.0028028488159179688
# seq length=5 hidden_units=15 nr_episodes=200 0.2617719769477844
# seq length=5 hidden_units=15 nr_episodes=400 0.26087260246276855
# seq length=5 hidden_units=15 nr_episodes=600 0.2198479175567627
# seq length=5 hidden_units=15 nr_episodes=800 0.19575268030166626
# seq length=5 hidden_units=15 nr_episodes=1000 0.17734414339065552
# seq length=5 hidden_units=15 nr_episodes=1200 0.1701943278312683
# seq length=5 hidden_units=15 nr_episodes=1400 0.15802788734436035
# seq length=5 hidden_units=15 nr_episodes=1600 0.14920753240585327
# seq length=5 hidden_units=15 nr_episodes=1800 0.12679517269134521
# seq length=5 hidden_units=15 nr_episodes=2000 0.09809696674346924
# seq length=5 hidden_units=25 nr_episodes=0 0.0019114017486572266
# seq length=5 hidden_units=25 nr_episodes=200 0.25956618785858154
# seq length=5 hidden_units=25 nr_episodes=400 0.2659742832183838
# seq length=5 hidden_units=25 nr_episodes=600 0.2136051058769226
# seq length=5 hidden_units=25 nr_episodes=800 0.15367519855499268
# seq length=5 hidden_units=25 nr_episodes=1000 0.10187268257141113
# seq length=5 hidden_units=25 nr_episodes=1200 0.040922701358795166
# seq length=5 hidden_units=25 nr_episodes=1400 -0.03419601917266846
# seq length=5 hidden_units=25 nr_episodes=1600 -0.1294412612915039
# seq length=5 hidden_units=25 nr_episodes=1800 -0.22200119495391846
# seq length=5 hidden_units=25 nr_episodes=2000 -0.30984222888946533
# seq length=5 hidden_units=50 nr_episodes=0 0.008360505104064941
# seq length=5 hidden_units=50 nr_episodes=200 0.2505142092704773
# seq length=5 hidden_units=50 nr_episodes=400 0.21496814489364624
# seq length=5 hidden_units=50 nr_episodes=600 0.052751898765563965
# seq length=5 hidden_units=50 nr_episodes=800 -0.09224247932434082
# seq length=5 hidden_units=50 nr_episodes=1000 -0.18653714656829834
# seq length=5 hidden_units=50 nr_episodes=1200 -0.3702981472015381
# seq length=5 hidden_units=50 nr_episodes=1400 -0.6359531879425049
# seq length=5 hidden_units=50 nr_episodes=1600 -0.973381757736206
# seq length=5 hidden_units=50 nr_episodes=1800 -1.2961533069610596
# seq length=5 hidden_units=50 nr_episodes=2000 -1.6553776264190674
# seq length=5 hidden_units=75 nr_episodes=0 0.009350359439849854
# seq length=5 hidden_units=75 nr_episodes=200 0.2560473680496216
# seq length=5 hidden_units=75 nr_episodes=400 0.08873957395553589
# seq length=5 hidden_units=75 nr_episodes=600 -0.03859424591064453
# seq length=5 hidden_units=75 nr_episodes=800 -0.17791271209716797
# seq length=5 hidden_units=75 nr_episodes=1000 -0.3955717086791992
# seq length=5 hidden_units=75 nr_episodes=1200 -0.5802038908004761
# seq length=5 hidden_units=75 nr_episodes=1400 -0.7496985197067261
# seq length=5 hidden_units=75 nr_episodes=1600 -0.9495751857757568
# seq length=5 hidden_units=75 nr_episodes=1800 -1.213165283203125
# seq length=5 hidden_units=75 nr_episodes=2000 -1.4402129650115967
# seq length=7 hidden_units=5 nr_episodes=0 -0.032894134521484375
# seq length=7 hidden_units=5 nr_episodes=200 0.21883004903793335
# seq length=7 hidden_units=5 nr_episodes=400 0.21677440404891968
# seq length=7 hidden_units=5 nr_episodes=600 0.24071860313415527
# seq length=7 hidden_units=5 nr_episodes=800 0.2404889464378357
# seq length=7 hidden_units=5 nr_episodes=1000 0.2356380820274353
# seq length=7 hidden_units=5 nr_episodes=1200 0.22792404890060425
# seq length=7 hidden_units=5 nr_episodes=1400 0.2220941185951233
# seq length=7 hidden_units=5 nr_episodes=1600 0.21799325942993164
# seq length=7 hidden_units=5 nr_episodes=1800 0.2164861559867859
# seq length=7 hidden_units=5 nr_episodes=2000 0.21513402462005615
# seq length=7 hidden_units=10 nr_episodes=0 -0.02635800838470459
# seq length=7 hidden_units=10 nr_episodes=200 0.23436307907104492
# seq length=7 hidden_units=10 nr_episodes=400 0.17743778228759766
# seq length=7 hidden_units=10 nr_episodes=600 0.1645844578742981
# seq length=7 hidden_units=10 nr_episodes=800 0.16254889965057373
# seq length=7 hidden_units=10 nr_episodes=1000 0.16197079420089722
# seq length=7 hidden_units=10 nr_episodes=1200 0.1411529779434204
# seq length=7 hidden_units=10 nr_episodes=1400 0.10823690891265869
# seq length=7 hidden_units=10 nr_episodes=1600 0.0566135048866272
# seq length=7 hidden_units=10 nr_episodes=1800 0.020120739936828613
# seq length=7 hidden_units=10 nr_episodes=2000 -0.0119858980178833
# seq length=7 hidden_units=15 nr_episodes=0 -0.10274994373321533
# seq length=7 hidden_units=15 nr_episodes=200 0.2334965467453003
# seq length=7 hidden_units=15 nr_episodes=400 0.2041366696357727
# seq length=7 hidden_units=15 nr_episodes=600 0.20505517721176147
# seq length=7 hidden_units=15 nr_episodes=800 0.20317530632019043
# seq length=7 hidden_units=15 nr_episodes=1000 0.18138158321380615
# seq length=7 hidden_units=15 nr_episodes=1200 0.13693243265151978
# seq length=7 hidden_units=15 nr_episodes=1400 0.08386027812957764
# seq length=7 hidden_units=15 nr_episodes=1600 0.028261959552764893
# seq length=7 hidden_units=15 nr_episodes=1800 -0.029660463333129883
# seq length=7 hidden_units=15 nr_episodes=2000 -0.08891618251800537
# seq length=7 hidden_units=25 nr_episodes=0 0.0006380677223205566
# seq length=7 hidden_units=25 nr_episodes=200 0.1178290843963623
# seq length=7 hidden_units=25 nr_episodes=400 -0.11249756813049316
# seq length=7 hidden_units=25 nr_episodes=600 -0.29761219024658203
# seq length=7 hidden_units=25 nr_episodes=800 -0.2728450298309326
# seq length=7 hidden_units=25 nr_episodes=1000 -0.26932811737060547
# seq length=7 hidden_units=25 nr_episodes=1200 -0.3454023599624634
# seq length=7 hidden_units=25 nr_episodes=1400 -0.4121512174606323
# seq length=7 hidden_units=25 nr_episodes=1600 -0.44405972957611084
# seq length=7 hidden_units=25 nr_episodes=1800 -0.43067336082458496
# seq length=7 hidden_units=25 nr_episodes=2000 -0.46293962001800537
# seq length=7 hidden_units=50 nr_episodes=0 0.003567636013031006
# seq length=7 hidden_units=50 nr_episodes=200 0.19577795267105103
# seq length=7 hidden_units=50 nr_episodes=400 0.053605616092681885
# seq length=7 hidden_units=50 nr_episodes=600 -0.0672605037689209
# seq length=7 hidden_units=50 nr_episodes=800 -0.09947359561920166
# seq length=7 hidden_units=50 nr_episodes=1000 -0.2629743814468384
# seq length=7 hidden_units=50 nr_episodes=1200 -0.4625842571258545
# seq length=7 hidden_units=50 nr_episodes=1400 -0.7439045906066895
# seq length=7 hidden_units=50 nr_episodes=1600 -1.0056817531585693
# seq length=7 hidden_units=50 nr_episodes=1800 -1.3211710453033447
# seq length=7 hidden_units=50 nr_episodes=2000 -1.5929396152496338
# seq length=7 hidden_units=75 nr_episodes=0 0.007475614547729492
# seq length=7 hidden_units=75 nr_episodes=200 0.2351256012916565
# seq length=7 hidden_units=75 nr_episodes=400 0.038862645626068115
# seq length=7 hidden_units=75 nr_episodes=600 -0.10546445846557617
# seq length=7 hidden_units=75 nr_episodes=800 -0.32553231716156006
# seq length=7 hidden_units=75 nr_episodes=1000 -0.6105028390884399
# seq length=7 hidden_units=75 nr_episodes=1200 -1.0094707012176514
# seq length=7 hidden_units=75 nr_episodes=1400 -1.5016155242919922
# seq length=7 hidden_units=75 nr_episodes=1600 -1.9042670726776123
# seq length=7 hidden_units=75 nr_episodes=1800 -2.2000248432159424
# seq length=7 hidden_units=75 nr_episodes=2000 -2.418342351913452
# seq length=12 hidden_units=5 nr_episodes=0 -0.09790682792663574
# seq length=12 hidden_units=5 nr_episodes=200 0.10602563619613647
# seq length=12 hidden_units=5 nr_episodes=400 0.1945623755455017
# seq length=12 hidden_units=5 nr_episodes=600 0.1796550750732422
# seq length=12 hidden_units=5 nr_episodes=800 0.16244864463806152
# seq length=12 hidden_units=5 nr_episodes=1000 0.14206570386886597
# seq length=12 hidden_units=5 nr_episodes=1200 0.11716902256011963
# seq length=12 hidden_units=5 nr_episodes=1400 0.09516853094100952
# seq length=12 hidden_units=5 nr_episodes=1600 0.07291746139526367
# seq length=12 hidden_units=5 nr_episodes=1800 0.05031406879425049
# seq length=12 hidden_units=5 nr_episodes=2000 0.02078378200531006
# seq length=12 hidden_units=10 nr_episodes=0 0.0001309514045715332
# seq length=12 hidden_units=10 nr_episodes=200 0.2307688593864441
# seq length=12 hidden_units=10 nr_episodes=400 0.2058599591255188
# seq length=12 hidden_units=10 nr_episodes=600 0.1845386028289795
# seq length=12 hidden_units=10 nr_episodes=800 0.1491795778274536
# seq length=12 hidden_units=10 nr_episodes=1000 0.09919607639312744
# seq length=12 hidden_units=10 nr_episodes=1200 0.05219733715057373
# seq length=12 hidden_units=10 nr_episodes=1400 -0.003726363182067871
# seq length=12 hidden_units=10 nr_episodes=1600 -0.047324419021606445
# seq length=12 hidden_units=10 nr_episodes=1800 -0.07850325107574463
# seq length=12 hidden_units=10 nr_episodes=2000 -0.08935177326202393
# seq length=12 hidden_units=15 nr_episodes=0 0.0020113587379455566
# seq length=12 hidden_units=15 nr_episodes=200 0.1407223343849182
# seq length=12 hidden_units=15 nr_episodes=400 0.16547787189483643
# seq length=12 hidden_units=15 nr_episodes=600 0.06339102983474731
# seq length=12 hidden_units=15 nr_episodes=800 0.05415511131286621
# seq length=12 hidden_units=15 nr_episodes=1000 0.0060204267501831055
# seq length=12 hidden_units=15 nr_episodes=1200 -0.020572423934936523
# seq length=12 hidden_units=15 nr_episodes=1400 -0.015023112297058105
# seq length=12 hidden_units=15 nr_episodes=1600 0.006201446056365967
# seq length=12 hidden_units=15 nr_episodes=1800 0.020390689373016357
# seq length=12 hidden_units=15 nr_episodes=2000 0.027580440044403076
# seq length=12 hidden_units=25 nr_episodes=0 0.0017691254615783691
# seq length=12 hidden_units=25 nr_episodes=200 0.031092822551727295
# seq length=12 hidden_units=25 nr_episodes=400 -0.00422978401184082
# seq length=12 hidden_units=25 nr_episodes=600 -0.030791521072387695
# seq length=12 hidden_units=25 nr_episodes=800 -0.20294058322906494
# seq length=12 hidden_units=25 nr_episodes=1000 -0.35587263107299805
# seq length=12 hidden_units=25 nr_episodes=1200 -0.578116774559021
# seq length=12 hidden_units=25 nr_episodes=1400 -0.8406792879104614
# seq length=12 hidden_units=25 nr_episodes=1600 -1.0759930610656738
# seq length=12 hidden_units=25 nr_episodes=1800 -1.2748780250549316
# seq length=12 hidden_units=25 nr_episodes=2000 -1.5025384426116943
# seq length=12 hidden_units=50 nr_episodes=0 0.007474422454833984
# seq length=12 hidden_units=50 nr_episodes=200 -0.26674437522888184
# seq length=12 hidden_units=50 nr_episodes=400 -0.01396024227142334
# seq length=12 hidden_units=50 nr_episodes=600 -0.3562047481536865
# seq length=12 hidden_units=50 nr_episodes=800 -0.6325751543045044
# seq length=12 hidden_units=50 nr_episodes=1000 -0.9002001285552979
# seq length=12 hidden_units=50 nr_episodes=1200 -1.0514321327209473
# seq length=12 hidden_units=50 nr_episodes=1400 -1.1597046852111816
# seq length=12 hidden_units=50 nr_episodes=1600 -1.3403964042663574
# seq length=12 hidden_units=50 nr_episodes=1800 -1.6443939208984375
# seq length=12 hidden_units=50 nr_episodes=2000 -1.7789409160614014
# seq length=12 hidden_units=75 nr_episodes=0 0.004174470901489258
# seq length=12 hidden_units=75 nr_episodes=200 0.12631666660308838
# seq length=12 hidden_units=75 nr_episodes=400 -0.15143823623657227
# seq length=12 hidden_units=75 nr_episodes=600 -0.3803364038467407
# seq length=12 hidden_units=75 nr_episodes=800 -0.6952059268951416
# seq length=12 hidden_units=75 nr_episodes=1000 -1.0863761901855469
# seq length=12 hidden_units=75 nr_episodes=1200 -1.520444631576538
# seq length=12 hidden_units=75 nr_episodes=1400 -2.2148873805999756
# seq length=12 hidden_units=75 nr_episodes=1600 -2.7776267528533936
# seq length=12 hidden_units=75 nr_episodes=1800 -3.01176118850708
# seq length=12 hidden_units=75 nr_episodes=2000 -3.2650957107543945
# seq length=16 hidden_units=5 nr_episodes=0 -0.15569233894348145
# seq length=16 hidden_units=5 nr_episodes=200 -0.06860411167144775
# seq length=16 hidden_units=5 nr_episodes=400 0.10370498895645142
# seq length=16 hidden_units=5 nr_episodes=600 0.12135672569274902
# seq length=16 hidden_units=5 nr_episodes=800 0.047707438468933105
# seq length=16 hidden_units=5 nr_episodes=1000 0.02917855978012085
# seq length=16 hidden_units=5 nr_episodes=1200 0.07236737012863159
# seq length=16 hidden_units=5 nr_episodes=1400 0.1300649642944336
# seq length=16 hidden_units=5 nr_episodes=1600 0.1713314652442932
# seq length=16 hidden_units=5 nr_episodes=1800 0.18467164039611816
# seq length=16 hidden_units=5 nr_episodes=2000 0.1879914402961731
# seq length=16 hidden_units=10 nr_episodes=0 -0.0654144287109375
# seq length=16 hidden_units=10 nr_episodes=200 0.18726563453674316
# seq length=16 hidden_units=10 nr_episodes=400 0.16414028406143188
# seq length=16 hidden_units=10 nr_episodes=600 0.16151249408721924
# seq length=16 hidden_units=10 nr_episodes=800 0.11239320039749146
# seq length=16 hidden_units=10 nr_episodes=1000 0.017388761043548584
# seq length=16 hidden_units=10 nr_episodes=1200 -0.02689683437347412
# seq length=16 hidden_units=10 nr_episodes=1400 -0.07975280284881592
# seq length=16 hidden_units=10 nr_episodes=1600 -0.13870656490325928
# seq length=16 hidden_units=10 nr_episodes=1800 -0.15122544765472412
# seq length=16 hidden_units=10 nr_episodes=2000 -0.1718817949295044
# seq length=16 hidden_units=15 nr_episodes=0 -0.012462019920349121
# seq length=16 hidden_units=15 nr_episodes=200 0.012204766273498535
# seq length=16 hidden_units=15 nr_episodes=400 0.1138770580291748
# seq length=16 hidden_units=15 nr_episodes=600 -0.07094788551330566
# seq length=16 hidden_units=15 nr_episodes=800 -0.16560864448547363
# seq length=16 hidden_units=15 nr_episodes=1000 -0.2236722707748413
# seq length=16 hidden_units=15 nr_episodes=1200 -0.19241511821746826
# seq length=16 hidden_units=15 nr_episodes=1400 -0.14158189296722412
# seq length=16 hidden_units=15 nr_episodes=1600 -0.10153710842132568
# seq length=16 hidden_units=15 nr_episodes=1800 -0.1141195297241211
# seq length=16 hidden_units=15 nr_episodes=2000 -0.13840198516845703
# seq length=16 hidden_units=25 nr_episodes=0 -0.007417798042297363
# seq length=16 hidden_units=25 nr_episodes=200 0.23152178525924683
# seq length=16 hidden_units=25 nr_episodes=400 0.11455690860748291
# seq length=16 hidden_units=25 nr_episodes=600 0.04270559549331665
# seq length=16 hidden_units=25 nr_episodes=800 -0.09689199924468994
# seq length=16 hidden_units=25 nr_episodes=1000 -0.20900213718414307
# seq length=16 hidden_units=25 nr_episodes=1200 -0.26264238357543945
# seq length=16 hidden_units=25 nr_episodes=1400 -0.1879633665084839
# seq length=16 hidden_units=25 nr_episodes=1600 -0.19293642044067383
# seq length=16 hidden_units=25 nr_episodes=1800 -0.19479775428771973
# seq length=16 hidden_units=25 nr_episodes=2000 -0.23172295093536377
# seq length=16 hidden_units=50 nr_episodes=0 0.009169042110443115
# seq length=16 hidden_units=50 nr_episodes=200 0.22959297895431519
# seq length=16 hidden_units=50 nr_episodes=400 0.16278409957885742
# seq length=16 hidden_units=50 nr_episodes=600 0.021539032459259033
# seq length=16 hidden_units=50 nr_episodes=800 -0.20604383945465088
# seq length=16 hidden_units=50 nr_episodes=1000 -0.47149741649627686
# seq length=16 hidden_units=50 nr_episodes=1200 -0.7579960823059082
# seq length=16 hidden_units=50 nr_episodes=1400 -0.9795244932174683
# seq length=16 hidden_units=50 nr_episodes=1600 -1.2815418243408203
# seq length=16 hidden_units=50 nr_episodes=1800 -1.5154707431793213
# seq length=16 hidden_units=50 nr_episodes=2000 -1.7348482608795166
# seq length=16 hidden_units=75 nr_episodes=0 0.011747181415557861
# seq length=16 hidden_units=75 nr_episodes=200 0.09748268127441406
# seq length=16 hidden_units=75 nr_episodes=400 -0.15529406070709229
# seq length=16 hidden_units=75 nr_episodes=600 -0.23146188259124756
# seq length=16 hidden_units=75 nr_episodes=800 -0.5045536756515503
# seq length=16 hidden_units=75 nr_episodes=1000 -0.7595592737197876
# seq length=16 hidden_units=75 nr_episodes=1200 -0.9288372993469238
# seq length=16 hidden_units=75 nr_episodes=1400 -1.284456491470337
# seq length=16 hidden_units=75 nr_episodes=1600 -1.7779004573822021
# seq length=16 hidden_units=75 nr_episodes=1800 -2.3509700298309326
# seq length=16 hidden_units=75 nr_episodes=2000 -2.7861127853393555
# LSTM best results achieved with length=5 hidden_units=5 and nr_episodes=600) ==> measure=0.27

# %% [markdown]
# ## Univariate Pytorch eval

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from dslabs_functions import plot_multibar_chart


def plot_single_model_evaluation(train: Series, test: Series, prd_train: Series, prd_test: Series, title: str = ""):
    # Drop NaN values from the input series
    # train = train.dropna()
    # test = test.dropna()
    # prd_train = prd_train.dropna()
    # prd_test = prd_test.dropna()      
    
    # Calculate performance metrics
    metrics = {
        "MAE": [
            mean_absolute_error(train, prd_train),
            mean_absolute_error(test, prd_test),
        ],
        "MSE": [
            mean_squared_error(train, prd_train),
            mean_squared_error(test, prd_test),
        ],
        "RMSE": [
            np.sqrt(mean_squared_error(train, prd_train)),
            np.sqrt(mean_squared_error(test, prd_test)),
        ],
        "R²": [
            r2_score(train, prd_train),
            r2_score(test, prd_test),
        ]
    }

    # Create a DataFrame from the metrics dictionary
    performance_df = pd.DataFrame(metrics, index=["Train", "Test"]).T
    
    # Create subplots
    fig, axs = plt.subplots(1, 2, figsize=(14, 6))
    fig.suptitle(title, fontsize=16)
    
    # Plot scale-dependent errors
    scale_dependent_errors = ["MAE", "MSE", "RMSE"]
    scale_dependent_data = performance_df.loc[scale_dependent_errors]
    ax = axs[0]
    ax.set_title("Scale-dependent errors")
    ax.set_xlabel("Metrics")
    ax.set_ylabel("Values")
    bar_width = 0.2  # Adjusted bar width for more spacing
    index = np.arange(len(scale_dependent_data.columns))
    for i, metric in enumerate(scale_dependent_data.index):
        bars = ax.bar(index + i * bar_width * 1.5, scale_dependent_data.loc[metric], bar_width, label=metric)
        ax.bar_label(bars, fmt='%.2f')
    ax.set_xticks(index + bar_width)
    ax.set_xticklabels(scale_dependent_data.columns)
    ax.legend()
    
    # Plot percentage errors
    percentage_errors = ["R²"]
    percentage_data = performance_df.loc[percentage_errors]
    ax = axs[1]
    ax.set_title("Percentage errors")
    ax.set_xlabel("Metrics")
    ax.set_ylabel("Values")
    bar_width = 0.35
    index = np.arange(len(percentage_data.columns))
    for i, metric in enumerate(percentage_data.index):
        bars = ax.bar(index + i * bar_width, percentage_data.loc[metric], bar_width, label=metric)
        ax.bar_label(bars, fmt='%.2f')
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(percentage_data.columns)
    ax.legend()
    
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# %%
params = best_params["params"]
best_length = params[0]


# Assuming train and test are DataFrames with a DateTime index
trn_series = train[[target]]
tst_series = test[[target]]


trnX, trnY = prepare_dataset_for_lstm_uni(trn_series.values.astype("float32"), seq_length=best_length)
tstX, tstY  = prepare_dataset_for_lstm_uni(tst_series.values.astype("float32"), seq_length=best_length)


prd_trn = best_model.predict(trnX)
prd_tst = best_model.predict(tstX)

# Plot the forecasting evaluation
plot_single_model_evaluation(trn_series[best_length:], tst_series[best_length:], prd_trn, prd_tst, title=f"{file_tag} - LSTM Univariate (length={best_length}, hidden={params[1]}, epochs={params[2]})")

# %% [markdown]
# ## Plot lstm tensorflow model univariate

# %%
from pandas import Series
pred_series = Series(prd_tst.numpy().ravel(), index=tst_series.index[best_length:])


plot_forecasting_series(
    trn_series[best_length:],
    tst_series[best_length:],
    pred_series,
    title=f"{file_tag} - LSTM Univariate Predictions (length={best_length}, hidden={params[1]}, epochs={params[2]})",
    xlabel='Date',
    ylabel=target,
)
# Out:
# <Axes: xlabel='Date', ylabel='target_station_load_rate'>

# %% [markdown]
# ## Pytorch Univariate Model and Loss

# %%
model = DS_LSTM_Univariate(train_series_float, input_size=train_series_float.shape[1], hidden_size=50, num_layers=1)
loss = model.fit()
print(loss)
# Out:
# tensor(0.9404, grad_fn=<MseLossBackward0>)

# %% [markdown]
# # LSTM Pytorch Multivariate

# %% [markdown]
# ## Pytorch Multivariate Functions

# %%
from torch import no_grad, tensor
from torch.nn import LSTM, Linear, Module, MSELoss
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

def prepare_dataset_for_lstm_multi(features, target, seq_length: int = 4):
    setX: list = []
    setY: list = []
    for i in range(len(target) - seq_length):
        past = features[i : i + seq_length]
        future = target[i + seq_length]  # Predict the next value only
        setX.append(past)
        setY.append(future)
    setX = tensor(np.array(setX, dtype=np.float32))  # Convert to torch.float32
    setY = tensor(np.array(setY, dtype=np.float32)).view(-1, 1)  # Convert to torch.float32 and reshape
    return setX, setY


class DS_LSTM_Multivariate(Module):
    def __init__(self, trainX, trainY, input_size: int, hidden_size: int = 50, num_layers: int = 1, length: int = 4):
        super().__init__()
        self.lstm = LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.linear = Linear(hidden_size, 1)
        self.optimizer = Adam(self.parameters())
        self.loss_fn = MSELoss()

        trnX, trnY = prepare_dataset_for_lstm_multi(trainX, trainY, seq_length=length)
        self.loader = DataLoader(TensorDataset(trnX, trnY), shuffle=True, batch_size=len(trainX) // 10)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.linear(x[:, -1, :])  # Use the last output of the LSTM
        return x

    def fit(self):
        self.train()
        for batchX, batchY in self.loader:
            y_pred = self(batchX)
            loss = self.loss_fn(y_pred, batchY)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
        return loss

    def predict(self, X):
        with no_grad():
            y_pred = self(X)
        return y_pred

from dslabs_functions import HEIGHT, plot_multiline_chart
from copy import deepcopy
from matplotlib.pyplot import figure, savefig, subplots
from dslabs_functions import FORECAST_MEASURES, DELTA_IMPROVE, plot_multiline_chart
from sklearn.model_selection import train_test_split

def lstm_study_multi(trainX, trainY, testX, testY, nr_episodes: int = 1000, sequence_size: list = [2, 4, 8], nr_hidden_units: list = [25, 50, 100], measure: str = "R2", val_split: float = 0.2):
    """
    Train, study, and validate a multivariate LSTM model using only the training dataset.

    Parameters:
    - trainX: Features of the training dataset
    - trainY: Target of the training dataset
    - testX: Features of the test dataset (not used during training)
    - testY: Target of the test dataset (not used during training)
    - nr_episodes: Number of training episodes
    - sequence_size: List of sequence lengths to evaluate
    - nr_hidden_units: List of hidden unit sizes to evaluate
    - measure: Evaluation metric (e.g., "R2")
    - val_split: Fraction of the training data to use for validation (default: 20%)

    Returns:
    - best_model: The best LSTM model based on validation performance
    - best_params: Parameters of the best model
    """
    # Split the training data into training and validation subsets
    trainX_split, valX_split, trainY_split, valY_split = train_test_split(trainX, trainY, test_size=val_split, shuffle=False)

    step: int = nr_episodes // 10
    episodes = [1] + list(range(0, nr_episodes + 1, step))[1:]
    flag = measure == "R2" or measure == "MAPE"
    best_model = None
    best_params: dict = {"name": "LSTM", "metric": measure, "params": ()}
    best_performance: float = -100000

    _, axs = subplots(1, len(sequence_size), figsize=(len(sequence_size) * HEIGHT, HEIGHT))

    for i in range(len(sequence_size)):
        length = sequence_size[i]
        # Prepare datasets for LSTM
        trnX, trnY = prepare_dataset_for_lstm_multi(trainX_split, trainY_split, seq_length=length)
        valX, valY = prepare_dataset_for_lstm_multi(valX_split, valY_split, seq_length=length)

        values = {}
        for hidden in nr_hidden_units:
            yvalues = []
            model = DS_LSTM_Multivariate(trainX_split, trainY_split, input_size=trainX.shape[1], hidden_size=hidden, length=length)
            for n in range(0, nr_episodes + 1):
                model.fit()
                if n % step == 0:
                    prd_val = model.predict(valX)
                    # Align lengths of valY and prd_val
                    eval: float = FORECAST_MEASURES[measure](valY[length:], prd_val[:len(valY[length:])])
                    print(f"seq length={length} hidden_units={hidden} nr_episodes={n}", eval)
                    if eval > best_performance and abs(eval - best_performance) > DELTA_IMPROVE:
                        best_performance: float = eval
                        best_params["params"] = (length, hidden, n)
                        best_model = deepcopy(model)
                    yvalues.append(eval)
            values[hidden] = yvalues
        plot_multiline_chart(
            episodes,
            values,
            ax=axs[i],
            title=f"LSTM seq length={length} ({measure})",
            xlabel="nr episodes",
            ylabel=measure,
            percentage=flag,
        )
    print(
        f"LSTM best results achieved with length={best_params['params'][0]} hidden_units={best_params['params'][1]} and nr_episodes={best_params['params'][2]}) ==> measure={best_performance:.2f}"
    )
    return best_model, best_params

# %% [markdown]
# ## Pytorch Multivariate Data Study

# %%
# smoothed time series with split. uncomment to use
# train=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_train.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)
# test=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_test.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)


# unsmoothed time series with split to test the model. uncomment to use
test_split_threshold = 0.9
data_no_smoothing=pd.read_csv('data/df_gira_agg_2h_diff_input.csv', decimal=".",  index_col='date', parse_dates=True,  infer_datetime_format=True)     
train, test = series_train_test_split(data_no_smoothing, trn_pct=test_split_threshold)







# Example usage
# Assuming `train` and `test` are your DataFrames and `target` is the target column name
trnY_float = train.pop(target).values.astype(np.float32)
tstY_float = test.pop(target).values.astype(np.float32)
trnX_float = train.values.astype(np.float32)
tstX_float = test.values.astype(np.float32)

# Run the study
best_model, best_params = lstm_study_multi(trnX_float,
                                            trnY_float,
                                            tstX_float,
                                            tstY_float,
                                            nr_episodes=50,
                                            sequence_size=[5,7,12,16],
                                            nr_hidden_units=[5,10,15,25,50],
                                            measure='R2',
                                            val_split=0.2)
# Out:
# seq length=5 hidden_units=5 nr_episodes=0 -0.11658034692759367
# seq length=5 hidden_units=5 nr_episodes=5 -0.025084555653696272
# seq length=5 hidden_units=5 nr_episodes=10 -0.012459437036689947
# seq length=5 hidden_units=5 nr_episodes=15 -0.010702292931757507
# seq length=5 hidden_units=5 nr_episodes=20 -0.011029368972749864
# seq length=5 hidden_units=5 nr_episodes=25 -0.016293199250444923
# seq length=5 hidden_units=5 nr_episodes=30 -0.03442720433725732
# seq length=5 hidden_units=5 nr_episodes=35 -0.06820338647210145
# seq length=5 hidden_units=5 nr_episodes=40 -0.09273587411962048
# seq length=5 hidden_units=5 nr_episodes=45 -0.10526556719478197
# seq length=5 hidden_units=5 nr_episodes=50 -0.11383066307894785
# seq length=5 hidden_units=10 nr_episodes=0 0.003088264584764744
# seq length=5 hidden_units=10 nr_episodes=5 -0.0005357719135312689
# seq length=5 hidden_units=10 nr_episodes=10 -0.01868376278720074
# seq length=5 hidden_units=10 nr_episodes=15 -0.06783870032465766
# seq length=5 hidden_units=10 nr_episodes=20 -0.10740500513315032
# seq length=5 hidden_units=10 nr_episodes=25 -0.1321114251226081
# seq length=5 hidden_units=10 nr_episodes=30 -0.13699245254710957
# seq length=5 hidden_units=10 nr_episodes=35 -0.14794120536684963
# seq length=5 hidden_units=10 nr_episodes=40 -0.1564358520414577
# seq length=5 hidden_units=10 nr_episodes=45 -0.1578799846705159
# seq length=5 hidden_units=10 nr_episodes=50 -0.1634051188362664
# seq length=5 hidden_units=15 nr_episodes=0 0.006739340261964988
# seq length=5 hidden_units=15 nr_episodes=5 0.011439279368229971
# seq length=5 hidden_units=15 nr_episodes=10 -0.01705810950993958
# seq length=5 hidden_units=15 nr_episodes=15 -0.09023987037860426
# seq length=5 hidden_units=15 nr_episodes=20 -0.11729896690804198
# seq length=5 hidden_units=15 nr_episodes=25 -0.1272467790273455
# seq length=5 hidden_units=15 nr_episodes=30 -0.1413065643556748
# seq length=5 hidden_units=15 nr_episodes=35 -0.15699127161086768
# seq length=5 hidden_units=15 nr_episodes=40 -0.1773290932171112
# seq length=5 hidden_units=15 nr_episodes=45 -0.18059601274956072
# seq length=5 hidden_units=15 nr_episodes=50 -0.19563534266438687
# seq length=5 hidden_units=25 nr_episodes=0 -0.024499856613541926
# seq length=5 hidden_units=25 nr_episodes=5 -0.0014198491900558885
# seq length=5 hidden_units=25 nr_episodes=10 -0.06858227395498706
# seq length=5 hidden_units=25 nr_episodes=15 -0.10377064115381174
# seq length=5 hidden_units=25 nr_episodes=20 -0.11894581847930263
# seq length=5 hidden_units=25 nr_episodes=25 -0.13048570387768188
# seq length=5 hidden_units=25 nr_episodes=30 -0.14100243547479052
# seq length=5 hidden_units=25 nr_episodes=35 -0.16138484941171471
# seq length=5 hidden_units=25 nr_episodes=40 -0.18358744715590825
# seq length=5 hidden_units=25 nr_episodes=45 -0.18197376770000684
# seq length=5 hidden_units=25 nr_episodes=50 -0.19841811695419365
# seq length=5 hidden_units=50 nr_episodes=0 0.006275667749513603
# seq length=5 hidden_units=50 nr_episodes=5 -0.052413091551071433
# seq length=5 hidden_units=50 nr_episodes=10 -0.07935172744630581
# seq length=5 hidden_units=50 nr_episodes=15 -0.0992889297650772
# seq length=5 hidden_units=50 nr_episodes=20 -0.10853912865623738
# seq length=5 hidden_units=50 nr_episodes=25 -0.13190035958054924
# seq length=5 hidden_units=50 nr_episodes=30 -0.1349016948303734
# seq length=5 hidden_units=50 nr_episodes=35 -0.16664665342147233
# seq length=5 hidden_units=50 nr_episodes=40 -0.1743298409475713
# seq length=5 hidden_units=50 nr_episodes=45 -0.1872840048067239
# seq length=5 hidden_units=50 nr_episodes=50 -0.21390058311410098
# seq length=7 hidden_units=5 nr_episodes=0 -0.10272933612212332
# seq length=7 hidden_units=5 nr_episodes=5 -0.026700196570093926
# seq length=7 hidden_units=5 nr_episodes=10 -0.02216441065457264
# seq length=7 hidden_units=5 nr_episodes=15 -0.029202757239711996
# seq length=7 hidden_units=5 nr_episodes=20 -0.03978339651665186
# seq length=7 hidden_units=5 nr_episodes=25 -0.05513748725507517
# seq length=7 hidden_units=5 nr_episodes=30 -0.07749754917619112
# seq length=7 hidden_units=5 nr_episodes=35 -0.11072890397569579
# seq length=7 hidden_units=5 nr_episodes=40 -0.1542752991660381
# seq length=7 hidden_units=5 nr_episodes=45 -0.20115314424952335
# seq length=7 hidden_units=5 nr_episodes=50 -0.23829336611751017
# seq length=7 hidden_units=10 nr_episodes=0 -0.0395534219114515
# seq length=7 hidden_units=10 nr_episodes=5 -0.005675426307296005
# seq length=7 hidden_units=10 nr_episodes=10 -0.029129276813431026
# seq length=7 hidden_units=10 nr_episodes=15 -0.11732191098682798
# seq length=7 hidden_units=10 nr_episodes=20 -0.25012455642969766
# seq length=7 hidden_units=10 nr_episodes=25 -0.2765682867305863
# seq length=7 hidden_units=10 nr_episodes=30 -0.2973766170831593
# seq length=7 hidden_units=10 nr_episodes=35 -0.3106696948370935
# seq length=7 hidden_units=10 nr_episodes=40 -0.3192049297248363
# seq length=7 hidden_units=10 nr_episodes=45 -0.3268223206630181
# seq length=7 hidden_units=10 nr_episodes=50 -0.3333517358061615
# seq length=7 hidden_units=15 nr_episodes=0 -0.052619734001364105
# seq length=7 hidden_units=15 nr_episodes=5 -0.020439054003040358
# seq length=7 hidden_units=15 nr_episodes=10 -0.13798220870993516
# seq length=7 hidden_units=15 nr_episodes=15 -0.26659571522122283
# seq length=7 hidden_units=15 nr_episodes=20 -0.3130259374217015
# seq length=7 hidden_units=15 nr_episodes=25 -0.33987950306224146
# seq length=7 hidden_units=15 nr_episodes=30 -0.35244493159785395
# seq length=7 hidden_units=15 nr_episodes=35 -0.3705732127947263
# seq length=7 hidden_units=15 nr_episodes=40 -0.3799591004562406
# seq length=7 hidden_units=15 nr_episodes=45 -0.37925024848207456
# seq length=7 hidden_units=15 nr_episodes=50 -0.37203540473579544
# seq length=7 hidden_units=25 nr_episodes=0 -0.006036780462451485
# seq length=7 hidden_units=25 nr_episodes=5 -0.06360587328207368
# seq length=7 hidden_units=25 nr_episodes=10 -0.27337950745014594
# seq length=7 hidden_units=25 nr_episodes=15 -0.32027688379334673
# seq length=7 hidden_units=25 nr_episodes=20 -0.33890461693765617
# seq length=7 hidden_units=25 nr_episodes=25 -0.3664289421940916
# seq length=7 hidden_units=25 nr_episodes=30 -0.3812391188380351
# seq length=7 hidden_units=25 nr_episodes=35 -0.3855357183230268
# seq length=7 hidden_units=25 nr_episodes=40 -0.39657380975653944
# seq length=7 hidden_units=25 nr_episodes=45 -0.38443196096076315
# seq length=7 hidden_units=25 nr_episodes=50 -0.40234545468431193
# seq length=7 hidden_units=50 nr_episodes=0 -0.010732768996887021
# seq length=7 hidden_units=50 nr_episodes=5 -0.26442470362150083
# seq length=7 hidden_units=50 nr_episodes=10 -0.32782773673856624
# seq length=7 hidden_units=50 nr_episodes=15 -0.34899255035015275
# seq length=7 hidden_units=50 nr_episodes=20 -0.3205396244311165
# seq length=7 hidden_units=50 nr_episodes=25 -0.33457187007496736
# seq length=7 hidden_units=50 nr_episodes=30 -0.31302740034354626
# seq length=7 hidden_units=50 nr_episodes=35 -0.35535026482024623
# seq length=7 hidden_units=50 nr_episodes=40 -0.32827599054230894
# seq length=7 hidden_units=50 nr_episodes=45 -0.3595211389722832
# seq length=7 hidden_units=50 nr_episodes=50 -0.35591767666631147
# seq length=12 hidden_units=5 nr_episodes=0 -0.13448970300460683
# seq length=12 hidden_units=5 nr_episodes=5 -0.012165097717688811
# seq length=12 hidden_units=5 nr_episodes=10 0.021635868444973116
# seq length=12 hidden_units=5 nr_episodes=15 0.029309267403621053
# seq length=12 hidden_units=5 nr_episodes=20 0.03809671720646257
# seq length=12 hidden_units=5 nr_episodes=25 0.04531526459654911
# seq length=12 hidden_units=5 nr_episodes=30 0.051435710756362774
# seq length=12 hidden_units=5 nr_episodes=35 0.05669090356251749
# seq length=12 hidden_units=5 nr_episodes=40 0.06168049596072156
# seq length=12 hidden_units=5 nr_episodes=45 0.06674587151938316
# seq length=12 hidden_units=5 nr_episodes=50 0.07332734059600599
# seq length=12 hidden_units=10 nr_episodes=0 -0.005607898019421409
# seq length=12 hidden_units=10 nr_episodes=5 0.004237641804976988
# seq length=12 hidden_units=10 nr_episodes=10 0.0164303236135791
# seq length=12 hidden_units=10 nr_episodes=15 0.049502812337288926
# seq length=12 hidden_units=10 nr_episodes=20 0.07831934962955289
# seq length=12 hidden_units=10 nr_episodes=25 0.08835196547274138
# seq length=12 hidden_units=10 nr_episodes=30 0.09773590837320012
# seq length=12 hidden_units=10 nr_episodes=35 0.10555518234317429
# seq length=12 hidden_units=10 nr_episodes=40 0.10861221969616608
# seq length=12 hidden_units=10 nr_episodes=45 0.10975102774434242
# seq length=12 hidden_units=10 nr_episodes=50 0.1145687659293142
# seq length=12 hidden_units=15 nr_episodes=0 -0.09621057464983584
# seq length=12 hidden_units=15 nr_episodes=5 0.008199738512938093
# seq length=12 hidden_units=15 nr_episodes=10 0.043389667490476014
# seq length=12 hidden_units=15 nr_episodes=15 0.0834882789921283
# seq length=12 hidden_units=15 nr_episodes=20 0.10169479141440008
# seq length=12 hidden_units=15 nr_episodes=25 0.11391546728777924
# seq length=12 hidden_units=15 nr_episodes=30 0.12808822210809423
# seq length=12 hidden_units=15 nr_episodes=35 0.13012426880864336
# seq length=12 hidden_units=15 nr_episodes=40 0.13577033155410223
# seq length=12 hidden_units=15 nr_episodes=45 0.13660073242913073
# seq length=12 hidden_units=15 nr_episodes=50 0.13823011398775364
# seq length=12 hidden_units=25 nr_episodes=0 0.0006679690841030483
# seq length=12 hidden_units=25 nr_episodes=5 0.03482898402499279
# seq length=12 hidden_units=25 nr_episodes=10 0.09526521780062758
# seq length=12 hidden_units=25 nr_episodes=15 0.11146753724804126
# seq length=12 hidden_units=25 nr_episodes=20 0.11505208205744277
# seq length=12 hidden_units=25 nr_episodes=25 0.11853031060675923
# seq length=12 hidden_units=25 nr_episodes=30 0.11807156552445841
# seq length=12 hidden_units=25 nr_episodes=35 0.12197486165219573
# seq length=12 hidden_units=25 nr_episodes=40 0.12656880418017535
# seq length=12 hidden_units=25 nr_episodes=45 0.1263165831193378
# seq length=12 hidden_units=25 nr_episodes=50 0.13076136493003743
# seq length=12 hidden_units=50 nr_episodes=0 -0.009587250797675528
# seq length=12 hidden_units=50 nr_episodes=5 0.058165272208888896
# seq length=12 hidden_units=50 nr_episodes=10 0.0942833495320119
# seq length=12 hidden_units=50 nr_episodes=15 0.1083983777287395
# seq length=12 hidden_units=50 nr_episodes=20 0.1241137895029999
# seq length=12 hidden_units=50 nr_episodes=25 0.11532003279350944
# seq length=12 hidden_units=50 nr_episodes=30 0.11823097897589341
# seq length=12 hidden_units=50 nr_episodes=35 0.11454057840484233
# seq length=12 hidden_units=50 nr_episodes=40 0.13507263482309206
# seq length=12 hidden_units=50 nr_episodes=45 0.13775873555706952
# seq length=12 hidden_units=50 nr_episodes=50 0.126149740964289
# seq length=16 hidden_units=5 nr_episodes=0 -0.11837543622217561
# seq length=16 hidden_units=5 nr_episodes=5 -0.02363703868603717
# seq length=16 hidden_units=5 nr_episodes=10 -0.013239510638690666
# seq length=16 hidden_units=5 nr_episodes=15 -0.013210663467096095
# seq length=16 hidden_units=5 nr_episodes=20 -0.015343086561068642
# seq length=16 hidden_units=5 nr_episodes=25 -0.01892296132980409
# seq length=16 hidden_units=5 nr_episodes=30 -0.023625168392601426
# seq length=16 hidden_units=5 nr_episodes=35 -0.030493398027129803
# seq length=16 hidden_units=5 nr_episodes=40 -0.04205247337219631
# seq length=16 hidden_units=5 nr_episodes=45 -0.05843252437127222
# seq length=16 hidden_units=5 nr_episodes=50 -0.07732950049399068
# seq length=16 hidden_units=10 nr_episodes=0 -0.025159121828689734
# seq length=16 hidden_units=10 nr_episodes=5 0.0027956769525832037
# seq length=16 hidden_units=10 nr_episodes=10 -0.0030692784754451363
# seq length=16 hidden_units=10 nr_episodes=15 -0.06931703521972699
# seq length=16 hidden_units=10 nr_episodes=20 -0.10971023758487597
# seq length=16 hidden_units=10 nr_episodes=25 -0.12770980813603017
# seq length=16 hidden_units=10 nr_episodes=30 -0.14651154490280716
# seq length=16 hidden_units=10 nr_episodes=35 -0.1643270574912823
# seq length=16 hidden_units=10 nr_episodes=40 -0.17924050705391625
# seq length=16 hidden_units=10 nr_episodes=45 -0.17937816871706724
# seq length=16 hidden_units=10 nr_episodes=50 -0.208723707196119
# seq length=16 hidden_units=15 nr_episodes=0 -0.04671017609708161
# seq length=16 hidden_units=15 nr_episodes=5 0.0052298478945138616
# seq length=16 hidden_units=15 nr_episodes=10 0.0017293874528302444
# seq length=16 hidden_units=15 nr_episodes=15 -0.05416560487250055
# seq length=16 hidden_units=15 nr_episodes=20 -0.11336067692284635
# seq length=16 hidden_units=15 nr_episodes=25 -0.13722168772579546
# seq length=16 hidden_units=15 nr_episodes=30 -0.1539090464899049
# seq length=16 hidden_units=15 nr_episodes=35 -0.17307318506901703
# seq length=16 hidden_units=15 nr_episodes=40 -0.18923282909332384
# seq length=16 hidden_units=15 nr_episodes=45 -0.19987772130058357
# seq length=16 hidden_units=15 nr_episodes=50 -0.21418621615118005
# seq length=16 hidden_units=25 nr_episodes=0 -0.01893938564759501
# seq length=16 hidden_units=25 nr_episodes=5 0.005555542502082789
# seq length=16 hidden_units=25 nr_episodes=10 -0.1025311907526445
# seq length=16 hidden_units=25 nr_episodes=15 -0.12503152590390654
# seq length=16 hidden_units=25 nr_episodes=20 -0.14503278862753377
# seq length=16 hidden_units=25 nr_episodes=25 -0.1466015782011234
# seq length=16 hidden_units=25 nr_episodes=30 -0.15600764395655853
# seq length=16 hidden_units=25 nr_episodes=35 -0.18357400035930027
# seq length=16 hidden_units=25 nr_episodes=40 -0.1964889651098487
# seq length=16 hidden_units=25 nr_episodes=45 -0.2319195007377639
# seq length=16 hidden_units=25 nr_episodes=50 -0.27153437007677184
# seq length=16 hidden_units=50 nr_episodes=0 -0.009364791782488169
# seq length=16 hidden_units=50 nr_episodes=5 -0.006974820626971301
# seq length=16 hidden_units=50 nr_episodes=10 -0.09824332159306826
# seq length=16 hidden_units=50 nr_episodes=15 -0.11096700660607928
# seq length=16 hidden_units=50 nr_episodes=20 -0.1548000171941648
# seq length=16 hidden_units=50 nr_episodes=25 -0.1613172605937956
# seq length=16 hidden_units=50 nr_episodes=30 -0.21161868860659427
# seq length=16 hidden_units=50 nr_episodes=35 -0.20949629406962256
# seq length=16 hidden_units=50 nr_episodes=40 -0.3352701175055022
# seq length=16 hidden_units=50 nr_episodes=45 -0.31450692738395714
# seq length=16 hidden_units=50 nr_episodes=50 -0.36024322593439706
# LSTM best results achieved with length=12 hidden_units=15 and nr_episodes=50) ==> measure=0.14

# %% [markdown]
# ## Pytorch Multivariate Model Evaluation

# %%
params = best_params["params"]
best_length = params[0]


# smoothed time series with split. uncomment to use
# train=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_train.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)
# test=pd.read_csv(f"data/df_merch_0_2024_agg_time_final_test.csv", decimal=".",  index_col='Date', parse_dates=True,  infer_datetime_format=True)


# unsmoothed time series with split to test the model. uncomment to use
test_split_threshold = 0.9
data_no_smoothing=pd.read_csv('data/df_gira_agg_2h_diff_input.csv', decimal=".",  index_col='date', parse_dates=True,  infer_datetime_format=True)     
train, test = series_train_test_split(data_no_smoothing, trn_pct=test_split_threshold)



# Assuming `train` and `test` are your DataFrames and `target` is the target column name
trnY_float = train.pop(target).values.astype(np.float32)
tstY_float = test.pop(target).values.astype(np.float32)
trnX_float = train.values.astype(np.float32)
tstX_float = test.values.astype(np.float32)


trnX, trnY = prepare_dataset_for_lstm_multi(trnX_float, trnY_float, seq_length=best_length)
tstX, tstY  = prepare_dataset_for_lstm_multi(tstX_float, tstY_float, seq_length=best_length)


prd_trn = best_model.predict(trnX)
prd_tst = best_model.predict(tstX)


# Assuming train and test are DataFrames with a DateTime index
# Reconstruct the series for plotting
train[target] = trnY_float
test[target] = tstY_float
trn_series = train[[target]]
tst_series = test[[target]]


# Plot the forecasting evaluation
plot_single_model_evaluation(trn_series[best_length:], tst_series[best_length:], prd_trn, prd_tst, title=f"{file_tag} - LSTM Multivariate (length={best_length}, hidden={params[1]}, epochs={params[2]})")
savefig(f"images/{file_tag}_LSTM_multivariate_predictions.png")

# %% [markdown]
# ## Pytorch Multivariate Plots

# %%
from pandas import Series
pred_series = Series(prd_tst.numpy().ravel(), index=tst_series.index[best_length:])


plot_forecasting_series(
    trn_series[best_length:],
    tst_series[best_length:],
    pred_series,
    title=f"{file_tag} - LSTM Multivariate Predictions (length={best_length}, hidden={params[1]}, epochs={params[2]})",
    xlabel='Date',
    ylabel=target,
)
# Out:
# <Axes: xlabel='Date', ylabel='target_station_load_rate'>

# %% [markdown]
# ## Pytorch Multivariate Model and Loss

# %%
model = DS_LSTM_Multivariate(trnX_float, trnY_float, input_size=trnX_float.shape[1], hidden_size=50, num_layers=1)
loss = model.fit()
print(loss)
# Out:
# tensor(0.6422, grad_fn=<MseLossBackward0>)
